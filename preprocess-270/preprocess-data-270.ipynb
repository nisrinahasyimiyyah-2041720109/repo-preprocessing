# %%
# Load data ke dalam data frame 
import pandas as pd

# Spesifikasi encoding diperlukan karena data tidak menggunakan UTF-8
df = pd.read_csv('dataset gabungan-270.csv', encoding='latin-1')

df.head()
# Out:
#                                               Review Sentimen
# 0  Kecewa banget. Saya pesan yang free pouch tapi...  Negatif
# 1  Kali ini pengemasan tidak safe,, sepertinya tu...  Negatif
# 2  paket datangnya barang sudah pecah dan sy retu...  Negatif
# 3              ga ada sabun nya, ga sesuai deskripsi  Negatif
# 4                                  ga sesuai harapan  Negatif

# %% [markdown]
# PREPROCESSING

# %%
# PROSES CASE FOLDING (menjadikan semua huruf di kolom Review menjadi huruf kecil)
df['Review'] = df['Review'].str.lower()

print('Case Folding Result: \n')
df.head()
# Out:
# Case Folding Result:
#                                               Review Sentimen
# 0  kecewa banget. saya pesan yang free pouch tapi...  Negatif
# 1  kali ini pengemasan tidak safe,, sepertinya tu...  Negatif
# 2  paket datangnya barang sudah pecah dan sy retu...  Negatif
# 3              ga ada sabun nya, ga sesuai deskripsi  Negatif
# 4                                  ga sesuai harapan  Negatif

# %%
# import hasil case folding menjadi csv
df.to_csv("casefolding_270.csv")

# %%
# CLEANING
import re # regex library

def remove_tweet_special(text):
    # remove tab, new line, and back slice
    text = text.replace('\\t'," ").replace('\\n', " ").replace('\\u', " ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

df['Review'] = df['Review'].apply(remove_tweet_special)

# remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Review'] = df['Review'].apply(remove_number)

# remove punctuation and replace with space
def remove_punctuation(text):
    return re.sub(r'[.,]', ' ', text)

df['Review'] = df['Review'].apply(remove_punctuation)

# remove punctuation
def remove_symbol(text):
    # Menghapus simbol-simbol tidak standar dan menggantinya dengan spasi
    cleaned_text = re.sub(r'[^\w\s]', ' ', text)
    
    # Menghapus multiple whitespace
    cleaned_text = re.sub('\s+', ' ', cleaned_text).strip()
    
    return cleaned_text

df['Review'] = df['Review'].apply(remove_symbol)

# Menentukan ambang batas panjang string acak
threshold_length = 20

# Fungsi untuk menghapus string acak berdasarkan panjangnya
def hapus_string_acak_dengan_panjang(text):
    # Memeriksa panjang string dan menghapus jika melebihi ambang batas
    return ' '.join(word for word in text.split() if len(word) <= threshold_length)

# Menggunakan fungsi untuk menghapus string acak pada kolom 'Text'
df['Review'] = df['Review'].apply(hapus_string_acak_dengan_panjang)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Review'] = df['Review'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['Review'] = df['Review'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Review'] = df['Review'].apply(remove_single_char)

def remove_laughter(text):
    laughter_patterns = r'\b((ha)+h*|(he)+h*|(hi)+h*|(wk)+w*k*|(eh)+e*|(ah)+a*|(ih)+i*|(kw)+k*w*|(hem)+m*)\b'
    return re.sub(laughter_patterns, '', text, flags=re.IGNORECASE)

df['Review'] = df['Review'].apply(remove_laughter)

print('Cleaning Result : \n') 
print(df.head())
# Out:
# Cleaning Result :
#
#                                               Review Sentimen
# 0  kecewa banget saya pesan yang free pouch tapi ...  Negatif
# 1  kali ini pengemasan tidak safe sepertinya tutu...  Negatif
# 2  paket datangnya barang sudah pecah dan sy retu...  Negatif
# 3               ga ada sabun nya ga sesuai deskripsi  Negatif
# 4                                  ga sesuai harapan  Negatif

# %%
# import hasil cleaning menjadi csv
df.to_csv("cleaning_270.csv")

# %%
# REMOVE DUPLICATE
# Menghapus baris yang memiliki duplikat data pada kolom review
df = df.drop_duplicates(subset=['Review'])
df = df.reset_index(drop=True)
# Menghapus baris yang kosong
df = df.dropna(subset=['Review'])
# Menghapus baris yang hanya berisi spasi atau whitespace
df = df[df['Review'].str.strip() != '']
df.head()
# Out:
#                                               Review Sentimen
# 0  kecewa banget saya pesan yang free pouch tapi ...  Negatif
# 1  kali ini pengemasan tidak safe sepertinya tutu...  Negatif
# 2  paket datangnya barang sudah pecah dan sy retu...  Negatif
# 3               ga ada sabun nya ga sesuai deskripsi  Negatif
# 4                                  ga sesuai harapan  Negatif

# %%
# import hasil remove duplicate menjadi csv
df.to_csv("removedup_270.csv")

# %%
# NORMALIZATION
import pandas as pd
import re

slang_dictionary = pd.read_csv('colloquial-indonesian-lexicon2.csv')
slang_dict = pd.Series(slang_dictionary['formal'].values,index=slang_dictionary['slang']).to_dict()

slang_dictionary.head()
# Out:
#      slang    formal  In-dictionary  \
# 0     woww       wow            1.0
# 1    aminn      amin            1.0
# 2      met   selamat            1.0
# 3   netaas   menetas            1.0
# 4  keberpa  keberapa            0.0
#
#                                              context  category1 category2  \
# 0                                                wow   elongasi         0
# 1  Selamat ulang tahun kakak tulus semoga panjang...   elongasi         0
# 2  Met hari netaas kak!? Wish you all the best @t...  abreviasi         0
# 3  Met hari netaas kak!? Wish you all the best @t...   afiksasi  elongasi
# 4                           Birthday yg keberpa kak?  abreviasi         0
#
#   category3
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# Normalisasi kata menggunakan kamus colloquial-indonesian-lexicon2.csv
def Slangwords(text, slang_dict):
    for word in text.split():
        if word in slang_dict.keys():
            # menambahkan \b untuk menandakan batas kata di sekitar kata slang
            text = re.sub(r'\b{}\b'.format(re.escape(word)), slang_dict[word], text)
    
    text = re.sub('@[\w]+', '', text)
    return text

df['Review_norm'] = df['Review'].apply(lambda x: Slangwords(x, slang_dict))
print(df.head())
# Out:
#                                               Review Sentimen  \
# 0  kecewa banget saya pesan yang free pouch tapi ...  Negatif
# 1  kali ini pengemasan tidak safe sepertinya tutu...  Negatif
# 2  paket datangnya barang sudah pecah dan sy retu...  Negatif
# 3               ga ada sabun nya ga sesuai deskripsi  Negatif
# 4                                  ga sesuai harapan  Negatif
#
#                                          Review_norm
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan saya re...
# 3       enggak ada sabun nya enggak sesuai deskripsi
# 4                              enggak sesuai harapan

# %%
# import hasil replace slang words menjadi csv
df.to_csv("normalization_270.csv")

# %%
# PROSES TOKENIZING (word_tokenize() untuk memecah string kedalam tokens)

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Tokenizing
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['review_tokens'] = df['Review_norm'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df.head())
# Out:
# Tokenizing Result :
#
#                                               Review Sentimen  \
# 0  kecewa banget saya pesan yang free pouch tapi ...  Negatif
# 1  kali ini pengemasan tidak safe sepertinya tutu...  Negatif
# 2  paket datangnya barang sudah pecah dan sy retu...  Negatif
# 3               ga ada sabun nya ga sesuai deskripsi  Negatif
# 4                                  ga sesuai harapan  Negatif
#
#                                          Review_norm  \
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan saya re...
# 3       enggak ada sabun nya enggak sesuai deskripsi
# 4                              enggak sesuai harapan
#
#                                        review_tokens
# 0  [kecewa, banget, saya, pesan, yang, free, pouc...
# 1  [kali, ini, pengemasan, tidak, safe, sepertiny...
# 2  [paket, datangnya, barang, sudah, pecah, dan, ...
# 3  [enggak, ada, sabun, nya, enggak, sesuai, desk...
# 4                          [enggak, sesuai, harapan]

# %%
# import hasil tokenizing menjadi csv
df.to_csv("tokenizing_270.csv")

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
# PROSES FILTERING (Stopword Removal) menggunakan library sastrawi

class CustomStopWordRemover:
    def __init__(self, stop_words):
        self.stop_words = stop_words

    def remove(self, text):
        words = text.split()
        filtered_words = [word for word in words if word.lower() not in self.stop_words]
        return ' '.join(filtered_words)

# Tentukan lokasi file stopword Bahasa Indonesia
stopword_file = 'stopwords_indonesian.txt'

# Baca isi file stopword
with open(stopword_file, 'r', encoding='utf-8') as file:
    stopwords = file.read().splitlines()

# Kata-kata yang ingin dikecualikan
exceptions = ["belum", "tidak", "tanpa"]

# Buat daftar stopword baru tanpa kata-kata pengecualian
custom_stopwords = [word.lower() for word in stopwords if word.lower() not in exceptions]

# Buat instance custom stopword remover
custom_stopword_remover = CustomStopWordRemover(custom_stopwords)

# remove stopword pada list token
def stopwords_removal(words):
    filtered_words = [custom_stopword_remover.remove(w) for w in words]
    filtered_words = [word for word in filtered_words if word != '']  # Memfilter kata-kata kosong
    return filtered_words

df['review_tokens_SR'] = df['review_tokens'].apply(stopwords_removal) 

print(df.head())
# Out:
#                                               Review Sentimen  \
# 0  kecewa banget saya pesan yang free pouch tapi ...  Negatif
# 1  kali ini pengemasan tidak safe sepertinya tutu...  Negatif
# 2  paket datangnya barang sudah pecah dan sy retu...  Negatif
# 3               ga ada sabun nya ga sesuai deskripsi  Negatif
# 4                                  ga sesuai harapan  Negatif
#
#                                          Review_norm  \
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan saya re...
# 3       enggak ada sabun nya enggak sesuai deskripsi
# 4                              enggak sesuai harapan
#
#                                        review_tokens  \
# 0  [kecewa, banget, saya, pesan, yang, free, pouc...
# 1  [kali, ini, pengemasan, tidak, safe, sepertiny...
# 2  [paket, datangnya, barang, sudah, pecah, dan, ...
# 3  [enggak, ada, sabun, nya, enggak, sesuai, desk...
# 4                          [enggak, sesuai, harapan]
#
#                                     review_tokens_SR
# 0  [kecewa, banget, pesan, free, pouch, dikirimny...
# 1  [kali, pengemasan, tidak, safe, sepertinya, tu...
# 2  [paket, datangnya, barang, pecah, return, sell...
# 3    [enggak, sabun, nya, enggak, sesuai, deskripsi]
# 4                          [enggak, sesuai, harapan]

# %%
# import hasil stopword removal menjadi csv
df.to_csv("stopword_270.csv")

# %%
# PROSES LEMMATIZATION 
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['review_tokens_SR']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['review_tokens_stemmed'] = df['review_tokens_SR'].swifter.apply(get_stemmed_term)
print(df['review_tokens_stemmed'])
print(df.head())
# Out:
# 938
# ------------------------
# kecewa : kecewa
# banget : banget
# pesan : pesan
# free : free
# pouch : pouch
# dikirimnya : kirim
# cotton : cotton
# pad : pad
# kaget : kaget
# pas : pas
# unboxing : unboxing
# untung : untung
# videokan : video
# segera : segera
# kabarin : kabarin
# customer : customer
# servicenya : servicenya
# disuruh : suruh
# isi : isi
# googleform : googleform
# dikirimkan : kirim
# ulang : ulang
# pouchnya : pouchnya
# hari : hari
# enggak : enggak
# kabar : kabar
# akhirnya : akhir
# tanya : tanya
# dikabari : kabar
# kalau : kalau
# stock : stock
# ternyata : nyata
# habis : habis
# padahal : padahal
# baik : baik
# sabar : sabar
# mengikuti : ikut
# prosedur : prosedur
# service : service
# berpikiran : pikir
# positif : positif
# begini : begini
# caranya : cara
# kali : kali
# pengemasan : emas
# tidak : tidak
# safe : safe
# sepertinya : seperti
# tutup : tutup
# botol : botol
# kencang : kencang
# toner : toner
# merembes : rembes
# keluar : keluar
# dus : dus
# basah : basah
# memang : memang
# membuat : buat
# video : video
# selalu : selalu
# mendapat : dapat
# produk : produk
# packaging : packaging
# bagus : bagus
# avoskin : avoskin
# kira : kira
# hujan : hujan
# dibuka : buka
# kosong : kosong
# semoga : moga
# tanggapan : tanggap
# paket : paket
# datangnya : datang
# barang : barang
# pecah : pecah
# return : return
# seller : seller
# ikuti : ikut
# komplain : komplain
# proses : proses
# sebagainya : bagai
# malah : malah
# tiba : tiba
# seakan : akan
# pesanan : pesan
# selesai : selesai
# terima : terima
# uangnya : uang
# dilepas : lepas
# sekali : sekali
# jadi : jadi
# trauma : trauma
# beli : beli
# kesini : kesini
# chat : chat
# nanyain : nanyain
# diterima : terima
# dijawab : jawab
# formalitas : formalitas
# baru : baru
# belanja : belanja
# uang : uang
# mungkin : mungkin
# seberapa : berapa
# cuman : cuman
# responsnya : respons
# mengecewakan : kecewa
# mohon : mohon
# improvement : improvement
# selanjutnya : lanjut
# thanks : thanks
# sabun : sabun
# nya : nya
# sesuai : sesuai
# deskripsi : deskripsi
# harapan : harap
# buat : buat
# kulit : kulit
# oily : oily
# menghilangkan : hilang
# bruntusan : bruntusan
# mengecilkan : kecil
# pori : pori
# perlu : perlu
# diragukan : ragu
# sih : sih
# worth : worth
# buy : buy
# pengiriman : kirim
# cepat : cepat
# packagingnya : packagingnya
# super : super
# aman : aman
# expired : expired
# lah : lah
# mencoba : coba
# mudah : mudah
# mudahan : mudah
# cocok : cocok
# reviewnya : reviewnya
# mantap : mantap
# bismillah : bismillah
# pokoknya : pokok
# kecewaaaaa : kecewaaaaa
# lama : lama
# wajah : wajah
# breakout : breakout
# tau : tau
# bagaimana : bagaimana
# mengerti : erti
# belum : belum
# dicoba : coba
# langganan : langgan
# pakai : pakai
# serum : serum
# serumnya : serum
# benar : benar
# cair : cair
# pemakaian : pakai
# selama : lama
# berasa : asa
# efeknya : efek
# perjalanan : jalan
# ngabisin : ngabisin
# dulu : dulu
# next : next
# bakal : bakal
# review : review
# kalo : kalo
# hasilnya : hasil
# skin : skin
# kayak : kayak
# aku : aku
# kerasa : rasa
# halus : halus
# dimuka : muka
# barangnya : barang
# pernah : pernah
# tanggal : tanggal
# hilang : hilang
# kesalahan : salah
# anteraja : anteraja
# apa : apa
# beserta : serta
# care : care
# tapitidak : tapitidak
# menerima : terima
# sheet : sheet
# mask : mask
# complaint : complaint
# ujung : ujung
# ditindak : tindak
# lanjuti : lanjut
# harusnya : harus
# jam : jam
# ordernya : order
# buru : buru
# cekout : cekout
# biar : biar
# datang : datang
# cuma : cuma
# asli : asli
# ngalamin : ngalamin
# beginian : begini
# melembabkan : melembabkan
# teksturnya : tekstur
# kental : kental
# nyerepnya : nyerepnya
# jelek : jelek
# oknum : oknum
# mau : mau
# ngambil : ngambil
# kardusnya : kardus
# buka : buka
# bagian : bagi
# samping : samping
# segel : segel
# packing : packing
# lebih : lebih
# tertipu : tipu
# gratis : gratis
# hadiah : hadiah
# sarung : sarung
# gambar : gambar
# dijanjikan : janji
# tahu : tahu
# dapetnyabulan : dapetnyabulan
# masker : masker
# dikirim : kirim
# my : my
# bad : bad
# lalai : lalai
# team : team
# please : please
# kerja : kerja
# fokus : fokus
# dirugikan : rugi
# semua : semua
# orang : orang
# sempat : sempat
# bikin : bikin
# so : so
# sorry : sorry
# kasih : kasih
# bintang : bintang
# benaran : benar
# baca : baca
# be : be
# more : more
# careful : careful
# disini : sini
# sesibuk : sibuk
# apapun : apa
# sempetin : sempetin
# bahan : bahan
# ringan : ringan
# tipe : tipe
# kulitku : kulit
# berminyak : minyak
# dibibir : bibir
# lup : lup
# dah : dah
# azarine : azarine
# no : no
# found : found
# white : white
# series : series
# dtng : dtng
# direspon : direspon
# sama : sama
# pantas : pantas
# didalam : dalam
# kertas : kertas
# cara : cara
# mengajukan : aju
# beres : beres
# isinya : isi
# geleuh : geleuh
# muka : muka
# kelihatan : lihat
# kotor : kotor
# ewh : ewh
# sunscreen : sunscreen
# soft : soft
# light : light
# deh : deh
# kata : kata
# sensitif : sensitif
# kering : kering
# jangan : jangan
# tangan : tangan
# area : area
# tubuh : tubuh
# gelap : gelap
# pertama : pertama
# coba : coba
# dipakai : pakai
# beberapa : beberapa
# sunscreennya : sunscreennya
# acne : acne
# face : face
# ku : ku
# lengket : lengket
# love : love
# tadinya : tadi
# pc : pc
# velvety : velvety
# lippie : lippie
# cream : cream
# warm : warm
# tone : tone
# elum : elum
# realpict : realpict
# sukses : sukses
# kaya : kaya
# merasa : rasa
# makenya : makenya
# twin : twin
# pack : pack
# harusanya : harusanya
# melakukan : laku
# tadi : tadi
# klaim : klaim
# setelahnya : telah
# berhati : hati
# memperhatikan : perhati
# pelayanan : layan
# admin : admin
# kesel : kesel
# menunggu : tunggu
# salah : salah
# dong : dong
# produknya : produk
# mana : mana
# bungkusnya : bungkus
# alhasil : alhasil
# tanpa : tanpa
# semisal : misal
# cek : cek
# kirim : kirim
# rugi : rugi
# harga : harga
# kehilangan : hilang
# kepercayaan : percaya
# toko : toko
# fotonya : foto
# dilampirkan : lampir
# tulisan : tulis
# gangguan : ganggu
# rumah : rumah
# toped : toped
# serah : serah
# data : data
# gudang : gudang
# pembelian : beli
# jumlahnya : jumlah
# beda : beda
# harian : hari
# merah : merah
# beruntusan : beruntus
# masalah : masalah
# jerawat : jerawat
# besar : besar
# pengemasannya : emas
# peyok : peyok
# dalemnya : dalem
# bubble : bubble
# wrap : wrap
# biasanya : biasa
# paketnya : paket
# kalinya : kali
# lengkap : lengkap
# sayangnya : sayang
# mei : mei
# katanya : kata
# batal : batal
# otomatis : otomatis
# malam : malam
# dibawa : bawa
# luar : luar
# kota : kota
# melihat : lihat
# status : status
# reseller : reseller
# jakarta : jakarta
# official : official
# store : store
# buruk : buruk
# box : box
# butuh : butuh
# pertimbangkan : timbang
# sudahlah : sudah
# prosesnya : proses
# bilang : bilang
# brgnya : brgnya
# membeli : beli
# kondisi : kondisi
# kotak : kotak
# kemasan : kemas
# prpduk : prpduk
# terbuka : buka
# penjual : jual
# direspond : direspond
# tumpah : tumpah
# berharap : harap
# tiap : tiap
# kurang : kurang
# ikhlasin : ikhlasin
# berkah : berkah
# karyawan : karyawan
# pelayanannya : layan
# exp : exp
# panjang : panjang
# tekstur : tekstur
# keras : keras
# menggumpal : gumpal
# keaadan : keaadan
# bocor : bocor
# bekas : bekas
# lubang : lubang
# paku : paku
# lem : lem
# malas : malas
# complain : complain
# entar : entar
# ngefek : ngefek
# probably : probably
# semprotnya : semprot
# suka : suka
# ngawur : ngawur
# arahnya : arah
# sering : sering
# repurchase : repurchase
# pumpnya : pumpnya
# banyak : banyak
# pump : pump
# susah : susah
# bahannya : bahan
# neko : neko
# respon : respon
# ramah : ramah
# berfungsi : fungsi
# gentle : gentle
# washnya : washnya
# wash : wash
# enak : enak
# terus : terus
# busa : busa
# sedikit : sedikit
# tuh : tuh
# full : full
# semuka : muka
# leher : leher
# material : material
# gel : gel
# langsung : langsung
# meresap : resap
# fragrance : fragrance
# hygenis : hygenis
# ro : ro
# bonus : bonus
# dikasih : kasih
# gift : gift
# keren : keren
# sebenarnya : benar
# meresapnya : resap
# greasy : greasy
# nyaman : nyaman
# daan : daan
# kebetulan : betul
# jerawatku : jerawat
# memudar : pudar
# tentunya : tentu
# bestie : bestie
# tapiii : tapiii
# menurutku : turut
# game : game
# perhatikan : perhati
# pemilihan : pilih
# lalu : lalu
# loncat : loncat
# terbuang : buang
# entah : entah
# terjun : terjun
# bebas : bebas
# sedih : sedih
# hiks : hiks
# konsiderasi : konsiderasi
# improve : improve
# maaf : maaf
# diratainnya : diratainnya
# whitecast : whitecast
# parah : parah
# warna : warna
# kuning : kuning
# besokannya : besok
# muncul : muncul
# kecil : kecil
# berantakan : beranta
# jerawatan : jerawat
# menggunakan : guna
# terasa : asa
# panas : panas
# lapisi : lapis
# terpapar : papar
# sinar : sinar
# matahari : matahari
# efektif : efektif
# kandungannya : kandung
# selangnya : selang
# sependek : pendek
# kebawah : bawah
# wtf : wtf
# annoying : annoying
# pakenya : pakenya
# cari : cari
# tube : tube
# ajalah : aja
# bermasalah : masalah
# mulu : mulu
# sayang : sayang
# formulanya : formula
# sebagus : bagus
# big : big
# kurir : kurir
# kirimnya : kirim
# plus : plus
# waktu : waktu
# rusak : rusak
# jelas : jelas
# professional : professional
# niat : niat
# jualan : jual
# meskipun : meski
# hargai : harga
# membungkus : bungkus
# pengeriman : rim
# kykny : kykny
# warnanya : warna
# kiri : kiri
# punya : punya
# bulan : bulan
# kanan : kanan
# bening : bening
# geprek : geprek
# hancur : hancur
# diberikan : beri
# pengantaran : antar
# fast : fast
# response : response
# on : on
# time : time
# delivery : delivery
# bonusnya : bonus
# sekarang : sekarang
# ditanya : tanya
# balesnya : balesnya
# dipindahtangankan : dipindahtangankan
# alamat : alamat
# kak : kak
# dikomplain : komplain
# ekspedisi : ekspedisi
# pengirimannya : kirim
# mukaku : muka
# tambah : tambah
# hadiahnya : hadiah
# bohongan : bohong
# bohong : bohong
# kombinasi : kombinasi
# oke : oke
# normal : normal
# cenderung : cenderung
# awalnya : awal
# pikir : pikir
# jomplang : jomplang
# blend : blend
# cerah : cerah
# bukan : bukan
# up : up
# foundy : foundy
# nyerap : nyerap
# mate : mate
# glow : glow
# secocok : cocok
# dikulit : kulit
# enaknya : enak
# cast : cast
# cemong : cemong
# putih : putih
# kedua : dua
# gampang : gampang
# menyerap : serap
# kulitnya : kulit
# cairannya : cair
# membantu : bantu
# bertele : tele
# tele : tele
# tempat : tempat
# terpaksa : paksa
# penilaian : nilai
# al : al
# el : el
# ve : ve
# handle : handle
# balasnya : balas
# asal : asal
# menjawab : jawab
# konsultasi : konsultasi
# pertanyan : pertanyan
# jawabannya : jawab
# balas : balas
# membaca : baca
# permasalahan : masalah
# pembeli : beli
# recommended : recommended
# tinted : tinted
# oksidasi : oksidasi
# klaimnya : klaim
# kardus : kardus
# ditambah : tambah
# tebal : tebal
# sabtu : sabtu
# minggu : minggu
# tetap : tetap
# weekday : weekday
# online : online
# real : real
# bot : bot
# insecure : insecure
# lemot : lot
# responnya : responnya
# tutupnya : tutup
# keputer : puter
# moisturizernya : moisturizernya
# setengah : tengah
# well : well
# received : received
# abuan : abuan
# dikit : dikit
# ditoleransi : toleransi
# biasa : biasa
# paling : paling
# sangat : sangat
# memuaskan : muas
# helpfull : helpfull
# oriented : oriented
# hati : hati
# fatal : fatal
# check : check
# out : out
# taunya : tau
# boohong : boohong
# percaya : percaya
# dibatalkan : batal
# alasan : alas
# pusat : pusat
# melambung : lambung
# jauh : jauh
# ribu : ribu
# ganti : ganti
# eye : eye
# somethinc : somethinc
# jahat : jahat
# pesannya : pesan
# usaha : usaha
# changer : changer
# sini : sini
# stockist : stockist
# harganya : harga
# kadang : kadang
# pre : pre
# order : order
# sungguh : sungguh
# beautiful : beautiful
# package : package
# safety : safety
# provinsi : provinsi
# gapapa : gapapa
# packingnya : packingnya
# memperbaiki : baik
# top : top
# kerutan : kerut
# biru : biru
# tahun : tahun
# viral : viral
# perskincare : perskincare
# an : an
# semenjak : semenjak
# hamil : hamil
# stop : stop
# bayi : bayi
# kangen : kangen
# sensasinya : sensasi
# memakai : pakai
# feelnya : feelnya
# ngaruh : ngaruh
# saran : saran
# facial : facial
# ditambahkan : tambah
# baunya : bau
# soalnya : soal
# digunakan : guna
# moga : moga
# alhamdulillah : alhamdulillah
# thank : thank
# you : you
# sicepat : sicepat
# mini : mini
# selau : selau
# diskon : diskon
# yes : yes
# berkali : kali
# amanah : amanah
# repeat : repeat
# nih : nih
# first : first
# jatuh : jatuh
# cinta : cinta
# pilih : pilih
# shade : shade
# strawberrypine : strawberrypine
# raspberry : raspberry
# muffin : muffin
# short : short
# lasting : lasting
# masa : masa
# iya : iya
# minum : minum
# air : air
# pindah : pindah
# haluan : haluan
# byeee : byeee
# overall : overall
# kecepatan : cepat
# warp : warp
# ceban : ceban
# yay : yay
# kesekian : sekian
# bnafas : bnafas
# selamat : selamat
# segitu : segitu
# bau : bau
# menyengat : sengat
# berjerawat : jerawat
# the : the
# best : best
# original : original
# makai : maka
# sebelumnya : belum
# teman : teman
# mesti : mesti
# pelembab : pelembab
# cantik : cantik
# jujur : jujur
# panik : panik
# lihat : lihat
# dusnya : dus
# penyok : penyok
# moist : moist
# rapet : rapet
# luber : luber
# barunya : baru
# kemasannya : kemas
# lucu : lucu
# usah : usah
# lembab : lembab
# bantu : bantu
# pulih : pulih
# barier : barier
# sejauh : jauh
# moisturizer : moisturizer
# bangus : bangus
# simple : simple
# menemukan : temu
# moistnya : moistnya
# tergantung : gantung
# pemakaiannya : pakai
# orisinal : orisinal
# kakak : kakak
# adminnya : adminnya
# kayaknya : kayak
# lumayan : lumayan
# mateng : mateng
# thankyou : thankyou
# aneh : aneh
# apek : apek
# besi : besi
# tempatnya : tempat
# pakainya : pakai
# solusi : solusi
# checkout : checkout
# holy : holy
# grail : grail
# serebu : rebu
# rapi : rapi
# this : this
# is : is
# seriously : seriously
# how : how
# one : one
# bottle : bottle
# could : could
# last : last
# me : me
# months : months
# diofflinestore : diofflinestore
# mahal : mahal
# dionline : dionline
# potongan : potong
# flashsale : flashsale
# tumben : tumben
# rangkaian : rangkai
# semingguan : minggu
# efek : efek
# cukup : cukup
# datenya : datenya
# tertarik : tarik
# lipstiknya : lipstik
# patah : patah
# diulur : ulur
# terlalu : terlalu
# productnya : productnya
# bacanya : baca
# biji : biji
# pipi : pipi
# meradang : radang
# besoknya : besok
# mendingan : mending
# kempes : kempes
# jatuhnya : jatuh
# bibir : bibir
# walaupun : walaupun
# lipstick : lipstick
# lipbalm : lipbalm
# pigmented : pigmented
# queennya : queennya
# date : date
# diskonnya : diskon
# rekomen : rekomen
# kiriman : kirim
# ingredients : ingredients
# penasaran : penasaran
# pengin : pengin
# avo : avo
# aaaa : aaaa
# diganti : ganti
# kurirnya : kurir
# pertamanya : pertama
# dikirimin : dikirimin
# perbedaan : beda
# sale : sale
# ribet : ribet
# terutama : utama
# pihak : pihak
# expedisi : expedisi
# pick : pick
# maksudnya : maksud
# awal : awal
# teliti : teliti
# buang : buang
# mengurusi : urus
# kedepannya : depan
# makin : makin
# responsive : responsive
# huhu : huhu
# lempar : lempar
# fragile : fragile
# terbaik : baik
# sejak : sejak
# rewel : rewel
# produksi : produksi
# mencari : cari
# alternatif : alternatif
# menyamarkan : samar
# vit : vit
# niacin : niacin
# alpha : alpha
# arbutin : arbutin
# dibarengin : dibarengin
# refining : refining
# tonernya : tonernya
# terbang : terbang
# mendapatkan : dapat
# menyenangkan : senang
# menjadi : jadi
# pengguna : guna
# bublewrapnya : bublewrapnya
# sidoarjo : sidoarjo
# lambat : lambat
# diantar : antar
# nama : nama
# keadaan : ada
# min : min
# nice : nice
# price : price
# pcs : pcs
# cashback : cashback
# perlahan : perlahan
# teratasi : atas
# repurchased : repurchased
# indak : indak
# kusam : kusam
# affordable : affordable
# bingung : bingung
# mengira : ira
# namanya : nama
# menutupi : tutup
# kemerahan : merah
# nina : nina
# butter : butter
# creamy : creamy
# smugeproof : smugeproof
# loh : loh
# pigment : pigment
# spf : spf
# daily : daily
# coverage : coverage
# merata : rata
# bakalan : bakal
# flash : flash
# nilai : nilai
# gapaham : gapaham
# skincare : skincare
# works : works
# feel : feel
# dimukanya : muka
# tidur : tidur
# miring : miring
# kena : kena
# angin : angin
# adem : adem
# mukanya : muka
# yaudah : yaudah
# salahku : salah
# hasil : hasil
# akhir : akhir
# bersih : bersih
# sehat : sehat
# {'kecewa': 'kecewa', 'banget': 'banget', 'pesan': 'pesan', 'free': 'free', 'pouch': 'pouch', 'dikirimnya': 'kirim', 'cotton': 'cotton', 'pad': 'pad', 'kaget': 'kaget', 'pas': 'pas', 'unboxing': 'unboxing', 'untung': 'untung', 'videokan': 'video', 'segera': 'segera', 'kabarin': 'kabarin', 'customer': 'customer', 'servicenya': 'servicenya', 'disuruh': 'suruh', 'isi': 'isi', 'googleform': 'googleform', 'dikirimkan': 'kirim', 'ulang': 'ulang', 'pouchnya': 'pouchnya', 'hari': 'hari', 'enggak': 'enggak', 'kabar': 'kabar', 'akhirnya': 'akhir', 'tanya': 'tanya', 'dikabari': 'kabar', 'kalau': 'kalau', 'stock': 'stock', 'ternyata': 'nyata', 'habis': 'habis', 'padahal': 'padahal', 'baik': 'baik', 'sabar': 'sabar', 'mengikuti': 'ikut', 'prosedur': 'prosedur', 'service': 'service', 'berpikiran': 'pikir', 'positif': 'positif', 'begini': 'begini', 'caranya': 'cara', 'kali': 'kali', 'pengemasan': 'emas', 'tidak': 'tidak', 'safe': 'safe', 'sepertinya': 'seperti', 'tutup': 'tutup', 'botol': 'botol', 'kencang': 'kencang', 'toner': 'toner', 'merembes': 'rembes', 'keluar': 'keluar', 'dus': 'dus', 'basah': 'basah', 'memang': 'memang', 'membuat': 'buat', 'video': 'video', 'selalu': 'selalu', 'mendapat': 'dapat', 'produk': 'produk', 'packaging': 'packaging', 'bagus': 'bagus', 'avoskin': 'avoskin', 'kira': 'kira', 'hujan': 'hujan', 'dibuka': 'buka', 'kosong': 'kosong', 'semoga': 'moga', 'tanggapan': 'tanggap', 'paket': 'paket', 'datangnya': 'datang', 'barang': 'barang', 'pecah': 'pecah', 'return': 'return', 'seller': 'seller', 'ikuti': 'ikut', 'komplain': 'komplain', 'proses': 'proses', 'sebagainya': 'bagai', 'malah': 'malah', 'tiba': 'tiba', 'seakan': 'akan', 'pesanan': 'pesan', 'selesai': 'selesai', 'terima': 'terima', 'uangnya': 'uang', 'dilepas': 'lepas', 'sekali': 'sekali', 'jadi': 'jadi', 'trauma': 'trauma', 'beli': 'beli', 'kesini': 'kesini', 'chat': 'chat', 'nanyain': 'nanyain', 'diterima': 'terima', 'dijawab': 'jawab', 'formalitas': 'formalitas', 'baru': 'baru', 'belanja': 'belanja', 'uang': 'uang', 'mungkin': 'mungkin', 'seberapa': 'berapa', 'cuman': 'cuman', 'responsnya': 'respons', 'mengecewakan': 'kecewa', 'mohon': 'mohon', 'improvement': 'improvement', 'selanjutnya': 'lanjut', 'thanks': 'thanks', 'sabun': 'sabun', 'nya': 'nya', 'sesuai': 'sesuai', 'deskripsi': 'deskripsi', 'harapan': 'harap', 'buat': 'buat', 'kulit': 'kulit', 'oily': 'oily', 'menghilangkan': 'hilang', 'bruntusan': 'bruntusan', 'mengecilkan': 'kecil', 'pori': 'pori', 'perlu': 'perlu', 'diragukan': 'ragu', 'sih': 'sih', 'worth': 'worth', 'buy': 'buy', 'pengiriman': 'kirim', 'cepat': 'cepat', 'packagingnya': 'packagingnya', 'super': 'super', 'aman': 'aman', 'expired': 'expired', 'lah': 'lah', 'mencoba': 'coba', 'mudah': 'mudah', 'mudahan': 'mudah', 'cocok': 'cocok', 'reviewnya': 'reviewnya', 'mantap': 'mantap', 'bismillah': 'bismillah', 'pokoknya': 'pokok', 'kecewaaaaa': 'kecewaaaaa', 'lama': 'lama', 'wajah': 'wajah', 'breakout': 'breakout', 'tau': 'tau', 'bagaimana': 'bagaimana', 'mengerti': 'erti', 'belum': 'belum', 'dicoba': 'coba', 'langganan': 'langgan', 'pakai': 'pakai', 'serum': 'serum', 'serumnya': 'serum', 'benar': 'benar', 'cair': 'cair', 'pemakaian': 'pakai', 'selama': 'lama', 'berasa': 'asa', 'efeknya': 'efek', 'perjalanan': 'jalan', 'ngabisin': 'ngabisin', 'dulu': 'dulu', 'next': 'next', 'bakal': 'bakal', 'review': 'review', 'kalo': 'kalo', 'hasilnya': 'hasil', 'skin': 'skin', 'kayak': 'kayak', 'aku': 'aku', 'kerasa': 'rasa', 'halus': 'halus', 'dimuka': 'muka', 'barangnya': 'barang', 'pernah': 'pernah', 'tanggal': 'tanggal', 'hilang': 'hilang', 'kesalahan': 'salah', 'anteraja': 'anteraja', 'apa': 'apa', 'beserta': 'serta', 'care': 'care', 'tapitidak': 'tapitidak', 'menerima': 'terima', 'sheet': 'sheet', 'mask': 'mask', 'complaint': 'complaint', 'ujung': 'ujung', 'ditindak': 'tindak', 'lanjuti': 'lanjut', 'harusnya': 'harus', 'jam': 'jam', 'ordernya': 'order', 'buru': 'buru', 'cekout': 'cekout', 'biar': 'biar', 'datang': 'datang', 'cuma': 'cuma', 'asli': 'asli', ...
# ------------------------
# Pandas Apply: 100%|██████████| 247/247 [00:00<00:00, 21660.81it/s]
# 0      [kecewa, banget, pesan, free, pouch, kirim, co...
# 1      [kali, emas, tidak, safe, seperti, tutup, boto...
# 2      [paket, datang, barang, pecah, return, seller,...
# 3        [enggak, sabun, nya, enggak, sesuai, deskripsi]
# 4                                [enggak, sesuai, harap]
#                              ...
# 242              [suka, sama, warna, next, order, warna]
# 243    [tipe, kulit, minyak, alhamdulillah, cocok, th...
# 244    [beli, serum, pas, harga, flash, sale, lumayan...
# 245    [jujur, buat, aku, enggak, cocok, aku, gapaham...
# 246    [hasil, akhir, bagus, kayak, kulit, bersih, se...
# Name: review_tokens_stemmed, Length: 247, dtype: object
#                                               Review Sentimen  \
# 0  kecewa banget saya pesan yang free pouch tapi ...  Negatif
# 1  kali ini pengemasan tidak safe sepertinya tutu...  Negatif
# 2  paket datangnya barang sudah pecah dan sy retu...  Negatif
# 3               ga ada sabun nya ga sesuai deskripsi  Negatif
# 4                                  ga sesuai harapan  Negatif
#
#                                          Review_norm  \
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan saya re...
# 3       enggak ada sabun nya enggak sesuai deskripsi
# 4                              enggak sesuai harapan
#
#                                        review_tokens  \
# 0  [kecewa, banget, saya, pesan, yang, free, pouc...
# 1  [kali, ini, pengemasan, tidak, safe, sepertiny...
# 2  [paket, datangnya, barang, sudah, pecah, dan, ...
# 3  [enggak, ada, sabun, nya, enggak, sesuai, desk...
# 4                          [enggak, sesuai, harapan]
#
#                                     review_tokens_SR  \
# 0  [kecewa, banget, pesan, free, pouch, dikirimny...
# 1  [kali, pengemasan, tidak, safe, sepertinya, tu...
# 2  [paket, datangnya, barang, pecah, return, sell...
# 3    [enggak, sabun, nya, enggak, sesuai, deskripsi]
# 4                          [enggak, sesuai, harapan]
#
#                                review_tokens_stemmed
# 0  [kecewa, banget, pesan, free, pouch, kirim, co...
# 1  [kali, emas, tidak, safe, seperti, tutup, boto...
# 2  [paket, datang, barang, pecah, return, seller,...
# 3    [enggak, sabun, nya, enggak, sesuai, deskripsi]
# 4                            [enggak, sesuai, harap]

# %%
# import hasil preprocessing menjadi csv
df.to_csv("lemma_270.csv")
