# %%
# Load data ke dalam data frame 
import pandas as pd

# Spesifikasi encoding diperlukan karena data tidak menggunakan UTF-8
df = pd.read_csv('scraping_azarine.csv', encoding='latin-1')

df.head()
# Out:
#                                               Review  \
# 0                                               sipp
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  Ini kurang oke menurut sy. Dipake ga bikin bib...
#
#                                              Product     Rating Username  \
# 0  Azarine Cicamide Barrier Sunscreen Moisturiser...  bintang 5    V***i
# 1  [Twin Pack] Azarine Ceraspray Sunscreen Spray ...  bintang 5   Frisca
# 2          Azarine Retinol Smooth Glowing Serum 20ml  bintang 5   ridwan
# 3                       Azarine Acne Spot Serum 20ml  bintang 5    B***H
# 4  [Twin pack] Azarine Magic Colour Lip Serum 3.5...  bintang 4   Sabina
#
#         Date
# 0  1/30/2024
# 1  1/30/2024
# 2  1/30/2024
# 3  1/30/2024
# 4  1/30/2024

# %%
# Drop kolom yang tidak terpakai
df = df.drop(df.iloc[:,1:], axis=1)

# Cek data teratas
df.head()
# Out:
#                                               Review
# 0                                               sipp
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  Ini kurang oke menurut sy. Dipake ga bikin bib...

# %% [markdown]
# PREPROCESSING

# %%
# PROSES CASE FOLDING (menjadikan semua huruf di kolom Review menjadi huruf kecil)
df['Review'] = df['Review'].str.lower()

print('Case Folding Result: \n')
df.head()
# Out:
# Case Folding Result:
#                                               Review
# 0                                               sipp
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  ini kurang oke menurut sy. dipake ga bikin bib...

# %%
# import hasil case folding menjadi csv
df.to_csv("casefolding_azarine.csv")

# %%
# CLEANING
import re # regex library

def remove_tweet_special(text):
    # remove tab, new line, and back slice
    text = text.replace('\\t'," ").replace('\\n', " ").replace('\\u', " ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

df['Review'] = df['Review'].apply(remove_tweet_special)

# remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Review'] = df['Review'].apply(remove_number)

# remove punctuation and replace with space
def remove_punctuation(text):
    return re.sub(r'[.,]', ' ', text)

df['Review'] = df['Review'].apply(remove_punctuation)

# remove punctuation
def remove_symbol(text):
    # Menghapus simbol-simbol tidak standar dan menggantinya dengan spasi
    cleaned_text = re.sub(r'[^\w\s]', ' ', text)
    
    # Menghapus multiple whitespace
    cleaned_text = re.sub('\s+', ' ', cleaned_text).strip()
    
    return cleaned_text

df['Review'] = df['Review'].apply(remove_symbol)

# Menentukan ambang batas panjang string acak
threshold_length = 20

# Fungsi untuk menghapus string acak berdasarkan panjangnya
def hapus_string_acak_dengan_panjang(text):
    # Memeriksa panjang string dan menghapus jika melebihi ambang batas
    return ' '.join(word for word in text.split() if len(word) <= threshold_length)

# Menggunakan fungsi untuk menghapus string acak pada kolom 'Text'
df['Review'] = df['Review'].apply(hapus_string_acak_dengan_panjang)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Review'] = df['Review'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['Review'] = df['Review'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Review'] = df['Review'].apply(remove_single_char)

def remove_laughter(text):
    laughter_patterns = r'\b((ha)+h*|(he)+h*|(hi)+h*|(wk)+w*k*|(eh)+e*|(ah)+a*|(ih)+i*|(kw)+k*w*|(hem)+m*)\b'
    return re.sub(laughter_patterns, '', text, flags=re.IGNORECASE)

df['Review'] = df['Review'].apply(remove_laughter)

print('Cleaning Result : \n') 
print(df.head())
# Out:
# Cleaning Result :
#
#                                               Review
# 0                                               sipp
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  ini kurang oke menurut sy dipake ga bikin bibi...

# %%
# import hasil cleaning menjadi csv
df.to_csv("cleaning_azarine.csv")

# %%
# REMOVE DUPLICATE
df = df.drop_duplicates()
df = df.reset_index(drop=True)
# Menghapus baris yang kosong
df = df.dropna(subset=['Review'])
# Menghapus baris yang hanya berisi spasi atau whitespace
df = df[df['Review'].str.strip() != '']
df.head()
# Out:
#                                               Review
# 0                                               sipp
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  ini kurang oke menurut sy dipake ga bikin bibi...

# %%
# import hasil remove duplicate menjadi csv
df.to_csv("removedup_azarine.csv")

# %%
# NORMALIZATION
import pandas as pd
import re

slang_dictionary = pd.read_csv('../colloquial-indonesian-lexicon2.csv')
slang_dict = pd.Series(slang_dictionary['formal'].values,index=slang_dictionary['slang']).to_dict()

slang_dictionary.head()
# Out:
#      slang    formal  In-dictionary  \
# 0     woww       wow            1.0
# 1    aminn      amin            1.0
# 2      met   selamat            1.0
# 3   netaas   menetas            1.0
# 4  keberpa  keberapa            0.0
#
#                                              context  category1 category2  \
# 0                                                wow   elongasi         0
# 1  Selamat ulang tahun kakak tulus semoga panjang...   elongasi         0
# 2  Met hari netaas kak!? Wish you all the best @t...  abreviasi         0
# 3  Met hari netaas kak!? Wish you all the best @t...   afiksasi  elongasi
# 4                           Birthday yg keberpa kak?  abreviasi         0
#
#   category3
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# Normalisasi kata menggunakan kamus colloquial-indonesian-lexicon2.csv
def Slangwords(text, slang_dict):
    for word in text.split():
        if word in slang_dict.keys():
            # menambahkan \b untuk menandakan batas kata di sekitar kata slang
            text = re.sub(r'\b{}\b'.format(re.escape(word)), slang_dict[word], text)
    
    text = re.sub('@[\w]+', '', text)
    return text

df['Review_norm'] = df['Review'].apply(lambda x: Slangwords(x, slang_dict))
print(df.head())
# Out:
#                                               Review  \
# 0                                               sipp
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  ini kurang oke menurut sy dipake ga bikin bibi...
#
#                                          Review_norm
# 0                                                sip
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  ini kurang oke menurut saya dipakai enggak bik...

# %%
# import hasil replace slang words menjadi csv
df.to_csv("normalization_azarine.csv")

# %%
# PROSES TOKENIZING (word_tokenize() untuk memecah string kedalam tokens)

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Tokenizing
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['review_tokens'] = df['Review_norm'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df.head())
# Out:
# Tokenizing Result :
#
#                                               Review  \
# 0                                               sipp
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  ini kurang oke menurut sy dipake ga bikin bibi...
#
#                                          Review_norm  \
# 0                                                sip
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  ini kurang oke menurut saya dipakai enggak bik...
#
#                                        review_tokens
# 0                                              [sip]
# 1  [proses, orderan, san, pengirimannya, sesuai, ...
# 2     [terima, kasih, sudah, diterima, dengan, baik]
# 3  [tipe, kulitku, kombinasi, tipe, kulitku, norm...
# 4  [ini, kurang, oke, menurut, saya, dipakai, eng...

# %%
# import hasil tokenizing menjadi csv
df.to_csv("tokenizing_azarine.csv")

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
# PROSES FILTERING (Stopword Removal) menggunakan library sastrawi
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

# remove stopword pada list token
def stopwords_removal(words):
    filtered_words = [stopword.remove(w) for w in words]
    filtered_words = [word for word in filtered_words if word != '']  # Memfilter kata-kata kosong
    return filtered_words

df['review_tokens_SR'] = df['review_tokens'].apply(stopwords_removal) 

print(df.head())
# Out:
#                                               Review  \
# 0                                               sipp
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  ini kurang oke menurut sy dipake ga bikin bibi...
#
#                                          Review_norm  \
# 0                                                sip
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  ini kurang oke menurut saya dipakai enggak bik...
#
#                                        review_tokens  \
# 0                                              [sip]
# 1  [proses, orderan, san, pengirimannya, sesuai, ...
# 2     [terima, kasih, sudah, diterima, dengan, baik]
# 3  [tipe, kulitku, kombinasi, tipe, kulitku, norm...
# 4  [ini, kurang, oke, menurut, saya, dipakai, eng...
#
#                                     review_tokens_SR
# 0                                              [sip]
# 1  [proses, orderan, san, pengirimannya, sesuai, ...
# 2                    [terima, kasih, diterima, baik]
# 3  [tipe, kulitku, kombinasi, tipe, kulitku, norm...
# 4  [kurang, oke, dipakai, enggak, bikin, bibir, l...

# %%
# import hasil stopword removal menjadi csv
df.to_csv("stopword_azarine.csv")

# %%
# PROSES LEMMATIZATION 
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['review_tokens_SR']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['review_tokens_stemmed'] = df['review_tokens_SR'].swifter.apply(get_stemmed_term)
print(df['review_tokens_stemmed'])
print(df.head())
# Out:
# 987
# ------------------------
# sip : sip
# proses : proses
# orderan : order
# san : san
# pengirimannya : kirim
# sesuai : sesuai
# estimasi : estimasi
# pengemasannya : emas
# aman : aman
# banget : banget
# kulitku : kulit
# cukup : cukup
# sensitif : sensitif
# sering : sering
# pakai : pakai
# makeup : makeup
# jadi : jadi
# mau : mau
# coba : coba
# sunscreen : sunscreen
# spray : spray
# menarik : tarik
# cooling : cooling
# sensationnya : sensationnya
# semoga : moga
# cocok : cocok
# thank : thank
# you : you
# azarine : azarine
# terima : terima
# kasih : kasih
# diterima : terima
# baik : baik
# tipe : tipe
# kombinasi : kombinasi
# normal : normal
# kering : kering
# berminyak : minyak
# masalah : masalah
# jerawat : jerawat
# pori : pori
# besar : besar
# kurang : kurang
# oke : oke
# dipakai : pakai
# enggak : enggak
# bikin : bikin
# bibir : bibir
# lembab : lembab
# malah : malah
# kasar : kasar
# warnanya : warna
# merah : merah
# menor : menor
# approved : approved
# sawo : sawo
# matang : matang
# hitam : hitam
# kelihatan : lihat
# dicoba : coba
# takut : takut
# ternyata : nyata
# kulit : kulit
# padahal : padahal
# top : top
# ramah : ramah
# kantong : kantong
# selalu : selalu
# sama : sama
# produk : produk
# deh : deh
# lebih : lebih
# fresh : fresh
# cepat : cepat
# nyerapnya : nyerapnya
# buat : buat
# jerawatan : jerawat
# lengket : lengket
# suncreen : suncreen
# terfavorit : favorit
# ringan : ringan
# bahannya : bahan
# mufah : mufah
# dserap : dserap
# terasa : asa
# wanginya : wangi
# enak : enak
# bagus : bagus
# menghadap : hadap
# uv : uv
# barang : barang
# deskripsi : deskripsi
# pengiriman : kirim
# penjual : jual
# orisinal : orisinal
# teksturnya : tekstur
# gampang : gampang
# menyerap : serap
# lama : lama
# kelamaan : lama
# rada : rada
# area : area
# zone : zone
# packet : packet
# packing : packing
# rapi : rapi
# cuma : cuma
# kurir : kurir
# expedisinya : expedisinya
# blegug : blegug
# ditungguin : ditungguin
# siang : siang
# sore : sore
# urusan : urus
# dadakan : dada
# kagak : kagak
# ngabarin : ngabarin
# pas : pas
# cek : cek
# tokped : tokped
# termyata : termyata
# tiba : tiba
# tujuan : tuju
# rumah : rumah
# orang : orang
# entah : entah
# ditaro : ditaro
# mana : mana
# kurirnya : kurir
# buru : buru
# pulang : pulang
# paketnya : paket
# diselipin : diselipin
# kusen : kusen
# pintu : pintu
# kacau : kacau
# sih : sih
# bukannya : bukan
# kontak : kontak
# dulu : dulu
# main : main
# diselip : selip
# bagaimana : bagaimana
# kalo : kalo
# pemulung : pulung
# kira : kira
# kotak : kotak
# kardus : kardus
# sampah : sampah
# hilang : hilang
# paket : paket
# alhamdulillah : alhamdulillah
# pembelian : beli
# kedua : dua
# thanks : thanks
# semua : semua
# productnya : productnya
# kusuka : suka
# beli : beli
# satuan : satu
# total : total
# item : item
# ribu : ribu
# ku : ku
# cashback : cashback
# syenangnya : syenangnya
# free : free
# gift : gift
# pouch : pouch
# kaca : kaca
# card : card
# gemas : gemas
# cantik : cantik
# repeat : repeat
# order : order
# beda : beda
# nih : nih
# pertama : pertama
# first : first
# time : time
# mencoba : coba
# jatuh : jatuh
# cinta : cinta
# waktu : waktu
# pilih : pilih
# shade : shade
# strawberrypine : strawberrypine
# raspberry : raspberry
# muffin : muffin
# terus : terus
# merasa : rasa
# formulanya : formula
# short : short
# lasting : lasting
# masa : masa
# iya : iya
# habis : habis
# minum : minum
# air : air
# lah : lah
# rugi : rugi
# dong : dong
# sudahlah : sudah
# aku : aku
# pindah : pindah
# haluan : haluan
# byeee : byeee
# overall : overall
# worth : worth
# kecepatan : cepat
# bubble : bubble
# warp : warp
# harga : harga
# ceban : ceban
# yay : yay
# kesekian : sekian
# kalinya : kali
# muka : muka
# kulitnya : kulit
# tetap : tetap
# bnafas : bnafas
# baru : baru
# kali : kali
# mudahan : mudah
# datang : datang
# selamat : selamat
# datangnya : datang
# nya : nya
# cream : cream
# segitu : segitu
# tekstur : tekstur
# meresap : resap
# bau : bau
# menyengat : sengat
# sekali : sekali
# bruntusan : bruntusan
# mudah : mudah
# berjerawat : jerawat
# breakout : breakout
# the : the
# best : best
# pokoknya : pokok
# original : original
# digunakan : guna
# makai : maka
# sebelumnya : belum
# punya : punya
# teman : teman
# berasa : asa
# cerah : cerah
# cuman : cuman
# mesti : mesti
# pelembab : pelembab
# beberapa : beberapa
# tahun : tahun
# memang : memang
# white : white
# cast : cast
# nyaman : nyaman
# seller : seller
# satu : satu
# mantap : mantap
# pengepakan : epak
# respon : respon
# puas : puas
# langganan : langgan
# disini : sini
# belanja : belanja
# recommended : recommended
# dibibir : bibir
# ngeset : ngeset
# kerutan : kerut
# ceept : ceept
# sampainya : sampai
# belinya : beli
# voucher : voucher
# lokal : lokal
# gopay : gopay
# favorit : favorit
# good : good
# koleksi : koleksi
# varian : varian
# suka : suka
# diombre : diombre
# puff : puff
# kalau : kalau
# bakal : bakal
# tinted : tinted
# pinkish : pinkish
# kayak : kayak
# warna : warna
# natural : natural
# makser : makser
# dibiarkan : biar
# benar : benar
# biar : biar
# terlalu : terlalu
# banyak : banyak
# transfer : transfer
# sangat : sangat
# produknya : produk
# great : great
# ekspektasi : ekspektasi
# keep : keep
# up : up
# work : work
# serumnya : serum
# sekarang : sekarang
# bundle : bundle
# ssnya : ssnya
# murah : murah
# jadinya : jadi
# berapa : berapa
# repurchase : repurchase
# hydramax : hydramax
# sesuka : suka
# nyiptain : nyiptain
# butuh : butuh
# ukuran : ukur
# liter : liter
# product : product
# efeknya : efek
# botol : botol
# bingung : bingung
# cenderung : cenderung
# warm : warm
# olive : olive
# tone : tone
# combo : combo
# rusberry : rusberry
# mantul : mantul
# ombre : ombre
# sendiri : sendiri
# nego : nego
# anak : anak
# muda : muda
# wangi : wangi
# packaging : packaging
# lucu : lucu
# affordable : affordable
# terjangkau : jangkau
# toplahyyyu : toplahyyyu
# amin : amin
# serum : serum
# bungkus : bungkus
# wrap : wrap
# kemarin : kemarin
# face : face
# wash : wash
# hampir : hampir
# setengah : tengah
# tahunan : tahun
# dimuka : muka
# oily : oily
# standard : standard
# woilaah : woilaah
# promo : promo
# gedean : gede
# danbocher : danbocher
# favorite : favorite
# tepat : tepat
# diskonannya : diskon
# bakalan : bakal
# sedikit : sedikit
# kecewa : kecewa
# packagingnya : packagingnya
# bublewrapnya : bublewrapnya
# perjalanan : jalan
# jauh : jauh
# sidoarjo : sidoarjo
# jakarta : jakarta
# sicepat : sicepat
# lambat : lambat
# gudang : gudang
# tanggal : tanggal
# diantar : antar
# sayang : sayang
# nama : nama
# keadaan : ada
# min : min
# fast : fast
# nice : nice
# price : price
# pcs : pcs
# wajah : wajah
# perlahan : perlahan
# teratasi : atas
# repurchased : repurchased
# indak : indak
# kusam : kusam
# susah : susah
# blend : blend
# alisnya : alis
# numpuk : numpuk
# ngeblock : ngeblock
# huhu : huhu
# lumayan : lumayan
# ter : ter
# thebest : thebest
# acne : acne
# prone : prone
# luvv : luvv
# berkata : kata
# moisturizer : moisturizer
# pol : pol
# menenangkan : tenang
# disaat : saat
# sedang : sedang
# meradang : radang
# lembut : lembut
# gel : gel
# dikulit : kulit
# melembapkan : lembap
# job : job
# luck : luck
# sepertinya : seperti
# pesan : pesan
# vitamin : vitamin
# dikirim : kirim
# retinol : retinol
# hasilnya : hasil
# klaim : klaim
# garansi : garansi
# menyiapkan : siap
# video : video
# unboxing : unboxing
# pesanan : pesan
# salah : salah
# mengasih : asih
# bintang : bintang
# teliti : teliti
# barangnya : barang
# diskon : diskon
# thankyouu : thankyouu
# stainnya : stainnya
# recommend : recommend
# love : love
# oil : oil
# waternya : waternya
# menghapus : hapus
# waterproof : waterproof
# memakai : pakai
# micellar : micellar
# tebal : tebal
# sunscreennya : sunscreennya
# no : no
# whitecast : whitecast
# diblend : diblend
# diskom : diskom
# kondisi : kondisi
# mengirim : kirim
# dipakein : dipakein
# perlu : perlu
# khawatir : khawatir
# pecah : pecah
# berhubung : hubung
# minggu : minggu
# mulai : mulai
# hasil : hasil
# hyperpigmentation : hyperpigmentation
# memudar : pudar
# mungkin : mungkin
# kudu : kudu
# rutin : rutin
# kayanya : kaya
# bulan : bulan
# betul : betul
# get : get
# rid : rid
# of : of
# hyperpigmentationnya : hyperpigmentationnya
# musti : musti
# follow : follow
# sosmednya : sosmednya
# syukur : syukur
# website : website
# azarinenya : azarinenya
# menu : menu
# news : news
# bahas : bahas
# apa : apa
# dikerjain : dikerjain
# tim : tim
# rndnya : rndnya
# mungkinn : mungkinn
# perhatian : perhati
# calon : calon
# customer : customer
# ataupun : atau
# loyal : loyal
# customernya : customernya
# dah : dah
# selama : lama
# pemakaian : pakai
# working : working
# well : well
# depan : depan
# for : for
# research : research
# before : before
# what : what
# your : your
# type : type
# skin : skin
# and : and
# problem : problem
# with : with
# langsung : langsung
# bajyak : bajyak
# as : as
# usual : usual
# memplump : memplump
# kan : kan
# melembabkan : melembabkan
# dicombine : dicombine
# pure : pure
# paw : paw
# memuaskan : muas
# review : review
# found : found
# pengemasan : emas
# pesenanya : sena
# udah : udah
# skincare : skincare
# merk : merk
# kualitas : kualitas
# tambah : tambah
# exp : exp
# cair : cair
# kental : kental
# diaplikasikan : aplikasi
# menggunakan : guna
# sekalipun : sekalipun
# luar : luar
# biasa : biasa
# pernah : pernah
# membuat : buat
# jel : jel
# aplikasikan : aplikasi
# berubah : ubah
# menjadi : jadi
# dibilas : bilas
# dibersihkan : bersih
# micelar : micelar
# water : water
# bersih : bersih
# ketiganya : tiga
# menghidrasi : hidrasi
# digabungkan : gabung
# gatal : gatal
# dikasih : kasih
# tau : tau
# enakk : enakk
# nyengat : nyengat
# kena : kena
# licin : licin
# gapapa : gapapa
# kerasa : rasa
# done : done
# laki : laki
# lovependkdksnz : lovependkdksnz
# dikardusin : dikardusin
# expired : expired
# segel : segel
# etalase : etalase
# pink : pink
# menambah : tambah
# twin : twin
# difollow : difollow
# admin : admin
# katanya : kata
# diluar : luar
# toped : toped
# kekuranganya : kekuranganya
# maximal : maximal
# hari : hari
# kerja : kerja
# kemudia : kemudia
# tanya : tanya
# dijawab : jawab
# kok : kok
# kak : kak
# really : really
# bad : bad
# attitude : attitude
# edit : edit
# kekurangan : kurang
# amanah : amanah
# next : next
# qc : qc
# diperketat : ketat
# shingga : shingga
# konsumen : konsumen
# repot : repot
# percaya : percaya
# parah : parah
# harganya : harga
# eeeh : eeeh
# besoknya : besok
# turun : turun
# kapan : kapan
# lanjut : lanjut
# dilewatin : dilewatin
# flash : flash
# sale : sale
# ulang : ulang
# moga : moga
# berkah : berkah
# dagangannya : dagang
# laku : laku
# wajahku : wajah
# ditokped : ditokped
# ketimbang : ketimbang
# keranjang : keranjang
# oranye : oranye
# sejauh : jauh
# putih : putih
# glowing : glowing
# klaimnya : klaim
# sebenarnya : benar
# eyebrownya : eyebrownya
# isi : isi
# patah : patah
# diperbaiki : baik
# ditoko : toko
# keberapa : berapa
# sebagus : bagus
# mleyot : mleyot
# so : so
# far : far
# paling : paling
# capet : capet
# cakep : cakep
# gercep : gercep
# combination : combination
# ijo : ijo
# nympe : nympe
# lip : lip
# tint : tint
# combi : combi
# nyerap : nyerap
# ngaruh : ngaruh
# andalan : andal
# mukaku : muka
# buy : buy
# items : items
# packingnya : packingnya
# niat : niat
# somuch : somuch
# plis : plis
# non : non
# aktifin : aktifin
# ekspedisi : ekspedisi
# sda : sda
# sub : sub
# sapx : sapx
# sehari : hari
# loh : loh
# mah : mah
# bukan : bukan
# silambat : silambat
# kemasan : kemas
# khasiatnya : khasiat
# khasiat : khasiat
# wanginyaa : wanginyaa
# blind : blind
# bermanfaat : manfaat
# ss : ss
# diharapkan : harap
# disaranin : disaranin
# lumayaan : lumayaan
# texture : texture
# disayangkan : sayang
# lubang : lubang
# tubenya : tube
# gede : gede
# dosis : dosis
# jari : jari
# gendut : gendut
# tuh : tuh
# radak : radak
# segi : segi
# halus : halus
# bantu : bantu
# btw : btw
# tutupnya : tutup
# dalem : dalem
# buka : buka
# tadinya : tadi
# nyasar : nyasar
# kirim : kirim
# pigmented : pigmented
# expetasii : expetasii
# plus : plus
# wrapnya : wrapnya
# cust : cust
# halo : halo
# ubah : ubah
# ratingnya : ratingnya
# kurangnya : kurang
# harusnya : harus
# hak : hak
# lihat : lihat
# ikut : ikut
# _ :
# tube : tube
# buatku : buat
# sesuk : sesuk
# finish : finish
# akuuuu : akuuuu
# perih : perih
# keringgg : keringgg
# sukakk : sukakk
# nude : nude
# foto : foto
# packsging : packsging
# sukses : sukses
# ajarkan : ajar
# lotion : lotion
# light : light
# watery : watery
# easy : easy
# apply : apply
# oya : oya
# spf : spf
# benaran : benar
# kilang : kilang
# minyak : minyak
# berkali : kali
# seenak : enak
# panjang : panjang
# gess : gess
# gonta : gonta
# ganti : ganti
# potongan : potong
# diakon : diakon
# bayar : bayar
# pantengin : pantengin
# usah : usah
# ditanya : tanya
# kualitasnya : kualitas
# akhir : akhir
# kepotong : potong
# libur : libur
# berat : berat
# terserap : serap
# sun : sun
# screen : screen
# terbukti : bukti
# juara : juara
# liptint : liptint
# liptintnya : liptintnya
# isinya : isi
# baca : baca
# toko : toko
# offline : offline
# meski : meski
# mengangkat : angkat
# kotoran : kotor
# dilakukan : laku
# berulang : ulang
# apa-apa : apa
# namanya : nama
# xixi : xixi
# komedo : komedo
# enakan : enak
# akhirnya : akhir
# menemukan : temu
# dermatitis : dermatitis
# physical : physical
# chemical : chemical
# salep : salep
# harinya : hari
# keras : keras
# makin : makin
# trust : trust
# issue : issue
# desas : desas
# desus : desus
# anjurkan : anjur
# pemilik : milik
# modal : modal
# fd : fd
# apk : apk
# checkout : checkout
# iritasi : iritasi
# komedoan : komedoan
# sensitive : sensitive
# dry : dry
# nyetok : nyetok
# konsisten : konsisten
# moisturizernya : moisturizernya
# mendarat : darat
# sempurna : sempurna
# an : an
# revieuw : revieuw
# vit : vit
# retinolnya : retinolnya
# rasa : rasa
# dinginnya : dingin
# diaplikasiin : diaplikasiin
# matte : matte
# klop : klop
# toner : toner
# menghilangkan : hilang
# works : works
# lup : lup
# pack : pack
# komplen : komplen
# pihak : pihak
# meminta : minta
# batalkan : batal
# manual : manual
# complen : complen
# dana : dana
# kembalikan : kembali
# bagian : bagi
# kebetulan : betul
# voc : voc
# teksturenya : teksturenya
# dibuka : buka
# kardusnya : kardus
# kecium : cium
# seenggaknya : enggak
# lakban : lakban
# mencegah : cegah
# kebocoran : bocor
# bejerawat : bejerawat
# bonyok : bonyok
# brng : brng
# tangan : tangan
# kaki : kaki
# pagi : pagi
# diruang : ruang
# ber : ber
# ac : ac
# fine : fine
# bermasalah : masalah
# dom : dom
# jak : jak
# sel : sel
# micellarnya : micellarnya
# gabikin : gabikin
# dngn : dngn
# mumpung : mumpung
# diisolasi : isolasi
# variasi : variasi
# date : date
# official : official
# store : store
# dijamin : jamin
# asli : asli
# seminggu : minggu
# rasakan : rasa
# gatel : gatel
# diarea : area
# hidung : hidung
# alis : alis
# gatelnya : gatelnya
# sensi : sensi
# ngebland : ngebland
# abu : abu
# medium : medium
# poinnya : poin
# moist : moist
# tempat : tempat
# kebutuhan : butuh
# lupa : lupa
# ambil : ambil
# claim : claim
# buktikan : bukti
# wokey : wokey
# sini : sini
# pelayanan : layan
# realpict : realpict
# respond : respond
# kaya : kaya
# makenya : makenya
# sorry : sorry
# rambutku : rambut
# dibilasnya : bilas
# rambut : rambut
# rontok : rontok
# masyaallah : masyaallah
# nemu : nemu
# secocok : cocok
# dipakek : dipakek
# keamanan : aman
# rekomen : rekomen
# ane : ane
# hempaskan : hempas
# terbaik : baik
# twinoack : twinoack
# doang : doang
# dikomplain : komplain
# solusinya : solusi
# kapok : kapok
# bahan : bahan
# safety : safety
# dtgnya : dtgnya
# jar : jar
# recomended : recomended
# under : under
# netral : netral
# cool : cool
# adek : adek
# fotonya : foto
# diwajah : wajah
# efek : efek
# omagaa : omagaa
# mencerahkan : cerah
# yaeaayy : yaeaayy
# meriah : riah
# sabunnya : sabun
# bersihh : bersihh
# pc : pc
# velvety : velvety
# lippie : lippie
# elum : elum
# umunya : umu
# gas : gas
# maksudnya : maksud
# lipbalm : lipbalm
# orange : orange
# atas : atas
# gelap : gelap
# ketutup : tutup
# pinkny : pinkny
# bentuknya : bentuk
# dibawa : bawa
# tas : tas
# berumur : umur
# sebesar : besar
# gambar : gambar
# kecil : kecil
# ml : ml
# perlindungan : lindung
# utama : utama
# gila : gila
# berkomentar : komentar
# dibeli : beli
# komplain : komplain
# hati : hati
# guys : guys
# twinpack : twinpack
# hai : hai
# kekurangannya : kurang
# alhamdulikah : alhamdulikah
# atok : atok
# awal : awal
# keren : keren
# pastika : pastika
# mantulity : mantulity
# sekebon : kebon
# reaksi : reaksi
# negatif : negatif
# bangun : bangun
# tidur : tidur
# sempat : sempat
# selesai : selesai
# menunggu : tunggu
# keringnya : kering
# sensani : sensani
# mint : mint
# segar : segar
# jam : jam
# mirip : mirip
# artis : artis
# korea : korea
# oppa : oppa
# update : update
# expores : expores
# hydrashoote : hydrashoote
# wadahnya : wadah
# minii : mini
# compact : compact
# shadesnya : shadesnya
# mateng : mateng
# man : man
# bublenya : bublenya
# biasanya : biasa
# kesayangan : sayang
# peyok : peyok
# dalemnya : dalem
# untung : untung
# super : super
# ingredientsnya : ingredientsnya
# {'sip': 'sip', 'proses': 'proses', 'orderan': 'order', 'san': 'san', 'pengirimannya': 'kirim', 'sesuai': 'sesuai', 'estimasi': 'estimasi', 'pengemasannya': 'emas', 'aman': 'aman', 'banget': 'banget', 'kulitku': 'kulit', 'cukup': 'cukup', 'sensitif': 'sensitif', 'sering': 'sering', 'pakai': 'pakai', 'makeup': 'makeup', 'jadi': 'jadi', 'mau': 'mau', 'coba': 'coba', 'sunscreen': 'sunscreen', 'spray': 'spray', 'menarik': 'tarik', 'cooling': 'cooling', 'sensationnya': 'sensationnya', 'semoga': 'moga', 'cocok': 'cocok', 'thank': 'thank', 'you': 'you', 'azarine': 'azarine', 'terima': 'terima', 'kasih': 'kasih', 'diterima': 'terima', 'baik': 'baik', 'tipe': 'tipe', 'kombinasi': 'kombinasi', 'normal': 'normal', 'kering': 'kering', 'berminyak': 'minyak', 'masalah': 'masalah', 'jerawat': 'jerawat', 'pori': 'pori', 'besar': 'besar', 'kurang': 'kurang', 'oke': 'oke', 'dipakai': 'pakai', 'enggak': 'enggak', 'bikin': 'bikin', 'bibir': 'bibir', 'lembab': 'lembab', 'malah': 'malah', 'kasar': 'kasar', 'warnanya': 'warna', 'merah': 'merah', 'menor': 'menor', 'approved': 'approved', 'sawo': 'sawo', 'matang': 'matang', 'hitam': 'hitam', 'kelihatan': 'lihat', 'dicoba': 'coba', 'takut': 'takut', 'ternyata': 'nyata', 'kulit': 'kulit', 'padahal': 'padahal', 'top': 'top', 'ramah': 'ramah', 'kantong': 'kantong', 'selalu': 'selalu', 'sama': 'sama', 'produk': 'produk', 'deh': 'deh', 'lebih': 'lebih', 'fresh': 'fresh', 'cepat': 'cepat', 'nyerapnya': 'nyerapnya', 'buat': 'buat', 'jerawatan': 'jerawat', 'lengket': 'lengket', 'suncreen': 'suncreen', 'terfavorit': 'favorit', 'ringan': 'ringan', 'bahannya': 'bahan', 'mufah': 'mufah', 'dserap': 'dserap', 'terasa': 'asa', 'wanginya': 'wangi', 'enak': 'enak', 'bagus': 'bagus', 'menghadap': 'hadap', 'uv': 'uv', 'barang': 'barang', 'deskripsi': 'deskripsi', 'pengiriman': 'kirim', 'penjual': 'jual', 'orisinal': 'orisinal', 'teksturnya': 'tekstur', 'gampang': 'gampang', 'menyerap': 'serap', 'lama': 'lama', 'kelamaan': 'lama', 'rada': 'rada', 'area': 'area', 'zone': 'zone', 'packet': 'packet', 'packing': 'packing', 'rapi': 'rapi', 'cuma': 'cuma', 'kurir': 'kurir', 'expedisinya': 'expedisinya', 'blegug': 'blegug', 'ditungguin': 'ditungguin', 'siang': 'siang', 'sore': 'sore', 'urusan': 'urus', 'dadakan': 'dada', 'kagak': 'kagak', 'ngabarin': 'ngabarin', 'pas': 'pas', 'cek': 'cek', 'tokped': 'tokped', 'termyata': 'termyata', 'tiba': 'tiba', 'tujuan': 'tuju', 'rumah': 'rumah', 'orang': 'orang', 'entah': 'entah', 'ditaro': 'ditaro', 'mana': 'mana', 'kurirnya': 'kurir', 'buru': 'buru', 'pulang': 'pulang', 'paketnya': 'paket', 'diselipin': 'diselipin', 'kusen': 'kusen', 'pintu': 'pintu', 'kacau': 'kacau', 'sih': 'sih', 'bukannya': 'bukan', 'kontak': 'kontak', 'dulu': 'dulu', 'main': 'main', 'diselip': 'selip', 'bagaimana': 'bagaimana', 'kalo': 'kalo', 'pemulung': 'pulung', 'kira': 'kira', 'kotak': 'kotak', 'kardus': 'kardus', 'sampah': 'sampah', 'hilang': 'hilang', 'paket': 'paket', 'alhamdulillah': 'alhamdulillah', 'pembelian': 'beli', 'kedua': 'dua', 'thanks': 'thanks', 'semua': 'semua', 'productnya': 'productnya', 'kusuka': 'suka', 'beli': 'beli', 'satuan': 'satu', 'total': 'total', 'item': 'item', 'ribu': 'ribu', 'ku': 'ku', 'cashback': 'cashback', 'syenangnya': 'syenangnya', 'free': 'free', 'gift': 'gift', 'pouch': 'pouch', 'kaca': 'kaca', 'card': 'card', 'gemas': 'gemas', 'cantik': 'cantik', 'repeat': 'repeat', 'order': 'order', 'beda': 'beda', 'nih': 'nih', 'pertama': 'pertama', 'first': 'first', 'time': 'time', 'mencoba': 'coba', 'jatuh': 'jatuh', 'cinta': 'cinta', 'waktu': 'waktu', 'pilih': 'pilih', 'shade': 'shade', 'strawberrypine': 'strawberrypine', 'raspberry': 'raspberry', 'muffin': 'muffin', 'terus': 'terus', 'merasa': 'rasa', 'formulanya': 'formula', 'short': 'short', 'lasting': 'lasting', 'masa': 'masa', 'iya': 'iya', 'habis': 'habis', 'minum': 'minum', 'air': 'air', 'lah': 'lah', 'rugi': 'rugi', 'dong': 'dong', 'sudahlah': 'sudah', 'aku': 'aku', 'pindah': 'pindah', 'haluan': 'haluan', 'byeee': 'byeee', 'over ...
# ------------------------
# Pandas Apply: 100%|██████████| 372/372 [00:00<?, ?it/s]
# 0                                                  [sip]
# 1      [proses, order, san, kirim, sesuai, estimasi, ...
# 2                          [terima, kasih, terima, baik]
# 3      [tipe, kulit, kombinasi, tipe, kulit, normal, ...
# 4      [kurang, oke, pakai, enggak, bikin, bibir, lem...
#                              ...
# 368    [kecewa, sama, emas, kardus, peyok, dalem, eng...
# 369    [ringan, banget, tipe, tekstur, moist, suka, c...
# 370    [suka, ingredientsnya, mudah, cocok, terima, k...
# 371         [tipe, kulit, minyak, tipe, kulit, sensitif]
# 372                                              [bagus]
# Name: review_tokens_stemmed, Length: 372, dtype: object
#                                               Review  \
# 0                                               sipp
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  ini kurang oke menurut sy dipake ga bikin bibi...
#
#                                          Review_norm  \
# 0                                                sip
# 1  proses orderan san pengirimannya sesuai estima...
# 2            terima kasih sudah diterima dengan baik
# 3  tipe kulitku kombinasi tipe kulitku normal tip...
# 4  ini kurang oke menurut saya dipakai enggak bik...
#
#                                        review_tokens  \
# 0                                              [sip]
# 1  [proses, orderan, san, pengirimannya, sesuai, ...
# 2     [terima, kasih, sudah, diterima, dengan, baik]
# 3  [tipe, kulitku, kombinasi, tipe, kulitku, norm...
# 4  [ini, kurang, oke, menurut, saya, dipakai, eng...
#
#                                     review_tokens_SR  \
# 0                                              [sip]
# 1  [proses, orderan, san, pengirimannya, sesuai, ...
# 2                    [terima, kasih, diterima, baik]
# 3  [tipe, kulitku, kombinasi, tipe, kulitku, norm...
# 4  [kurang, oke, dipakai, enggak, bikin, bibir, l...
#
#                                review_tokens_stemmed
# 0                                              [sip]
# 1  [proses, order, san, kirim, sesuai, estimasi, ...
# 2                      [terima, kasih, terima, baik]
# 3  [tipe, kulit, kombinasi, tipe, kulit, normal, ...
# 4  [kurang, oke, pakai, enggak, bikin, bibir, lem...

# %%
# Menghapus baris yang kosong
df = df.dropna(subset=['review_tokens_stemmed'])
# Menghapus baris yang hanya berisi spasi atau whitespace
df = df[df['review_tokens_stemmed'].str.strip() != '']
# Menghapus baris yang memiliki list kosong
df = df[df['review_tokens_stemmed'].apply(lambda x: x != [])]
df.head(15)
# Out:
#                                                Review  \
# 0                                                sipp
# 1   proses orderan san pengirimannya sesuai estima...
# 2             terima kasih sudah diterima dengan baik
# 3   tipe kulitku kombinasi tipe kulitku normal tip...
# 4   ini kurang oke menurut sy dipake ga bikin bibi...
# 5                              tipe kulitku berminyak
# 6       tipe kulitku sensitif masalah kulitku jerawat
# 7   gak approved untuk sawo matang bibir hitam krn...
# 8   setelah dicoba takut gak cocok ternyata cocok ...
# 9           selalu cocok sama produk azarine top dech
# 10         cocok banget kulit jadi lembab lebih fresh
# 11                 selalu cocok dengan produk azarine
# 13                                tipe kulitku normal
# 14  cepet banget nyerapnya cocok buat kulit bermin...
# 15                                             ringan
#
#                                           Review_norm  \
# 0                                                 sip
# 1   proses orderan san pengirimannya sesuai estima...
# 2             terima kasih sudah diterima dengan baik
# 3   tipe kulitku kombinasi tipe kulitku normal tip...
# 4   ini kurang oke menurut saya dipakai enggak bik...
# 5                              tipe kulitku berminyak
# 6       tipe kulitku sensitif masalah kulitku jerawat
# 7   enggak approved untuk sawo matang bibir hitam ...
# 8   setelah dicoba takut enggak cocok ternyata coc...
# 9            selalu cocok sama produk azarine top deh
# 10         cocok banget kulit jadi lembab lebih fresh
# 11                 selalu cocok dengan produk azarine
# 13                                tipe kulitku normal
# 14  cepat banget nyerapnya cocok buat kulit bermin...
# 15                                             ringan
#
#                                         review_tokens  \
# 0                                               [sip]
# 1   [proses, orderan, san, pengirimannya, sesuai, ...
# 2      [terima, kasih, sudah, diterima, dengan, baik]
# 3   [tipe, kulitku, kombinasi, tipe, kulitku, norm...
# 4   [ini, kurang, oke, menurut, saya, dipakai, eng...
# 5                          [tipe, kulitku, berminyak]
# 6   [tipe, kulitku, sensitif, masalah, kulitku, je...
# 7   [enggak, approved, untuk, sawo, matang, bibir,...
# 8   [setelah, dicoba, takut, enggak, cocok, ternya...
# 9    [selalu, cocok, sama, produk, azarine, top, deh]
# 10  [cocok, banget, kulit, jadi, lembab, lebih, fr...
# 11           [selalu, cocok, dengan, produk, azarine]
# 13                            [tipe, kulitku, normal]
# 14  [cepat, banget, nyerapnya, cocok, buat, kulit,...
# 15                                           [ringan]
#
#                                      review_tokens_SR  \
# 0                                               [sip]
# 1   [proses, orderan, san, pengirimannya, sesuai, ...
# 2                     [terima, kasih, diterima, baik]
# 3   [tipe, kulitku, kombinasi, tipe, kulitku, norm...
# 4   [kurang, oke, dipakai, enggak, bikin, bibir, l...
# 5                          [tipe, kulitku, berminyak]
# 6   [tipe, kulitku, sensitif, masalah, kulitku, je...
# 7   [enggak, approved, sawo, matang, bibir, hitam,...
# 8   [dicoba, takut, enggak, cocok, ternyata, cocok...
# 9    [selalu, cocok, sama, produk, azarine, top, deh]
# 10  [cocok, banget, kulit, jadi, lembab, lebih, fr...
# 11                   [selalu, cocok, produk, azarine]
# 13                            [tipe, kulitku, normal]
# 14  [cepat, banget, nyerapnya, cocok, buat, kulit,...
# 15                                           [ringan]
#
#                                 review_tokens_stemmed
# 0                                               [sip]
# 1   [proses, order, san, kirim, sesuai, estimasi, ...
# 2                       [terima, kasih, terima, baik]
# 3   [tipe, kulit, kombinasi, tipe, kulit, normal, ...
# 4   [kurang, oke, pakai, enggak, bikin, bibir, lem...
# 5                               [tipe, kulit, minyak]
# 6    [tipe, kulit, sensitif, masalah, kulit, jerawat]
# 7   [enggak, approved, sawo, matang, bibir, hitam,...
# 8   [coba, takut, enggak, cocok, nyata, cocok, kul...
# 9    [selalu, cocok, sama, produk, azarine, top, deh]
# 10  [cocok, banget, kulit, jadi, lembab, lebih, fr...
# 11                   [selalu, cocok, produk, azarine]
# 13                              [tipe, kulit, normal]
# 14  [cepat, banget, nyerapnya, cocok, buat, kulit,...
# 15                                           [ringan]

# %%
# import hasil preprocessing menjadi csv
df.to_csv("lemma_azarine.csv")
