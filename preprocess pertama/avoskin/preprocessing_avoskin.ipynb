# %%
# Load data ke dalam data frame 
import pandas as pd

# Spesifikasi encoding diperlukan karena data tidak menggunakan UTF-8
df = pd.read_csv('scraping_avoskin.csv', encoding='latin-1')

df.head()
# Out:
#                                               Review  \
# 0  it's beautiful package, bintang 5 buat safety ...
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi, tap...
# 3                                              top..
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                              Product     Rating Username  \
# 0  Toner Avoskin Miraculous Refining 100ml-AHA BH...  bintang 5     Dafa
# 1  Cream Malam Avoskin Ultra Brightening Cream 10...  bintang 5    F***d
# 2  Toner Avoskin Miraculous Refining 100ml-AHA BH...  bintang 5    A***a
# 3  Face Mist Avoskin Hydrating Treatment Essence ...  bintang 5     Dina
# 4  Toner Avoskin Your Skin Bae Marine Collagen 10...  bintang 5    i***a
#
#          Date
# 0  2024-01-30
# 1  2024-01-30
# 2  2024-01-30
# 3  2024-01-30
# 4  2024-01-30

# %%
# Drop kolom yang tidak terpakai
df = df.drop(df.iloc[:,1:], axis=1)

# Cek data teratas
df.head()
# Out:
#                                               Review
# 0  it's beautiful package, bintang 5 buat safety ...
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi, tap...
# 3                                              top..
# 4  tipe kulitku berminyak tipe kulitku kering tip...

# %% [markdown]
# PREPROCESSING

# %%
# PROSES CASE FOLDING (menjadikan semua huruf di kolom Review menjadi huruf kecil)
df['Review'] = df['Review'].str.lower()

print('Case Folding Result: \n')
df.head()
# Out:
# Case Folding Result:
#                                               Review
# 0  it's beautiful package, bintang 5 buat safety ...
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi, tap...
# 3                                              top..
# 4  tipe kulitku berminyak tipe kulitku kering tip...

# %%
# import hasil case folding menjadi csv
df.to_csv("casefolding_avoskin.csv")

# %%
# CLEANING
import re # regex library

def remove_tweet_special(text):
    # remove tab, new line, and back slice
    text = text.replace('\\t'," ").replace('\\n', " ").replace('\\u', " ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

df['Review'] = df['Review'].apply(remove_tweet_special)

# remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Review'] = df['Review'].apply(remove_number)

# remove punctuation and replace with space
def remove_punctuation(text):
    return re.sub(r'[.,]', ' ', text)

df['Review'] = df['Review'].apply(remove_punctuation)

# remove punctuation
def remove_symbol(text):
    # Menghapus simbol-simbol tidak standar dan menggantinya dengan spasi
    cleaned_text = re.sub(r'[^\w\s]', ' ', text)
    
    # Menghapus multiple whitespace
    cleaned_text = re.sub('\s+', ' ', cleaned_text).strip()
    
    return cleaned_text

df['Review'] = df['Review'].apply(remove_symbol)

# Menentukan ambang batas panjang string acak
threshold_length = 20

# Fungsi untuk menghapus string acak berdasarkan panjangnya
def hapus_string_acak_dengan_panjang(text):
    # Memeriksa panjang string dan menghapus jika melebihi ambang batas
    return ' '.join(word for word in text.split() if len(word) <= threshold_length)

# Menggunakan fungsi untuk menghapus string acak pada kolom 'Text'
df['Review'] = df['Review'].apply(hapus_string_acak_dengan_panjang)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Review'] = df['Review'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['Review'] = df['Review'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Review'] = df['Review'].apply(remove_single_char)

def remove_laughter(text):
    laughter_patterns = r'\b((ha)+h*|(he)+h*|(hi)+h*|(wk)+w*k*|(eh)+e*|(ah)+a*|(ih)+i*|(kw)+k*w*|(hem)+m*)\b'
    return re.sub(laughter_patterns, '', text, flags=re.IGNORECASE)

df['Review'] = df['Review'].apply(remove_laughter)

print('Cleaning Result : \n') 
print(df.head())
# Out:
# Cleaning Result :
#
#                                               Review
# 0      it  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...

# %%
# import hasil cleaning menjadi csv
df.to_csv("cleaning_avoskin.csv")

# %%
# REMOVE DUPLICATE
df = df.drop_duplicates()
df = df.reset_index(drop=True)
# Menghapus baris yang kosong
df = df.dropna(subset=['Review'])
# Menghapus baris yang hanya berisi spasi atau whitespace
df = df[df['Review'].str.strip() != '']
df.head()
# Out:
#                                               Review
# 0      it  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...

# %%
# import hasil remove duplicate menjadi csv
df.to_csv("removedup_avoskin.csv")

# %%
# NORMALIZATION
import pandas as pd
import re

slang_dictionary = pd.read_csv('../colloquial-indonesian-lexicon2.csv')
slang_dict = pd.Series(slang_dictionary['formal'].values,index=slang_dictionary['slang']).to_dict()

slang_dictionary.head()
# Out:
#      slang    formal  In-dictionary  \
# 0     woww       wow            1.0
# 1    aminn      amin            1.0
# 2      met   selamat            1.0
# 3   netaas   menetas            1.0
# 4  keberpa  keberapa            0.0
#
#                                              context  category1 category2  \
# 0                                                wow   elongasi         0
# 1  Selamat ulang tahun kakak tulus semoga panjang...   elongasi         0
# 2  Met hari netaas kak!? Wish you all the best @t...  abreviasi         0
# 3  Met hari netaas kak!? Wish you all the best @t...   afiksasi  elongasi
# 4                           Birthday yg keberpa kak?  abreviasi         0
#
#   category3
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# Normalisasi kata menggunakan kamus colloquial-indonesian-lexicon2.csv
def Slangwords(text, slang_dict):
    for word in text.split():
        if word in slang_dict.keys():
            # menambahkan \b untuk menandakan batas kata di sekitar kata slang
            text = re.sub(r'\b{}\b'.format(re.escape(word)), slang_dict[word], text)
    
    text = re.sub('@[\w]+', '', text)
    return text

df['Review_norm'] = df['Review'].apply(lambda x: Slangwords(x, slang_dict))
print(df.head())
# Out:
#                                               Review  \
# 0      it  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                          Review_norm
# 0     itu  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...

# %%
# import hasil replace slang words menjadi csv
df.to_csv("normalization_avoskin.csv")

# %%
# PROSES TOKENIZING (word_tokenize() untuk memecah string kedalam tokens)

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Tokenizing
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['review_tokens'] = df['Review_norm'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df.head())
# Out:
# Tokenizing Result :
#
#                                               Review  \
# 0      it  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                          Review_norm  \
# 0     itu  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                        review_tokens
# 0  [itu, beautiful, package, bintang, buat, safet...
# 1                            [tipe, kulitku, kering]
# 2  [pengiriman, agak, lama, karena, beda, provins...
# 3                                              [top]
# 4  [tipe, kulitku, berminyak, tipe, kulitku, keri...

# %%
# import hasil tokenizing menjadi csv
df.to_csv("tokenizing_avoskin.csv")

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
# PROSES FILTERING (Stopword Removal) menggunakan library sastrawi
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

# remove stopword pada list token
def stopwords_removal(words):
    filtered_words = [stopword.remove(w) for w in words]
    filtered_words = [word for word in filtered_words if word != '']  # Memfilter kata-kata kosong
    return filtered_words

df['review_tokens_SR'] = df['review_tokens'].apply(stopwords_removal) 

print(df.head())
# Out:
#                                               Review  \
# 0      it  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                          Review_norm  \
# 0     itu  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                        review_tokens  \
# 0  [itu, beautiful, package, bintang, buat, safet...
# 1                            [tipe, kulitku, kering]
# 2  [pengiriman, agak, lama, karena, beda, provins...
# 3                                              [top]
# 4  [tipe, kulitku, berminyak, tipe, kulitku, keri...
#
#                                     review_tokens_SR
# 0   [beautiful, package, bintang, buat, safety, nya]
# 1                            [tipe, kulitku, kering]
# 2  [pengiriman, lama, beda, provinsi, gapapa, pac...
# 3                                              [top]
# 4  [tipe, kulitku, berminyak, tipe, kulitku, keri...

# %%
# import hasil stopword removal menjadi csv
df.to_csv("stopword_avoskin.csv")

# %%
# PROSES LEMMATIZATION 
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['review_tokens_SR']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['review_tokens_stemmed'] = df['review_tokens_SR'].swifter.apply(get_stemmed_term)
print(df['review_tokens_stemmed'])
print(df.head())
# Out:
# 1039
# ------------------------
# beautiful : beautiful
# package : package
# bintang : bintang
# buat : buat
# safety : safety
# nya : nya
# tipe : tipe
# kulitku : kulit
# kering : kering
# pengiriman : kirim
# lama : lama
# beda : beda
# provinsi : provinsi
# gapapa : gapapa
# packingnya : packingnya
# aman : aman
# banget : banget
# semoga : moga
# cocok : cocok
# memperbaiki : baik
# kulit : kulit
# aku : aku
# berminyak : minyak
# top : top
# normal : normal
# kombinasi : kombinasi
# masalah : masalah
# kerutan : kerut
# jerawat : jerawat
# pori : pori
# besar : besar
# sensitif : sensitif
# exp : exp
# no : no
# review : review
# found : found
# pertama : pertama
# dulu : dulu
# sih : sih
# beli : beli
# bagus : bagus
# muka : muka
# waktu : waktu
# kemasan : kemas
# biru : biru
# mungkin : mungkin
# tahun : tahun
# lalu : lalu
# viral : viral
# perskincare : perskincare
# an : an
# semenjak : semenjak
# hamil : hamil
# stop : stop
# pakai : pakai
# produk : produk
# bayi : bayi
# mau : mau
# coba : coba
# kangen : kangen
# sensasinya : sensasi
# memakai : pakai
# memang : memang
# feelnya : feelnya
# ngaruh : ngaruh
# suka : suka
# muncul : muncul
# tiba : tiba
# barang : barang
# sesuai : sesuai
# pesanan : pesan
# oke : oke
# saran : saran
# facial : facial
# wash : wash
# perlu : perlu
# ditambahkan : tambah
# fragrance : fragrance
# biar : biar
# baunya : bau
# lebih : lebih
# enak : enak
# soalnya : soal
# kurang : kurang
# nyaman : nyaman
# digunakan : guna
# moga : moga
# cepat : cepat
# mantap : mantap
# alhamdulillah : alhamdulillah
# barangnya : barang
# pengemasan : emas
# thank : thank
# you : you
# kurir : kurir
# sicepat : sicepat
# team : team
# avoskin : avoskin
# bahannya : bahan
# gampang : gampang
# menyerap : serap
# gratis : gratis
# mini : mini
# pouch : pouch
# terima : terima
# kasih : kasih
# selau : selau
# harga : harga
# diskon : diskon
# yes : yes
# sama : sama
# produknya : produk
# berkali : kali
# kali : kali
# toko : toko
# official : official
# pembelian : beli
# selalu : selalu
# amanah : amanah
# thanks : thanks
# so : so
# far : far
# good : good
# for : for
# daily : daily
# use : use
# baru : baru
# kelihatan : lihat
# hasilnya : hasil
# dicoba : coba
# jadi : jadi
# kemarin : kemarin
# mencoba : coba
# kecil : kecil
# rupanya : rupa
# teksturnya : tekstur
# ringan : ringan
# mudah : mudah
# blend : blend
# whitecast : whitecast
# enggak : enggak
# oily : oily
# apply : apply
# sering : sering
# manjur : manjur
# exfoliasi : exfoliasi
# wajahku : wajah
# doesn : doesn
# smell : smell
# as : as
# nice : nice
# other : other
# brands : brands
# very : very
# chemical : chemical
# akhirnya : akhir
# nemu : nemu
# serum : serum
# ternyata : nyata
# seller : seller
# tokped : tokped
# product : product
# banyak : banyak
# diterima : terima
# bocor : bocor
# berasa : asa
# lembab : lembab
# keluarkan : keluar
# sunscreen : sunscreen
# spf : spf
# dong : dong
# avo : avo
# formulasinya : formulasi
# persis : persis
# kayak : kayak
# tgs : tgs
# please : please
# kulitnya : kulit
# paket : paket
# rapi : rapi
# seblmnya : seblmnya
# varian : varian
# ybs : ybs
# tau : tau
# yeey : yeey
# deh : deh
# menetap : tetap
# selamat : selamat
# packaging : packaging
# orderan : order
# always : always
# the : the
# best : best
# avoo : avoo
# kece : kece
# kesekian : sekian
# kalinya : kali
# rugi : rugi
# benar : benar
# menyesal : sesal
# toner : toner
# padahal : padahal
# berpaling : paling
# merk : merk
# malah : malah
# dibikin : bikin
# kecewa : kecewa
# ml : ml
# dikirim : kirim
# cuma : cuma
# aaaaaa : aaaaaa
# chat : chat
# meminta : minta
# solusi : solusi
# disuruh : suruh
# tunggu : tunggu
# senin : senin
# bikin : bikin
# menambah : tambah
# emosi : emosi
# rating : rating
# ganti : ganti
# kalau : kalau
# sangat : sangat
# komunikatif : komunikatif
# gercep : gercep
# amin : amin
# gede : gede
# komedo : komedo
# hidung : hidung
# bantu : bantu
# xixi : xixi
# andalan : andal
# exfo : exfo
# dimalam : malam
# hari : hari
# mengasih : asih
# promo : promo
# pemakaian : pakai
# terpercaya : percaya
# lah : lah
# usah : usah
# diragukan : ragu
# kalo : kalo
# mah : mah
# serumnya : serum
# meresap : resap
# wajah : wajah
# lengket : lengket
# sekali : sekali
# benaran : benar
# mencerahkan : cerah
# orisinal : orisinal
# memuaskan : muas
# kualitas : kualitas
# moisturizer : moisturizer
# habis : habis
# worthed : worthed
# buy : buy
# super : super
# murce : murce
# pesan : pesan
# datang : datang
# diresi : resi
# tertulis : tulis
# pcs : pcs
# salah : salah
# divideoin : divideoin
# percaya : percaya
# eeeehh : eeeehh
# sudahlah : sudah
# bagaimana : bagaimana
# foto : foto
# doang : doang
# penjual : jual
# responsif : responsif
# mama : mama
# usia : usia
# mulus : mulus
# berkurang : kurang
# repurchase : repurchase
# retinol : retinol
# refining : refining
# lembut : lembut
# dry : dry
# berjerawat : jerawat
# pump : pump
# terlalu : terlalu
# dekat : dekat
# mendingan : mending
# cream : cream
# mata : mata
# mengurangi : kurang
# panda : panda
# terlihat : lihat
# segar : segar
# pokoknya : pokok
# keren : keren
# terbaik : baik
# pernah : pernah
# mengecewakan : kecewa
# packagingnya : packagingnya
# mudahan : mudah
# rangkain : rangkain
# tinggal : tinggal
# safe : safe
# tanganku : tangan
# segel : segel
# ditangan : tang
# expired : expired
# gel : gel
# travel : travel
# size : size
# pas : pas
# katup : katup
# plastiknya : plastik
# kadang : kadang
# rapat : rapat
# tumpah : tumpah
# vit : vit
# sebagus : bagus
# rajin : rajin
# tiap : tiap
# pagi : pagi
# bekas : bekas
# hempas : hempas
# dipakai : pakai
# pemula : mula
# jum : jum
# at : at
# siang : siang
# ribu : ribu
# cashback : cashback
# gopay : gopay
# coin : coin
# free : free
# ongkir : ongkir
# btw : btw
# treatment : treatment
# dermapen : dermapen
# memudar : pudar
# packing : packing
# puffiness : puffiness
# bawah : bawah
# biasanya : biasa
# ampuh : ampuh
# eksfoliasi : eksfoliasi
# sekarang : sekarang
# tonernya : tonernya
# ngt : ngt
# packingan : packingan
# disini : sini
# gambar : gambar
# masyaallah : masyaallah
# glowing : glowing
# maskernya : masker
# melembabkan : melembabkan
# ed : ed
# stok : stok
# mumpung : mumpung
# sajja : sajja
# everyone : everyone
# hulu : hulu
# hilir : hilir
# lot : lot
# dikasih : kasih
# makin : makin
# laris : laris
# sukses : sukses
# love : love
# all : all
# sebelumnya : belum
# alpha : alpha
# arbutin : arbutin
# dibawah : bawah
# tepat : tepat
# tekstur : tekstur
# acneprone : acneprone
# parah : parah
# perubahan : ubah
# next : next
# order : order
# fan : fan
# ingredients : ingredients
# penasaran : penasaran
# pengin : pengin
# sejauh : jauh
# aaaa : aaaa
# pengirimannya : kirim
# diganti : ganti
# kurirnya : kurir
# pertamanya : pertama
# dikirimin : dikirimin
# tanya : tanya
# perbedaan : beda
# sale : sale
# walaupun : walaupun
# return : return
# proses : proses
# ribet : ribet
# terutama : utama
# pihak : pihak
# expedisi : expedisi
# segera : segera
# pick : pick
# up : up
# maksudnya : maksud
# awal : awal
# teliti : teliti
# buang : buang
# mengurusi : urus
# kedepannya : depan
# admin : admin
# responsive : responsive
# huhu : huhu
# ku : ku
# lempar : lempar
# jelas : jelas
# tulisan : tulis
# fragile : fragile
# dusnya : dus
# skin : skin
# barier : barier
# rusak : rusak
# sejak : sejak
# jerawatku : jerawat
# rewel : rewel
# jangan : jangan
# produksi : produksi
# mencari : cari
# alternatif : alternatif
# menyamarkan : samar
# niacin : niacin
# ngefek : ngefek
# beruntusan : beruntus
# dibarengin : dibarengin
# tanggal : tanggal
# dibawa : bawa
# terbang : terbang
# mendapatkan : dapat
# pelayanan : layan
# menyenangkan : senang
# menjadi : jadi
# pengguna : guna
# tetap : tetap
# selama : lama
# setia : setia
# menjelaskan : jelas
# detail : detail
# dibungkus : bungkus
# kardus : kardus
# bolong : bolong
# trigger : trigger
# trypophobia : trypophobia
# norak : norak
# seminggu : minggu
# puas : puas
# seri : seri
# miraculous : miraculous
# berbotol : botol
# botol : botol
# mulai : mulai
# plastik : plastik
# kaca : kaca
# teman : teman
# punya : punya
# kusam : kusam
# whitehead : whitehead
# blackhead : blackhead
# wajib : wajib
# bismillah : bismillah
# voc : voc
# lokal : lokal
# mantul : mantul
# malam : malam
# paginya : pagi
# clearance : clearance
# depan : depan
# semingguan : minggu
# lumayan : lumayan
# pliket : pliket
# menimbulkan : timbul
# original : original
# sedikit : sedikit
# apa : apa
# deskripsi : deskripsi
# display : display
# sewaktu : waktu
# memesan : mes
# skincare : skincare
# loveable : loveable
# exfoliating : exfoliating
# kit : kit
# berisi : isi
# macam : macam
# salycylic : salycylic
# acid : acid
# lactic : lactic
# dipesan : pes
# moisturizernya : moisturizernya
# lupa : lupa
# me : me
# record : record
# vidio : vidio
# unboxing : unboxing
# mengajukan : aju
# complain : complain
# tim : tim
# cekit : cekit
# besok : besok
# langsung : langsung
# oiya : oiya
# pakenya : pakenya
# keberapa : berapa
# eks : eks
# packinganny : packinganny
# kerdus : kerdus
# paperwrap : paperwrap
# dimuka : muka
# and : and
# teringan : tering
# dikulit : kulit
# mungil : mungil
# traveling : traveling
# friendly : friendly
# menghidrasi : hidrasi
# sepanjang : panjang
# bening : bening
# kental : kental
# kenyal : kenyal
# sehat : sehat
# tampak : tampak
# muda : muda
# phte : phte
# kelembaban : kelembaban
# acne : acne
# prone : prone
# beberapa : beberapa
# panjang : panjang
# langganan : langgan
# store : store
# terjamin : jamin
# keaslian : asli
# diserap : serap
# min : min
# pertamaku : pertama
# kedua : dua
# cukup : cukup
# memberikan : beri
# efek : efek
# jogja : jogja
# jakarta : jakarta
# hampir : hampir
# yaampun : yaampun
# bakalan : bakal
# stay : stay
# tune : tune
# echo : echo
# dikombinasi : kombinasi
# ysb : ysb
# menghilangkan : hilang
# hitam : hitam
# debuan : debu
# dalemnya : dalem
# kebetulan : betul
# recommend : recommend
# lactacid : lactacid
# kemasannya : kemas
# ampeg : ampeg
# rutin : rutin
# tidur : tidur
# hasil : hasil
# signifikan : signifikan
# ukurannya : ukur
# baik : baik
# kondisi : kondisi
# respon : respon
# senang : senang
# first : first
# time : time
# trying : trying
# this : this
# hopefully : hopefully
# works : works
# on : on
# my : my
# overall : overall
# well : well
# packaged : packaged
# coz : coz
# there : there
# is : is
# plastic : plastic
# sustainable : sustainable
# but : but
# takes : takes
# lil : lil
# bit : bit
# longer : longer
# tahan : tahan
# expect : expect
# nyampainya : nyampainya
# siap : siap
# responnya : responnya
# komplain : komplain
# untung : untung
# harganya : harga
# relatif : relatif
# terjangkau : jangkau
# gacha : gacha
# bahan : bahan
# cair : cair
# ramah : ramah
# lingkungan : lingkung
# kok : kok
# dah : dah
# fyi : fyi
# face : face
# viscosity : viscosity
# sabun : sabun
# niat : niat
# perbaikan : baik
# brand : brand
# luar : luar
# mana : mana
# jual : jual
# diri : diri
# customer : customer
# service : service
# bilang : bilang
# merasa : rasa
# bersalah : salah
# silakan : sila
# cek : cek
# ulasan : ulas
# semua : semua
# komennya : komennya
# batch : batch
# akhir : akhir
# berubah : ubah
# encer : encer
# mending : mending
# dirugikan : rugi
# hte : hte
# vakum : vakum
# dibotolnya : botol
# tadinya : tadi
# jumat : jumat
# sore : sore
# kesalahan : salah
# sentosa : sentosa
# date : date
# bonusnya : bonus
# cabe : cabe
# rawit : rawit
# sekeren : keren
# sekecil : kecil
# terharu : haru
# mall : mall
# malas : malas
# keluar : keluar
# belanja : belanja
# hidup : hidup
# sedang : sedang
# penuh : penuh
# pekerjaan : kerja
# laporan : lapor
# kantor : kantor
# apa-apa : apa
# penting : penting
# paketnya : paket
# freebiesnya : freebiesnya
# kirim : kirim
# terbuka : buka
# brush : brush
# keras : keras
# bonus : bonus
# bibirku : bibir
# dioles : oles
# bagusnya : bagus
# warna : warna
# pink : pink
# bibir : bibir
# halus : halus
# tahap : tahap
# cuman : cuman
# ngirimnya : ngirimnya
# salut : salut
# sabar : sabar
# profesional : profesional
# menjalankan : jalan
# tugasnya : tugas
# fast : fast
# hyaluronic : hyaluronic
# plump : plump
# glass : glass
# thick : thick
# murah : murah
# berkah : berkah
# memudarkan : pudar
# imut : imut
# kotak : kotak
# dibuka : buka
# kotaknya : kotak
# request : request
# pembeli : beli
# kukasih : kasih
# aroma : aroma
# setelahnya : telah
# minggu : minggu
# oren : oren
# bandung : bandung
# bayar : bayar
# keterlambatan : lambat
# pengalaman : alam
# berbelanjanya : belanja
# reviewnya : reviewnya
# prosesnya : proses
# isi : isi
# favorit : favorit
# clearence : clearence
# affdorable : affdorable
# kayaknya : kayak
# cantik : cantik
# bersihin : bersihin
# debu : debu
# meskipun : meski
# keseluruhan : seluruh
# kecintaanku : cinta
# ngeresap : ngeresap
# uas : uas
# excellent : excellent
# iritasi : iritasi
# voucher : voucher
# buatan : buat
# anak : anak
# bangsa : bangsa
# kak : kak
# avoskinnya : avoskinnya
# membantu : bantu
# noda : noda
# jauh : jauh
# eaa : eaa
# worry : worry
# bulan : bulan
# maret : maret
# tumben : tumben
# cuci : cuci
# gudang : gudang
# akkk : akkk
# aga : aga
# kaya : kaya
# soldout : soldout
# prmo : prmo
# thanku : thanku
# taro : taro
# meja : meja
# kesenggol : senggol
# pembantu : bantu
# alhasil : alhasil
# pecah : pecah
# cerminnya : cermin
# kecintaan : cinta
# biki : bik
# aaa : aaa
# dompet : dompet
# yhh : yhh
# minvoo : minvoo
# hihii : hihii
# juara : juara
# kertas : kertas
# cakep : cakep
# bergulung : gulung
# really : really
# mwahh : mwahh
# efeknya : efek
# wah : wah
# aa : aa
# dikulitku : kulit
# kombinasiin : kombinasiin
# ekspedisinya : ekspedisi
# bogor : bogor
# iseng : iseng
# checkout : checkout
# takut : takut
# bukan : bukan
# sempat : sempat
# inbox : inbox
# csnya : csnya
# bareng : bareng
# ampoulenya : ampoulenya
# devine : devine
# aura : aura
# katanya : kata
# rasanya : rasa
# kempes : kempes
# perbandingan : banding
# picnya : picnya
# versi : versi
# cool : cool
# too : too
# mas : mas
# warnanya : warna
# kuning : kuning
# negatif : negatif
# satu : satu
# ngilangi : ngilangi
# rilis : rilis
# diskonan : diskon
# coklat : coklat
# cz : cz
# ijo : ijo
# biasa : biasa
# gentle : gentle
# bruntusan : bruntusan
# mengecilkan : kecil
# worth : worth
# bakal : bakal
# combo : combo
# malamnya : malam
# kesayangan : sayang
# retinolnya : retinolnya
# kentel : kentel
# cinta : cinta
# lovee : lovee
# tokopedia : tokopedia
# giftnya : giftnya
# licin : licin
# gilasiiihh : gilasiiihh
# dikemas : kemas
# problem : problem
# libur : libur
# meragukan : ragu
# secair : cair
# tube : tube
# boros : boros
# kata : kata
# penurusan : turus
# viskositas : viskositas
# berarti : arti
# masa : masa
# buka : buka
# hyaluron : hyaluron
# sekian : sekian
# cermin : cermin
# butuh : butuh
# skinker : skinker
# ah : ah
# happy : happy
# sayang : sayang
# kasar : kasar
# alasannya : alas
# jadwal : jadwal
# payday : payday
# double : double
# pilihannya : pilih
# sekalian : sekali
# niacinamide : niacinamide
# konsistensinya : konsistensi
# tuang : tuang
# kapas : kapas
# diusap : usap
# pengelupasan : kelupas
# which : which
# mempercepat : cepat
# peluruhan : peluruh
# mati : mati
# paling : paling
# botolnya : botol
# mereview : mereview
# tutup : tutup
# menempel : tempel
# job : job
# beri : beri
# segini : gin
# perbarui : baru
# alhamdulillaah : alhamdulillaah
# tuh : tuh
# recomended : recomended
# atas : atas
# bantuan : bantu
# maksimal : maksimal
# hingga : hingga
# penerimaan : terima
# panjanhmg : panjanhmg
# diawali : awal
# berusaha : usaha
# menghubungi : hubung
# bertanggung : tanggung
# jawab : jawab
# terpakai : pakai
# perjalanan : jalan
# cekoutnya : cekoutnya
# mendekati : dekat
# tujuan : tuju
# xixixi : xixixi
# berapa : berapa
# guys : guys
# perfect : perfect
# awalnya : awal
# terasa : asa
# sebulan : bulan
# han : han
# lucu : lucu
# kacanya : kaca
# avoskinn : avoskinn
# penutup : tutup
# dalamnya : dalam
# seprti : seprti
# lipatnya : lipat
# tambah : tambah
# amaan : ama
# dobel : dobel
# paper : paper
# wrap : wrap
# termasuk : masuk
# wajar : wajar
# bdg : bdg
# begini : begini
# nih : nih
# anyway : anyway
# gift : gift
# terlama : lama
# des : des
# hayo : hayo
# lamanya : lama
# bulu : bulu
# mataku : mata
# ihiww : ihiww
# bahagianya : bahagia
# pelanggan : langgan
# menunggu : tunggu
# kira : kira
# timur : timur
# jawa : jawa
# type : type
# concern : concern
# penuaan : tua
# barusan : barusan
# berwarna : warna
# berbau : bau
# diusapkan : usap
# mesti : mesti
# war : war
# menyusui : susu
# recommended : recommended
# bumil : bumil
# busui : busui
# wishlist : wishlist
# terpenuhi : penuh
# pelembab : pelembab
# moist : moist
# comfort : comfort
# klaim : klaim
# bangun : bangun
# auto : auto
# cerah : cerah
# plumpy : plumpy
# minyakan : minyak
# menurutku : turut
# saking : saking
# cintanya : cinta
# eye : eye
# ampoule : ampoule
# pemakian : maki
# alergi : alergi
# name : name
# tag : tag
# butek : butek
# niacinemed : niacinemed
# lihat : lihat
# mash : mash
# hoki : hoki
# hilang : hilang
# ngabisin : ngabisin
# kerasa : rasa
# solid : solid
# delivery : delivery
# gesit : gesit
# patut : patut
# diacungi : acung
# ol : ol
# packinya : packinya
# lactid : lactid
# terlanjur : lanjur
# adminnya : adminnya
# makanya : makanya
# skalian : skalian
# nyetok : nyetok
# ovoskin : ovoskin
# rada : rada
# gemas : gemas
# secocok : cocok
# menutrisi : nutrisi
# pastinya : pasti
# cus : cus
# wiiii : wiiii
# potongan : potong
# harian : hari
# digabungin : digabungin
# overnight : overnight
# fluffy : fluffy
# dipegang : pegang
# kelamaan : lama
# lambat : lambat
# kan : kan
# test : test
# textured : textured
# sendiri : sendiri
# sip : sip
# terus : terus
# zonk : zonk
# tuker : tuker
# cancel : cancel
# tukar : tukar
# konfirmasi : konfirmasi
# kecewakan : kecewa
# penanganan : tangan
# diwaktu : waktu
# gue : gue
# jeroan : jeroan
# tamia : tamia
# sialan : sial
# tanggung : tanggung
# ekspedisi : ekspedisi
# lelet : lelet
# blunder : blunder
# angkat : angkat
# tangan : tangan
# solutif : solutif
# duit : duit
# packingannya : packingannya
# baca : baca
# taunya : tau
# thankyou : thankyou
# nyerepnya : nyerepnya
# polypeptide : polypeptide
# aqua : aqua
# ceramide : ceramide
# {'beautiful': 'beautiful', 'package': 'package', 'bintang': 'bintang', 'buat': 'buat', 'safety': 'safety', 'nya': 'nya', 'tipe': 'tipe', 'kulitku': 'kulit', 'kering': 'kering', 'pengiriman': 'kirim', 'lama': 'lama', 'beda': 'beda', 'provinsi': 'provinsi', 'gapapa': 'gapapa', 'packingnya': 'packingnya', 'aman': 'aman', 'banget': 'banget', 'semoga': 'moga', 'cocok': 'cocok', 'memperbaiki': 'baik', 'kulit': 'kulit', 'aku': 'aku', 'berminyak': 'minyak', 'top': 'top', 'normal': 'normal', 'kombinasi': 'kombinasi', 'masalah': 'masalah', 'kerutan': 'kerut', 'jerawat': 'jerawat', 'pori': 'pori', 'besar': 'besar', 'sensitif': 'sensitif', 'exp': 'exp', 'no': 'no', 'review': 'review', 'found': 'found', 'pertama': 'pertama', 'dulu': 'dulu', 'sih': 'sih', 'beli': 'beli', 'bagus': 'bagus', 'muka': 'muka', 'waktu': 'waktu', 'kemasan': 'kemas', 'biru': 'biru', 'mungkin': 'mungkin', 'tahun': 'tahun', 'lalu': 'lalu', 'viral': 'viral', 'perskincare': 'perskincare', 'an': 'an', 'semenjak': 'semenjak', 'hamil': 'hamil', 'stop': 'stop', 'pakai': 'pakai', 'produk': 'produk', 'bayi': 'bayi', 'mau': 'mau', 'coba': 'coba', 'kangen': 'kangen', 'sensasinya': 'sensasi', 'memakai': 'pakai', 'memang': 'memang', 'feelnya': 'feelnya', 'ngaruh': 'ngaruh', 'suka': 'suka', 'muncul': 'muncul', 'tiba': 'tiba', 'barang': 'barang', 'sesuai': 'sesuai', 'pesanan': 'pesan', 'oke': 'oke', 'saran': 'saran', 'facial': 'facial', 'wash': 'wash', 'perlu': 'perlu', 'ditambahkan': 'tambah', 'fragrance': 'fragrance', 'biar': 'biar', 'baunya': 'bau', 'lebih': 'lebih', 'enak': 'enak', 'soalnya': 'soal', 'kurang': 'kurang', 'nyaman': 'nyaman', 'digunakan': 'guna', 'moga': 'moga', 'cepat': 'cepat', 'mantap': 'mantap', 'alhamdulillah': 'alhamdulillah', 'barangnya': 'barang', 'pengemasan': 'emas', 'thank': 'thank', 'you': 'you', 'kurir': 'kurir', 'sicepat': 'sicepat', 'team': 'team', 'avoskin': 'avoskin', 'bahannya': 'bahan', 'gampang': 'gampang', 'menyerap': 'serap', 'gratis': 'gratis', 'mini': 'mini', 'pouch': 'pouch', 'terima': 'terima', 'kasih': 'kasih', 'selau': 'selau', 'harga': 'harga', 'diskon': 'diskon', 'yes': 'yes', 'sama': 'sama', 'produknya': 'produk', 'berkali': 'kali', 'kali': 'kali', 'toko': 'toko', 'official': 'official', 'pembelian': 'beli', 'selalu': 'selalu', 'amanah': 'amanah', 'thanks': 'thanks', 'so': 'so', 'far': 'far', 'good': 'good', 'for': 'for', 'daily': 'daily', 'use': 'use', 'baru': 'baru', 'kelihatan': 'lihat', 'hasilnya': 'hasil', 'dicoba': 'coba', 'jadi': 'jadi', 'kemarin': 'kemarin', 'mencoba': 'coba', 'kecil': 'kecil', 'rupanya': 'rupa', 'teksturnya': 'tekstur', 'ringan': 'ringan', 'mudah': 'mudah', 'blend': 'blend', 'whitecast': 'whitecast', 'enggak': 'enggak', 'oily': 'oily', 'apply': 'apply', 'sering': 'sering', 'manjur': 'manjur', 'exfoliasi': 'exfoliasi', 'wajahku': 'wajah', 'doesn': 'doesn', 'smell': 'smell', 'as': 'as', 'nice': 'nice', 'other': 'other', 'brands': 'brands', 'very': 'very', 'chemical': 'chemical', 'akhirnya': 'akhir', 'nemu': 'nemu', 'serum': 'serum', 'ternyata': 'nyata', 'seller': 'seller', 'tokped': 'tokped', 'product': 'product', 'banyak': 'banyak', 'diterima': 'terima', 'bocor': 'bocor', 'berasa': 'asa', 'lembab': 'lembab', 'keluarkan': 'keluar', 'sunscreen': 'sunscreen', 'spf': 'spf', 'dong': 'dong', 'avo': 'avo', 'formulasinya': 'formulasi', 'persis': 'persis', 'kayak': 'kayak', 'tgs': 'tgs', 'please': 'please', 'kulitnya': 'kulit', 'paket': 'paket', 'rapi': 'rapi', 'seblmnya': 'seblmnya', 'varian': 'varian', 'ybs': 'ybs', 'tau': 'tau', 'yeey': 'yeey', 'deh': 'deh', 'menetap': 'tetap', 'selamat': 'selamat', 'packaging': 'packaging', 'orderan': 'order', 'always': 'always', 'the': 'the', 'best': 'best', 'avoo': 'avoo', 'kece': 'kece', 'kesekian': 'sekian', 'kalinya': 'kali', 'rugi': 'rugi', 'benar': 'benar', 'menyesal': 'sesal', 'toner': 'toner', 'padahal': 'padahal', 'berpaling': 'paling', 'merk': 'merk', 'malah': 'malah', 'dibikin': 'bikin', 'kecewa': 'kecewa', 'ml': 'ml', 'dikirim': 'kirim', 'cuma': 'cuma', 'aaaaaa': 'aaa ...
# ------------------------
# Pandas Apply: 100%|██████████| 401/401 [00:00<00:00, 21404.68it/s]
# 0       [beautiful, package, bintang, buat, safety, nya]
# 1                                  [tipe, kulit, kering]
# 2      [kirim, lama, beda, provinsi, gapapa, packingn...
# 3                                                  [top]
# 4      [tipe, kulit, minyak, tipe, kulit, kering, tip...
#                              ...
# 397    [melembabkan, banget, tekstur, kental, cepat, ...
# 398         [beli, cocok, kulit, enggak, bikin, iritasi]
# 399         [order, polypeptide, terima, aqua, ceramide]
# 400    [produk, sesuai, deskripsi, jual, recommended,...
# 401    [selalu, pakai, cocok, enggak, bikin, kulit, k...
# Name: review_tokens_stemmed, Length: 401, dtype: object
#                                               Review  \
# 0      it  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                          Review_norm  \
# 0     itu  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                        review_tokens  \
# 0  [itu, beautiful, package, bintang, buat, safet...
# 1                            [tipe, kulitku, kering]
# 2  [pengiriman, agak, lama, karena, beda, provins...
# 3                                              [top]
# 4  [tipe, kulitku, berminyak, tipe, kulitku, keri...
#
#                                     review_tokens_SR  \
# 0   [beautiful, package, bintang, buat, safety, nya]
# 1                            [tipe, kulitku, kering]
# 2  [pengiriman, lama, beda, provinsi, gapapa, pac...
# 3                                              [top]
# 4  [tipe, kulitku, berminyak, tipe, kulitku, keri...
#
#                                review_tokens_stemmed
# 0   [beautiful, package, bintang, buat, safety, nya]
# 1                              [tipe, kulit, kering]
# 2  [kirim, lama, beda, provinsi, gapapa, packingn...
# 3                                              [top]
# 4  [tipe, kulit, minyak, tipe, kulit, kering, tip...

# %%
# Menghapus baris yang kosong
df = df.dropna(subset=['review_tokens_stemmed'])
# Menghapus baris yang hanya berisi spasi atau whitespace
df = df[df['review_tokens_stemmed'].str.strip() != '']
# Menghapus baris yang memiliki list kosong
df = df[df['review_tokens_stemmed'].apply(lambda x: x != [])]
df.head(15)
# Out:
#                                                Review  \
# 0       it  beautiful package bintang buat safety nya
# 1                                 tipe kulitku kering
# 2   pengiriman agak lama karena beda provinsi tapi...
# 3                                                 top
# 4   tipe kulitku berminyak tipe kulitku kering tip...
# 5                                                 exp
# 6                                     no review found
# 7   pertama banget dulu sih beli bagus bgt ya di m...
# 8                              tipe kulitku berminyak
# 9   tipe kulitku berminyak masalah kulitku pori besar
# 10  tipe kulitku berminyak tipe kulitku normal tip...
# 11                              barang sesuai pesanan
# 12  pengiriman oke saran untuk facial wash nya mun...
# 13         moga cocok soalnya dulu cocok bgt pake ini
# 14                          pengiriman cepat mantabbb
#
#                                           Review_norm  \
# 0      itu  beautiful package bintang buat safety nya
# 1                                 tipe kulitku kering
# 2   pengiriman agak lama karena beda provinsi tapi...
# 3                                                 top
# 4   tipe kulitku berminyak tipe kulitku kering tip...
# 5                                                 exp
# 6                                     no review found
# 7   pertama banget dulu sih beli bagus banget ya d...
# 8                              tipe kulitku berminyak
# 9   tipe kulitku berminyak masalah kulitku pori besar
# 10  tipe kulitku berminyak tipe kulitku normal tip...
# 11                              barang sesuai pesanan
# 12  pengiriman oke saran untuk facial wash nya mun...
# 13     moga cocok soalnya dulu cocok banget pakai ini
# 14                            pengiriman cepat mantap
#
#                                         review_tokens  \
# 0   [itu, beautiful, package, bintang, buat, safet...
# 1                             [tipe, kulitku, kering]
# 2   [pengiriman, agak, lama, karena, beda, provins...
# 3                                               [top]
# 4   [tipe, kulitku, berminyak, tipe, kulitku, keri...
# 5                                               [exp]
# 6                                 [no, review, found]
# 7   [pertama, banget, dulu, sih, beli, bagus, bang...
# 8                          [tipe, kulitku, berminyak]
# 9   [tipe, kulitku, berminyak, masalah, kulitku, p...
# 10  [tipe, kulitku, berminyak, tipe, kulitku, norm...
# 11                          [barang, sesuai, pesanan]
# 12  [pengiriman, oke, saran, untuk, facial, wash, ...
# 13  [moga, cocok, soalnya, dulu, cocok, banget, pa...
# 14                        [pengiriman, cepat, mantap]
#
#                                      review_tokens_SR  \
# 0    [beautiful, package, bintang, buat, safety, nya]
# 1                             [tipe, kulitku, kering]
# 2   [pengiriman, lama, beda, provinsi, gapapa, pac...
# 3                                               [top]
# 4   [tipe, kulitku, berminyak, tipe, kulitku, keri...
# 5                                               [exp]
# 6                                 [no, review, found]
# 7   [pertama, banget, dulu, sih, beli, bagus, bang...
# 8                          [tipe, kulitku, berminyak]
# 9   [tipe, kulitku, berminyak, masalah, kulitku, p...
# 10  [tipe, kulitku, berminyak, tipe, kulitku, norm...
# 11                          [barang, sesuai, pesanan]
# 12  [pengiriman, oke, saran, facial, wash, nya, mu...
# 13  [moga, cocok, soalnya, dulu, cocok, banget, pa...
# 14                        [pengiriman, cepat, mantap]
#
#                                 review_tokens_stemmed
# 0    [beautiful, package, bintang, buat, safety, nya]
# 1                               [tipe, kulit, kering]
# 2   [kirim, lama, beda, provinsi, gapapa, packingn...
# 3                                               [top]
# 4   [tipe, kulit, minyak, tipe, kulit, kering, tip...
# 5                                               [exp]
# 6                                 [no, review, found]
# 7   [pertama, banget, dulu, sih, beli, bagus, bang...
# 8                               [tipe, kulit, minyak]
# 9   [tipe, kulit, minyak, masalah, kulit, pori, be...
# 10  [tipe, kulit, minyak, tipe, kulit, normal, tip...
# 11                            [barang, sesuai, pesan]
# 12  [kirim, oke, saran, facial, wash, nya, mungkin...
# 13    [moga, cocok, soal, dulu, cocok, banget, pakai]
# 14                             [kirim, cepat, mantap]

# %%
# import hasil preprocessing menjadi csv
df.to_csv("lemma_avoskin.csv")
