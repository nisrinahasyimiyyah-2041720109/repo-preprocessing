# %%
# Load data ke dalam data frame 
import pandas as pd

# spesifikasi encoding diperlukan karena data tidak menggunakan UTF-8
df = pd.read_csv('scraping_skingame.csv', encoding='latin-1')

df.head()
# Out:
#                                               Review  \
# 0                                    No review found
# 1  pengiriman sengaja pakai gosend biar cepat, ta...
# 2  cepat meresap, ringan di kulit wajah, cuman bu...
# 3  Seller sangat cepat memproses barang. Packing ...
# 4                              Cocok di kulit normal
#
#                                              Product     Rating Username
# 0  Skin Game Kind Watery Moisturizer - Pelembab W...  bintang 5    Nurul
# 1  Skin Game Kind Watery Moisturizer - Pelembab W...  bintang 3   Firman
# 2             Skin Game Daily Kind Moisturizer 50 ml  bintang 5    I***y
# 3  Skin Game Kind Cream Moisturizer - Pelembab Wa...  bintang 5    Hesty
# 4  Skin Game Acne Warrior Paste 15 ml - Krim Jerawat  bintang 5    F***i

# %%
# Drop kolom yang tidak terpakai
df = df.drop(df.iloc[:,1:], axis=1)

# Cek data teratas
df.head()
# Out:
#                                               Review
# 0                                    No review found
# 1  pengiriman sengaja pakai gosend biar cepat, ta...
# 2  cepat meresap, ringan di kulit wajah, cuman bu...
# 3  Seller sangat cepat memproses barang. Packing ...
# 4                              Cocok di kulit normal

# %% [markdown]
# PREPROCESSING

# %%
# PROSES CASE FOLDING (menjadikan semua huruf di kolom content menjadi huruf kecil)
df['Review'] = df['Review'].str.lower()

print('Case Folding Result: \n')
df.head()
# Out:
# Case Folding Result:
#                                               Review
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat, ta...
# 2  cepat meresap, ringan di kulit wajah, cuman bu...
# 3  seller sangat cepat memproses barang. packing ...
# 4                              cocok di kulit normal

# %%
# import hasil case folding menjadi csv
df.to_csv("casefolding.csv")

# %%
# CLEANING
import string
import re #regex library

def remove_tweet_special(text):
    #remove tab, new line, and back slice
    text = text.replace('\\t'," ").replace('\\n', " ").replace('\\u', " ").replace('\\',"")
    #remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

df['Review'] = df['Review'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Review'] = df['Review'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df['Review'] = df['Review'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Review'] = df['Review'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['Review'] = df['Review'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Review'] = df['Review'].apply(remove_single_char)

print('Cleaning Result : \n') 
print(df.head())
# Out:
# Cleaning Result :
#
#                                               Review
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat tap...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal

# %%
# import hasil cleaning menjadi csv
df.to_csv("cleaning.csv")

# %%
# REMOVE DUPLICATE
df = df.drop_duplicates()
df = df.reset_index(drop=True)
df.head()
# Out:
#                                               Review
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat tap...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal

# %%
# import hasil remove duplicate menjadi csv
df.to_csv("removedup.csv")

# %%
# NORMALIZATION
import pandas as pd
import re
import csv
import string

slang_dictionary = pd.read_csv('colloquial-indonesian-lexicon2.csv')
slang_dict = pd.Series(slang_dictionary['formal'].values,index=slang_dictionary['slang']).to_dict()

slang_dictionary.head()
# Out:
#      slang    formal  In-dictionary  \
# 0     woww       wow            1.0
# 1    aminn      amin            1.0
# 2      met   selamat            1.0
# 3   netaas   menetas            1.0
# 4  keberpa  keberapa            0.0
#
#                                              context  category1 category2  \
# 0                                                wow   elongasi         0
# 1  Selamat ulang tahun kakak tulus semoga panjang...   elongasi         0
# 2  Met hari netaas kak!? Wish you all the best @t...  abreviasi         0
# 3  Met hari netaas kak!? Wish you all the best @t...   afiksasi  elongasi
# 4                           Birthday yg keberpa kak?  abreviasi         0
#
#   category3
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
def Slangwords(text):
    for word in text.split():
        if word in slang_dict.keys():
            text = text.replace(word, slang_dict[word])
    
    text = re.sub('@[\w]+', '',text)
    return text

df['Review_norm'] = df['Review'].apply(Slangwords)
df.head()
# Out:
#                                               Review  \
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat tap...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal
#
#                                          Review_norm
# 0                                    no review found
# 1  pengiriman senenggakja pakai gosend biar cepat...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal

# %%
# import hasil replace slang words menjadi csv
df.to_csv("normalization.csv")

# %%
# PROSES TOKENIZING (word_tokenize() untuk memecah string kedalam tokens)

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Tokenizing
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['review_tokens'] = df['Review_norm'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df.head())
# Out:
# Tokenizing Result :
#
#                                               Review  \
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat tap...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal
#
#                                          Review_norm  \
# 0                                    no review found
# 1  pengiriman senenggakja pakai gosend biar cepat...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal
#
#                                        review_tokens
# 0                                [no, review, found]
# 1  [pengiriman, senenggakja, pakai, gosend, biar,...
# 2  [cepat, meresap, ringan, di, kulit, wajah, cum...
# 3  [seller, sangat, cepat, memproses, barang, pac...
# 4                         [cocok, di, kulit, normal]

# %%
# import hasil tokenizing menjadi csv
df.to_csv("tokenizing.csv")

# %%
# PROSES FILTERING (Stopword Removal)
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['review_tokens_SR'] = df['review_tokens'].apply(stopwords_removal) 

print(df.head())
# Out:
#                                               Review  \
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat tap...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal
#
#                                          Review_norm  \
# 0                                    no review found
# 1  pengiriman senenggakja pakai gosend biar cepat...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal
#
#                                        review_tokens  \
# 0                                [no, review, found]
# 1  [pengiriman, senenggakja, pakai, gosend, biar,...
# 2  [cepat, meresap, ringan, di, kulit, wajah, cum...
# 3  [seller, sangat, cepat, memproses, barang, pac...
# 4                         [cocok, di, kulit, normal]
#
#                                     review_tokens_SR
# 0                                [no, review, found]
# 1  [pengiriman, senenggakja, pakai, gosend, biar,...
# 2  [cepat, meresap, ringan, kulit, wajah, cuman, ...
# 3  [seller, cepat, memproses, barang, packing, am...
# 4                             [cocok, kulit, normal]

# %%
# import hasil sr menjadi csv
df.to_csv("stopword.csv")

# %%
# PROSES LEMMATIZATION 
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['review_tokens_SR']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['review_tokens_stemmed'] = df['review_tokens_SR'].swifter.apply(get_stemmed_term)
print(df['review_tokens_stemmed'])
print(df.head())
# Out:
# 1231
# ------------------------
# no : no
# review : review
# found : found
# pengiriman : kirim
# senenggakja : senenggakja
# pakai : pakai
# gosend : gosend
# biar : biar
# cepat : cepat
# dikirim : kirim
# disuruh : suruh
# reorder : reorder
# denenggakn : denenggakn
# alasan : alas
# kompensasi : kompensasi
# taunya : tau
# pas : pas
# meresap : resap
# ringan : ringan
# kulit : kulit
# wajah : wajah
# cuman : cuman
# dryskin : dryskin
# krg : krg
# melembabkan : melembabkan
# enak : enak
# prep : prep
# makeup : makeup
# seller : seller
# memproses : proses
# barang : barang
# packing : packing
# aman : aman
# reliable : reliable
# cocok : cocok
# normal : normal
# selangnya : selang
# sependek : pendek
# sih : sih
# hilang : hilang
# kebawah : bawah
# wtf : wtf
# annoying : annoying
# banget : banget
# pakainya : pakai
# coba : coba
# cari : cari
# tube : tube
# ajalah : aja
# kalo : kalo
# packaging : packaging
# kayak : kayak
# gi : gi
# mendaratpelembab : mendaratpelembab
# kesayangan : sayang
# mantap : mantap
# pesanan : pesan
# sesuai : sesuai
# responsif : responsif
# tebal : tebal
# bravo : bravo
# packagingnya : packagingnya
# diperbaiki : baik
# ya : ya
# untungnya : untung
# barangnya : barang
# tinggal : tinggal
# selipin : selipin
# keambil : ambil
# produknya : produk
# semoga : moga
# awet : awet
# waotery : waotery
# ok : ok
# diaku : dia
# kulitnya : kulit
# kering : kering
# tumbuh : tumbuh
# jerawat : jerawat
# bergantian : ganti
# adik : adik
# kombinasi : kombinasi
# cocokoo : cocokoo
# cekot : cekot
# kemasan : kemas
# favoritue : favoritue
# gampang : gampang
# kempess : kempess
# baunya : bau
# ganggu : ganggu
# worth : worth
# kaget : kaget
# moisturizernya : moisturizernya
# ssudah : ssudah
# berevolusi : evolusi
# skin : skin
# type : type
# moisturizer : moisturizer
# kali : kali
# versi : versi
# hasilnya : hasil
# mantaaaaab : mantaaaaab
# bekas : bekas
# luv : luv
# baju : baju
# barunya : baru
# cantik : cantik
# mewah : mewah
# kualitas : kualitas
# diragukan : ragu
# bagus : bagus
# semenjak : semenjak
# moist : moist
# game : game
# kulitku : kulit
# better : better
# semingguan : minggu
# bikin : bikin
# muka : muka
# lumayan : lumayan
# tipe : tipe
# dahi : dahi
# pipi : pipi
# jad : jad
# mari : mari
# pelayanannya : layan
# oke : oke
# bubble : bubble
# wrap : wrap
# terjaga : jaga
# reformulasi : reformulasi
# formula : formula
# mnatap : mnatap
# berbeda : beda
# safely : safely
# arrived : arrived
# mudah : mudah
# menyerapp : menyerapp
# skintype : skintype
# oily : oily
# acne : acne
# prone : prone
# enggakis : enggak
# preloved : preloved
# punyaku : punya
# jual : jual
# murah : murah
# kondisi : kondisi
# box : box
# dijual : jual
# ngrsa : ngrsa
# brand : brand
# apapun : apa
# kesini : kesini
# and : and
# shes : shes
# back : back
# with : with
# new : new
# thank : thank
# you : you
# for : for
# being : being
# my : my
# most : most
# holy : holy
# grail : grail
# memakai : pakai
# skingame : skingame
# cocokaku : cocokaku
# sensitif : sensitif
# pie : pie
# nyaman : nyaman
# dipakai : pakai
# efek : efek
# samping : samping
# dicoba : coba
# teman : teman
# packingnyaa : packingnyaa
# feels : feels
# secured : secured
# danaman : danaman
# the : the
# product : product
# itself : itself
# is : is
# pretty : pretty
# bulky : bulky
# enggakmpang : enggakmpang
# bocorr : bocorr
# enggakperlu : enggakperlu
# khawatirr : khawatirr
# harii : hari
# sok : sok
# jujur : jujur
# aenggak : aenggak
# panik : panik
# lihat : lihat
# dusnya : dus
# penyok : penyok
# isinya : isi
# buka : buka
# dus : dus
# tutup : tutup
# botol : botol
# nya : nya
# rapet : rapet
# untung : untung
# berminyak : minyak
# kemasannya : kemas
# lucu : lucu
# bahannya : bahan
# terima : terima
# kasih : kasih
# paket : paket
# selamat : selamat
# engenggak : engenggak
# sebagus : bagus
# lembab : lembab
# bantu : bantu
# pulih : pulih
# barier : barier
# ganti : ganti
# produk : produk
# bangus : bangus
# langsung : langsung
# menyerap : serap
# repurchase : repurchase
# berkali : kali
# simple : simple
# efektif : efektif
# tekstur : tekstur
# super : super
# recommended : recommended
# beli : beli
# mudahan : mudah
# akhirnyaaa : akhirnyaaa
# menemukan : temu
# moistnya : moistnya
# tergantung : gantung
# pemakaiannya : pakai
# orisinal : orisinal
# kakak : kakak
# adminnya : adminnya
# ramah : ramah
# deh : deh
# kayaknya : kayak
# pengemasan : emas
# mateng : mateng
# thankyou : thankyou
# aenggakk : aenggakk
# aneh : aneh
# apek : apek
# bau : bau
# besi : besi
# tempatnya : tempat
# sabun : sabun
# langganan : langgan
# solusi : solusi
# jerawatan : jerawat
# breakout : breakout
# pikir : pikir
# checkout : checkout
# lov : lov
# warna : warna
# kuning : kuning
# rapi : rapi
# this : this
# seriously : seriously
# changer : changer
# love : love
# how : how
# one : one
# bottle : bottle
# could : could
# last : last
# me : me
# months : months
# baeu : baeu
# mencoba : coba
# reviewnya : reviewnya
# apply : apply
# parah : parah
# keduaaa : keduaaa
# aslii : asli
# butuh : butuh
# habisin : habisin
# oilyy : oilyy
# menurutku : turut
# meredakan : reda
# delivery : delivery
# nih : nih
# harian : hari
# wow : wow
# suka : suka
# teksturnyaa : teksturnyaa
# oilyskin : oilyskin
# friendly : friendly
# luvvv : luvvv
# habis : habis
# gede : gede
# harga : harga
# promo : promo
# cashback : cashback
# pengemasannya : emas
# far : far
# thanks : thanks
# pumpnya : pumpnya
# jelek : jelek
# muncrat : muncrat
# perubahan : ubah
# megecil : megecil
# mild : mild
# gel : gel
# exp : exp
# expired : expired
# beda : beda
# kebanyakan : banyak
# teksturnya : tekstur
# kental : kental
# dioles : oles
# sensasi : sensasi
# dinginnya : dingin
# pump : pump
# pemakaian : pakai
# sel : sel
# trmaksih : trmaksih
# favorit : favorit
# rinenggakn : rinenggakn
# salah : salah
# first : first
# impression : impression
# botolnya : botol
# woy : woy
# plisss : plisss
# ulas : ulas
# gim : gim
# merasap : merasap
# packingnya : packingnya
# dikasih : kasih
# sensitive : sensitive
# kelembaban : kelembaban
# seharian : hari
# dipakainya : pakai
# ngelembabin : ngelembabin
# malam : malam
# siangnya : siang
# sayang : sayang
# mahal : mahal
# cocokan : cocok
# pelayanan : layan
# okay : okay
# bahan : bahan
# kukit : kit
# ukuran : ukur
# lebi : lebi
# pengirimannya : kirim
# cepetttt : cepetttt
# ml : ml
# bulanan : bulan
# fast : fast
# update : update
# terkait : kait
# kecocokannya : cocok
# ngeresap : ngeresap
# kekulit : kulit
# pokoknya : pokok
# deskripsi : deskripsi
# proses : proses
# dikemas : kemas
# top : top
# sukses : sukses
# beralih : alih
# rada : rada
# gue : gue
# kerasa : rasa
# melembapkan : lembap
# berat : berat
# alhamdulillah : alhamdulillah
# paketnya : paket
# order : order
# mssudahan : mssudahan
# mendem : mendem
# obat : obat
# totol : totol
# ampuh : ampuh
# wajahku : wajah
# timer : timer
# kombi : kombi
# dry : dry
# puas : puas
# rusak : rusak
# nyerep : nyerep
# untukku : untuk
# bentuk : bentuk
# higienis : higienis
# trying : trying
# time : time
# but : but
# here : here
# service : service
# tanggung : tanggung
# jawa : jawa
# merawat : rawat
# huaa : huaa
# milia : milia
# berharap : harap
# btw : btw
# segi : segi
# mohon : mohon
# diperhatikan : perhati
# satuan : satu
# masuk : masuk
# kondisinya : kondisi
# kon : kon
# point : point
# ngunci : ngunci
# rewel : rewel
# berasa : asa
# lamaaa : lamaaa
# info : info
# buy : buy
# tryta : tryta
# tahan : tahan
# jam : jam
# price : price
# ukurannya : ukur
# calming : calming
# klaim : klaim
# tertarik : tarik
# brighteningnya : brighteningnya
# keren : keren
# pengantarannya : antar
# lengket : lengket
# tenang : tenang
# cek : cek
# tersertifikasi : sertifikasi
# halal : halal
# mui : mui
# tks : tks
# all : all
# rembes : rembes
# cairan : cair
# berkurang : kurang
# diperkuat : kuat
# sealernya : sealernya
# berlanganan : berlanganan
# tokped : tokped
# plus : plus
# cair : cair
# disayang : sayang
# paksu : paksu
# tq : tq
# menghidrasi : hidrasi
# pembelian : beli
# texturenya : texturenya
# saran : saran
# dikembangkan : kembang
# model : model
# pompa : pompa
# maksimal : maksimal
# kelembapan : lembap
# agakbanyak : agakbanyak
# banding : banding
# punyanya : punya
# somethinc : somethinc
# goks : goks
# keempat : empat
# menahan : tahan
# minyak : minyak
# dikulit : kulit
# hasil : hasil
# signifikan : signifikan
# terhidrasi : hidrasi
# ku : ku
# bayangkan : bayang
# penggunaan : guna
# seru : seru
# baikkk : baikkk
# betulll : betulll
# freebies : freebies
# engenggakkkk : engenggakkkk
# dichat : dichat
# engengenggakkkk : engengenggakkkk
# konfirm : konfirm
# chat : chat
# diantar : antar
# diluar : luar
# estimasi : estimasi
# kurir : kurir
# next : next
# day : day
# datenggg : datenggg
# dikasi : kasi
# bonus : bonus
# snack : snack
# kesekian : sekian
# kalirecommended : kalirecommended
# pelembab : pelembab
# sediannya : dian
# menyumbat : sumbat
# pori : pori
# awww : awww
# freebie : freebie
# mingem : mingem
# as : as
# said : said
# berjodoh : jodoh
# kind : kind
# kena : kena
# racun : racun
# twitter : twitter
# temenku : temenku
# tulisannya : tulis
# po : po
# mengecek : ecek
# eh : eh
# tbtb : tbtb
# sampee : sampee
# senang : senang
# juenggak : juenggak
# bonusnya : bonus
# teks : teks
# snacknya : snacknya
# min : min
# initapi : initapi
# leb : leb
# minggu : minggu
# bedanya : beda
# spot : spot
# memudar : pudar
# kinclong : kinclong
# isi : isi
# rekomendasi : rekomendasi
# sodara : sodara
# respond : respond
# diharapkan : harap
# yeay : yeay
# toemakasii : toemakasii
# jajan : jajan
# respon : respon
# penjual : jual
# guncang : guncang
# bersih : bersih
# mulus : mulus
# ikiut : ikiut
# pembelanjaan : belanja
# bundle : bundle
# hemat : hemat
# diterima : terima
# kempes : kempes
# mdhan : mdhan
# ditambahin : ditambahin
# kardus : kardus
# penjualnya : jual
# macet : macet
# nampol : nampol
# layer : layer
# reaksi : reaksi
# negatif : negatif
# seminggu : minggu
# alus : alus
# minyakan : minyak
# bang : bang
# pertamakali : pertamakali
# bngeett : bngeett
# dikirimnya : kirim
# kupikir : pikir
# basuh : basuh
# air : air
# sejuk : sejuk
# membekas : bekas
# rutin : rutin
# berbekas : bekas
# ketiga : tiga
# moizturizer : moizturizer
# cerah : cerah
# sepromo : sepromo
# tergolong : golong
# orang : orang
# menyerapnya : serap
# lembabnya : lembabnya
# gerah : gerah
# pack : pack
# pelelehan : leleh
# masya : masya
# allah : allah
# toto : toto
# team : team
# loveeee : loveeee
# sehat : sehat
# huhu : huhu
# kalinya : kali
# aweeeet : aweeeet
# segitu : segitu
# habisnya : habis
# engenggakk : engenggakk
# macemmacem : macemmacem
# rinengenggakkn : rinengenggakkn
# kelembabannya : kelembabannya
# berm : berm
# sssudah : sssudah
# pengin : pengin
# plumpy : plumpy
# terimakasih : terimakasih
# kak : kak
# ketemu : ketemu
# finishnya : finishnya
# alias : alias
# muncul : muncul
# jer : jer
# gelnya : gel
# mayang : mayang
# enggakbada : enggakbada
# pore : pore
# armor : armor
# diproduksi : produksi
# hasihlnya : hasihlnya
# safety : safety
# bismillah : bismillah
# repeat : repeat
# berjerawat : jerawat
# keberapa : berapa
# gonta : gonta
# cocoksampe : cocoksampe
# brenti : brenti
# mencari : cari
# alot : alot
# official : official
# store : store
# terjamin : jamin
# keasliannya : asli
# fix : fix
# kandunenggaknnya : kandunenggaknnya
# sunscreen : sunscreen
# gr : gr
# juenggakaa : juenggakaa
# diaplikasikan : aplikasi
# productnya : productnya
# neko : neko
# really : really
# have : have
# step : step
# up : up
# on : on
# marketing : marketing
# wise : wise
# ide : ide
# packagin : packagin
# value : value
# terjangkau : jangkau
# diratakan : rata
# obati : obat
# foam : foam
# sdikit : sdikit
# whitecast : whitecast
# diratain : diratain
# minusnya : minus
# aluminum : aluminum
# penutupnya : tutup
# susah : susah
# dibuka : buka
# tolong : tolong
# krim : krim
# kentalpadat : kentalpadat
# warnanya : warna
# pink : pink
# cowok : cowok
# fs : fs
# uk : uk
# ed : ed
# cowokcowokk : cowokcowokk
# takut : takut
# turns : turns
# out : out
# mukaku : muka
# matanya : mata
# besok : besok
# sangaaat : sangaaat
# menyembukan : menyembukan
# oh : oh
# lil : lil
# gift : gift
# sunscreenya : sunscreenya
# sampenya : sampenya
# perkiraan : kira
# admin : admin
# tangan : tangan
# lembap : lembap
# sample : sample
# sabar : sabar
# depannya : depan
# formulanya : formula
# claim : claim
# lemgket : lemgket
# baurkan : baur
# meninggalkan : tinggal
# white : white
# cast : cast
# menghilangkan : hilang
# kemerahan : merah
# sekian : sekian
# hrga : hrga
# pgiriman : pgiriman
# dksih : dksih
# dakron : dakron
# ditangan : tang
# diatasin : diatasin
# inj : inj
# grenjelgrenjelnya : grenjelgrenjelnya
# nakar : nakar
# konsisten : konsisten
# volume : volume
# jari : jari
# jug : jug
# membantu : bantu
# paginya : pagi
# totolannya : totol
# foto : foto
# disegel : segel
# gontai : gontai
# merk : merk
# gemec : gemec
# indak : indak
# padat : padat
# jerawatnya : jerawat
# beruntusan : beruntus
# dipakein : dipakein
# kempesnya : kempes
# je : je
# tau : tau
# semprotannya : semprot
# doang : doang
# hehehehe : hehehehe
# toner : toner
# idk : idk
# why : why
# mengakak : akak
# its : its
# not : not
# because : because
# ngepacking : ngepacking
# itemnya : item
# they : they
# use : use
# kesannya : kesan
# mengambang : ambang
# diatas : atas
# andalan : andal
# terbaik : baik
# busetttt : busetttt
# hempass : hempass
# belii : beli
# efeknya : efek
# dahsyatt : dahsyatt
# full : full
# size : size
# berdua : dua
# uwow : uwow
# khaaaannnn : khaaaannnn
# bargain : bargain
# very : very
# versatile : versatile
# frills : frills
# just : just
# solid : solid
# standar : standar
# hidup : hidup
# terhitung : hitung
# pakenya : pakenya
# penutup : tutup
# effective : effective
# keluarkan : keluar
# wkwkwk : wkwkwk
# kenyal : kenyal
# lebay : lebay
# sticky : sticky
# harganya : harga
# dibandingkan : banding
# dcoba : dcoba
# premium : premium
# texture : texture
# seksama : seksama
# sesingkatsingkatnya : sesingkatsingkatnya
# date : date
# kombinasiku : kombinasi
# oilnya : oilnya
# enggaknggu : enggaknggu
# wangi : wangi
# kimia : kimia
# harenggak : harenggak
# segituu : segituu
# ingredient : ingredient
# gedenya : gede
# kecintaan : cinta
# akuhhhh : akuhhhh
# sebotol : botol
# seenak : enak
# tekturnya : tekturnya
# melembabkannya : melembabkannya
# mantul : mantul
# barrier : barrier
# kokoh : kokoh
# keliataan : keliataan
# pumpingnya : pumpingnya
# sudeh : sudeh
# kex : kex
# terampuh : ampuh
# tidur : tidur
# dijamin : jamin
# kempesjerawat : kempesjerawat
# be : be
# nyerap : nyerap
# kerusakan : rusa
# design : design
# watery : watery
# komedo : komedo
# eenggakk : eenggakk
# bb : bb
# cream : cream
# ngelupas : ngelupas
# mending : mending
# ribu : ribu
# banyakan : banyak
# udara : udara
# niat : niat
# smoengenggakk : smoengenggakk
# siang : siang
# surantul : surantul
# best : best
# hydrating : hydrating
# hypenya : hypenya
# thanjs : thanjs
# cepatnya : cepat
# euy : euy
# serum : serum
# mengobati : obat
# mengasih : asih
# natural : natural
# bibir : bibir
# cenderung : cenderung
# hitam : hitam
# kadang : kadang
# lip : lip
# oil : oil
# anak : anak
# abang : abang
# satusatunya : satusatunya
# terbukti : bukti
# enaak : enaak
# lovvv : lovvv
# rekomen : rekomen
# brentusan : brentusan
# viral : viral
# skinc : skinc
# ampuhkebalik : ampuhkebalik
# fkus : fkus
# toko : toko
# lem : lem
# dibagian : bagi
# body : body
# solasiban : solasiban
# bukanya : buka
# favorittt : favorittt
# ujungnya : ujung
# bbegitu : bbegitu
# tuh : tuh
# penguruman : penguruman
# travel : travel
# ngirimnya : ngirimnya
# meriah : riah
# muaaahhh : muaaahhh
# mantab : mantab
# yeayy : yeayy
# makasihh : makasihh
# gemas : gemas
# ditempel : tempel
# stiker : stiker
# plastik : plastik
# pelit : pelit
# dikasinya : kas
# skincare : skincare
# tujuan : tuju
# request : request
# good : good
# kentel : kentel
# mencair : cair
# nyeess : nyeess
# kayanya : kaya
# bonu : bonu
# mantapsssss : mantapsssss
# kulitu : kulitu
# dikulitu : dikulitu
# wtb : wtb
# im : im
# sad : sad
# didnt : didnt
# works : works
# sampaidenga : sampaidenga
# utuh : utuh
# iseng : iseng
# research : research
# range : range
# murce : murce
# dibanding : banding
# deserves : deserves
# more : more
# rec : rec
# jar : jar
# membaikk : membaikk
# setahun : tahun
# gaperna : gaperna
# maskeran : masker
# wkwk : wkwk
# combo : combo
# krimnya : krim
# mengempeskan : kempes
# besoknya : besok
# akyu : akyu
# beruntus : beruntus
# luka : luka
# merah : merah
# nutup : nutup
# purchase : purchase
# ever : ever
# every : every
# dime : dime
# cyst : cyst
# radang : radang
# dimuka : muka
# anakku : anak
# rangkaian : rangkai
# active : active
# response : response
# makenya : makenya
# sehari : hari
# diskon : diskon
# flash : flash
# sale : sale
# hero : hero
# dalemnya : dalem
# aluminium : aluminium
# dilepas : lepas
# sisa : sisa
# praktis : praktis
# moisterizer : moisterizer
# nyerepnya : nyerepnya
# memuaskan : muas
# ajaib : ajaib
# original : original
# cacat : cacat
# recomendasi : recomendasi
# cetaphil : cetaphil
# busabisa : busabisa
# less : less
# busa : busa
# rek : rek
# dipacking : dipacking
# dicobain : dicobain
# semalem : semalem
# light : light
# sbnrnya : sbnrnya
# ttapi : ttapi
# mukanya : muka
# paking : paking
# laamaaa : laamaaa
# facial : facial
# wash : wash
# maju : maju
# toopppp : toopppp
# barriernya : barriernya
# blend : blend
# pakau : pakau
# ngeset : ngeset
# manfaat : manfaat
# hebat : hebat
# iritasi : iritasi
# overall : overall
# dikit : dikit
# kekurangannya : kurang
# dikeluarin : dikeluarin
# selang : selang
# menambah : tambah
# akhirnyaaaa : akhirnyaaaa
# bentuknya : bentuk
# eeenggakkk : eeenggakkk
# greasy : greasy
# setelahnya : telah
# engengenggakkk : engengenggakkk
# hhhilang : hhhilang
# benjolan : benjol
# gosong : gosong
# engengengenggakkkk : engengengenggakkkk
# nimbul : nimbul
# berfungsi : fungsi
# gentle : gentle
# washnya : washnya
# thick : thick
# enough : enough
# pengaplikasiannya : aplikasi
# problem : problem
# aaah : aaah
# senangnya : senang
# nemu : nemu
# kusam : kusam
# pilling : pilling
# masker : masker
# rambut : rambut
# halus : halus
# anti : anti
# lepek : lepek
# fw : fw
# semuka : muka
# leher : leher
# material : material
# bocor : bocor
# fragrance : fragrance
# hygenis : hygenis
# semoenggak : semoenggak
# ro : ro
# baguus : baguus
# voucher : voucher
# giveaway : giveaway
# terbaru : baru
# ketimbang : ketimbang
# berkualitas : kualitas
# mudahmudahan : mudahmudahan
# tonernya : tonernya
# cuci : cuci
# cuy : cuy
# nano : nano
# baguspengiriman : baguspengiriman
# okedapet : okedapet
# hadiah : hadiah
# hair : hair
# mask : mask
# hahahaha : hahahaha
# cangkep : cangkep
# free : free
# spa : spa
# savior : savior
# dikala : kala
# break : break
# sembuh : sembuh
# gara : gara
# warrior : warrior
# paketan : paket
# pesan : pesan
# minimalis : minimal
# oles : oles
# kir : kir
# duit : duit
# asik : asik
# seringin : ringin
# pecinta : cinta
# conditioner : conditioner
# voucer : voucer
# belanja : belanja
# bermanfaat : manfaat
# pemesanan : mesan
# semalam : malam
# batu : batu
# mengeluarkan : keluar
# batunya : batu
# mengering : ering
# masknya : masknya
# halo : halo
# kalimya : kalimya
# woshlist : woshlist
# nabung : nabung
# nyisihin : nyisihin
# uang : uang
# estima : estima
# freebiesnyaaa : freebiesnyaaa
# menarik : tarik
# ekspektasih : ekspektasih
# tnyt : tnyt
# mate : mate
# tone : tone
# porefessihonal : porefessihonal
# gatal : gatal
# panas : panas
# makasiih : makasiih
# bonusan : bonus
# much : much
# mantuliti : mantuliti
# thannks : thannks
# bruntusan : bruntusan
# serumnya : serum
# menyebalkan : sebal
# layanan : layan
# sip : sip
# menyamarkan : samar
# penasaran : penasaran
# hairmask : hairmask
# sampainiya : sampainiya
# skinigame : skinigame
# your : your
# especially : especially
# kinid : kinid
# name : name
# face : face
# ditempat : tempat
# kerja : kerja
# mundur : mundur
# menyenangkan : senang
# menenangkan : tenang
# tersegel : segel
# formulasinya : formulasi
# affordable : affordable
# hehe : hehe
# mantull : mantull
# kulituku : kulituku
# dibeli : beli
# mengadakan : ada
# dibawah : bawah
# mingguan : minggu
# baiksemoga : baiksemoga
# servisnya : servis
# basic : basic
# dibawa : bawa
# traveling : traveling
# loveee : loveee
# adem : adem
# dipengiriman : kirim
# pulau : pulau
# ngaruh : ngaruh
# struggle : struggle
# dilayani : layan
# dikombinasi : kombinasi
# calmdown : calmdown
# ngefek : ngefek
# lengkap : lengkap
# restock : restock
# rumah : rumah
# ter : ter
# boncos : boncos
# sebagusss : sebagusss
# ituuhh : ituuhh
# akuu : akuu
# aenggakkuu : aenggakkuu
# keset : keset
# kokk : kokk
# wanginya : wangi
# hrg : hrg
# goodeal : goodeal
# hih : hih
# baikpackingan : baikpackingan
# amaaann : amaaann
# orii : orii
# mini : mini
# cepett : cepett
# sampeenyaa : sampeenyaa
# guard : guard
# berbentuk : bentuk
# bening : bening
# theory : theory
# of : of
# everything : everything
# essencenya : essencenya
# kema : kema
# berprogres : progres
# cute : cute
# aju : aju
# nice : nice
# kotak : kotak
# lapisi : lapis
# bintang : bintang
# pengantaran : antar
# gram : gram
# loooove : loooove
# daaaan : daaaan
# jumbo : jumbo
# definitely : definitely
# steal : steal
# st : st
# becek : becek
# dikulitku : kulit
# kemana : mana
# gasabar : gasabar
# setia : setia
# kerutan : kerut
# tipis : tipis
# usia : usia
# noted : noted
# aplikasikan : aplikasi
# harengenggakknya : harengenggakknya
# benchmark : benchmark
# berbaengenggakki : berbaengenggakki
# diapp : diapp
# terluv : terluv
# memudarkan : pudar
# glowing : glowing
# youu : youu
# setrlah : setrlah
# kepatil : patil
# fullsize : fullsize
# sebelah : belah
# tapinya : tapi
# whipped : whipped
# ha : ha
# hempaskan : hempas
# kebocoran : bocor
# produkny : produkny
# alhamdulilah : alhamdulilah
# acneprone : acneprone
# sc : sc
# kumel : mel
# wudhu : wudhu
# kesiram : siram
# susu : susu
# lunturnya : luntur
# wkwkwkwk : wkwkwkwk
# tha : tha
# jarang : jarang
# which : which
# prefer : prefer
# gabikin : gabikin
# khawatir : khawatir
# balm : balm
# dariugstore : dariugstore
# ngempesin : ngempesin
# cystic : cystic
# scarring : scarring
# colek : colek
# higenis : higenis
# berbulan : bulan
# cowokbain : cowokbain
# menunggu : tunggu
# disc : disc
# dikiiiit : dikiiiit
# {'no': 'no', 'review': 'review', 'found': 'found', 'pengiriman': 'kirim', 'senenggakja': 'senenggakja', 'pakai': 'pakai', 'gosend': 'gosend', 'biar': 'biar', 'cepat': 'cepat', 'dikirim': 'kirim', 'disuruh': 'suruh', 'reorder': 'reorder', 'denenggakn': 'denenggakn', 'alasan': 'alas', 'kompensasi': 'kompensasi', 'taunya': 'tau', 'pas': 'pas', 'meresap': 'resap', 'ringan': 'ringan', 'kulit': 'kulit', 'wajah': 'wajah', 'cuman': 'cuman', 'dryskin': 'dryskin', 'krg': 'krg', 'melembabkan': 'melembabkan', 'enak': 'enak', 'prep': 'prep', 'makeup': 'makeup', 'seller': 'seller', 'memproses': 'proses', 'barang': 'barang', 'packing': 'packing', 'aman': 'aman', 'reliable': 'reliable', 'cocok': 'cocok', 'normal': 'normal', 'selangnya': 'selang', 'sependek': 'pendek', 'sih': 'sih', 'hilang': 'hilang', 'kebawah': 'bawah', 'wtf': 'wtf', 'annoying': 'annoying', 'banget': 'banget', 'pakainya': 'pakai', 'coba': 'coba', 'cari': 'cari', 'tube': 'tube', 'ajalah': 'aja', 'kalo': 'kalo', 'packaging': 'packaging', 'kayak': 'kayak', 'gi': 'gi', 'mendaratpelembab': 'mendaratpelembab', 'kesayangan': 'sayang', 'mantap': 'mantap', 'pesanan': 'pesan', 'sesuai': 'sesuai', 'responsif': 'responsif', 'tebal': 'tebal', 'bravo': 'bravo', 'packagingnya': 'packagingnya', 'diperbaiki': 'baik', 'ya': 'ya', 'untungnya': 'untung', 'barangnya': 'barang', 'tinggal': 'tinggal', 'selipin': 'selipin', 'keambil': 'ambil', 'produknya': 'produk', 'semoga': 'moga', 'awet': 'awet', 'waotery': 'waotery', 'ok': 'ok', 'diaku': 'dia', 'kulitnya': 'kulit', 'kering': 'kering', 'tumbuh': 'tumbuh', 'jerawat': 'jerawat', 'bergantian': 'ganti', 'adik': 'adik', 'kombinasi': 'kombinasi', 'cocokoo': 'cocokoo', 'cekot': 'cekot', 'kemasan': 'kemas', 'favoritue': 'favoritue', 'gampang': 'gampang', 'kempess': 'kempess', 'baunya': 'bau', 'ganggu': 'ganggu', 'worth': 'worth', 'kaget': 'kaget', 'moisturizernya': 'moisturizernya', 'ssudah': 'ssudah', 'berevolusi': 'evolusi', 'skin': 'skin', 'type': 'type', 'moisturizer': 'moisturizer', 'kali': 'kali', 'versi': 'versi', 'hasilnya': 'hasil', 'mantaaaaab': 'mantaaaaab', 'bekas': 'bekas', 'luv': 'luv', 'baju': 'baju', 'barunya': 'baru', 'cantik': 'cantik', 'mewah': 'mewah', 'kualitas': 'kualitas', 'diragukan': 'ragu', 'bagus': 'bagus', 'semenjak': 'semenjak', 'moist': 'moist', 'game': 'game', 'kulitku': 'kulit', 'better': 'better', 'semingguan': 'minggu', 'bikin': 'bikin', 'muka': 'muka', 'lumayan': 'lumayan', 'tipe': 'tipe', 'dahi': 'dahi', 'pipi': 'pipi', 'jad': 'jad', 'mari': 'mari', 'pelayanannya': 'layan', 'oke': 'oke', 'bubble': 'bubble', 'wrap': 'wrap', 'terjaga': 'jaga', 'reformulasi': 'reformulasi', 'formula': 'formula', 'mnatap': 'mnatap', 'berbeda': 'beda', 'safely': 'safely', 'arrived': 'arrived', 'mudah': 'mudah', 'menyerapp': 'menyerapp', 'skintype': 'skintype', 'oily': 'oily', 'acne': 'acne', 'prone': 'prone', 'enggakis': 'enggak', 'preloved': 'preloved', 'punyaku': 'punya', 'jual': 'jual', 'murah': 'murah', 'kondisi': 'kondisi', 'box': 'box', 'dijual': 'jual', 'ngrsa': 'ngrsa', 'brand': 'brand', 'apapun': 'apa', 'kesini': 'kesini', 'and': 'and', 'shes': 'shes', 'back': 'back', 'with': 'with', 'new': 'new', 'thank': 'thank', 'you': 'you', 'for': 'for', 'being': 'being', 'my': 'my', 'most': 'most', 'holy': 'holy', 'grail': 'grail', 'memakai': 'pakai', 'skingame': 'skingame', 'cocokaku': 'cocokaku', 'sensitif': 'sensitif', 'pie': 'pie', 'nyaman': 'nyaman', 'dipakai': 'pakai', 'efek': 'efek', 'samping': 'samping', 'dicoba': 'coba', 'teman': 'teman', 'packingnyaa': 'packingnyaa', 'feels': 'feels', 'secured': 'secured', 'danaman': 'danaman', 'the': 'the', 'product': 'product', 'itself': 'itself', 'is': 'is', 'pretty': 'pretty', 'bulky': 'bulky', 'enggakmpang': 'enggakmpang', 'bocorr': 'bocorr', 'enggakperlu': 'enggakperlu', 'khawatirr': 'khawatirr', 'harii': 'hari', 'sok': 'sok', 'jujur': 'jujur', 'aenggak': 'aenggak', 'panik': 'panik', 'lihat': 'lihat', 'dusnya': 'dus', 'penyok': 'penyok', 'isinya': 'isi', 'buka': 'buka', 'dus': 'dus', 'tutup': ...
# ------------------------
# Pandas Apply: 100%|██████████| 457/457 [00:00<00:00, 57149.58it/s]
# 0                                    [no, review, found]
# 1      [kirim, senenggakja, pakai, gosend, biar, cepa...
# 2      [cepat, resap, ringan, kulit, wajah, cuman, dr...
# 3      [seller, cepat, proses, barang, packing, aman,...
# 4                                 [cocok, kulit, normal]
#                              ...
# 452    [serum, ampuh, muka, sensitif, minyak, acne, p...
# 453    [tekstur, enak, banget, engenggak, bau, aneh, ...
# 454    [pakai, bulan, cocok, kirim, cepat, bagus, all...
# 455    [for, the, first, time, cowok, moist, skingame...
# 456    [pikir, kental, cair, ya, cepat, resap, sih, m...
# Name: review_tokens_stemmed, Length: 457, dtype: object
#                                               Review  \
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat tap...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal
#
#                                          Review_norm  \
# 0                                    no review found
# 1  pengiriman senenggakja pakai gosend biar cepat...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal
#
#                                        review_tokens  \
# 0                                [no, review, found]
# 1  [pengiriman, senenggakja, pakai, gosend, biar,...
# 2  [cepat, meresap, ringan, di, kulit, wajah, cum...
# 3  [seller, sangat, cepat, memproses, barang, pac...
# 4                         [cocok, di, kulit, normal]
#
#                                     review_tokens_SR  \
# 0                                [no, review, found]
# 1  [pengiriman, senenggakja, pakai, gosend, biar,...
# 2  [cepat, meresap, ringan, kulit, wajah, cuman, ...
# 3  [seller, cepat, memproses, barang, packing, am...
# 4                             [cocok, kulit, normal]
#
#                                review_tokens_stemmed
# 0                                [no, review, found]
# 1  [kirim, senenggakja, pakai, gosend, biar, cepa...
# 2  [cepat, resap, ringan, kulit, wajah, cuman, dr...
# 3  [seller, cepat, proses, barang, packing, aman,...
# 4                             [cocok, kulit, normal]

# %%
# import hasil preprocessing menjadi csv
df.to_csv("lemma.csv")
