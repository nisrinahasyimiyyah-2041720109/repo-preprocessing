# %%
# Load data ke dalam data frame 
import pandas as pd

# Spesifikasi encoding diperlukan karena data tidak menggunakan UTF-8
df = pd.read_csv('scraping_somethinc.csv', encoding='latin-1')

df.head()
# Out:
#                                               Review  \
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2                            masalah kulitku kerutan
# 3  bagus banget lip tint nya warnanya jg bagus2, ...
# 4  expire 2026, pengiriman cepat. cocok asal peng...
#
#                                              Product     Rating Username  \
# 0             SOMETHINC BAKUCHIOL Skinpair Oil Serum  bintang 5    A***y
# 1     SOMETHINC CERAMIC SKIN Saviour Moisturizer Gel  bintang 5    A***y
# 2         SOMETHINC HYALuronic9+ Advanced + B5 Serum  bintang 5    A***y
# 3  SOMETHINC Holiday Lip Tint Kit (Ombrella Lip T...  bintang 5  rohimah
# 4  SOMETHINC AHA 7%, BHA 1%, PHA 3% Weekly Peelin...  bintang 5    n***a
#
#         Date
# 0  1/30/2024
# 1  1/30/2024
# 2  1/30/2024
# 3  1/30/2024
# 4  1/30/2024

# %%
# Drop kolom yang tidak terpakai
df = df.drop(df.iloc[:,1:], axis=1)

# Cek data teratas
df.head()
# Out:
#                                               Review
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2                            masalah kulitku kerutan
# 3  bagus banget lip tint nya warnanya jg bagus2, ...
# 4  expire 2026, pengiriman cepat. cocok asal peng...

# %% [markdown]
# PREPROCESSING

# %%
# PROSES CASE FOLDING (menjadikan semua huruf di kolom Review menjadi huruf kecil)
df['Review'] = df['Review'].str.lower()

print('Case Folding Result: \n')
df.head()
# Out:
# Case Folding Result:
#                                               Review
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2                            masalah kulitku kerutan
# 3  bagus banget lip tint nya warnanya jg bagus2, ...
# 4  expire 2026, pengiriman cepat. cocok asal peng...

# %%
# import hasil case folding menjadi csv
df.to_csv("casefolding_somethinc.csv")

# %%
# CLEANING
import re # regex library

def remove_tweet_special(text):
    # remove tab, new line, and back slice
    text = text.replace('\\t'," ").replace('\\n', " ").replace('\\u', " ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

df['Review'] = df['Review'].apply(remove_tweet_special)

# remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Review'] = df['Review'].apply(remove_number)

# remove punctuation and replace with space
def remove_punctuation(text):
    return re.sub(r'[.,]', ' ', text)

df['Review'] = df['Review'].apply(remove_punctuation)

# remove punctuation
def remove_symbol(text):
    # Menghapus simbol-simbol tidak standar dan menggantinya dengan spasi
    cleaned_text = re.sub(r'[^\w\s]', ' ', text)
    
    # Menghapus multiple whitespace
    cleaned_text = re.sub('\s+', ' ', cleaned_text).strip()
    
    return cleaned_text

df['Review'] = df['Review'].apply(remove_symbol)

# Menentukan ambang batas panjang string acak
threshold_length = 20

# Fungsi untuk menghapus string acak berdasarkan panjangnya
def hapus_string_acak_dengan_panjang(text):
    # Memeriksa panjang string dan menghapus jika melebihi ambang batas
    return ' '.join(word for word in text.split() if len(word) <= threshold_length)

# Menggunakan fungsi untuk menghapus string acak pada kolom 'Text'
df['Review'] = df['Review'].apply(hapus_string_acak_dengan_panjang)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Review'] = df['Review'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['Review'] = df['Review'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Review'] = df['Review'].apply(remove_single_char)

def remove_laughter(text):
    laughter_patterns = r'\b((ha)+h*|(he)+h*|(hi)+h*|(wk)+w*k*|(eh)+e*|(ah)+a*|(ih)+i*|(kw)+k*w*|(hem)+m*)\b'
    return re.sub(laughter_patterns, '', text, flags=re.IGNORECASE)

df['Review'] = df['Review'].apply(remove_laughter)

print('Cleaning Result : \n') 
print(df.head())
# Out:
# Cleaning Result :
#
#                                               Review
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2                            masalah kulitku kerutan
# 3  bagus banget lip tint nya warnanya jg bagus ke...
# 4  expire pengiriman cepat cocok asal penggunaan ...

# %%
# import hasil cleaning menjadi csv
df.to_csv("cleaning_somethinc.csv")

# %%
# REMOVE DUPLICATE
df = df.drop_duplicates()
df = df.reset_index(drop=True)
# Menghapus baris yang kosong
df = df.dropna(subset=['Review'])
# Menghapus baris yang hanya berisi spasi atau whitespace
df = df[df['Review'].str.strip() != '']
df.head()
# Out:
#                                               Review
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2  bagus banget lip tint nya warnanya jg bagus ke...
# 3  expire pengiriman cepat cocok asal penggunaan ...
# 4                                    no review found

# %%
# import hasil remove duplicate menjadi csv
df.to_csv("removedup_somethinc.csv")

# %%
# NORMALIZATION
import pandas as pd
import re

slang_dictionary = pd.read_csv('../colloquial-indonesian-lexicon2.csv')
slang_dict = pd.Series(slang_dictionary['formal'].values,index=slang_dictionary['slang']).to_dict()

slang_dictionary.head()
# Out:
#      slang    formal  In-dictionary  \
# 0     woww       wow            1.0
# 1    aminn      amin            1.0
# 2      met   selamat            1.0
# 3   netaas   menetas            1.0
# 4  keberpa  keberapa            0.0
#
#                                              context  category1 category2  \
# 0                                                wow   elongasi         0
# 1  Selamat ulang tahun kakak tulus semoga panjang...   elongasi         0
# 2  Met hari netaas kak!? Wish you all the best @t...  abreviasi         0
# 3  Met hari netaas kak!? Wish you all the best @t...   afiksasi  elongasi
# 4                           Birthday yg keberpa kak?  abreviasi         0
#
#   category3
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# Normalisasi kata menggunakan kamus colloquial-indonesian-lexicon2.csv
def Slangwords(text, slang_dict):
    for word in text.split():
        if word in slang_dict.keys():
            # menambahkan \b untuk menandakan batas kata di sekitar kata slang
            text = re.sub(r'\b{}\b'.format(re.escape(word)), slang_dict[word], text)
    
    text = re.sub('@[\w]+', '', text)
    return text

df['Review_norm'] = df['Review'].apply(lambda x: Slangwords(x, slang_dict))
print(df.head())
# Out:
#                                               Review  \
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2  bagus banget lip tint nya warnanya jg bagus ke...
# 3  expire pengiriman cepat cocok asal penggunaan ...
# 4                                    no review found
#
#                                          Review_norm
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2  bagus banget lip tint nya warnanya juga bagus ...
# 3  expire pengiriman cepat cocok asal penggunaan ...
# 4                                    no review found

# %%
# import hasil replace slang words menjadi csv
df.to_csv("normalization_somethinc.csv")

# %%
# PROSES TOKENIZING (word_tokenize() untuk memecah string kedalam tokens)

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Tokenizing
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['review_tokens'] = df['Review_norm'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df.head())
# Out:
# Tokenizing Result :
#
#                                               Review  \
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2  bagus banget lip tint nya warnanya jg bagus ke...
# 3  expire pengiriman cepat cocok asal penggunaan ...
# 4                                    no review found
#
#                                          Review_norm  \
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2  bagus banget lip tint nya warnanya juga bagus ...
# 3  expire pengiriman cepat cocok asal penggunaan ...
# 4                                    no review found
#
#                                        review_tokens
# 0                        [masalah, kulitku, kerutan]
# 1                            [tipe, kulitku, kering]
# 2  [bagus, banget, lip, tint, nya, warnanya, juga...
# 3  [expire, pengiriman, cepat, cocok, asal, pengg...
# 4                                [no, review, found]

# %%
# import hasil tokenizing menjadi csv
df.to_csv("tokenizing_somethinc.csv")

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
# PROSES FILTERING (Stopword Removal) menggunakan library sastrawi
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

# remove stopword pada list token
def stopwords_removal(words):
    filtered_words = [stopword.remove(w) for w in words]
    filtered_words = [word for word in filtered_words if word != '']  # Memfilter kata-kata kosong
    return filtered_words

df['review_tokens_SR'] = df['review_tokens'].apply(stopwords_removal) 

print(df.head())
# Out:
#                                               Review  \
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2  bagus banget lip tint nya warnanya jg bagus ke...
# 3  expire pengiriman cepat cocok asal penggunaan ...
# 4                                    no review found
#
#                                          Review_norm  \
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2  bagus banget lip tint nya warnanya juga bagus ...
# 3  expire pengiriman cepat cocok asal penggunaan ...
# 4                                    no review found
#
#                                        review_tokens  \
# 0                        [masalah, kulitku, kerutan]
# 1                            [tipe, kulitku, kering]
# 2  [bagus, banget, lip, tint, nya, warnanya, juga...
# 3  [expire, pengiriman, cepat, cocok, asal, pengg...
# 4                                [no, review, found]
#
#                                     review_tokens_SR
# 0                        [masalah, kulitku, kerutan]
# 1                            [tipe, kulitku, kering]
# 2  [bagus, banget, lip, tint, nya, warnanya, bagu...
# 3  [expire, pengiriman, cepat, cocok, asal, pengg...
# 4                                [no, review, found]

# %%
# import hasil stopword removal menjadi csv
df.to_csv("stopword_somethinc.csv")

# %%
# PROSES LEMMATIZATION 
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['review_tokens_SR']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['review_tokens_stemmed'] = df['review_tokens_SR'].swifter.apply(get_stemmed_term)
print(df['review_tokens_stemmed'])
print(df.head())
# Out:
# 1054
# ------------------------
# masalah : masalah
# kulitku : kulit
# kerutan : kerut
# tipe : tipe
# kering : kering
# bagus : bagus
# banget : banget
# lip : lip
# tint : tint
# nya : nya
# warnanya : warna
# kemasannya : kemas
# gemas : gemas
# kecil : kecil
# terima : terima
# kasih : kasih
# expire : expire
# pengiriman : kirim
# cepat : cepat
# cocok : cocok
# asal : asal
# penggunaan : guna
# sesuai : sesuai
# instruksi : instruksi
# no : no
# review : review
# found : found
# gift : gift
# pembelian : beli
# lucu : lucu
# suka : suka
# ringan : ringan
# kayak : kayak
# enggak : enggak
# pakai : pakai
# apa : apa
# terus : terus
# benaran : benar
# transferproof : transferproof
# mana : mana
# design : design
# sensitif : sensitif
# bikin : bikin
# sama : sama
# sekali : sekali
# datang : datang
# estimasi : estimasi
# packing : packing
# aman : aman
# jne : jne
# tokopedia : tokopedia
# pertama : pertama
# coba : coba
# nih : nih
# serum : serum
# moga : moga
# kurir : kurir
# top : top
# berminyak : minyak
# jerawat : jerawat
# pori : pori
# besar : besar
# retinolnya : retinolnya
# somethinc : somethinc
# warna : warna
# pas : pas
# coverage : coverage
# buatku : buat
# bedak : bedak
# awalnya : awal
# memang : memang
# abu : abu
# dikulit : kulit
# kalo : kalo
# meresap : resap
# good : good
# diamond : diamond
# enak : enak
# dipakai : pakai
# lemonade : lemonade
# ku : ku
# baru : baru
# mau : mau
# semoga : moga
# aplikatornya : aplikatornya
# fast : fast
# response : response
# on : on
# time : time
# delivery : delivery
# tqpi : tqpi
# lainnya : lain
# kesekian : sekian
# kali : kali
# kulit : kulit
# sejauh : jauh
# perubahan : ubah
# signifikan : signifikan
# jadi : jadi
# beli : beli
# pelembab : pelembab
# selalu : selalu
# siang : siang
# malam : malam
# lebih : lebih
# packaging : packaging
# ml : ml
# kontrol : kontrol
# pemakaiannya : pakai
# kebanyakan : banyak
# menempel : tempel
# muka : muka
# mencoba : coba
# produk : produk
# skin : skin
# care : care
# beberapa : beberapa
# bulu : bulu
# mata : mata
# lentik : lentik
# awet : awet
# first : first
# moist : moist
# min : min
# dikasih : kasih
# bonus : bonus
# sukses : sukses
# best : best
# matte : matte
# lipstick : lipstick
# repeat : repeat
# order : order
# kalinya : kali
# tak : tak
# terhitung : hitung
# favourite : favourite
# normal : normal
# alhamdulillah : alhamdulillah
# diskonan : diskon
# kak : kak
# wanginya : wangi
# soft : soft
# encer : encer
# dicoba : coba
# dulu : dulu
# thanks : thanks
# orisinal : orisinal
# paket : paket
# diterima : terima
# baik : baik
# packagingnya : packagingnya
# istri : istri
# senang : senang
# deskripsi : deskripsi
# seller : seller
# barang : barang
# aku : aku
# kombinasi : kombinasi
# harga : harga
# promo : promo
# padahal : padahal
# ditulisannya : tulis
# eyelashes : eyelashes
# curler : curler
# dong : dong
# huhu : huhu
# thank : thank
# you : you
# perfect : perfect
# shade : shade
# terbaik : baik
# favorite : favorite
# seminggu : minggu
# bacne : bacne
# mulai : mulai
# hilang : hilang
# purgingnya : purgingnya
# mateng : mateng
# habis : habis
# dikit : dikit
# isinya : isi
# mungkin : mungkin
# pakenya : pakenya
# terlalu : terlalu
# banyak : banyak
# nice : nice
# biasanya : biasa
# jar : jar
# ver : ver
# refilnya : refilnya
# pernah : pernah
# luka : luka
# hitam : hitam
# tertarik : tarik
# kulitnya : kulit
# benar : benar
# sembuh : sembuh
# bekasnya : bekas
# pudar : pudar
# ribu : ribu
# cleansing : cleansing
# keren : keren
# selamat : selamat
# disini : sini
# ngurangin : ngurangin
# garis : garis
# halus : halus
# kerut : kerut
# mantap : mantap
# diskon : diskon
# next : next
# pesanan : pesan
# bocor : bocor
# recomended : recomended
# weh : weh
# sat : sat
# set : set
# tiap : tiap
# pagi : pagi
# buat : buat
# super : super
# keringetan : keringetan
# transfer : transfer
# cuma : cuma
# heboh : heboh
# pastinya : pasti
# original : original
# cakep : cakep
# hasil : hasil
# tahan : tahan
# lama : lama
# teksturnya : tekstur
# cair : cair
# mudah : mudah
# gunakan : guna
# sih : sih
# ketahanannya : tahan
# diaplikasikannya : aplikasi
# respon : respon
# diupdate : diupdate
# rapi : rapi
# tokped : tokped
# texture : texture
# baunya : bau
# kurang : kurang
# biasa : biasa
# ditoleransi : toleransi
# kok : kok
# ukuran : ukur
# mengira : ira
# airless : airless
# pump : pump
# ternyata : nyata
# overall : overall
# pemakaian : pakai
# tetap : tetap
# coveragenya : coveragenya
# tipis : tipis
# sering : sering
# hooman : hooman
# copy : copy
# paste : paste
# cushion : cushion
# perle : perle
# fair : fair
# dempulnya : dempul
# tau : tau
# malah : malah
# muncul : muncul
# btw : btw
# merk : merk
# kebetulan : betul
# checkout : checkout
# tadinya : tadi
# diofflinestore : diofflinestore
# mahal : mahal
# cek : cek
# dionline : dionline
# store : store
# potongan : potong
# flashsale : flashsale
# langsung : langsung
# tumben : tumben
# rangkaian : rangkai
# semingguan : minggu
# bruntusan : bruntusan
# efek : efek
# samping : samping
# pengirimannya : kirim
# cukup : cukup
# dikirimkan : kirim
# expired : expired
# datenya : datenya
# lipstiknya : lipstik
# patah : patah
# saran : saran
# kalau : kalau
# jangan : jangan
# diulur : ulur
# panjang : panjang
# lengkap : lengkap
# productnya : productnya
# bacanya : baca
# mudahan : mudah
# bonusnya : bonus
# butuh : butuh
# biji : biji
# pipi : pipi
# meradang : radang
# besoknya : besok
# mendingan : mending
# kempes : kempes
# sebenarnya : benar
# jatuhnya : jatuh
# bibir : bibir
# walaupun : walaupun
# lipbalm : lipbalm
# pigmented : pigmented
# merah : merah
# queennya : queennya
# exp : exp
# date : date
# diskonnya : diskon
# lumayan : lumayan
# teman : teman
# rekomen : rekomen
# kiriman : kirim
# lembut : lembut
# free : free
# penjepit : jepit
# youu : youu
# teruntuk : untuk
# gtl : gtl
# anter : anter
# jam : jam
# hujan : hujan
# seharian : hari
# lembur : lembur
# gtr : gtr
# simple : simple
# dibawa : bawa
# cuci : cuci
# tangan : tangan
# namanya : nama
# wrappingnya : wrappingnya
# bubble : bubble
# wrap : wrap
# bersegel : segel
# senangnya : senang
# kipas : kipas
# mini : mini
# semiga : semiga
# acne : acne
# hempas : hempas
# pelayanan : layan
# oke : oke
# shadenya : shadenya
# full : full
# menahan : tahan
# minyak : minyak
# hasilnya : hasil
# foundi : foundi
# alus : alus
# alami : alami
# jatuh : jatuh
# cinta : cinta
# kirimnya : kirim
# plus : plus
# dus : dus
# sip : sip
# komentar : komentar
# datangnya : datang
# meskipun : meski
# diberikan : beri
# box : box
# mengadakan : ada
# pengemasan : emas
# brang : brang
# belanja : belanja
# flash : flash
# sale : sale
# gan : gan
# rban : rban
# lembab : lembab
# giftnya : giftnya
# sedikit : sedikit
# lah : lah
# komplain : komplain
# imut : imut
# match : match
# sawo : sawo
# matang : matang
# sensasi : sensasi
# aroma : aroma
# mint : mint
# loose : loose
# powdernya : powdernya
# love : love
# pecah : pecah
# up : up
# bottle : bottle
# higenis : higenis
# pipet : pipet
# menyerap : serap
# lengket : lengket
# berbau : bau
# fragrance : fragrance
# rasa : rasa
# layer : layer
# netral : netral
# soothing : soothing
# kualitasnya : kualitas
# putih : putih
# kelihatan : lihat
# retinol : retinol
# proses : proses
# kirim : kirim
# pesan : pesan
# same : same
# day : day
# dikirim : kirim
# hari : hari
# untungnya : untung
# besok : besok
# paginya : pagi
# jarak : jarak
# setahun : tahun
# jari : jari
# bismillah : bismillah
# berhasil : hasil
# membantu : bantu
# ngurangi : ngurangi
# dipakek : dipakek
# busanya : busa
# gabanyak : gabanyak
# kualitas : kualitas
# ontime : ontime
# produknya : produk
# blend : blend
# wajah : wajah
# terlihat : lihat
# natural : natural
# oily : oily
# air : air
# minim : minim
# gampang : gampang
# break : break
# out : out
# medan : medan
# sayangnya : sayang
# jasa : jasa
# rekomendasi : rekomendasi
# kadang : kadang
# bermasalah : masalah
# nyasar : nyasar
# diperhatikan : perhati
# bekerjasama : bekerjasama
# baiknya : baik
# ajukan : aju
# menunggu : tunggu
# maksimal : maksimal
# pembeli : beli
# panik : panik
# duluan : duluan
# paketnya : paket
# rumah : rumah
# orang : orang
# entah : entah
# kabar : kabar
# dibilang : bilang
# gatal : gatal
# panas : panas
# tidur : tidur
# tanya : tanya
# admin : admin
# chat : chat
# sebelumnya : belum
# keluhan : keluh
# direkomendasi : rekomendasi
# tengah : tengah
# bangun : bangun
# kuat : kuat
# sampainya : sampai
# kemarin : kemarin
# wajahku : wajah
# glowing : glowing
# penipu : tipu
# rasanya : rasa
# nyaman : nyaman
# dibuatkan : buat
# premium : premium
# barangnya : barang
# berguna : guna
# pack : pack
# cepaat : cepaat
# yeaaaay : yeaaaay
# niat : niat
# eyeliner : eyeliner
# nina : nina
# moisturizer : moisturizer
# andalan : andal
# under : under
# tone : tone
# warm : warm
# facial : facial
# wash : wash
# favorit : favorit
# membersihkan : bersih
# pcs : pcs
# murah : murah
# satuan : satu
# ribuan : ribu
# sayang : sayang
# ed : ed
# awal : awal
# yeayyy : yeayyy
# finally : finally
# aplikasinya : aplikasi
# mbleber : mbleber
# ujungnya : ujung
# runcing : runcing
# jetblack : jetblack
# seharii : hari
# cool : cool
# lipsticknya : lipsticknya
# sangat : sangat
# light : light
# recommended : recommended
# for : for
# daily : daily
# use : use
# sunscreennya : sunscreennya
# berat : berat
# sunscreen : sunscreen
# lighter : lighter
# foundie : foundie
# finishingnya : finishingnya
# dewy : dewy
# average : average
# easy : easy
# kerusakan : rusa
# zone : zone
# minyakan : minyak
# makin : makin
# soalnya : soal
# parah : parah
# cus : cus
# waterproof : waterproof
# pensil : pensil
# kotak : kotak
# skincare : skincare
# lokal : lokal
# happy : happy
# semua : semua
# kupake : kupake
# great : great
# cashback : cashback
# maa : maa
# syaa : syaa
# allah : allah
# semriwing : semriwing
# wow : wow
# gagal : gagal
# beneran : beneran
# safety : safety
# didalamnya : dalam
# dilapis : lap
# maaf : maaf
# luntur : luntur
# esok : esok
# harinya : hari
# soleyn : soleyn
# coral : coral
# coklat : coklat
# muda : muda
# aebelum : aebelum
# swipe : swipe
# translucent : translucent
# menghaluskan : halus
# menutup : tutup
# noda : noda
# bekas : bekas
# fungsi : fungsi
# setting : setting
# powder : powder
# berlangganan : langgan
# kinclong : kinclong
# sekampung : kampung
# menyangka : sangka
# korea : korea
# luber : luber
# tiba : tiba
# scent : scent
# gum : gum
# jadul : jadul
# greasy : greasy
# white : white
# cast : cast
# sedang : sedang
# terjangkau : jangkau
# worth : worth
# try : try
# test : test
# not : not
# biasamya : biasamya
# pki : pki
# sinscreen : sinscreen
# skinti : skinti
# pricey : pricey
# fotonya : foto
# bulan : bulan
# kesempatan : sempat
# update : update
# barrier : barrier
# penuh : penuh
# rutin : rutin
# olahraga : olahraga
# luar : luar
# jadinya : jadi
# kusam : kusam
# dunia : dunia
# perputihan : putih
# kondisi : kondisi
# walopun : walopun
# spray : spray
# botol : botol
# dikocok : kocok
# beleber : beber
# bijoux : bijoux
# versatile : versatile
# kedepannya : depan
# kagak : kagak
# pacaking : pacaking
# product : product
# tekstur : tekstur
# kental : kental
# bukan : bukan
# wangi : wangi
# permen : permen
# karet : karet
# suguss : suguss
# menyengat : sengat
# kinerja : kerja
# terasa : asa
# minggu : minggu
# hangover : hangover
# mascara : mascara
# harapan : harap
# omega : omega
# butter : butter
# gel : gel
# pencil : pencil
# kecintaan : cinta
# biar : biar
# kena : kena
# wudhu : wudhu
# secinta : cinta
# kecewain : kecewain
# lalu : lalu
# akhirnya : akhir
# sekarang : sekarang
# digunakan : guna
# salah : salah
# satu : satu
# incaran : incar
# real : real
# spf : spf
# whitecast : whitecast
# cowok : cowok
# dinginnya : dingin
# gelap : gelap
# senempel : senempel
# bakal : bakal
# ahahhaa : ahahhaa
# euyy : euyy
# prosesnya : proses
# cck : cck
# cermin : cermin
# hore : hore
# fitur : fitur
# ambil : ambil
# tempat : tempat
# perlu : perlu
# ribet : ribet
# ganti : ganti
# alamat : alamat
# raja : raja
# ampat : ampat
# lihat : lihat
# beauty : beauty
# influencers : influencers
# sebagus : bagus
# touch : touch
# purrrrfect : purrrrfect
# type : type
# combination : combination
# undertone : undertone
# kotaknya : kotak
# matt : matt
# smooth : smooth
# diblend : diblend
# alhamdulilah : alhamdulilah
# kenyal : kenyal
# sempurna : sempurna
# bersihin : bersihin
# memakai : pakai
# tebal : tebal
# berasa : asa
# bersih : bersih
# setelahnya : telah
# abuan : abuan
# bermunculan : muncul
# timbul : timbul
# bl : bl
# list : list
# praktis : praktis
# keluarga : keluarga
# tua : tua
# ketiga : tiga
# khasiatnya : khasiat
# impressive : impressive
# but : but
# menghidrasi : hidrasi
# undereye : undereye
# disayangkan : sayang
# kemasan : kemas
# merasa : rasa
# simpan : simpan
# sembarangan : sembarang
# bagian : bagi
# tutupan : tutup
# sendirinya : sendiri
# ceroboh : ceroboh
# sempat : sempat
# ngejatohin : ngejatohin
# retak : retak
# kayaknya : kayak
# plastiknya : plastik
# diperbaiki : baik
# menjadi : jadi
# somethic : somethic
# meragukan : ragu
# mesennya : mesennya
# telat : telat
# waktu : waktu
# libur : libur
# gercep : gercep
# ngirimnya : ngirimnya
# ekspektasi : ekspektasi
# tahun : tahun
# so : so
# far : far
# check : check
# tentukan : tentu
# filter : filter
# ig : ig
# official : official
# account : account
# pastikan : pasti
# pencahayaan : cahaya
# lightweight : lightweight
# oksidasi : oksidasi
# nyatu : nyatu
# wajar : wajar
# reapply : reapply
# niacinemade : niacinemade
# mencerahkan : cerah
# tersegel : segel
# kardus : kardus
# hayg : hayg
# savage : savage
# medium : medium
# sehari : hari
# iritasi : iritasi
# isi : isi
# fulll : fulll
# punggung : punggung
# keluar : keluar
# dingin : dingin
# kecewa : kecewa
# terhapus : hapus
# brand : brand
# termasuk : masuk
# kesalah : salah
# suudzon : suudzon
# berbeda : beda
# keaslian : asli
# percaya : percaya
# dipastikan : pasti
# mohon : mohon
# teliti : teliti
# toner : toner
# viral : viral
# fiks : fiks
# checkmatte : checkmatte
# joker : joker
# asli : asli
# wah : wah
# berkurang : kurang
# haluus : haluus
# efektif : efektif
# dempul : dempul
# kemudian : kemudian
# ngeblend : ngeblend
# sore : sore
# diproses : proses
# kekurangan : kurang
# lubang : lubang
# bedaknya : bedak
# dibanding : banding
# sponsnya : spons
# cara : cara
# dibalik : balik
# berceceran : cecer
# sekelilingnya : keliling
# repurchase : repurchase
# liptintnya : liptintnya
# ampuh : ampuh
# deh : deh
# calming : calming
# akhir : akhir
# thick : thick
# padat : padat
# berminysk : berminysk
# fruity : fruity
# sepertinya : seperti
# perih : perih
# dimata : mata
# lupa : lupa
# sellernya : sellernya
# barusan : barusan
# swatch : swatch
# shades : shades
# coklatnya : coklat
# terang : terang
# tadi : tadi
# dihapus : hapus
# babang : babang
# bro : bro
# bantu : bantu
# perasaanku : asa
# formulanya : formula
# perasaan : asa
# punyaku : punya
# sblomnya : sblomnya
# kentel : kentel
# ditetesin : ditetesin
# mengalir : alir
# bwh : bwh
# pink : pink
# honestly : honestly
# kayanya : kaya
# dimuka : muka
# cushionnya : cushionnya
# refillnya : refillnya
# mukaku : muka
# segini : gin
# minyakku : minyak
# acara : acara
# wisuda : wisuda
# lanjut : lanjut
# gereja : gereja
# se : se
# kilang : kilang
# niatnya : niat
# menambah : tambah
# tambah : tambah
# masuk : masuk
# tas : tas
# always : always
# voucher : voucher
# eyelash : eyelash
# gratis : gratis
# kedua : dua
# botolnya : botol
# rusak : rusak
# keras : keras
# susah : susah
# diteken : teken
# foamnya : foamnya
# tuang : tuang
# cairan : cair
# sabun : sabun
# cici : cici
# biarpun : biarpun
# seri : seri
# imutnya : imutnya
# siap : siap
# brangkat : brangkat
# traveling : traveling
# an : an
# bawa : bawa
# gede : gede
# sebulan : bulan
# jujur : jujur
# oil : oil
# bakuchiol : bakuchiol
# masa : masa
# agustus : agustus
# sensai : sensai
# serumnya : serum
# lipstik : lipstik
# spatulanya : spatula
# aplikasi : aplikasi
# cantik : cantik
# aaa : aaa
# direfund : direfund
# aaaaaaaa : aaaaaaaa
# grandmaster : grandmaster
# mumpung : mumpung
# bahannya : bahan
# kuliat : liat
# cenderung : cenderung
# mengecewakan : kecewa
# as : as
# ekspedisi : ekspedisi
# slowresp : slowresp
# status : status
# well : well
# received : received
# yakin : yakin
# selevel : level
# begini : begini
# packingnya : packingnya
# kan : kan
# dicongkel : congkel
# boxnya : boxnya
# beri : beri
# plastik : plastik
# luarnya : luar
# mengingat : ingat
# musim : musim
# rembesan : rembes
# masukan : masuk
# tim : tim
# enakan : enak
# lipcream : lipcream
# langganan : langgan
# bundle : bundle
# buy : buy
# get : get
# silk : silk
# creme : creme
# alasan : alas
# dilayani : layan
# otomatis : otomatis
# pilih : pilih
# and : and
# berharap : harap
# kekurangannya : kurang
# tinted : tinted
# klaimnya : klaim
# ditambah : tambah
# the : the
# oekk : oekk
# gratisan : gratis
# bzier : bzier
# tifak : tifak
# lofyuu : lofyuu
# pikir : pikir
# jomplang : jomplang
# cerah : cerah
# kaya : kaya
# foundy : foundy
# nyerap : nyerap
# mate : mate
# glow : glow
# secocok : cocok
# enaknya : enak
# cemong : cemong
# micellarnya : micellarnya
# sekian : sekian
# cleanser : cleanser
# seenak : enak
# jerawatan : jerawat
# bermerah : merah
# nenangin : nenangin
# pokoknya : pokok
# pol : pol
# terniat : niat
# drl : drl
# ramah : ramah
# mattenya : mattenya
# thankyou : thankyou
# somethinccc : somethinccc
# calm : calm
# down : down
# packingan : packingan
# detailnya : detail
# pengepakan : epak
# expnya : expnya
# save : save
# package : package
# ketarinya : ketar
# gentle : gentle
# daya : daya
# pembersihnya : bersih
# samtink : samtink
# hahahha : hahahha
# berhenti : henti
# paling : paling
# penting : penting
# mah : mah
# berkali : kali
# yeay : yeay
# dana : dana
# pedih : pedih
# makeup : makeup
# bahkan : bahkan
# creamy : creamy
# merek : merek
# sebelah : belah
# gavocok : gavocok
# alis : alis
# melebar : lebar
# ahli : ahli
# texturenya : texturenya
# muat : muat
# case : case
# meski : meski
# balik : balik
# kerja : kerja
# ngeblur : ngeblur
# imperfection : imperfection
# samplenya : samplenya
# fullnya : fullnya
# long : long
# term : term
# walo : walo
# subs : subs
# rada : rada
# please : please
# dibenahin : dibenahin
# bingung : bingung
# menutupi : tutup
# kemerahan : merah
# kuning : kuning
# smugeproof : smugeproof
# loh : loh
# pigment : pigment
# merata : rata
# bakalan : bakal
# nilai : nilai
# gapaham : gapaham
# works : works
# feel : feel
# dimukanya : muka
# miring : miring
# angin : angin
# adem : adem
# mukanya : muka
# yaudah : yaudah
# salahku : salah
# sehat : sehat
# {'masalah': 'masalah', 'kulitku': 'kulit', 'kerutan': 'kerut', 'tipe': 'tipe', 'kering': 'kering', 'bagus': 'bagus', 'banget': 'banget', 'lip': 'lip', 'tint': 'tint', 'nya': 'nya', 'warnanya': 'warna', 'kemasannya': 'kemas', 'gemas': 'gemas', 'kecil': 'kecil', 'terima': 'terima', 'kasih': 'kasih', 'expire': 'expire', 'pengiriman': 'kirim', 'cepat': 'cepat', 'cocok': 'cocok', 'asal': 'asal', 'penggunaan': 'guna', 'sesuai': 'sesuai', 'instruksi': 'instruksi', 'no': 'no', 'review': 'review', 'found': 'found', 'gift': 'gift', 'pembelian': 'beli', 'lucu': 'lucu', 'suka': 'suka', 'ringan': 'ringan', 'kayak': 'kayak', 'enggak': 'enggak', 'pakai': 'pakai', 'apa': 'apa', 'terus': 'terus', 'benaran': 'benar', 'transferproof': 'transferproof', 'mana': 'mana', 'design': 'design', 'sensitif': 'sensitif', 'bikin': 'bikin', 'sama': 'sama', 'sekali': 'sekali', 'datang': 'datang', 'estimasi': 'estimasi', 'packing': 'packing', 'aman': 'aman', 'jne': 'jne', 'tokopedia': 'tokopedia', 'pertama': 'pertama', 'coba': 'coba', 'nih': 'nih', 'serum': 'serum', 'moga': 'moga', 'kurir': 'kurir', 'top': 'top', 'berminyak': 'minyak', 'jerawat': 'jerawat', 'pori': 'pori', 'besar': 'besar', 'retinolnya': 'retinolnya', 'somethinc': 'somethinc', 'warna': 'warna', 'pas': 'pas', 'coverage': 'coverage', 'buatku': 'buat', 'bedak': 'bedak', 'awalnya': 'awal', 'memang': 'memang', 'abu': 'abu', 'dikulit': 'kulit', 'kalo': 'kalo', 'meresap': 'resap', 'good': 'good', 'diamond': 'diamond', 'enak': 'enak', 'dipakai': 'pakai', 'lemonade': 'lemonade', 'ku': 'ku', 'baru': 'baru', 'mau': 'mau', 'semoga': 'moga', 'aplikatornya': 'aplikatornya', 'fast': 'fast', 'response': 'response', 'on': 'on', 'time': 'time', 'delivery': 'delivery', 'tqpi': 'tqpi', 'lainnya': 'lain', 'kesekian': 'sekian', 'kali': 'kali', 'kulit': 'kulit', 'sejauh': 'jauh', 'perubahan': 'ubah', 'signifikan': 'signifikan', 'jadi': 'jadi', 'beli': 'beli', 'pelembab': 'pelembab', 'selalu': 'selalu', 'siang': 'siang', 'malam': 'malam', 'lebih': 'lebih', 'packaging': 'packaging', 'ml': 'ml', 'kontrol': 'kontrol', 'pemakaiannya': 'pakai', 'kebanyakan': 'banyak', 'menempel': 'tempel', 'muka': 'muka', 'mencoba': 'coba', 'produk': 'produk', 'skin': 'skin', 'care': 'care', 'beberapa': 'beberapa', 'bulu': 'bulu', 'mata': 'mata', 'lentik': 'lentik', 'awet': 'awet', 'first': 'first', 'moist': 'moist', 'min': 'min', 'dikasih': 'kasih', 'bonus': 'bonus', 'sukses': 'sukses', 'best': 'best', 'matte': 'matte', 'lipstick': 'lipstick', 'repeat': 'repeat', 'order': 'order', 'kalinya': 'kali', 'tak': 'tak', 'terhitung': 'hitung', 'favourite': 'favourite', 'normal': 'normal', 'alhamdulillah': 'alhamdulillah', 'diskonan': 'diskon', 'kak': 'kak', 'wanginya': 'wangi', 'soft': 'soft', 'encer': 'encer', 'dicoba': 'coba', 'dulu': 'dulu', 'thanks': 'thanks', 'orisinal': 'orisinal', 'paket': 'paket', 'diterima': 'terima', 'baik': 'baik', 'packagingnya': 'packagingnya', 'istri': 'istri', 'senang': 'senang', 'deskripsi': 'deskripsi', 'seller': 'seller', 'barang': 'barang', 'aku': 'aku', 'kombinasi': 'kombinasi', 'harga': 'harga', 'promo': 'promo', 'padahal': 'padahal', 'ditulisannya': 'tulis', 'eyelashes': 'eyelashes', 'curler': 'curler', 'dong': 'dong', 'huhu': 'huhu', 'thank': 'thank', 'you': 'you', 'perfect': 'perfect', 'shade': 'shade', 'terbaik': 'baik', 'favorite': 'favorite', 'seminggu': 'minggu', 'bacne': 'bacne', 'mulai': 'mulai', 'hilang': 'hilang', 'purgingnya': 'purgingnya', 'mateng': 'mateng', 'habis': 'habis', 'dikit': 'dikit', 'isinya': 'isi', 'mungkin': 'mungkin', 'pakenya': 'pakenya', 'terlalu': 'terlalu', 'banyak': 'banyak', 'nice': 'nice', 'biasanya': 'biasa', 'jar': 'jar', 'ver': 'ver', 'refilnya': 'refilnya', 'pernah': 'pernah', 'luka': 'luka', 'hitam': 'hitam', 'tertarik': 'tarik', 'kulitnya': 'kulit', 'benar': 'benar', 'sembuh': 'sembuh', 'bekasnya': 'bekas', 'pudar': 'pudar', 'ribu': 'ribu', 'cleansing': 'cleansing', 'keren': 'keren', 'selamat': 'selamat', 'disini': 'sini', 'ngurangin': 'ngurangin', 'garis': 'garis', ' ...
# ------------------------
# Pandas Apply: 100%|██████████| 394/394 [00:00<00:00, 66210.82it/s]
# 0                                [masalah, kulit, kerut]
# 1                                  [tipe, kulit, kering]
# 2      [bagus, banget, lip, tint, nya, warna, bagus, ...
# 3      [expire, kirim, cepat, cocok, asal, guna, sesu...
# 4                                    [no, review, found]
#                              ...
# 390    [tipe, kulit, minyak, alhamdulillah, cocok, th...
# 391    [beli, serum, pas, harga, flash, sale, lumayan...
# 392    [jujur, buat, aku, enggak, cocok, aku, gapaham...
# 393    [hasil, akhir, bagus, kayak, kulit, bersih, se...
# 394                                  [bagus, tahan, air]
# Name: review_tokens_stemmed, Length: 394, dtype: object
#                                               Review  \
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2  bagus banget lip tint nya warnanya jg bagus ke...
# 3  expire pengiriman cepat cocok asal penggunaan ...
# 4                                    no review found
#
#                                          Review_norm  \
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2  bagus banget lip tint nya warnanya juga bagus ...
# 3  expire pengiriman cepat cocok asal penggunaan ...
# 4                                    no review found
#
#                                        review_tokens  \
# 0                        [masalah, kulitku, kerutan]
# 1                            [tipe, kulitku, kering]
# 2  [bagus, banget, lip, tint, nya, warnanya, juga...
# 3  [expire, pengiriman, cepat, cocok, asal, pengg...
# 4                                [no, review, found]
#
#                                     review_tokens_SR  \
# 0                        [masalah, kulitku, kerutan]
# 1                            [tipe, kulitku, kering]
# 2  [bagus, banget, lip, tint, nya, warnanya, bagu...
# 3  [expire, pengiriman, cepat, cocok, asal, pengg...
# 4                                [no, review, found]
#
#                                review_tokens_stemmed
# 0                            [masalah, kulit, kerut]
# 1                              [tipe, kulit, kering]
# 2  [bagus, banget, lip, tint, nya, warna, bagus, ...
# 3  [expire, kirim, cepat, cocok, asal, guna, sesu...
# 4                                [no, review, found]

# %%
# Menghapus baris yang kosong
df = df.dropna(subset=['review_tokens_stemmed'])
# Menghapus baris yang hanya berisi spasi atau whitespace
df = df[df['review_tokens_stemmed'].str.strip() != '']
# Menghapus baris yang memiliki list kosong
df = df[df['review_tokens_stemmed'].apply(lambda x: x != [])]
df.head(15)
# Out:
#                                                Review  \
# 0                             masalah kulitku kerutan
# 1                                 tipe kulitku kering
# 2   bagus banget lip tint nya warnanya jg bagus ke...
# 3   expire pengiriman cepat cocok asal penggunaan ...
# 4                                     no review found
# 5   dapet gift setiap pembelian lucu bgt sukaaa ma...
# 6   ringan banget kaya ga pake apa apa terus bener...
# 7   tipe kulitku sensitif dan cocok banget pake in...
# 8   datang sesuai estimasi pengiriman packing aman...
# 9   pertama coba nih serum moga cocok packing aman...
# 10                     suka sama retinolnya somethinc
# 11                      baguuus warna pas coverage ok
# 12  cocok buatku yg ga pake bedak awalnya emang ad...
# 13  diamond nak bgt dipake lemonade ku baru mau co...
# 14                         enak banget aplikatornyaaa
#
#                                           Review_norm  \
# 0                             masalah kulitku kerutan
# 1                                 tipe kulitku kering
# 2   bagus banget lip tint nya warnanya juga bagus ...
# 3   expire pengiriman cepat cocok asal penggunaan ...
# 4                                     no review found
# 5   dapat gift setiap pembelian lucu banget suka t...
# 6   ringan banget kayak enggak pakai apa apa terus...
# 7   tipe kulitku sensitif dan cocok banget pakai i...
# 8   datang sesuai estimasi pengiriman packing aman...
# 9   pertama coba nih serum moga cocok packing aman...
# 10                     suka sama retinolnya somethinc
# 11                        bagus warna pas coverage ok
# 12  cocok buatku yang enggak pakai bedak awalnya m...
# 13  diamond enak banget dipakai lemonade ku baru m...
# 14                           enak banget aplikatornya
#
#                                         review_tokens  \
# 0                         [masalah, kulitku, kerutan]
# 1                             [tipe, kulitku, kering]
# 2   [bagus, banget, lip, tint, nya, warnanya, juga...
# 3   [expire, pengiriman, cepat, cocok, asal, pengg...
# 4                                 [no, review, found]
# 5   [dapat, gift, setiap, pembelian, lucu, banget,...
# 6   [ringan, banget, kayak, enggak, pakai, apa, ap...
# 7   [tipe, kulitku, sensitif, dan, cocok, banget, ...
# 8   [datang, sesuai, estimasi, pengiriman, packing...
# 9   [pertama, coba, nih, serum, moga, cocok, packi...
# 10                [suka, sama, retinolnya, somethinc]
# 11                  [bagus, warna, pas, coverage, ok]
# 12  [cocok, buatku, yang, enggak, pakai, bedak, aw...
# 13  [diamond, enak, banget, dipakai, lemonade, ku,...
# 14                       [enak, banget, aplikatornya]
#
#                                      review_tokens_SR  \
# 0                         [masalah, kulitku, kerutan]
# 1                             [tipe, kulitku, kering]
# 2   [bagus, banget, lip, tint, nya, warnanya, bagu...
# 3   [expire, pengiriman, cepat, cocok, asal, pengg...
# 4                                 [no, review, found]
# 5   [gift, pembelian, lucu, banget, suka, terima, ...
# 6   [ringan, banget, kayak, enggak, pakai, apa, ap...
# 7   [tipe, kulitku, sensitif, cocok, banget, pakai...
# 8   [datang, sesuai, estimasi, pengiriman, packing...
# 9   [pertama, coba, nih, serum, moga, cocok, packi...
# 10                [suka, sama, retinolnya, somethinc]
# 11                      [bagus, warna, pas, coverage]
# 12  [cocok, buatku, enggak, pakai, bedak, awalnya,...
# 13  [diamond, enak, banget, dipakai, lemonade, ku,...
# 14                       [enak, banget, aplikatornya]
#
#                                 review_tokens_stemmed
# 0                             [masalah, kulit, kerut]
# 1                               [tipe, kulit, kering]
# 2   [bagus, banget, lip, tint, nya, warna, bagus, ...
# 3   [expire, kirim, cepat, cocok, asal, guna, sesu...
# 4                                 [no, review, found]
# 5     [gift, beli, lucu, banget, suka, terima, kasih]
# 6   [ringan, banget, kayak, enggak, pakai, apa, ap...
# 7   [tipe, kulit, sensitif, cocok, banget, pakai, ...
# 8   [datang, sesuai, estimasi, kirim, packing, ama...
# 9   [pertama, coba, nih, serum, moga, cocok, packi...
# 10                [suka, sama, retinolnya, somethinc]
# 11                      [bagus, warna, pas, coverage]
# 12  [cocok, buat, enggak, pakai, bedak, awal, mema...
# 13  [diamond, enak, banget, pakai, lemonade, ku, b...
# 14                       [enak, banget, aplikatornya]

# %%
# import hasil preprocessing menjadi csv
df.to_csv("lemma_somethinc.csv")
