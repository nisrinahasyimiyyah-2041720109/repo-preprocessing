# %%
# Load data ke dalam data frame 
import pandas as pd

# spesifikasi encoding diperlukan karena data tidak menggunakan UTF-8
df = pd.read_csv('scraping_skingame.csv', encoding='latin-1')

df.head()
# Out:
#                                               Review  \
# 0                                    No review found
# 1  pengiriman sengaja pakai gosend biar cepat, ta...
# 2  cepat meresap, ringan di kulit wajah, cuman bu...
# 3  Seller sangat cepat memproses barang. Packing ...
# 4                              Cocok di kulit normal
#
#                                              Product     Rating Username
# 0  Skin Game Kind Watery Moisturizer - Pelembab W...  bintang 5    Nurul
# 1  Skin Game Kind Watery Moisturizer - Pelembab W...  bintang 3   Firman
# 2             Skin Game Daily Kind Moisturizer 50 ml  bintang 5    I***y
# 3  Skin Game Kind Cream Moisturizer - Pelembab Wa...  bintang 5    Hesty
# 4  Skin Game Acne Warrior Paste 15 ml - Krim Jerawat  bintang 5    F***i

# %%
# Drop kolom yang tidak terpakai
df = df.drop(df.iloc[:,1:], axis=1)

# Cek data teratas
df.head()
# Out:
#                                               Review
# 0                                    No review found
# 1  pengiriman sengaja pakai gosend biar cepat, ta...
# 2  cepat meresap, ringan di kulit wajah, cuman bu...
# 3  Seller sangat cepat memproses barang. Packing ...
# 4                              Cocok di kulit normal

# %% [markdown]
# PREPROCESSING

# %%
# PROSES CASE FOLDING (menjadikan semua huruf di kolom content menjadi huruf kecil)
df['Review'] = df['Review'].str.lower()

print('Case Folding Result: \n')
df.head()
# Out:
# Case Folding Result:
#                                               Review
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat, ta...
# 2  cepat meresap, ringan di kulit wajah, cuman bu...
# 3  seller sangat cepat memproses barang. packing ...
# 4                              cocok di kulit normal

# %%
# import hasil case folding menjadi csv
df.to_csv("casefolding2.csv")

# %%
# CLEANING
import string
import re #regex library

def remove_tweet_special(text):
    #remove tab, new line, and back slice
    text = text.replace('\\t'," ").replace('\\n', " ").replace('\\u', " ").replace('\\',"")
    #remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

df['Review'] = df['Review'].apply(remove_tweet_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Review'] = df['Review'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df['Review'] = df['Review'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Review'] = df['Review'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['Review'] = df['Review'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Review'] = df['Review'].apply(remove_single_char)

print('Cleaning Result : \n') 
print(df.head())
# Out:
# Cleaning Result :
#
#                                               Review
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat tap...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal

# %%
# import hasil cleaning menjadi csv
df.to_csv("cleaning2.csv")

# %%
# REMOVE DUPLICATE
df = df.drop_duplicates()
df = df.reset_index(drop=True)
df.head()
# Out:
#                                               Review
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat tap...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal

# %%
# import hasil remove duplicate menjadi csv
df.to_csv("removedup2.csv")

# %%
# PROSES TOKENIZING (word_tokenize() untuk memecah string kedalam tokens)

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Tokenizing
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['review_tokens'] = df['Review'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df.head())
# Out:
# Tokenizing Result :
#
#                                               Review  \
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat tap...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal
#
#                                        review_tokens
# 0                                [no, review, found]
# 1  [pengiriman, sengaja, pakai, gosend, biar, cep...
# 2  [cepat, meresap, ringan, di, kulit, wajah, cum...
# 3  [seller, sangat, cepat, memproses, barang, pac...
# 4                         [cocok, di, kulit, normal]

# %%
# import hasil tokenizing menjadi csv
df.to_csv("tokenizing2.csv")

# %%
# PROSES FILTERING (Stopword Removal)
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['review_tokens_SR'] = df['review_tokens'].apply(stopwords_removal) 

print(df.head())
# Out:
#                                               Review  \
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat tap...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal
#
#                                        review_tokens  \
# 0                                [no, review, found]
# 1  [pengiriman, sengaja, pakai, gosend, biar, cep...
# 2  [cepat, meresap, ringan, di, kulit, wajah, cum...
# 3  [seller, sangat, cepat, memproses, barang, pac...
# 4                         [cocok, di, kulit, normal]
#
#                                     review_tokens_SR
# 0                                [no, review, found]
# 1  [pengiriman, sengaja, pakai, gosend, biar, cep...
# 2  [cepat, meresap, ringan, kulit, wajah, cuman, ...
# 3  [seller, cepat, memproses, barang, packing, am...
# 4                             [cocok, kulit, normal]

# %%
# import hasil sr menjadi csv
df.to_csv("stopword2.csv")

# %%
# PROSES LEMMATIZATION 
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['review_tokens_SR']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['review_tokens_stemmed'] = df['review_tokens_SR'].swifter.apply(get_stemmed_term)
print(df['review_tokens_stemmed'])
print(df.head())
# Out:
# 1367
# ------------------------
# no : no
# review : review
# found : found
# pengiriman : kirim
# sengaja : sengaja
# pakai : pakai
# gosend : gosend
# biar : biar
# cepat : cepat
# ga : ga
# dikirim : kirim
# disuruh : suruh
# reorder : reorder
# alasan : alas
# dapet : dapet
# kompensasi : kompensasi
# taunya : tau
# pas : pas
# sampe : sampe
# meresap : resap
# ringan : ringan
# kulit : kulit
# wajah : wajah
# cuman : cuman
# dryskin : dryskin
# krg : krg
# melembabkan : melembabkan
# enak : enak
# prep : prep
# sblm : sblm
# makeup : makeup
# seller : seller
# memproses : proses
# barang : barang
# packing : packing
# aman : aman
# reliable : reliable
# cocok : cocok
# normal : normal
# selangnya : selang
# sependek : pendek
# sih : sih
# ilang : ilang
# kebawah : bawah
# wtf : wtf
# annoying : annoying
# bgt : bgt
# pakenya : pakenya
# gmn : gmn
# coba : coba
# udah : udah
# cari : cari
# tp : tp
# gak : gak
# pake : pake
# tube : tube
# ajalah : aja
# kalo : kalo
# packaging : packaging
# kaya : kaya
# gi : gi
# mendaratpelembab : mendaratpelembab
# kesayangan : sayang
# mantap : mantap
# pesanan : pesan
# sesuai : sesuai
# responsif : responsif
# banget : banget
# tebal : tebal
# bravo : bravo
# packagingnya : packagingnya
# diperbaiki : baik
# ya : ya
# untungnya : untung
# barangnya : barang
# tinggal : tinggal
# selipin : selipin
# aja : aja
# keambil : ambil
# produknya : produk
# semoga : moga
# awet : awet
# waotery : waotery
# ok : ok
# diaku : dia
# yg : yg
# kulitnya : kulit
# kering : kering
# cuco : cuco
# tumbuh : tumbuh
# jerawat : jerawat
# bergantian : ganti
# adik : adik
# th : th
# kombinasi : kombinasi
# cucooo : cucooo
# wkt : wkt
# cekot : cekot
# masi : mas
# kemasan : kemas
# favorite : favorite
# gampang : gampang
# kempess : kempess
# emang : emang
# baunya : bau
# ganggu : ganggu
# worth : worth
# it : it
# kaget : kaget
# moisturizernya : moisturizernya
# berevolusi : evolusi
# skin : skin
# type : type
# moisturizer : moisturizer
# kali : kali
# versi : versi
# hasilnya : hasil
# mantaaaaab : mantaaaaab
# bekas : bekas
# cocokkk : cocokkk
# luv : luv
# baju : baju
# barunya : baru
# cantik : cantik
# keliatan : liat
# mewah : mewah
# kualitas : kualitas
# gausa : gausa
# diragukan : ragu
# bagus : bagus
# semenjak : semenjak
# moist : moist
# game : game
# kulitku : kulit
# better : better
# semingguan : minggu
# bikin : bikin
# muka : muka
# lumayan : lumayan
# tipe : tipe
# dahi : dahi
# pipi : pipi
# jad : jad
# mari : mari
# pelayanannya : layan
# oke : oke
# bubble : bubble
# wrap : wrap
# terjaga : jaga
# reformulasi : reformulasi
# formula : formula
# mnatap : mnatap
# berbeda : beda
# safely : safely
# arrived : arrived
# mudah : mudah
# menyerapp : menyerapp
# skintype : skintype
# oily : oily
# acne : acne
# prone : prone
# gais : gais
# preloved : preloved
# punyaku : punya
# klo : klo
# jual : jual
# murah : murah
# kondisi : kondisi
# msih : msih
# box : box
# dijual : jual
# karna : karna
# ngrsa : ngrsa
# brand : brand
# apapun : apa
# kesini : kesini
# and : and
# shes : shes
# back : back
# with : with
# new : new
# thank : thank
# you : you
# for : for
# being : being
# my : my
# most : most
# holy : holy
# grail : grail
# make : make
# skingame : skingame
# cocokaku : cocokaku
# sensitif : sensitif
# pie : pie
# jg : jg
# nyaman : nyaman
# dipake : dipake
# gk : gk
# efek : efek
# samping : samping
# dicoba : coba
# tmn : tmn
# uda : uda
# baguss : baguss
# packingnyaa : packingnyaa
# feels : feels
# secured : secured
# danaman : danaman
# the : the
# product : product
# itself : itself
# is : is
# pretty : pretty
# bulky : bulky
# bocorr : bocorr
# jd : jd
# gaperlu : gaperlu
# khawatirr : khawatirr
# bbrp : bbrp
# harii : hari
# so : so
# jujur : jujur
# panik : panik
# liat : liat
# dusnya : dus
# penyok : penyok
# isinya : isi
# buka : buka
# dus : dus
# tutup : tutup
# botol : botol
# nya : nya
# rapet : rapet
# untung : untung
# berminyak : minyak
# kemasannya : kemas
# lucu : lucu
# bahannya : bahan
# cepet : cepet
# terima : terima
# kasih : kasih
# paket : paket
# selamat : selamat
# gausah : gausah
# sebagus : bagus
# lembab : lembab
# bantu : bantu
# pulih : pulih
# barier : barier
# ganti : ganti
# produk : produk
# bangus : bangus
# langsung : langsung
# menyerap : serap
# repurchase : repurchase
# berkali : kali
# simple : simple
# efektif : efektif
# tekstur : tekstur
# super : super
# recommended : recommended
# beli : beli
# mudahan : mudah
# akhirnyaaa : akhirnyaaa
# menemukan : temu
# moistnya : moistnya
# tergantung : gantung
# pemakaiannya : pakai
# ori : ori
# kakak : kakak
# adminnya : adminnya
# ramah : ramah
# lagiii : lagiii
# deh : deh
# kayaknya : kayak
# pengemasan : emas
# udh : udh
# cpt : cpt
# mateng : mateng
# thankyou : thankyou
# aneh : aneh
# apek : apek
# bau : bau
# besi : besi
# dr : dr
# tempatnya : tempat
# sabun : sabun
# spt : spt
# pakainya : pakai
# skrg : skrg
# langganan : langgan
# solusi : solusi
# jerawatan : jerawat
# breakout : breakout
# pikir : pikir
# checkout : checkout
# lov : lov
# dgn : dgn
# warna : warna
# kuning : kuning
# rapi : rapi
# pesenan : sen
# this : this
# seriously : seriously
# changer : changer
# love : love
# how : how
# one : one
# bottle : bottle
# could : could
# last : last
# me : me
# months : months
# baeu : baeu
# nyoba : nyoba
# smoga : smoga
# krn : krn
# reviewnya : reviewnya
# apply : apply
# parahh : parahh
# keduaaa : keduaaa
# aslii : asli
# butuh : butuh
# habisin : habisin
# oilyy : oilyy
# menurutku : turut
# meredakan : reda
# sii : sii
# bagusss : bagusss
# delivery : delivery
# nih : nih
# harian : hari
# wow : wow
# suka : suka
# teksturnyaa : teksturnyaa
# oilyskin : oilyskin
# friendly : friendly
# luvvv : luvvv
# abis : abis
# gede : gede
# harga : harga
# promo : promo
# cashback : cashback
# pengemasannya : emas
# nyobain : nyobain
# far : far
# thanks : thanks
# pumpnya : pumpnya
# jelek : jelek
# dipakai : pakai
# muncrat : muncrat
# habis : habis
# perubahan : ubah
# megecil : megecil
# mild : mild
# gel : gel
# exp : exp
# expired : expired
# beda : beda
# kebanyakan : banyak
# teksturnya : tekstur
# kental : kental
# dioles : oles
# sensasi : sensasi
# dinginnya : dingin
# pump : pump
# pemakaian : pakai
# sel : sel
# trmaksih : trmaksih
# favorit : favorit
# bener : bener
# salah : salah
# first : first
# impression : impression
# botolnya : botol
# woy : woy
# plisss : plisss
# sebenernya : sebenernya
# ulas : ulas
# yaa : yaa
# gim : gim
# merasap : merasap
# packingnya : packingnya
# dikasih : kasih
# trus : trus
# sensitive : sensitive
# kelembaban : kelembaban
# seharian : hari
# gitu : gitu
# dipakenya : dipakenya
# ngelembabin : ngelembabin
# malem : malem
# siangnya : siang
# sayang : sayang
# mahal : mahal
# cocokan : cocok
# pelayanan : layan
# okay : okay
# bahan : bahan
# kukit : kit
# ukuran : ukur
# lebi : lebi
# ajaaa : ajaaa
# pengirimannya : kirim
# cepetttt : cepetttt
# ml : ml
# bs : bs
# bulanan : bulan
# fast : fast
# update : update
# terkait : kait
# kecocokannya : cocok
# ngeresap : ngeresap
# kekulit : kulit
# pokoknya : pokok
# deskripsi : deskripsi
# proses : proses
# dikemas : kemas
# top : top
# makasih : makasih
# sukses : sukses
# beralih : alih
# rada : rada
# kyak : kyak
# gw : gw
# kerasa : rasa
# melembapkan : lembap
# berat : berat
# alhamdulillah : alhamdulillah
# paketnya : paket
# order : order
# mendem : mendem
# obat : obat
# totol : totol
# ampuh : ampuh
# wajahku : wajah
# timer : timer
# kombi : kombi
# dry : dry
# puas : puas
# rusak : rusak
# nyerep : nyerep
# sbelum : sbelum
# untukku : untuk
# bentuk : bentuk
# higienis : higienis
# trying : trying
# time : time
# but : but
# here : here
# to : to
# service : service
# tanggung : tanggung
# jawa : jawa
# merawat : rawat
# huaa : huaa
# ngga : ngga
# bnyk : bnyk
# milia : milia
# gt : gt
# berharap : harap
# btw : btw
# segi : segi
# mohon : mohon
# diperhatikan : perhati
# satuan : satu
# masuk : masuk
# kondisinya : kondisi
# kon : kon
# bagusssss : bagusssss
# point : point
# ngunci : ngunci
# rewel : rewel
# berasa : asa
# lamaaa : lamaaa
# info : info
# bangett : bangett
# buy : buy
# tryta : tryta
# tahan : tahan
# jam : jam
# price : price
# ukurannya : ukur
# calming : calming
# klaim : klaim
# ketarik : tarik
# brighteningnya : brighteningnya
# keren : keren
# pengantarannya : antar
# lengket : lengket
# tenang : tenang
# cek : cek
# tersertifikasi : sertifikasi
# halal : halal
# mui : mui
# tks : tks
# all : all
# rembes : rembes
# cairan : cair
# berkurang : kurang
# diperkuat : kuat
# sealernya : sealernya
# berlanganan : berlanganan
# tokped : tokped
# plus : plus
# cair : cair
# byk : byk
# tmbh : tmbh
# disayang : sayang
# paksu : paksu
# tq : tq
# menghidrasi : hidrasi
# pembelian : beli
# texturenya : texturenya
# saran : saran
# dikembangkan : kembang
# model : model
# pompa : pompa
# nggak : nggak
# maksimal : maksimal
# kelembapan : lembap
# utk : utk
# agakbanyak : agakbanyak
# banding : banding
# punyanya : punya
# somethinc : somethinc
# goks : goks
# keempat : empat
# ituu : ituu
# menahan : tahan
# minyak : minyak
# dikulit : kulit
# malam : malam
# blom : blom
# hasil : hasil
# signifikan : signifikan
# terhidrasi : hidrasi
# ku : ku
# bayangkan : bayang
# penggunaan : guna
# seru : seru
# baikkk : baikkk
# lgsg : lgsg
# betulll : betulll
# freebies : freebies
# jugak : jugak
# lagiiii : lagiiii
# dichat : dichat
# engga : engga
# konfirm : konfirm
# chat : chat
# dianter : anter
# diluar : luar
# estimasi : estimasi
# dng : dng
# kurir : kurir
# next : next
# day : day
# lgi : lgi
# datenggg : datenggg
# dikasi : kasi
# bonus : bonus
# snack : snack
# kesekian : sekian
# kalirecommended : kalirecommended
# pelembab : pelembab
# sediannya : dian
# menyumbat : sumbat
# pori : pori
# awww : awww
# freebie : freebie
# mingem : mingem
# as : as
# said : said
# berjodoh : jodoh
# kind : kind
# kena : kena
# racun : racun
# twitter : twitter
# temenku : temenku
# tulisannya : tulis
# po : po
# ngecek : ngecek
# eh : eh
# tbtb : tbtb
# sampee : sampee
# seneng : neng
# bangeeet : bangeeet
# bonusnya : bonus
# teks : teks
# snacknya : snacknya
# min : min
# initapi : initapi
# leb : leb
# minggu : minggu
# bedanya : beda
# spot : spot
# memudar : pudar
# kinclong : kinclong
# isi : isi
# tetep : tetep
# rekomendasi : rekomendasi
# sodara : sodara
# respond : respond
# dg : dg
# diharapkan : harap
# yeay : yeay
# toemakasii : toemakasii
# jajan : jajan
# trims : trims
# respon : respon
# penjual : jual
# guncang : guncang
# bersih : bersih
# mulus : mulus
# ikiut : ikiut
# pembelanjaan : belanja
# bundle : bundle
# lbh : lbh
# hemat : hemat
# diterima : terima
# kempes : kempes
# mdhan : mdhan
# ditambahin : ditambahin
# kardus : kardus
# penjualnya : jual
# macet : macet
# nampol : nampol
# hrs : hrs
# layer : layer
# reaksi : reaksi
# negatif : negatif
# seminggu : minggu
# alus : alus
# minyakan : minyak
# bang : bang
# pertamakali : pertamakali
# bngeett : bngeett
# dikirimnya : kirim
# kupikir : pikir
# basuh : basuh
# air : air
# sejuk : sejuk
# membekas : bekas
# rutin : rutin
# berbekas : bekas
# ketiga : tiga
# moizturizer : moizturizer
# cerah : cerah
# sepromo : sepromo
# tergolong : golong
# orang : orang
# cocokk : cocokk
# menyerapnya : serap
# lembabnya : lembabnya
# gerah : gerah
# pack : pack
# pelelehan : leleh
# bngtt : bngtt
# masya : masya
# allah : allah
# toto : toto
# team : team
# loveeee : loveeee
# sehat : sehat
# huhu : huhu
# kalinya : kali
# aweeeet : aweeeet
# segitu : segitu
# habisnya : habis
# macemmacem : macemmacem
# kelembabannya : kelembabannya
# berm : berm
# pengen : ken
# plumpy : plumpy
# rapih : rapih
# terimakasih : terimakasih
# kak : kak
# ketemu : ketemu
# finishnya : finishnya
# alias : alias
# muncul : muncul
# jer : jer
# gelnya : gel
# mayang : mayang
# gakbada : gakbada
# sm : sm
# skali : skali
# pore : pore
# armor : armor
# tpi : tpi
# diproduksi : produksi
# si : si
# pke : pke
# bangettt : bangettt
# safety : safety
# bismillah : bismillah
# repeat : repeat
# mantep : mantep
# berjerawat : jerawat
# keberapa : berapa
# fav : fav
# gonta : gonta
# cocoksampe : cocoksampe
# brenti : brenti
# nyari : nyari
# alot : alot
# official : official
# store : store
# terjamin : jamin
# keasliannya : asli
# fix : fix
# kandungannya : kandung
# macem : macem
# dpt : dpt
# sunscreen : sunscreen
# gr : gr
# jugaaa : jugaaa
# makasi : makas
# yaaa : yaaa
# sukaa : sukaa
# diaplikasikan : aplikasi
# productnya : productnya
# neko : neko
# really : really
# have : have
# step : step
# up : up
# on : on
# marketing : marketing
# wise : wise
# ide : ide
# packagin : packagin
# value : value
# terjangkau : jangkau
# diratakan : rata
# obati : obat
# foam : foam
# sdikit : sdikit
# whitecast : whitecast
# diratain : diratain
# minusnya : minus
# aluminum : aluminum
# penutupnya : tutup
# susah : susah
# dibuka : buka
# tolong : tolong
# krim : krim
# kentalpadat : kentalpadat
# warnanya : warna
# pink : pink
# smp : smp
# co : co
# fs : fs
# uk : uk
# ed : ed
# msh : msh
# smg : smg
# takut : takut
# turns : turns
# out : out
# mukaku : muka
# matanya : mata
# besok : besok
# sangaaat : sangaaat
# menyembukan : menyembukan
# oh : oh
# lil : lil
# gift : gift
# sunscreenya : sunscreenya
# sampenya : sampenya
# perkiraan : kira
# bat : bat
# admin : admin
# tangan : tangan
# lembap : lembap
# sample : sample
# sabar : sabar
# depannya : depan
# formulanya : formula
# claim : claim
# lemgket : lemgket
# baurkan : baur
# meninggalkan : tinggal
# white : white
# cast : cast
# menghilangkan : hilang
# kemerahan : merah
# sdh : sdh
# sekian : sekian
# hrga : hrga
# pgiriman : pgiriman
# dksih : dksih
# dakron : dakron
# ditangan : tang
# diatasin : diatasin
# gabisa : gabisa
# ngilangin : ngilangin
# inj : inj
# kayak : kayak
# grenjelgrenjelnya : grenjelgrenjelnya
# nakar : nakar
# konsisten : konsisten
# volume : volume
# jari : jari
# jug : jug
# ngebantu : ngebantu
# paginya : pagi
# totolannya : totol
# foto : foto
# disegel : segel
# gontai : gontai
# merk : merk
# gemec : gemec
# nd : nd
# padet : padet
# jerawatnya : jerawat
# beruntusan : beruntus
# dipakein : dipakein
# kempesnya : kempes
# je : je
# kirain : kirain
# tau : tau
# semprotannya : semprot
# doang : doang
# hehehehe : hehehehe
# toner : toner
# idk : idk
# why : why
# ngakak : ngakak
# its : its
# not : not
# because : because
# ngepacking : ngepacking
# itemnya : item
# they : they
# use : use
# kesannya : kesan
# mengambang : ambang
# diatas : atas
# andalan : andal
# terbaikkk : terbaikkk
# busetttt : busetttt
# hempass : hempass
# brp : brp
# belii : beli
# efeknya : efek
# dahsyatt : dahsyatt
# gatau : gatau
# cucok : cucok
# full : full
# size : size
# berdua : dua
# uwow : uwow
# khaaaannnn : khaaaannnn
# bargain : bargain
# very : very
# versatile : versatile
# frills : frills
# just : just
# solid : solid
# standar : standar
# hidup : hidup
# terhitung : hitung
# penutup : tutup
# effective : effective
# keluarin : keluarin
# wkwkwk : wkwkwk
# kenyal : kenyal
# lebay : lebay
# sticky : sticky
# harganya : harga
# dibandingkan : banding
# blum : blum
# dcoba : dcoba
# premium : premium
# texture : texture
# tdk : tdk
# lg : lg
# seksama : seksama
# sesingkatsingkatnya : sesingkatsingkatnya
# date : date
# kombinasiku : kombinasi
# oilnya : oilnya
# koq : koq
# wangi : wangi
# kimia : kimia
# bner : bner
# ingredient : ingredient
# gedenya : gede
# kecintaan : cinta
# akuhhhh : akuhhhh
# sebotol : botol
# seenak : enak
# tekturnya : tekturnya
# melembabkannya : melembabkannya
# mantul : mantul
# sukaaa : sukaaa
# nyampe : nyampe
# barrier : barrier
# kokoh : kokoh
# keliataan : keliataan
# pumpingnya : pumpingnya
# kex : kex
# terampuh : ampuh
# tidur : tidur
# dah : dah
# dijamin : jamin
# kempesjerawat : kempesjerawat
# be : be
# nyerap : nyerap
# kerusakan : rusa
# design : design
# watery : watery
# komedo : komedo
# bb : bb
# cream : cream
# ngelupas : ngelupas
# mending : mending
# rb : rb
# trs : trs
# banyakan : banyak
# udara : udara
# krna : krna
# niat : niat
# dlu : dlu
# siang : siang
# surantul : surantul
# best : best
# hydrating : hydrating
# bgtt : bgtt
# hypenya : hypenya
# thanjs : thanjs
# cepatnya : cepat
# euy : euy
# serum : serum
# mengobati : obat
# ngasih : ngasih
# natural : natural
# bibir : bibir
# cenderung : cenderung
# hitam : hitam
# kadang : kadang
# lip : lip
# oil : oil
# anak : anak
# abg : abg
# satusatunya : satusatunya
# cobain : cobain
# terbukti : bukti
# enaak : enaak
# akuu : akuu
# lovvv : lovvv
# rekomen : rekomen
# temen : temen
# brentusan : brentusan
# viral : viral
# skinc : skinc
# ampuhkebalik : ampuhkebalik
# fkus : fkus
# toko : toko
# sll : sll
# lem : lem
# dibagian : bagi
# body : body
# solasiban : solasiban
# bukanya : buka
# favorittt : favorittt
# ujungnya : ujung
# ngerasa : ngerasa
# tuh : tuh
# penguruman : penguruman
# bangeett : bangeett
# travel : travel
# ngirimnya : ngirimnya
# meriah : riah
# muaaahhh : muaaahhh
# mantab : mantab
# yeayy : yeayy
# makasihh : makasihh
# gemess : gemess
# ditempel : tempel
# stiker : stiker
# plastik : plastik
# tebel : tebel
# pelit : pelit
# dikasinya : kas
# skincare : skincare
# tujuan : tuju
# request : request
# good : good
# kentel : kentel
# mencair : cair
# nyeess : nyeess
# kyanya : kyanya
# bonu : bonu
# mantapsssss : mantapsssss
# wtb : wtb
# im : im
# sad : sad
# didnt : didnt
# works : works
# sampaidenga : sampaidenga
# utuh : utuh
# iseng : iseng
# research : research
# range : range
# murce : murce
# dibanding : banding
# bagussss : bagussss
# deserves : deserves
# more : more
# rec : rec
# jar : jar
# membaikk : membaikk
# setahun : tahun
# gaperna : gaperna
# maskeran : masker
# wkwk : wkwk
# lagii : lagi
# combo : combo
# krimnya : krim
# padat : padat
# membantu : bantu
# mengempeskan : kempes
# besoknya : besok
# akyu : akyu
# parah : parah
# beruntus : beruntus
# luka : luka
# merah : merah
# nutup : nutup
# jdi : jdi
# purchase : purchase
# ever : ever
# every : every
# dime : dime
# inii : ini
# cyst : cyst
# radang : radang
# dimuka : muka
# anakku : anak
# rangkaian : rangkai
# active : active
# response : response
# makenya : makenya
# sehari : hari
# diskon : diskon
# flash : flash
# sale : sale
# murmer : murmer
# hero : hero
# dalemnya : dalem
# aluminium : aluminium
# dilepas : lepas
# sisa : sisa
# praktis : praktis
# moisterizer : moisterizer
# nyerepnya : nyerepnya
# memuaskan : muas
# ajaib : ajaib
# original : original
# cacat : cacat
# recomendasi : recomendasi
# cetaphil : cetaphil
# busabisa : busabisa
# less : less
# busa : busa
# rek : rek
# dipacking : dipacking
# dicobain : dicobain
# semalem : semalem
# light : light
# sbnrnya : sbnrnya
# ttp : ttp
# mukanya : muka
# paking : paking
# laamaaa : laamaaa
# facial : facial
# wash : wash
# maju : maju
# toopppp : toopppp
# barriernya : barriernya
# dtg : dtg
# memakai : pakai
# blend : blend
# pakau : pakau
# ngeset : ngeset
# manfaat : manfaat
# hebat : hebat
# iritasi : iritasi
# overall : overall
# dikit : dikit
# kekurangannya : kurang
# dikeluarin : dikeluarin
# kayanya : kaya
# selang : selang
# sbg : sbg
# nambah : nambah
# akhirnyaaaa : akhirnyaaaa
# nemuin : nemuin
# bentuknya : bentuk
# greasy : greasy
# setelahnya : telah
# benjolan : benjol
# gosong : gosong
# nimbul : nimbul
# berfungsi : fungsi
# gentle : gentle
# washnya : washnya
# thick : thick
# enough : enough
# pengaplikasiannya : aplikasi
# problem : problem
# aaah : aaah
# senangnya : senang
# nemu : nemu
# kusam : kusam
# pilling : pilling
# masker : masker
# rambut : rambut
# halus : halus
# anti : anti
# lepek : lepek
# fw : fw
# semuka : muka
# ampe : ampe
# leher : leher
# material : material
# bocor : bocor
# fragrance : fragrance
# hygenis : hygenis
# ro : ro
# baguus : baguus
# voucher : voucher
# giveaway : giveaway
# terbaru : baru
# ketimbang : ketimbang
# mayan : mayan
# berkualitas : kualitas
# mudahmudahan : mudahmudahan
# iniii : iniii
# tonernya : tonernya
# cuci : cuci
# cuy : cuy
# nano : nano
# baguspengiriman : baguspengiriman
# okedapet : okedapet
# hadiah : hadiah
# hair : hair
# mask : mask
# hahahaha : hahahaha
# cangkep : cangkep
# free : free
# spa : spa
# savior : savior
# dikala : kala
# break : break
# sempet : sempet
# sembuh : sembuh
# gara : gara
# warrior : warrior
# paketan : paket
# pesen : sen
# minimalis : minimal
# oles : oles
# kir : kir
# duit : duit
# asik : asik
# seringin : ringin
# ka : ka
# pecinta : cinta
# conditioner : conditioner
# voucer : voucer
# belanja : belanja
# bermanfaat : manfaat
# pemesanan : mesan
# sy : sy
# nyaa : nyaa
# semalam : malam
# batu : batu
# ngeluarin : ngeluarin
# batunya : batu
# mengering : ering
# masknya : masknya
# hallo : hallo
# kalimya : kalimya
# woshlist : woshlist
# nabung : nabung
# nyisihin : nyisihin
# uang : uang
# estima : estima
# semogaa : semogaa
# freebiesnyaaa : freebiesnyaaa
# narik : narik
# ekspektasi : ekspektasi
# tnyt : tnyt
# mate : mate
# tone : tone
# usa : usa
# pk : pk
# porefessional : porefessional
# gatal : gatal
# panas : panas
# makasiih : makasiih
# bonusan : bonus
# jugaa : jugaa
# much : much
# udahlah : udahlah
# mantuliti : mantuliti
# thannks : thannks
# bruntusan : bruntusan
# serumnya : serum
# nyebelin : nyebelin
# gituu : gituu
# mksh : mksh
# layanan : layan
# sip : sip
# menyamarkan : samar
# penasaran : penasaran
# hairmask : hairmask
# nyampenya : nyampenya
# your : your
# especially : especially
# name : name
# in : in
# face : face
# ditempat : tempat
# kerja : kerja
# mundur : mundur
# menyenangkan : senang
# menenangkan : tenang
# tersegel : segel
# formulasinya : formulasi
# affordable : affordable
# cobaaa : cobaaa
# hehe : hehe
# mantull : mantull
# keduaa : keduaa
# hilang : hilang
# dibeli : beli
# adain : adain
# yh : yh
# lihat : lihat
# dibawah : bawah
# mingguan : minggu
# baiksemoga : baiksemoga
# servisnya : servis
# basic : basic
# dibawa : bawa
# traveling : traveling
# loveee : loveee
# adem : adem
# dipengiriman : kirim
# pulau : pulau
# ngaruh : ngaruh
# struggle : struggle
# ntah : ntah
# dilayani : layan
# dikombinasi : kombinasi
# gimana : gimana
# calmdown : calmdown
# ngefek : ngefek
# lengkap : lengkap
# restock : restock
# rumah : rumah
# ter : ter
# boncos : boncos
# sebagusss : sebagusss
# ituuhh : ituuhh
# ak : ak
# bkin : bkin
# keset : keset
# kokk : kokk
# ad : ad
# wanginya : wangi
# hrg : hrg
# goodeal : goodeal
# hih : hih
# baikpackingan : baikpackingan
# amaaann : amaaann
# orii : orii
# mini : mini
# cepett : cepett
# sampeenyaa : sampeenyaa
# guard : guard
# berbentuk : bentuk
# bening : bening
# theory : theory
# of : of
# everything : everything
# essencenya : essencenya
# kema : kema
# berprogres : progres
# cute : cute
# aju : aju
# nice : nice
# kotak : kotak
# lapisi : lapis
# ja : ja
# bintang : bintang
# pengantaran : antar
# gram : gram
# loooove : loooove
# gini : gin
# daaaan : daaaan
# jumbo : jumbo
# segini : gin
# definitely : definitely
# steal : steal
# st : st
# becek : becek
# dikulitku : kulit
# kemana : mana
# gasabar : gasabar
# setia : setia
# kerutan : kerut
# tipis : tipis
# usia : usia
# thn : thn
# noted : noted
# aplikasikan : aplikasi
# benchmark : benchmark
# diapp : diapp
# terluv : terluv
# memudarkan : pudar
# glowing : glowing
# youu : youu
# setrlah : setrlah
# bgttt : bgttt
# kepatil : patil
# fullsize : fullsize
# sebelah : belah
# tapinya : tapi
# whipped : whipped
# ha : ha
# hempaskan : hempas
# kebocoran : bocor
# produkny : produkny
# alhamdulilah : alhamdulilah
# acneprone : acneprone
# sc : sc
# kumel : mel
# wudhu : wudhu
# kesiram : siram
# susu : susu
# lunturnya : luntur
# wkwkwkwk : wkwkwkwk
# tha : tha
# jarang : jarang
# gaada : gaada
# which : which
# prefer : prefer
# gabikin : gabikin
# khawatir : khawatir
# balm : balm
# drugstore : drugstore
# ngempesin : ngempesin
# cystic : cystic
# scarring : scarring
# colek : colek
# higenis : higenis
# berbulan : bulan
# nunggu : nunggu
# disc : disc
# yah : yah
# dikiiiit : dikiiiit
# {'no': 'no', 'review': 'review', 'found': 'found', 'pengiriman': 'kirim', 'sengaja': 'sengaja', 'pakai': 'pakai', 'gosend': 'gosend', 'biar': 'biar', 'cepat': 'cepat', 'ga': 'ga', 'dikirim': 'kirim', 'disuruh': 'suruh', 'reorder': 'reorder', 'alasan': 'alas', 'dapet': 'dapet', 'kompensasi': 'kompensasi', 'taunya': 'tau', 'pas': 'pas', 'sampe': 'sampe', 'meresap': 'resap', 'ringan': 'ringan', 'kulit': 'kulit', 'wajah': 'wajah', 'cuman': 'cuman', 'dryskin': 'dryskin', 'krg': 'krg', 'melembabkan': 'melembabkan', 'enak': 'enak', 'prep': 'prep', 'sblm': 'sblm', 'makeup': 'makeup', 'seller': 'seller', 'memproses': 'proses', 'barang': 'barang', 'packing': 'packing', 'aman': 'aman', 'reliable': 'reliable', 'cocok': 'cocok', 'normal': 'normal', 'selangnya': 'selang', 'sependek': 'pendek', 'sih': 'sih', 'ilang': 'ilang', 'kebawah': 'bawah', 'wtf': 'wtf', 'annoying': 'annoying', 'bgt': 'bgt', 'pakenya': 'pakenya', 'gmn': 'gmn', 'coba': 'coba', 'udah': 'udah', 'cari': 'cari', 'tp': 'tp', 'gak': 'gak', 'pake': 'pake', 'tube': 'tube', 'ajalah': 'aja', 'kalo': 'kalo', 'packaging': 'packaging', 'kaya': 'kaya', 'gi': 'gi', 'mendaratpelembab': 'mendaratpelembab', 'kesayangan': 'sayang', 'mantap': 'mantap', 'pesanan': 'pesan', 'sesuai': 'sesuai', 'responsif': 'responsif', 'banget': 'banget', 'tebal': 'tebal', 'bravo': 'bravo', 'packagingnya': 'packagingnya', 'diperbaiki': 'baik', 'ya': 'ya', 'untungnya': 'untung', 'barangnya': 'barang', 'tinggal': 'tinggal', 'selipin': 'selipin', 'aja': 'aja', 'keambil': 'ambil', 'produknya': 'produk', 'semoga': 'moga', 'awet': 'awet', 'waotery': 'waotery', 'ok': 'ok', 'diaku': 'dia', 'yg': 'yg', 'kulitnya': 'kulit', 'kering': 'kering', 'cuco': 'cuco', 'tumbuh': 'tumbuh', 'jerawat': 'jerawat', 'bergantian': 'ganti', 'adik': 'adik', 'th': 'th', 'kombinasi': 'kombinasi', 'cucooo': 'cucooo', 'wkt': 'wkt', 'cekot': 'cekot', 'masi': 'mas', 'kemasan': 'kemas', 'favorite': 'favorite', 'gampang': 'gampang', 'kempess': 'kempess', 'emang': 'emang', 'baunya': 'bau', 'ganggu': 'ganggu', 'worth': 'worth', 'it': 'it', 'kaget': 'kaget', 'moisturizernya': 'moisturizernya', 'berevolusi': 'evolusi', 'skin': 'skin', 'type': 'type', 'moisturizer': 'moisturizer', 'kali': 'kali', 'versi': 'versi', 'hasilnya': 'hasil', 'mantaaaaab': 'mantaaaaab', 'bekas': 'bekas', 'cocokkk': 'cocokkk', 'luv': 'luv', 'baju': 'baju', 'barunya': 'baru', 'cantik': 'cantik', 'keliatan': 'liat', 'mewah': 'mewah', 'kualitas': 'kualitas', 'gausa': 'gausa', 'diragukan': 'ragu', 'bagus': 'bagus', 'semenjak': 'semenjak', 'moist': 'moist', 'game': 'game', 'kulitku': 'kulit', 'better': 'better', 'semingguan': 'minggu', 'bikin': 'bikin', 'muka': 'muka', 'lumayan': 'lumayan', 'tipe': 'tipe', 'dahi': 'dahi', 'pipi': 'pipi', 'jad': 'jad', 'mari': 'mari', 'pelayanannya': 'layan', 'oke': 'oke', 'bubble': 'bubble', 'wrap': 'wrap', 'terjaga': 'jaga', 'reformulasi': 'reformulasi', 'formula': 'formula', 'mnatap': 'mnatap', 'berbeda': 'beda', 'safely': 'safely', 'arrived': 'arrived', 'mudah': 'mudah', 'menyerapp': 'menyerapp', 'skintype': 'skintype', 'oily': 'oily', 'acne': 'acne', 'prone': 'prone', 'gais': 'gais', 'preloved': 'preloved', 'punyaku': 'punya', 'klo': 'klo', 'jual': 'jual', 'murah': 'murah', 'kondisi': 'kondisi', 'msih': 'msih', 'box': 'box', 'dijual': 'jual', 'karna': 'karna', 'ngrsa': 'ngrsa', 'brand': 'brand', 'apapun': 'apa', 'kesini': 'kesini', 'and': 'and', 'shes': 'shes', 'back': 'back', 'with': 'with', 'new': 'new', 'thank': 'thank', 'you': 'you', 'for': 'for', 'being': 'being', 'my': 'my', 'most': 'most', 'holy': 'holy', 'grail': 'grail', 'make': 'make', 'skingame': 'skingame', 'cocokaku': 'cocokaku', 'sensitif': 'sensitif', 'pie': 'pie', 'jg': 'jg', 'nyaman': 'nyaman', 'dipake': 'dipake', 'gk': 'gk', 'efek': 'efek', 'samping': 'samping', 'dicoba': 'coba', 'tmn': 'tmn', 'uda': 'uda', 'baguss': 'baguss', 'packingnyaa': 'packingnyaa', 'feels': 'feels', 'secured': 'secured', 'danaman': 'danaman', 'the': 'the', 'product': 'product', 'itself': 'itself', 'is ...
# ------------------------
# Pandas Apply: 100%|██████████| 457/457 [00:00<00:00, 76157.06it/s]
# 0                                    [no, review, found]
# 1      [kirim, sengaja, pakai, gosend, biar, cepat, g...
# 2      [cepat, resap, ringan, kulit, wajah, cuman, dr...
# 3      [seller, cepat, proses, barang, packing, aman,...
# 4                                 [cocok, kulit, normal]
#                              ...
# 452    [serum, ampuh, muka, yg, sensitif, minyak, acn...
# 453    [tekstur, enak, banget, gak, bau, aneh, aneh, ...
# 454    [udh, pake, bulan, cocok, kirim, cepet, bagus,...
# 455    [for, the, first, time, co, moist, skingame, u...
# 456    [pikir, kental, cair, yah, cepat, resap, sih, ...
# Name: review_tokens_stemmed, Length: 457, dtype: object
#                                               Review  \
# 0                                    no review found
# 1  pengiriman sengaja pakai gosend biar cepat tap...
# 2  cepat meresap ringan di kulit wajah cuman buat...
# 3  seller sangat cepat memproses barang packing s...
# 4                              cocok di kulit normal
#
#                                        review_tokens  \
# 0                                [no, review, found]
# 1  [pengiriman, sengaja, pakai, gosend, biar, cep...
# 2  [cepat, meresap, ringan, di, kulit, wajah, cum...
# 3  [seller, sangat, cepat, memproses, barang, pac...
# 4                         [cocok, di, kulit, normal]
#
#                                     review_tokens_SR  \
# 0                                [no, review, found]
# 1  [pengiriman, sengaja, pakai, gosend, biar, cep...
# 2  [cepat, meresap, ringan, kulit, wajah, cuman, ...
# 3  [seller, cepat, memproses, barang, packing, am...
# 4                             [cocok, kulit, normal]
#
#                                review_tokens_stemmed
# 0                                [no, review, found]
# 1  [kirim, sengaja, pakai, gosend, biar, cepat, g...
# 2  [cepat, resap, ringan, kulit, wajah, cuman, dr...
# 3  [seller, cepat, proses, barang, packing, aman,...
# 4                             [cocok, kulit, normal]

# %%
# import hasil preprocessing menjadi csv
df.to_csv("lemma2.csv")
