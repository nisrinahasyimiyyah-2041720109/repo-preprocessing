# %%
# Load data ke dalam data frame 
import pandas as pd

# Spesifikasi encoding diperlukan karena data tidak menggunakan UTF-8
df = pd.read_csv('scraping_somethinc.csv', encoding='latin-1')

df.head()
# Out:
#                                               Review  \
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2                            masalah kulitku kerutan
# 3  bagus banget lip tint nya warnanya jg bagus2, ...
# 4  expire 2026, pengiriman cepat. cocok asal peng...
#
#                                              Product     Rating Username  \
# 0             SOMETHINC BAKUCHIOL Skinpair Oil Serum  bintang 5    A***y
# 1     SOMETHINC CERAMIC SKIN Saviour Moisturizer Gel  bintang 5    A***y
# 2         SOMETHINC HYALuronic9+ Advanced + B5 Serum  bintang 5    A***y
# 3  SOMETHINC Holiday Lip Tint Kit (Ombrella Lip T...  bintang 5  rohimah
# 4  SOMETHINC AHA 7%, BHA 1%, PHA 3% Weekly Peelin...  bintang 5    n***a
#
#         Date
# 0  1/30/2024
# 1  1/30/2024
# 2  1/30/2024
# 3  1/30/2024
# 4  1/30/2024

# %%
# Drop kolom yang tidak terpakai
df = df.drop(df.iloc[:,1:], axis=1)

# Cek data teratas
df.head()
# Out:
#                                               Review
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2                            masalah kulitku kerutan
# 3  bagus banget lip tint nya warnanya jg bagus2, ...
# 4  expire 2026, pengiriman cepat. cocok asal peng...

# %% [markdown]
# PREPROCESSING

# %%
# PROSES CASE FOLDING (menjadikan semua huruf di kolom Review menjadi huruf kecil)
df['Review'] = df['Review'].str.lower()

print('Case Folding Result: \n')
df.head()
# Out:
# Case Folding Result:
#                                               Review
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2                            masalah kulitku kerutan
# 3  bagus banget lip tint nya warnanya jg bagus2, ...
# 4  expire 2026, pengiriman cepat. cocok asal peng...

# %%
# import hasil case folding menjadi csv
df.to_csv("casefolding_somethinc.csv")

# %%
# CLEANING
import re # regex library

def remove_tweet_special(text):
    # remove tab, new line, and back slice
    text = text.replace('\\t'," ").replace('\\n', " ").replace('\\u', " ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

df['Review'] = df['Review'].apply(remove_tweet_special)

# remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Review'] = df['Review'].apply(remove_number)

# remove punctuation and replace with space
def remove_punctuation(text):
    return re.sub(r'[.,]', ' ', text)

df['Review'] = df['Review'].apply(remove_punctuation)

# remove punctuation
def remove_symbol(text):
    # Menghapus simbol-simbol tidak standar dan menggantinya dengan spasi
    cleaned_text = re.sub(r'[^\w\s]', ' ', text)
    
    # Menghapus multiple whitespace
    cleaned_text = re.sub('\s+', ' ', cleaned_text).strip()
    
    return cleaned_text

df['Review'] = df['Review'].apply(remove_symbol)

# Menentukan ambang batas panjang string acak
threshold_length = 20

# Fungsi untuk menghapus string acak berdasarkan panjangnya
def hapus_string_acak_dengan_panjang(text):
    # Memeriksa panjang string dan menghapus jika melebihi ambang batas
    return ' '.join(word for word in text.split() if len(word) <= threshold_length)

# Menggunakan fungsi untuk menghapus string acak pada kolom 'Text'
df['Review'] = df['Review'].apply(hapus_string_acak_dengan_panjang)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Review'] = df['Review'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['Review'] = df['Review'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Review'] = df['Review'].apply(remove_single_char)

print('Cleaning Result : \n') 
print(df.head())

def remove_laughter(text):
    laughter_patterns = r'\b((ha)+h*|(he)+h*|(hi)+h*|(wk)+w*k*|(eh)+e*|(ah)+a*|(ih)+i*|(kw)+k*w*|(hem)+m*)\b'
    return re.sub(laughter_patterns, '', text, flags=re.IGNORECASE)

df['Review'] = df['Review'].apply(remove_laughter)
# Out:
# Cleaning Result :
#
#                                               Review
# 0                            masalah kulitku kerutan
# 1                                tipe kulitku kering
# 2                            masalah kulitku kerutan
# 3  bagus banget lip tint nya warnanya jg bagus ke...
# 4  expire pengiriman cepat cocok asal penggunaan ...

# %%
# import hasil cleaning menjadi csv
df.to_csv("cleaning_somethinc.csv")

# %%
# REMOVE DUPLICATE
df = df.drop_duplicates()
df = df.reset_index(drop=True)
# Menghapus baris yang kosong
df = df.dropna(subset=['Review'])
# Menghapus baris yang hanya berisi spasi atau whitespace
df = df[df['Review'].str.strip() != '']
df.head()
# Out:
#                                               Review
# 0      it  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...

# %%
# import hasil remove duplicate menjadi csv
df.to_csv("removedup_avoskin.csv")

# %%
# NORMALIZATION
import pandas as pd
import re

slang_dictionary = pd.read_csv('../colloquial-indonesian-lexicon2.csv')
slang_dict = pd.Series(slang_dictionary['formal'].values,index=slang_dictionary['slang']).to_dict()

slang_dictionary.head()
# Out:
#      slang    formal  In-dictionary  \
# 0     woww       wow            1.0
# 1    aminn      amin            1.0
# 2      met   selamat            1.0
# 3   netaas   menetas            1.0
# 4  keberpa  keberapa            0.0
#
#                                              context  category1 category2  \
# 0                                                wow   elongasi         0
# 1  Selamat ulang tahun kakak tulus semoga panjang...   elongasi         0
# 2  Met hari netaas kak!? Wish you all the best @t...  abreviasi         0
# 3  Met hari netaas kak!? Wish you all the best @t...   afiksasi  elongasi
# 4                           Birthday yg keberpa kak?  abreviasi         0
#
#   category3
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# Normalisasi kata menggunakan kamus colloquial-indonesian-lexicon2.csv
def Slangwords(text, slang_dict):
    for word in text.split():
        if word in slang_dict.keys():
            # menambahkan \b untuk menandakan batas kata di sekitar kata slang
            text = re.sub(r'\b{}\b'.format(re.escape(word)), slang_dict[word], text)
    
    text = re.sub('@[\w]+', '', text)
    return text

df['Review_norm'] = df['Review'].apply(lambda x: Slangwords(x, slang_dict))
print(df.head())
# Out:
#                                               Review  \
# 0      it  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                          Review_norm
# 0     itu  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...

# %%
# import hasil replace slang words menjadi csv
df.to_csv("normalization_avoskin.csv")

# %%
# PROSES TOKENIZING (word_tokenize() untuk memecah string kedalam tokens)

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Tokenizing
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['review_tokens'] = df['Review_norm'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df.head())
# Out:
# Tokenizing Result :
#
#                                               Review  \
# 0      it  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                          Review_norm  \
# 0     itu  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                        review_tokens
# 0  [itu, beautiful, package, bintang, buat, safet...
# 1                            [tipe, kulitku, kering]
# 2  [pengiriman, agak, lama, karena, beda, provins...
# 3                                              [top]
# 4  [tipe, kulitku, berminyak, tipe, kulitku, keri...

# %%
# import hasil tokenizing menjadi csv
df.to_csv("tokenizing_avoskin.csv")

# %%
# PROSES FILTERING (Stopword Removal)
from nltk.corpus import stopwords

# get stopword indonesia from NLTK stopword
list_stopwords = stopwords.words('indonesian')

# convert list to dictionary
list_stopwords = set(list_stopwords)

# remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['review_tokens_SR'] = df['review_tokens'].apply(stopwords_removal) 

print(df.head())
# Out:
#                                               Review  \
# 0      it  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                          Review_norm  \
# 0     itu  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                        review_tokens  \
# 0  [itu, beautiful, package, bintang, buat, safet...
# 1                            [tipe, kulitku, kering]
# 2  [pengiriman, agak, lama, karena, beda, provins...
# 3                                              [top]
# 4  [tipe, kulitku, berminyak, tipe, kulitku, keri...
#
#                                     review_tokens_SR
# 0         [beautiful, package, bintang, safety, nya]
# 1                            [tipe, kulitku, kering]
# 2  [pengiriman, beda, provinsi, gapapa, packingny...
# 3                                              [top]
# 4  [tipe, kulitku, berminyak, tipe, kulitku, keri...

# %%
# import hasil stopword removal menjadi csv
df.to_csv("stopword_avoskin.csv")

# %%
# PROSES LEMMATIZATION 
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['review_tokens_SR']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['review_tokens_stemmed'] = df['review_tokens_SR'].swifter.apply(get_stemmed_term)
print(df['review_tokens_stemmed'])
print(df.head())
# Out:
# 910
# ------------------------
# beautiful : beautiful
# package : package
# bintang : bintang
# safety : safety
# nya : nya
# tipe : tipe
# kulitku : kulit
# kering : kering
# pengiriman : kirim
# beda : beda
# provinsi : provinsi
# gapapa : gapapa
# packingnya : packingnya
# aman : aman
# banget : banget
# semoga : moga
# cocok : cocok
# memperbaiki : baik
# kulit : kulit
# berminyak : minyak
# top : top
# normal : normal
# kombinasi : kombinasi
# kerutan : kerut
# jerawat : jerawat
# pori : pori
# sensitif : sensitif
# exp : exp
# no : no
# review : review
# found : found
# sih : sih
# beli : beli
# bagus : bagus
# ya : ya
# muka : muka
# kemasan : kemas
# biru : biru
# viral : viral
# perskincare : perskincare
# an : an
# semenjak : semenjak
# hamil : hamil
# stop : stop
# pakai : pakai
# produk : produk
# bayi : bayi
# coba : coba
# kangen : kangen
# sensasinya : sensasi
# memakai : pakai
# feelnya : feelnya
# ngaruh : ngaruh
# suka : suka
# muncul : muncul
# barang : barang
# sesuai : sesuai
# pesanan : pesan
# oke : oke
# saran : saran
# facial : facial
# wash : wash
# fragrance : fragrance
# biar : biar
# baunya : bau
# enak : enak
# nyaman : nyaman
# moga : moga
# cepat : cepat
# mantap : mantap
# alhamdulillah : alhamdulillah
# barangnya : barang
# pengemasan : emas
# ok : ok
# thank : thank
# you : you
# kurir : kurir
# sicepat : sicepat
# team : team
# avoskin : avoskin
# bahannya : bahan
# gampang : gampang
# menyerap : serap
# gratis : gratis
# mini : mini
# pouch : pouch
# terima : terima
# kasih : kasih
# selau : selau
# harga : harga
# diskon : diskon
# yes : yes
# produknya : produk
# berkali : kali
# kali : kali
# toko : toko
# official : official
# pembelian : beli
# amanah : amanah
# thanks : thanks
# so : so
# far : far
# good : good
# for : for
# daily : daily
# use : use
# hasilnya : hasil
# dicoba : coba
# kemarin : kemarin
# mencoba : coba
# teksturnya : tekstur
# ringan : ringan
# mudah : mudah
# blend : blend
# whitecast : whitecast
# oily : oily
# apply : apply
# hehe : hehe
# manjur : manjur
# exfoliasi : exfoliasi
# wajahku : wajah
# doesn : doesn
# smell : smell
# as : as
# nice : nice
# other : other
# brands : brands
# very : very
# chemical : chemical
# nemu : nemu
# serum : serum
# seller : seller
# tokped : tokped
# product : product
# diterima : terima
# bocor : bocor
# berasa : asa
# lembab : lembab
# keluarkan : keluar
# sunscreen : sunscreen
# spf : spf
# avo : avo
# formulasinya : formulasi
# persis : persis
# kayak : kayak
# tgs : tgs
# please : please
# kulitnya : kulit
# paket : paket
# rapi : rapi
# seblmnya : seblmnya
# varian : varian
# ybs : ybs
# tau : tau
# yeey : yeey
# deh : deh
# menetap : tetap
# selamat : selamat
# packaging : packaging
# orderan : order
# always : always
# the : the
# best : best
# avoo : avoo
# kece : kece
# kesekian : sekian
# kalinya : kali
# rugi : rugi
# menyesal : sesal
# toner : toner
# berpaling : paling
# merk : merk
# dibikin : bikin
# kecewa : kecewa
# ml : ml
# dikirim : kirim
# aaaaaa : aaaaaa
# chat : chat
# solusi : solusi
# disuruh : suruh
# tunggu : tunggu
# senin : senin
# bikin : bikin
# menambah : tambah
# emosi : emosi
# rating : rating
# ganti : ganti
# komunikatif : komunikatif
# gercep : gercep
# amin : amin
# gede : gede
# komedo : komedo
# hidung : hidung
# bantu : bantu
# xixi : xixi
# andalan : andal
# exfo : exfo
# dimalam : malam
# mengasih : asih
# promo : promo
# pemakaian : pakai
# terpercaya : percaya
# diragukan : ragu
# kalo : kalo
# mah : mah
# serumnya : serum
# meresap : resap
# wajah : wajah
# lengket : lengket
# benaran : benar
# mencerahkan : cerah
# orisinal : orisinal
# memuaskan : muas
# kualitas : kualitas
# moisturizer : moisturizer
# habis : habis
# worthed : worthed
# buy : buy
# super : super
# murce : murce
# pesan : pesan
# diresi : resi
# tertulis : tulis
# pcs : pcs
# salah : salah
# divideoin : divideoin
# percaya : percaya
# eeeehh : eeeehh
# foto : foto
# doang : doang
# penjual : jual
# responsif : responsif
# mama : mama
# usia : usia
# mulus : mulus
# berkurang : kurang
# repurchase : repurchase
# retinol : retinol
# refining : refining
# lembut : lembut
# dry : dry
# berjerawat : jerawat
# pump : pump
# mendingan : mending
# cream : cream
# mata : mata
# mengurangi : kurang
# panda : panda
# segar : segar
# pokoknya : pokok
# keren : keren
# terbaik : baik
# mengecewakan : kecewa
# packagingnya : packagingnya
# mudahan : mudah
# rangkain : rangkain
# tinggal : tinggal
# safe : safe
# tanganku : tangan
# segel : segel
# ditangan : tang
# expired : expired
# gel : gel
# travel : travel
# size : size
# pas : pas
# katup : katup
# plastiknya : plastik
# kadang : kadang
# rapat : rapat
# tumpah : tumpah
# vit : vit
# sebagus : bagus
# rajin : rajin
# pagi : pagi
# bekas : bekas
# hempas : hempas
# dipakai : pakai
# pemula : mula
# jum : jum
# at : at
# siang : siang
# ribu : ribu
# cashback : cashback
# gopay : gopay
# coin : coin
# free : free
# ongkir : ongkir
# btw : btw
# treatment : treatment
# dermapen : dermapen
# memudar : pudar
# packing : packing
# puffiness : puffiness
# ampuh : ampuh
# eksfoliasi : eksfoliasi
# tonernya : tonernya
# ngt : ngt
# packingan : packingan
# gambar : gambar
# masyaallah : masyaallah
# glowing : glowing
# maskernya : masker
# melembabkan : melembabkan
# ed : ed
# stok : stok
# mumpung : mumpung
# sajja : sajja
# everyone : everyone
# hulu : hulu
# hilir : hilir
# lot : lot
# dikasih : kasih
# laris : laris
# sukses : sukses
# love : love
# all : all
# alpha : alpha
# arbutin : arbutin
# dibawah : bawah
# tekstur : tekstur
# acneprone : acneprone
# parah : parah
# perubahan : ubah
# next : next
# order : order
# fan : fan
# ingredients : ingredients
# penasaran : penasaran
# pengin : pengin
# aaaa : aaaa
# pengirimannya : kirim
# tolong : tolong
# diganti : ganti
# kurirnya : kurir
# pertamanya : pertama
# dikirimin : dikirimin
# perbedaan : beda
# sale : sale
# return : return
# proses : proses
# ribet : ribet
# expedisi : expedisi
# pick : pick
# up : up
# maksudnya : maksud
# teliti : teliti
# buang : buang
# mengurusi : urus
# kedepannya : depan
# admin : admin
# responsive : responsive
# huhu : huhu
# ku : ku
# lempar : lempar
# tulisan : tulis
# fragile : fragile
# dusnya : dus
# skin : skin
# barier : barier
# rusak : rusak
# jerawatku : jerawat
# rewel : rewel
# produksi : produksi
# mencari : cari
# alternatif : alternatif
# menyamarkan : samar
# niacin : niacin
# ngefek : ngefek
# beruntusan : beruntus
# dibarengin : dibarengin
# tanggal : tanggal
# dibawa : bawa
# terbang : terbang
# pelayanan : layan
# menyenangkan : senang
# pengguna : guna
# setia : setia
# detail : detail
# dibungkus : bungkus
# kardus : kardus
# bolong : bolong
# trigger : trigger
# trypophobia : trypophobia
# norak : norak
# seminggu : minggu
# puas : puas
# seri : seri
# miraculous : miraculous
# berbotol : botol
# botol : botol
# plastik : plastik
# kaca : kaca
# teman : teman
# kusam : kusam
# whitehead : whitehead
# blackhead : blackhead
# wajib : wajib
# bismillah : bismillah
# voc : voc
# lokal : lokal
# mantul : mantul
# malam : malam
# paginya : pagi
# clearance : clearance
# semingguan : minggu
# lumayan : lumayan
# pliket : pliket
# menimbulkan : timbul
# original : original
# deskripsi : deskripsi
# display : display
# memesan : mes
# skincare : skincare
# loveable : loveable
# exfoliating : exfoliating
# kit : kit
# berisi : isi
# salycylic : salycylic
# acid : acid
# lactic : lactic
# dipesan : pes
# moisturizernya : moisturizernya
# lupa : lupa
# me : me
# record : record
# vidio : vidio
# unboxing : unboxing
# mengajukan : aju
# complain : complain
# tim : tim
# cekit : cekit
# besok : besok
# langsung : langsung
# oiya : oiya
# pakenya : pakenya
# keberapa : berapa
# eks : eks
# packinganny : packinganny
# kerdus : kerdus
# paperwrap : paperwrap
# dimuka : muka
# and : and
# teringan : tering
# dikulit : kulit
# mungil : mungil
# traveling : traveling
# friendly : friendly
# menghidrasi : hidrasi
# bening : bening
# kental : kental
# kenyal : kenyal
# sehat : sehat
# muda : muda
# phte : phte
# kelembaban : kelembaban
# acne : acne
# prone : prone
# langganan : langgan
# store : store
# terjamin : jamin
# keaslian : asli
# diserap : serap
# min : min
# pertamaku : pertama
# efek : efek
# jogja : jogja
# jakarta : jakarta
# yaampun : yaampun
# hihihi : hihihi
# stay : stay
# tune : tune
# echo : echo
# dikombinasi : kombinasi
# ysb : ysb
# menghilangkan : hilang
# hitam : hitam
# debuan : debu
# dalemnya : dalem
# recommend : recommend
# lactacid : lactacid
# kemasannya : kemas
# ampeg : ampeg
# rutin : rutin
# tidur : tidur
# hasil : hasil
# signifikan : signifikan
# ukurannya : ukur
# kondisi : kondisi
# respon : respon
# senang : senang
# ehehe : ehehe
# first : first
# time : time
# trying : trying
# this : this
# hopefully : hopefully
# works : works
# on : on
# my : my
# overall : overall
# well : well
# packaged : packaged
# coz : coz
# there : there
# is : is
# plastic : plastic
# sustainable : sustainable
# but : but
# takes : takes
# lil : lil
# bit : bit
# longer : longer
# tahan : tahan
# expect : expect
# nyampainya : nyampainya
# responnya : responnya
# komplain : komplain
# untung : untung
# harganya : harga
# relatif : relatif
# terjangkau : jangkau
# gacha : gacha
# bahan : bahan
# cair : cair
# ramah : ramah
# lingkungan : lingkung
# dah : dah
# fyi : fyi
# face : face
# viscosity : viscosity
# sabun : sabun
# kecuali : kecuali
# niat : niat
# perbaikan : baik
# brand : brand
# jual : jual
# customer : customer
# service : service
# bilang : bilang
# bersalah : salah
# silakan : sila
# cek : cek
# ulasan : ulas
# komennya : komennya
# batch : batch
# berubah : ubah
# encer : encer
# mending : mending
# dirugikan : rugi
# hte : hte
# vakum : vakum
# dibotolnya : botol
# jumat : jumat
# sore : sore
# kesalahan : salah
# sentosa : sentosa
# date : date
# bonusnya : bonus
# cabe : cabe
# rawit : rawit
# sekeren : keren
# terharu : haru
# mall : mall
# malas : malas
# belanja : belanja
# hidup : hidup
# penuh : penuh
# pekerjaan : kerja
# laporan : lapor
# kantor : kantor
# hehehe : hehehe
# apa-apa : apa
# paketnya : paket
# freebiesnya : freebiesnya
# kirim : kirim
# terbuka : buka
# brush : brush
# keras : keras
# bonus : bonus
# bibirku : bibir
# dioles : oles
# bagusnya : bagus
# warna : warna
# pink : pink
# bibir : bibir
# halus : halus
# tahap : tahap
# cuman : cuman
# ngirimnya : ngirimnya
# salut : salut
# sabar : sabar
# profesional : profesional
# menjalankan : jalan
# tugasnya : tugas
# fast : fast
# hyaluronic : hyaluronic
# plump : plump
# glass : glass
# thick : thick
# murah : murah
# berkah : berkah
# memudarkan : pudar
# imut : imut
# kotak : kotak
# dibuka : buka
# kotaknya : kotak
# request : request
# pembeli : beli
# kukasih : kasih
# aroma : aroma
# setelahnya : telah
# minggu : minggu
# oren : oren
# bandung : bandung
# bayar : bayar
# keterlambatan : lambat
# pengalaman : alam
# berbelanjanya : belanja
# reviewnya : reviewnya
# prosesnya : proses
# isi : isi
# favorit : favorit
# clearence : clearence
# affdorable : affdorable
# kayaknya : kayak
# cantik : cantik
# bersihin : bersihin
# debu : debu
# kecintaanku : cinta
# ngeresap : ngeresap
# uas : uas
# excellent : excellent
# iritasi : iritasi
# voucher : voucher
# buatan : buat
# anak : anak
# bangsa : bangsa
# kak : kak
# avoskinnya : avoskinnya
# membantu : bantu
# noda : noda
# eaa : eaa
# worry : worry
# maret : maret
# tumben : tumben
# cuci : cuci
# gudang : gudang
# akkk : akkk
# aga : aga
# kaya : kaya
# soldout : soldout
# prmo : prmo
# thanku : thanku
# taro : taro
# meja : meja
# kesenggol : senggol
# pembantu : bantu
# alhasil : alhasil
# pecah : pecah
# cerminnya : cermin
# kecintaan : cinta
# biki : bik
# aaa : aaa
# dompet : dompet
# yhh : yhh
# minvoo : minvoo
# hihii : hihii
# juara : juara
# kertas : kertas
# cakep : cakep
# bergulung : gulung
# really : really
# mwahh : mwahh
# efeknya : efek
# aa : aa
# dikulitku : kulit
# kombinasiin : kombinasiin
# ekspedisinya : ekspedisi
# bogor : bogor
# iseng : iseng
# checkout : checkout
# takut : takut
# inbox : inbox
# csnya : csnya
# bareng : bareng
# ampoulenya : ampoulenya
# devine : devine
# aura : aura
# kempes : kempes
# perbandingan : banding
# picnya : picnya
# versi : versi
# cool : cool
# too : too
# mas : mas
# warnanya : warna
# kuning : kuning
# negatif : negatif
# ngilangi : ngilangi
# rilis : rilis
# diskonan : diskon
# coklat : coklat
# cz : cz
# ijo : ijo
# gentle : gentle
# bruntusan : bruntusan
# mengecilkan : kecil
# worth : worth
# combo : combo
# malamnya : malam
# kesayangan : sayang
# retinolnya : retinolnya
# kentel : kentel
# cinta : cinta
# lovee : lovee
# tokopedia : tokopedia
# giftnya : giftnya
# licin : licin
# gilasiiihh : gilasiiihh
# dikemas : kemas
# problem : problem
# libur : libur
# meragukan : ragu
# secair : cair
# tube : tube
# boros : boros
# penurusan : turus
# viskositas : viskositas
# buka : buka
# hyaluron : hyaluron
# sekian : sekian
# cermin : cermin
# butuh : butuh
# skinker : skinker
# ah : ah
# happy : happy
# sayang : sayang
# kasar : kasar
# alasannya : alas
# jadwal : jadwal
# payday : payday
# double : double
# pilihannya : pilih
# niacinamide : niacinamide
# konsistensinya : konsistensi
# tuang : tuang
# kapas : kapas
# diusap : usap
# pengelupasan : kelupas
# which : which
# mempercepat : cepat
# peluruhan : peluruh
# mati : mati
# botolnya : botol
# mereview : mereview
# tutup : tutup
# menempel : tempel
# job : job
# segini : gin
# perbarui : baru
# alhamdulillaah : alhamdulillaah
# tuh : tuh
# recomended : recomended
# bantuan : bantu
# maksimal : maksimal
# penerimaan : terima
# panjanhmg : panjanhmg
# diawali : awal
# berusaha : usaha
# menghubungi : hubung
# bertanggung : tanggung
# terpakai : pakai
# perjalanan : jalan
# cekoutnya : cekoutnya
# mendekati : dekat
# tujuan : tuju
# xixixi : xixixi
# wkwkw : wkwkw
# guys : guys
# perfect : perfect
# sebulan : bulan
# han : han
# lucu : lucu
# kacanya : kaca
# avoskinn : avoskinn
# wkwk : wkwk
# penutup : tutup
# dalamnya : dalam
# seprti : seprti
# lipatnya : lipat
# amaan : ama
# dobel : dobel
# paper : paper
# wrap : wrap
# wajar : wajar
# bdg : bdg
# nih : nih
# anyway : anyway
# gift : gift
# terlama : lama
# des : des
# hayo : hayo
# bulu : bulu
# mataku : mata
# ihiww : ihiww
# bahagianya : bahagia
# pelanggan : langgan
# menunggu : tunggu
# timur : timur
# jawa : jawa
# type : type
# concern : concern
# penuaan : tua
# barusan : barusan
# berwarna : warna
# berbau : bau
# diusapkan : usap
# mesti : mesti
# war : war
# menyusui : susu
# recommended : recommended
# bumil : bumil
# busui : busui
# wishlist : wishlist
# terpenuhi : penuh
# pelembab : pelembab
# moist : moist
# comfort : comfort
# klaim : klaim
# bangun : bangun
# auto : auto
# cerah : cerah
# plumpy : plumpy
# minyakan : minyak
# menurutku : turut
# saking : saking
# cintanya : cinta
# eye : eye
# ampoule : ampoule
# pemakian : maki
# alergi : alergi
# name : name
# tag : tag
# butek : butek
# niacinemed : niacinemed
# lihat : lihat
# mash : mash
# hoki : hoki
# hilang : hilang
# ngabisin : ngabisin
# kerasa : rasa
# solid : solid
# delivery : delivery
# gesit : gesit
# patut : patut
# diacungi : acung
# ol : ol
# packinya : packinya
# lactid : lactid
# terlanjur : lanjur
# adminnya : adminnya
# skalian : skalian
# nyetok : nyetok
# ovoskin : ovoskin
# rada : rada
# gemas : gemas
# secocok : cocok
# menutrisi : nutrisi
# pastinya : pasti
# cus : cus
# wiiii : wiiii
# potongan : potong
# harian : hari
# digabungin : digabungin
# overnight : overnight
# fluffy : fluffy
# dipegang : pegang
# lambat : lambat
# test : test
# textured : textured
# sip : sip
# zonk : zonk
# tuker : tuker
# cancel : cancel
# tukar : tukar
# konfirmasi : konfirmasi
# kecewakan : kecewa
# penanganan : tangan
# diwaktu : waktu
# gue : gue
# jeroan : jeroan
# tamia : tamia
# sialan : sial
# tanggung : tanggung
# ekspedisi : ekspedisi
# lelet : lelet
# blunder : blunder
# angkat : angkat
# tangan : tangan
# solutif : solutif
# duit : duit
# packingannya : packingannya
# baca : baca
# taunya : tau
# thankyou : thankyou
# nyerepnya : nyerepnya
# polypeptide : polypeptide
# aqua : aqua
# ceramide : ceramide
# {'beautiful': 'beautiful', 'package': 'package', 'bintang': 'bintang', 'safety': 'safety', 'nya': 'nya', 'tipe': 'tipe', 'kulitku': 'kulit', 'kering': 'kering', 'pengiriman': 'kirim', 'beda': 'beda', 'provinsi': 'provinsi', 'gapapa': 'gapapa', 'packingnya': 'packingnya', 'aman': 'aman', 'banget': 'banget', 'semoga': 'moga', 'cocok': 'cocok', 'memperbaiki': 'baik', 'kulit': 'kulit', 'berminyak': 'minyak', 'top': 'top', 'normal': 'normal', 'kombinasi': 'kombinasi', 'kerutan': 'kerut', 'jerawat': 'jerawat', 'pori': 'pori', 'sensitif': 'sensitif', 'exp': 'exp', 'no': 'no', 'review': 'review', 'found': 'found', 'sih': 'sih', 'beli': 'beli', 'bagus': 'bagus', 'ya': 'ya', 'muka': 'muka', 'kemasan': 'kemas', 'biru': 'biru', 'viral': 'viral', 'perskincare': 'perskincare', 'an': 'an', 'semenjak': 'semenjak', 'hamil': 'hamil', 'stop': 'stop', 'pakai': 'pakai', 'produk': 'produk', 'bayi': 'bayi', 'coba': 'coba', 'kangen': 'kangen', 'sensasinya': 'sensasi', 'memakai': 'pakai', 'feelnya': 'feelnya', 'ngaruh': 'ngaruh', 'suka': 'suka', 'muncul': 'muncul', 'barang': 'barang', 'sesuai': 'sesuai', 'pesanan': 'pesan', 'oke': 'oke', 'saran': 'saran', 'facial': 'facial', 'wash': 'wash', 'fragrance': 'fragrance', 'biar': 'biar', 'baunya': 'bau', 'enak': 'enak', 'nyaman': 'nyaman', 'moga': 'moga', 'cepat': 'cepat', 'mantap': 'mantap', 'alhamdulillah': 'alhamdulillah', 'barangnya': 'barang', 'pengemasan': 'emas', 'ok': 'ok', 'thank': 'thank', 'you': 'you', 'kurir': 'kurir', 'sicepat': 'sicepat', 'team': 'team', 'avoskin': 'avoskin', 'bahannya': 'bahan', 'gampang': 'gampang', 'menyerap': 'serap', 'gratis': 'gratis', 'mini': 'mini', 'pouch': 'pouch', 'terima': 'terima', 'kasih': 'kasih', 'selau': 'selau', 'harga': 'harga', 'diskon': 'diskon', 'yes': 'yes', 'produknya': 'produk', 'berkali': 'kali', 'kali': 'kali', 'toko': 'toko', 'official': 'official', 'pembelian': 'beli', 'amanah': 'amanah', 'thanks': 'thanks', 'so': 'so', 'far': 'far', 'good': 'good', 'for': 'for', 'daily': 'daily', 'use': 'use', 'hasilnya': 'hasil', 'dicoba': 'coba', 'kemarin': 'kemarin', 'mencoba': 'coba', 'teksturnya': 'tekstur', 'ringan': 'ringan', 'mudah': 'mudah', 'blend': 'blend', 'whitecast': 'whitecast', 'oily': 'oily', 'apply': 'apply', 'hehe': 'hehe', 'manjur': 'manjur', 'exfoliasi': 'exfoliasi', 'wajahku': 'wajah', 'doesn': 'doesn', 'smell': 'smell', 'as': 'as', 'nice': 'nice', 'other': 'other', 'brands': 'brands', 'very': 'very', 'chemical': 'chemical', 'nemu': 'nemu', 'serum': 'serum', 'seller': 'seller', 'tokped': 'tokped', 'product': 'product', 'diterima': 'terima', 'bocor': 'bocor', 'berasa': 'asa', 'lembab': 'lembab', 'keluarkan': 'keluar', 'sunscreen': 'sunscreen', 'spf': 'spf', 'avo': 'avo', 'formulasinya': 'formulasi', 'persis': 'persis', 'kayak': 'kayak', 'tgs': 'tgs', 'please': 'please', 'kulitnya': 'kulit', 'paket': 'paket', 'rapi': 'rapi', 'seblmnya': 'seblmnya', 'varian': 'varian', 'ybs': 'ybs', 'tau': 'tau', 'yeey': 'yeey', 'deh': 'deh', 'menetap': 'tetap', 'selamat': 'selamat', 'packaging': 'packaging', 'orderan': 'order', 'always': 'always', 'the': 'the', 'best': 'best', 'avoo': 'avoo', 'kece': 'kece', 'kesekian': 'sekian', 'kalinya': 'kali', 'rugi': 'rugi', 'menyesal': 'sesal', 'toner': 'toner', 'berpaling': 'paling', 'merk': 'merk', 'dibikin': 'bikin', 'kecewa': 'kecewa', 'ml': 'ml', 'dikirim': 'kirim', 'aaaaaa': 'aaaaaa', 'chat': 'chat', 'solusi': 'solusi', 'disuruh': 'suruh', 'tunggu': 'tunggu', 'senin': 'senin', 'bikin': 'bikin', 'menambah': 'tambah', 'emosi': 'emosi', 'rating': 'rating', 'ganti': 'ganti', 'komunikatif': 'komunikatif', 'gercep': 'gercep', 'amin': 'amin', 'gede': 'gede', 'komedo': 'komedo', 'hidung': 'hidung', 'bantu': 'bantu', 'xixi': 'xixi', 'andalan': 'andal', 'exfo': 'exfo', 'dimalam': 'malam', 'mengasih': 'asih', 'promo': 'promo', 'pemakaian': 'pakai', 'terpercaya': 'percaya', 'diragukan': 'ragu', 'kalo': 'kalo', 'mah': 'mah', 'serumnya': 'serum', 'meresap': 'resap', 'wajah': 'wajah', 'lengket': 'lengket', 'benaran': 'benar', 'me ...
# ------------------------
# Pandas Apply: 100%|██████████| 401/401 [00:00<00:00, 65006.61it/s]
# 0             [beautiful, package, bintang, safety, nya]
# 1                                  [tipe, kulit, kering]
# 2      [kirim, beda, provinsi, gapapa, packingnya, am...
# 3                                                  [top]
# 4      [tipe, kulit, minyak, tipe, kulit, kering, tip...
#                              ...
# 397    [melembabkan, banget, tekstur, kental, cepat, ...
# 398                 [beli, cocok, kulit, bikin, iritasi]
# 399         [order, polypeptide, terima, aqua, ceramide]
# 400    [produk, sesuai, deskripsi, jual, recommended,...
# 401                 [pakai, cocok, bikin, kulit, kering]
# Name: review_tokens_stemmed, Length: 401, dtype: object
#                                               Review  \
# 0      it  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                          Review_norm  \
# 0     itu  beautiful package bintang buat safety nya
# 1                                tipe kulitku kering
# 2  pengiriman agak lama karena beda provinsi tapi...
# 3                                                top
# 4  tipe kulitku berminyak tipe kulitku kering tip...
#
#                                        review_tokens  \
# 0  [itu, beautiful, package, bintang, buat, safet...
# 1                            [tipe, kulitku, kering]
# 2  [pengiriman, agak, lama, karena, beda, provins...
# 3                                              [top]
# 4  [tipe, kulitku, berminyak, tipe, kulitku, keri...
#
#                                     review_tokens_SR  \
# 0         [beautiful, package, bintang, safety, nya]
# 1                            [tipe, kulitku, kering]
# 2  [pengiriman, beda, provinsi, gapapa, packingny...
# 3                                              [top]
# 4  [tipe, kulitku, berminyak, tipe, kulitku, keri...
#
#                                review_tokens_stemmed
# 0         [beautiful, package, bintang, safety, nya]
# 1                              [tipe, kulit, kering]
# 2  [kirim, beda, provinsi, gapapa, packingnya, am...
# 3                                              [top]
# 4  [tipe, kulit, minyak, tipe, kulit, kering, tip...

# %%
# import hasil preprocessing menjadi csv
df.to_csv("lemma_avoskin.csv")
