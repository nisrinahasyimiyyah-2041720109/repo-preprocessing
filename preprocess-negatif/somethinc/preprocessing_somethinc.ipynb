# %%
# Load data ke dalam data frame 
import pandas as pd

# Spesifikasi encoding diperlukan karena data tidak menggunakan UTF-8
df = pd.read_csv('scraping_somethinc-neg.csv', encoding='latin-1')

df.head()
# Out:
#                                               Review  \
# 0  pengiriman yg sangat lambat. sungguh mengecewa...
# 1  Kecewa bgt pelayanannya krg bisa membantu.. ud...
# 2                   Salah kirim. Harusnya glow maker
# 3  Pesanan belum diterima dan amsih ajukan kompla...
# 4  Malah muncul jerawat pas pake ini sekali,,sebe...
#
#                                              Product     Rating Username  \
# 0                    SOMETHINC CATCH THE GLOW Bundle  bintang 1    n***a
# 1   SOMETHINC 2% BHA Salicylic Acid Liquid Perfector  bintang 1    F***y
# 2                             SOMETHINC DRY SKIN Kit  bintang 1    D***y
# 3                  SOMETHINC Repair Your Skinbarrier  bintang 1     Lisa
# 4  SOMETHINC AHA 7%, BHA 1%, PHA 3% Weekly Peelin...  bintang 1    dioka
#
#                       Date
# 0  Lebih dari 1 tahun lalu
# 1  Lebih dari 1 tahun lalu
# 2  Lebih dari 1 tahun lalu
# 3  Lebih dari 1 tahun lalu
# 4  Lebih dari 1 tahun lalu

# %%
# Drop kolom yang tidak terpakai
df = df.drop(df.iloc[:,1:], axis=1)

# Cek data teratas
df.head()
# Out:
#                                               Review
# 0  pengiriman yg sangat lambat. sungguh mengecewa...
# 1  Kecewa bgt pelayanannya krg bisa membantu.. ud...
# 2                   Salah kirim. Harusnya glow maker
# 3  Pesanan belum diterima dan amsih ajukan kompla...
# 4  Malah muncul jerawat pas pake ini sekali,,sebe...

# %% [markdown]
# PREPROCESSING

# %%
# PROSES CASE FOLDING (menjadikan semua huruf di kolom Review menjadi huruf kecil)
df['Review'] = df['Review'].str.lower()

print('Case Folding Result: \n')
df.head()
# Out:
# Case Folding Result:
#                                               Review
# 0  pengiriman yg sangat lambat. sungguh mengecewa...
# 1  kecewa bgt pelayanannya krg bisa membantu.. ud...
# 2                   salah kirim. harusnya glow maker
# 3  pesanan belum diterima dan amsih ajukan kompla...
# 4  malah muncul jerawat pas pake ini sekali,,sebe...

# %%
# import hasil case folding menjadi csv
df.to_csv("casefolding_somethinc.csv")

# %%
# CLEANING
import re # regex library

def remove_tweet_special(text):
    # remove tab, new line, and back slice
    text = text.replace('\\t'," ").replace('\\n', " ").replace('\\u', " ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

df['Review'] = df['Review'].apply(remove_tweet_special)

# remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Review'] = df['Review'].apply(remove_number)

# remove punctuation and replace with space
def remove_punctuation(text):
    return re.sub(r'[.,]', ' ', text)

df['Review'] = df['Review'].apply(remove_punctuation)

# remove punctuation
def remove_symbol(text):
    # Menghapus simbol-simbol tidak standar dan menggantinya dengan spasi
    cleaned_text = re.sub(r'[^\w\s]', ' ', text)
    
    # Menghapus multiple whitespace
    cleaned_text = re.sub('\s+', ' ', cleaned_text).strip()
    
    return cleaned_text

df['Review'] = df['Review'].apply(remove_symbol)

# Menentukan ambang batas panjang string acak
threshold_length = 20

# Fungsi untuk menghapus string acak berdasarkan panjangnya
def hapus_string_acak_dengan_panjang(text):
    # Memeriksa panjang string dan menghapus jika melebihi ambang batas
    return ' '.join(word for word in text.split() if len(word) <= threshold_length)

# Menggunakan fungsi untuk menghapus string acak pada kolom 'Text'
df['Review'] = df['Review'].apply(hapus_string_acak_dengan_panjang)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Review'] = df['Review'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['Review'] = df['Review'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Review'] = df['Review'].apply(remove_single_char)

def remove_laughter(text):
    laughter_patterns = r'\b((ha)+h*|(he)+h*|(hi)+h*|(wk)+w*k*|(eh)+e*|(ah)+a*|(ih)+i*|(kw)+k*w*|(hem)+m*)\b'
    return re.sub(laughter_patterns, '', text, flags=re.IGNORECASE)

df['Review'] = df['Review'].apply(remove_laughter)

print('Cleaning Result : \n') 
print(df.head())
# Out:
# Cleaning Result :
#
#                                               Review
# 0  pengiriman yg sangat lambat sungguh mengecewak...
# 1  kecewa bgt pelayanannya krg bisa membantu udah...
# 2                    salah kirim harusnya glow maker
# 3  pesanan belum diterima dan amsih ajukan kompla...
# 4  malah muncul jerawat pas pake ini sekali sebel...

# %%
# import hasil cleaning menjadi csv
df.to_csv("cleaning_somethinc.csv")

# %%
# REMOVE DUPLICATE
df = df.drop_duplicates()
df = df.reset_index(drop=True)
# Menghapus baris yang kosong
df = df.dropna(subset=['Review'])
# Menghapus baris yang hanya berisi spasi atau whitespace
df = df[df['Review'].str.strip() != '']
df.head()
# Out:
#                                               Review
# 0  pengiriman yg sangat lambat sungguh mengecewak...
# 1  kecewa bgt pelayanannya krg bisa membantu udah...
# 2                    salah kirim harusnya glow maker
# 3  pesanan belum diterima dan amsih ajukan kompla...
# 4  malah muncul jerawat pas pake ini sekali sebel...

# %%
# import hasil remove duplicate menjadi csv
df.to_csv("removedup_somethinc.csv")

# %%
# NORMALIZATION
import pandas as pd
import re

slang_dictionary = pd.read_csv('../colloquial-indonesian-lexicon2.csv')
slang_dict = pd.Series(slang_dictionary['formal'].values,index=slang_dictionary['slang']).to_dict()

slang_dictionary.head()
# Out:
#      slang    formal  In-dictionary  \
# 0     woww       wow            1.0
# 1    aminn      amin            1.0
# 2      met   selamat            1.0
# 3   netaas   menetas            1.0
# 4  keberpa  keberapa            0.0
#
#                                              context  category1 category2  \
# 0                                                wow   elongasi         0
# 1  Selamat ulang tahun kakak tulus semoga panjang...   elongasi         0
# 2  Met hari netaas kak!? Wish you all the best @t...  abreviasi         0
# 3  Met hari netaas kak!? Wish you all the best @t...   afiksasi  elongasi
# 4                           Birthday yg keberpa kak?  abreviasi         0
#
#   category3
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# Normalisasi kata menggunakan kamus colloquial-indonesian-lexicon2.csv
def Slangwords(text, slang_dict):
    for word in text.split():
        if word in slang_dict.keys():
            # menambahkan \b untuk menandakan batas kata di sekitar kata slang
            text = re.sub(r'\b{}\b'.format(re.escape(word)), slang_dict[word], text)
    
    text = re.sub('@[\w]+', '', text)
    return text

df['Review_norm'] = df['Review'].apply(lambda x: Slangwords(x, slang_dict))
print(df.head())
# Out:
#                                               Review  \
# 0  pengiriman yg sangat lambat sungguh mengecewak...
# 1  kecewa bgt pelayanannya krg bisa membantu udah...
# 2                    salah kirim harusnya glow maker
# 3  pesanan belum diterima dan amsih ajukan kompla...
# 4  malah muncul jerawat pas pake ini sekali sebel...
#
#                                          Review_norm
# 0  pengiriman yang sangat lambat sungguh mengecew...
# 1  kecewa banget pelayanannya kurang bisa membant...
# 2                    salah kirim harusnya glow maker
# 3  pesanan belum diterima dan amsih ajukan kompla...
# 4  malah muncul jerawat pas pakai ini sekali sebe...

# %%
# import hasil replace slang words menjadi csv
df.to_csv("normalization_somethinc.csv")

# %%
# PROSES TOKENIZING (word_tokenize() untuk memecah string kedalam tokens)

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Tokenizing
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['review_tokens'] = df['Review_norm'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df.head())
# Out:
# Tokenizing Result :
#
#                                               Review  \
# 0  pengiriman yg sangat lambat sungguh mengecewak...
# 1  kecewa bgt pelayanannya krg bisa membantu udah...
# 2                    salah kirim harusnya glow maker
# 3  pesanan belum diterima dan amsih ajukan kompla...
# 4  malah muncul jerawat pas pake ini sekali sebel...
#
#                                          Review_norm  \
# 0  pengiriman yang sangat lambat sungguh mengecew...
# 1  kecewa banget pelayanannya kurang bisa membant...
# 2                    salah kirim harusnya glow maker
# 3  pesanan belum diterima dan amsih ajukan kompla...
# 4  malah muncul jerawat pas pakai ini sekali sebe...
#
#                                        review_tokens
# 0  [pengiriman, yang, sangat, lambat, sungguh, me...
# 1  [kecewa, banget, pelayanannya, kurang, bisa, m...
# 2              [salah, kirim, harusnya, glow, maker]
# 3  [pesanan, belum, diterima, dan, amsih, ajukan,...
# 4  [malah, muncul, jerawat, pas, pakai, ini, seka...

# %%
# import hasil tokenizing menjadi csv
df.to_csv("tokenizing_somethinc.csv")

# %%
# PROSES FILTERING (Stopword Removal)
from nltk.corpus import stopwords

# get stopword indonesia from NLTK stopword
list_stopwords = stopwords.words('indonesian')

# convert list to dictionary
list_stopwords = set(list_stopwords)

# remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['review_tokens_SR'] = df['review_tokens'].apply(stopwords_removal) 

print(df.head())
# Out:
#                                               Review  \
# 0  pengiriman yg sangat lambat sungguh mengecewak...
# 1  kecewa bgt pelayanannya krg bisa membantu udah...
# 2                    salah kirim harusnya glow maker
# 3  pesanan belum diterima dan amsih ajukan kompla...
# 4  malah muncul jerawat pas pake ini sekali sebel...
#
#                                          Review_norm  \
# 0  pengiriman yang sangat lambat sungguh mengecew...
# 1  kecewa banget pelayanannya kurang bisa membant...
# 2                    salah kirim harusnya glow maker
# 3  pesanan belum diterima dan amsih ajukan kompla...
# 4  malah muncul jerawat pas pakai ini sekali sebe...
#
#                                        review_tokens  \
# 0  [pengiriman, yang, sangat, lambat, sungguh, me...
# 1  [kecewa, banget, pelayanannya, kurang, bisa, m...
# 2              [salah, kirim, harusnya, glow, maker]
# 3  [pesanan, belum, diterima, dan, amsih, ajukan,...
# 4  [malah, muncul, jerawat, pas, pakai, ini, seka...
#
#                                     review_tokens_SR
# 0  [pengiriman, lambat, sungguh, mengecewakan, pa...
# 1  [kecewa, banget, pelayanannya, membantu, kayak...
# 2                        [salah, kirim, glow, maker]
# 3  [pesanan, diterima, amsih, ajukan, komplain, t...
# 4                      [muncul, jerawat, pas, pakai]

# %%
# import hasil stopword removal menjadi csv
df.to_csv("stopword_somethinc.csv")

# %%
# PROSES LEMMATIZATION 
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['review_tokens_SR']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['review_tokens_stemmed'] = df['review_tokens_SR'].swifter.apply(get_stemmed_term)
print(df['review_tokens_stemmed'])
print(df.head())
# Out:
# 1450
# ------------------------
# pengiriman : kirim
# lambat : lambat
# sungguh : sungguh
# mengecewakan : kecewa
# pakai : pakai
# jasa : jasa
# merugikan : rugi
# konsumen : konsumen
# kecewa : kecewa
# banget : banget
# pelayanannya : layan
# membantu : bantu
# kayak : kayak
# chat : chat
# robot : robot
# salah : salah
# kirim : kirim
# glow : glow
# maker : maker
# pesanan : pesan
# diterima : terima
# amsih : amsih
# ajukan : aju
# komplain : komplain
# terima : terima
# selesai : selesai
# muncul : muncul
# jerawat : jerawat
# pas : pas
# kalo : kalo
# beli : beli
# nya : nya
# ya : ya
# sih : sih
# somethinc : somethinc
# masalahkan : masalah
# masalahkah : masalah
# packing : packing
# karyawan : karyawan
# jam : jam
# pagi : pagi
# loh : loh
# jarak : jarak
# kecamatan : camat
# tolong : tolong
# diperbaiki : baik
# management : management
# kalinya : kali
# kasih : kasih
# bintang : bintang
# pelayanan : layan
# nih : nih
# pembelian : beli
# sangatttttttttt : sangatttttttttt
# respon : respon
# penjual : jual
# lelet : lelet
# pikir : pikir
# cepat : cepat
# ditambah : tambah
# barang : barang
# free : free
# ongkir : ongkir
# pelit : pelit
# kikir : kikir
# care : care
# customer : customer
# laku : laku
# gratis : gratis
# kalah : kalah
# brand : brand
# mengasih : asih
# terbaik : baik
# note : note
# bye : bye
# produk : produk
# mukaku : muka
# beruntusan : beruntus
# parah : parah
# kulitnya : kulit
# disentuh : sentuh
# sakit : sakit
# konsultasi : konsultasi
# wa : wa
# please : please
# muka : muka
# orang : orang
# jual : jual
# doang : doang
# no : no
# review : review
# found : found
# irritated : irritated
# my : my
# eyelids : eyelids
# takes : takes
# while : while
# absorb : absorb
# kemasan : kemas
# botol : botol
# pecah : pecah
# isi : isi
# serum : serum
# tumpah : tumpah
# rapi : rapi
# pastikan : pasti
# mengirim : kirim
# periksa : periksa
# menambah : tambah
# baunya : bau
# menyengat : sengat
# suka : suka
# admin : admin
# pesan : pesan
# mata : mata
# matanya : mata
# invoice : invoice
# percaya : percaya
# notifnya : notifnya
# sekelas : kelas
# prima : prima
# stok : stok
# habis : habis
# tanggung : tanggung
# wanti : wanti
# sopan : sopan
# cek : cek
# dikemas : kemas
# aman : aman
# bikin : bikin
# botolnya : botol
# so : so
# disappointed : disappointed
# paraaaaah : paraaaaah
# produknya : produk
# bocor : bocor
# next : next
# time : time
# packaging : packaging
# rusak : rusak
# dikasih : kasih
# cocok : cocok
# kali : kali
# malam : malam
# wajah : wajah
# menyerap : serap
# kulit : kulit
# lengket : lengket
# pakeny : pakeny
# hancur : hancur
# edit : edit
# coba : coba
# holy : holy
# grail : grail
# bau : bau
# asam : asam
# bruntusan : bruntusan
# seblmnya : seblmnya
# halus : halus
# sulwha : sulwha
# mencoba : coba
# via : via
# service : service
# toped : toped
# muterrr : muterrr
# lelah : lelah
# sorry : sorry
# berniat : niat
# ganti : ganti
# rugi : rugi
# feedback : feedback
# jujur : jujur
# repurchase : repurchase
# holygrail : holygrail
# salmon : salmon
# dna : dna
# krim : krim
# sos : sos
# bakuchiol : bakuchiol
# tau : tau
# trigger : trigger
# anggep : anggep
# buang : buang
# sial : sial
# deh : deh
# first : first
# moga : moga
# bundling : bundling
# warnanya : warna
# beda : beda
# kuning : kuning
# gratisan : gratis
# mini : mini
# dikirimkan : kirim
# eyeshadow : eyeshadow
# bagus : bagus
# sayangnya : sayang
# shade : shade
# official : official
# store : store
# pipetnya : pipet
# gabisanyedot : gabisanyedot
# beling : beling
# pecahin : pecahin
# isinya : isi
# lumayan : lumayan
# astaga : astaga
# kekirim : kirim
# dimana : mana
# paketnya : paket
# follow : follow
# up : up
# bingunggg : bingunggg
# bha : bha
# colicylic : colicylic
# acid : acid
# lupa : lupa
# ngerekam : ngerekam
# dikirim : kirim
# alhasil : alhasil
# terpakai : pakai
# sumpah : sumpah
# toko : toko
# resmi : resmi
# karyawannya : karyawannya
# training : training
# betull : betull
# balikin : balikin
# berat : berat
# sayang : sayang
# mikir : mikir
# otak : otak
# dengkul : dengkul
# eyelinernya : eyelinernya
# kering : kering
# aplikator : aplikator
# keren : keren
# uplod : uplod
# video : video
# dijanjiin : dijanjiin
# sesuai : sesuai
# jadwal : jadwal
# bawa : bawa
# barangnya : barang
# dibalikin : dibalikin
# difollow : difollow
# rating : rating
# oily : oily
# nyaman : nyaman
# dipakai : pakai
# nyengat : nyengat
# cari : cari
# sunscreen : sunscreen
# direapply : direapply
# kegiatan : giat
# diluar : luar
# rumah : rumah
# serumnya : serum
# kaca : kaca
# fragile : fragile
# jatuh : jatuh
# rendah : rendah
# langsung : langsung
# lamaaaaa : lamaaaaa
# sayng : sayng
# sebagus : bagus
# tokonya : toko
# duh : duh
# nemu : nemu
# leletnya : lelet
# kebangetan : banget
# ditingkatkan : tingkat
# respond : respond
# suruh : suruh
# hubungi : hubung
# kurirnya : kurir
# status : status
# diinvestigasi : investigasi
# kerja : kerja
# refund : refund
# uang : uang
# kelar : kelar
# kapok : kapok
# kaleng : kaleng
# kualitasnya : kualitas
# hati : hati
# jebakan : jebak
# batman : batman
# kurir : kurir
# balesnya : balesnya
# dipindahtangankan : dipindahtangankan
# alamat : alamat
# kak : kak
# dikomplain : komplain
# ekspedisi : ekspedisi
# pengirimannya : kirim
# hadiahnya : hadiah
# bohongan : bohong
# bohong : bohong
# zzz : zzz
# maaf : maaf
# berminyak : minyak
# perusahaan : usaha
# ngirimnya : ngirimnya
# suffering : suffering
# from : from
# success : success
# efektif : efektif
# sedih : sedih
# kemasannya : kemas
# menutup : tutup
# rapat : rapat
# cairannya : cair
# viral : viral
# ekspektasi : ekspektasi
# breakout : breakout
# merah : merah
# pipi : pipi
# berjerawat : jerawat
# untung : untung
# obat : obat
# totol : totol
# bertele : tele
# tele : tele
# otomatis : otomatis
# bot : bot
# iya : iya
# oficial : oficial
# adjust : adjust
# sesuaikan : sesuai
# dear : dear
# diprosesnya : proses
# giliran : gilir
# cancel : cancel
# dkirim : dkirim
# jerawataaan : jerawataaan
# packingnya : packingnya
# tutup : tutup
# kebuka : buka
# tuh : tuh
# penggantian : ganti
# kirimnya : kirim
# repeat : repeat
# order : order
# berkali : kali
# nyesss : nyesss
# proses : proses
# dark : dark
# spot : spot
# reducer : reducer
# segel : segel
# terbang : terbang
# travelling : travelling
# lihat : lihat
# check : check
# pump : pump
# defect : defect
# saran : saran
# disuruh : suruh
# pindahin : pindahin
# share : share
# jar : jar
# menuduh : tuduh
# naro : naro
# safety : safety
# koper : koper
# skin : skin
# pouch : pouch
# conclusion : conclusion
# menawari : tawar
# retur : retur
# full : full
# videoin : videoin
# productnya : productnya
# unboxing : unboxing
# defectnya : defectnya
# cheapskate : cheapskate
# again : again
# original : original
# spatulanya : spatula
# pdahl : pdahl
# gift : gift
# terpaksa : paksa
# penilaian : nilai
# jelek : jelek
# al : al
# el : el
# ve : ve
# handle : handle
# balasnya : balas
# pertanyan : pertanyan
# jawabannya : jawab
# balas : balas
# membaca : baca
# permasalahan : masalah
# pembeli : beli
# serasa : serasa
# ditipu : tipu
# penjelasannya : jelas
# tutupnya : tutup
# sameday : sameday
# jerawatan : jerawat
# multibiome : multibiome
# jamuran : jamur
# jarang : jarang
# sebelahan : belah
# whatsapp : whatsapp
# mastiin : mastiin
# seram : seram
# luarnya : luar
# berani : berani
# retinol : retinol
# bakuchiolnya : bakuchiolnya
# oke : oke
# jatohnya : jatohnya
# efek : efek
# keramik : keramik
# pijat : pijat
# sensasi : sensasi
# dingin : dingin
# kado : kado
# tulis : tulis
# ucapan : ucap
# pengirim : kirim
# info : info
# dituliskan : tulis
# payah : payah
# emas : emas
# tanggal : tanggal
# okt : okt
# diproses : proses
# tegor : tegor
# berkalikali : berkalikali
# kapokkk : kapokkk
# dikasinya : kas
# supple : supple
# power : power
# direkam : rekam
# menyangka : sangka
# sebelah : belah
# melewati : lewat
# estimasi : estimasi
# cleansing : cleansing
# balm : balm
# meleleh : leleh
# kena : kena
# panas : panas
# paket : paket
# lengkap : lengkap
# sabtu : sabtu
# minggu : minggu
# weekday : weekday
# online : online
# real : real
# insecure : insecure
# lemot : lot
# responnya : responnya
# wtf : wtf
# buka : buka
# keputer : puter
# moisturizernya : moisturizernya
# voucher : voucher
# vouchernya : vouchernya
# apply : apply
# kemarin : kemarin
# kecantol : kecantol
# hilang : hilang
# tube : tube
# gede : gede
# seiprit : iprit
# kopong : kopong
# mengapai : kapai
# model : model
# ribet : ribet
# pakenya : pakenya
# diteken : teken
# worth : worth
# harganya : harga
# skincare : skincare
# mengikuti : ikut
# pakainya : pakai
# wax : wax
# menempel : tempel
# bulu : bulu
# ketiak : ketiak
# kertasnya : kertas
# idem : idem
# dibandingkan : banding
# kain : kain
# brgnya : brgnya
# cream : cream
# hijau : hijau
# pink : pink
# kejadian : jadi
# diperiksa : periksa
# lini : lini
# produksinya : produksi
# ofc : ofc
# lipstick : lipstick
# kondisi : kondisi
# patah : patah
# somplak : somplak
# ml : ml
# bocornya : bocor
# refill : refill
# sticky : sticky
# hard : hard
# blend : blend
# formula : formula
# doesn : doesn
# really : really
# conceal : conceal
# any : any
# darkness : darkness
# for : for
# me : me
# just : just
# looks : looks
# like : like
# an : an
# orange : orange
# layer : layer
# that : that
# sits : sits
# on : on
# top : top
# of : of
# moisturizer : moisturizer
# diplastikin : diplastikin
# disengaja : sengaja
# aneh : aneh
# thank : thank
# you : you
# rekomendasi : rekomendasi
# tokopedia : tokopedia
# oren : oren
# hp : hp
# jadul : jadul
# lampirkan : lampir
# foto : foto
# bukti : bukti
# ber : ber
# berulang : ulang
# merepotkan : repot
# penjelasan : jelas
# dikembalikan : kembali
# dagang : dagang
# kerontang : kerontang
# titik : titik
# ujung : ujung
# sticknya : sticknya
# melekat : lekat
# rese : rese
# dealing : dealing
# with : with
# such : such
# assholes : assholes
# dibawah : bawah
# bedak : bedak
# return : return
# bertanggung : tanggung
# scam : scam
# deskripsinya : deskripsi
# basic : basic
# wkaoakaowowoowakak : wkaoakaowowoowakak
# sebulan : bulan
# kasar : kasar
# terkelupas : kelupas
# perih : perih
# bermasalah : masalah
# menyebabkan : sebab
# tangan : tangan
# diskon : diskon
# ribu : ribu
# tertarik : tarik
# zonkk : zonkk
# nilai : nilai
# langganan : langgan
# checkout : checkout
# bundle : bundle
# buy : buy
# get : get
# silk : silk
# creme : creme
# bonus : bonus
# alasan : alas
# dilayani : layan
# pilih : pilih
# and : and
# berharap : harap
# kekurangannya : kurang
# semoga : moga
# kayanya : kaya
# sehari : hari
# kekuar : kuar
# packagingnya : packagingnya
# syaratnya : syarat
# nunggunya : nunggunya
# repacking : repacking
# ditulisan : tulis
# give : give
# menyesal : sesal
# mending : mending
# kepencet : pencet
# puas : puas
# star : star
# anehnya : aneh
# penyok : penyok
# lumerrr : lumerrr
# cuman : cuman
# niat : niat
# buruk : buruk
# apapun : apa
# niatnya : niat
# kepencer : kepencer
# hyaluronic : hyaluronic
# sadar : sadar
# niacinamide : niacinamide
# satunya : satu
# diganti : ganti
# niacinamidenya : niacinamidenya
# takut : takut
# tukar : tukar
# harga : harga
# lbarang : lbarang
# ironisnya : ironis
# melindungi : lindung
# bilang : bilang
# ukuran : ukur
# menyarankan : saran
# barangkali : barangkali
# teroksidasi : oksidasi
# profesional : profesional
# sop : sop
# nelpon : nelpon
# mengatai : katai
# dll : dll
# rir : rir
# menunggu : tunggu
# endingnya : endingnya
# butuh : butuh
# judul : judul
# pilihan : pilih
# warna : warna
# menipu : tipu
# taunya : tau
# ditetapin : ditetapin
# dijalan : jalan
# bubble : bubble
# rapping : rapping
# bersegel : segel
# kekeuh : kekeuh
# komplen : komplen
# hadeuhhh : hadeuhhh
# bawellllll : bawellllll
# super : super
# duperrrr : duperrrr
# ngomg : ngomg
# ramah : ramah
# fast : fast
# response : response
# berpengaruh : pengaruh
# tertulis : tulis
# resi : resi
# mengajukan : aju
# nomor : nomor
# telepon : telepon
# dilacak : lacak
# berpindah : pindah
# progress : progress
# sangaaaaattt : sangaaaaattt
# berganti : ganti
# mundur : mundur
# ampun : ampun
# berbeda : beda
# depannya : depan
# alasannya : alas
# seller : seller
# dibiarkan : biar
# klik : klik
# konfirmasi : konfirmasi
# prosesnya : proses
# hadiah : hadiah
# ultah : ultah
# keburu : keburu
# tanggalnya : tanggal
# dngn : dngn
# entar : entar
# reviewnya : reviewnya
# kotak : kotak
# kerdus : kerdus
# palette : palette
# sobek : sobek
# cantik : cantik
# expired : expired
# datenya : datenya
# september : september
# produksi : produksi
# iritasi : iritasi
# prank : prank
# expirednya : expirednya
# promo : promo
# bang : bang
# bahasa : bahasa
# complain : complain
# dksh : dksh
# berlaku : laku
# kelipatan : kelipat
# masak : masak
# promonya : promonya
# penjualnya : jual
# jeda : jeda
# ampas : ampas
# penipu : tipu
# solutif : solutif
# standar : standar
# memperhatikan : perhati
# prioritas : prioritas
# existing : existing
# pengin : pengin
# pindah : pindah
# merek : merek
# think : think
# the : the
# ordinary : ordinary
# is : is
# better : better
# malu : malu
# diskusi : diskusi
# ruang : ruang
# ketahuan : tahu
# bohongnya : bohong
# mengajak : ajak
# personal : personal
# kesalahan : salah
# memfitnah : fitnah
# mystery : mystery
# box : box
# murah : murah
# jualnya : jual
# dirugikan : rugi
# mengerti : erti
# diwrap : diwrap
# sisa : sisa
# kardusnya : kardus
# basah : basah
# alamt : alamt
# diubah : ubah
# item : item
# donasi : donasi
# waterproof : waterproof
# tissue : tissue
# keapus : keapus
# facial : facial
# washnya : washnya
# minyak : minyak
# tanah : tanah
# deskripsi : deskripsi
# size : size
# jelasin : jelasin
# ukuranya : ukuranya
# kiraiin : kiraiin
# besaran : besar
# puluhan : puluh
# products : products
# something : something
# purchase : purchase
# marketing : marketing
# dapatnya : dapat
# sebanding : banding
# bilangnya : bilang
# kelingking : kelingking
# jntny : jntny
# marah : marah
# serumny : serumny
# ruam : ruam
# gatal : gatal
# ku : ku
# lanjutkan : lanjut
# beruntsan : beruntsan
# timbul : timbul
# jrwt : jrwt
# akhirny : akhirny
# mnggu : mnggu
# brhrnti : brhrnti
# ujungnya : ujung
# dimuka : muka
# tes : tes
# benaran : benar
# besok : besok
# nipu : nipu
# sehabis : habis
# toner : toner
# mukanya : muka
# sensitif : sensitif
# sabun : sabun
# cucimuka : cucimuka
# micellar : micellar
# water : water
# skincarenya : skincarenya
# hasilnya : hasil
# gara : gara
# dibuka : buka
# pencetannya : pencet
# pemakaian : pakai
# perubahan : ubah
# kusam : kusam
# dikirimnya : kirim
# tunggu : tunggu
# seminggu : minggu
# kabar : kabar
# ikhlasin : ikhlasin
# hitung : hitung
# sedekah : sedekah
# korban : korban
# gacocok : gacocok
# air : air
# mengandung : kandung
# silikon : silikon
# anteraja : anteraja
# milia : milia
# sample : sample
# miring : miring
# meaning : meaning
# pastinya : pasti
# expect : expect
# much : much
# this : this
# launch : launch
# quality : quality
# konsepnya : konsep
# diterapkan : terap
# cuaca : cuaca
# indonesia : indonesia
# tint : tint
# product : product
# arab : arab
# ijo : ijo
# menjamin : jamin
# pengemasan : emas
# malas : malas
# rekomen : rekomen
# responsif : responsif
# sengaja : sengaja
# adminnya : adminnya
# ikhlas : ikhlas
# dikirimin : dikirimin
# shades : shades
# watermelon : watermelon
# snan : snan
# psfshsl : psfshsl
# lipsticknya : lipsticknya
# wlpn : wlpn
# menganggu : menganggu
# fungsi : fungsi
# ssh : ssh
# diaplikasi : aplikasi
# bibir : bibir
# segelnya : segel
# pumpnya : pumpnya
# tetes : tetes
# manual : manual
# out : out
# bingung : bingung
# kaish : kaish
# anter : anter
# hiks : hiks
# tertipu : tipu
# gbr : gbr
# ditukar : tukar
# membeli : beli
# bermanfaat : manfaat
# oktober : oktober
# bonusnya : bonus
# pigmented : pigmented
# asli : asli
# jakarta : jakarta
# berfungsi : fungsi
# ditekan : tekan
# macet : macet
# dibersihin : dibersihin
# eyeliner : eyeliner
# mudah : mudah
# lepas : lepas
# hitam : hitam
# difoto : foto
# gatel : gatel
# brontok : brontok
# diwajah : wajah
# mskipun : mskipun
# sponge : sponge
# kuningnya : kuning
# sabar : sabar
# eeeh : eeeh
# coco : coco
# charlotte : charlotte
# gakbisa : gakbisa
# bayar : bayar
# whitecast : whitecast
# abu : abu
# save : save
# ur : ur
# money : money
# guys : guys
# plusnya : plus
# teksturnya : tekstur
# taro : taro
# suhu : suhu
# sinar : sinar
# matahari : matahari
# nanggung : nanggung
# penipuan : tipu
# biar : biar
# kedapatan : dapat
# catokan : catokan
# tb : tb
# variannya : varian
# gambar : gambar
# versi : versi
# kpikiran : kpikiran
# ss : ss
# intinya : inti
# palsu : palsu
# ngecewain : ngecewain
# putih : putih
# susu : susu
# pertanggung : tanggung
# oknum : oknum
# meresahkan : resah
# ybs : ybs
# fotonya : foto
# dinding : dinding
# telitinya : teliti
# dipencet : pencet
# nyangkut : nyangkut
# tutulnya : tutul
# direview : direview
# youtube : youtube
# pipet : pipet
# eyelid : eyelid
# gila : gila
# gue : gue
# pusat : pusat
# ribuan : ribu
# shopee : shopee
# sampenye : sampenye
# piknik : piknik
# kemane : kemane
# barangnye : barangnye
# memuaskan : muas
# helpfull : helpfull
# oriented : oriented
# belanja : belanja
# fatal : fatal
# boohong : boohong
# dibatalkan : batal
# normal : normal
# reseller : reseller
# melambung : lambung
# eye : eye
# jahat : jahat
# pesannya : pesan
# usaha : usaha
# game : game
# changer : changer
# stockist : stockist
# kadang : kadang
# pre : pre
# teksturny : teksturny
# enak : enak
# teralu : alu
# padat : padat
# wangi : wangi
# kopi : kopi
# basi : basi
# bberapa : bberapa
# kelopak : kelopak
# mataku : mata
# gasuka : gasuka
# bahas : bahas
# gadapet : gadapet
# solusi : solusi
# etalse : etalse
# event : event
# baiknya : baik
# diupdate : diupdate
# etalase : etalase
# miskom : miskom
# labelnya : label
# barcode : barcode
# exp : exp
# dirusak : rusak
# tekstur : tekstur
# kelapa : kelapa
# testernya : tester
# gampang : gampang
# dibilangnya : bilang
# hoax : hoax
# suerr : suerr
# sampainya : sampai
# haduuh : haduuh
# dalemnya : dalem
# shopnya : shopnya
# bisanya : bisa
# puffnya : puffnya
# ketinggalan : tinggal
# dijual : jual
# terpisah : pisah
# lho : lho
# belinya : beli
# diofficial : diofficial
# shop : shop
# kosong : kosong
# confirmasi : confirmasi
# sistem : sistem
# cashles : cashles
# hmmm : hmmm
# menerima : terima
# orderan : order
# panel : panel
# reset : reset
# terlanjur : lanjur
# adik : adik
# lasting : lasting
# minum : minum
# efeknya : efek
# menangani : tangan
# dont : dont
# bother : bother
# using : using
# same : same
# day : day
# shipping : shipping
# because : because
# has : has
# sense : sense
# urgency : urgency
# bought : bought
# friday : friday
# morning : morning
# asked : asked
# politely : politely
# help : help
# ship : ship
# within : within
# chosen : chosen
# ended : ended
# receiving : receiving
# wednesday : wednesday
# following : following
# wig : wig
# they : they
# re : re
# going : going
# use : use
# lame : lame
# excuse : excuse
# dodge : dodge
# responsibility : responsibility
# now : now
# blaming : blaming
# courier : courier
# over : over
# flowed : flowed
# orders : orders
# etc : etc
# cekout : cekout
# dibilang : bilang
# aplikatornya : aplikatornya
# mah : mah
# besokannya : besok
# asia : asia
# tahan : tahan
# crack : crack
# opsi : opsi
# dikulit : kulit
# mengelupas : kelupas
# diguyur : guyur
# lotion : lotion
# sebegininya : begini
# huhu : huhu
# tertera : tera
# perasaan : asa
# seencer : encer
# encer : encer
# dibanding : banding
# berbau : bau
# smin : smin
# savior : savior
# bening : bening
# chemicals : chemicals
# kencang : kencang
# semuka : muka
# dibalas : balas
# template : template
# menyelesaikan : selesai
# memakai : pakai
# recommended : recommended
# memicu : picu
# plastik : plastik
# apa-apa : apa
# dibatalin : dibatalin
# dipisah : pisah
# sticker : sticker
# dihiraukan : hirau
# catatan : catat
# dpet : dpet
# konsistensinya : konsistensi
# kehijauan : hijau
# white : white
# cast : cast
# belepotan : belepotan
# terkesan : kes
# kotor : kotor
# mintak : mintak
# surat : surat
# msds : msds
# susahnya : susah
# cacat : cacat
# susah : susah
# sedot : sedot
# posisi : posisi
# tertutup : tutup
# diperhatikan : perhati
# puff : puff
# rusakkkkkkkk : rusakkkkkkkk
# masuk : masuk
# diklaim : klaim
# allah : allah
# nyaasar : nyaasar
# busanya : busa
# pusing : pusing
# munculnya : muncul
# bergantian : ganti
# aslinya : asli
# ngaruh : ngaruh
# kemana : mana
# tokped : tokped
# paksa : paksa
# wort : wort
# tintanya : tinta
# ok : ok
# tinta : tinta
# long : long
# pemakaiannya : pakai
# mohon : mohon
# anti : anti
# aging : aging
# kit : kit
# ih : ih
# gua : gua
# hubungan : hubung
# tlong : tlong
# du : du
# bantu : bantu
# gerak : gerak
# gliran : gliran
# pergerakan : gera
# lempar : lempar
# bell : bell
# nonaktifin : nonaktifin
# anterajanya : anterajanya
# rugiin : rugiin
# pembelinya : bel
# imbas : imbas
# aplikasikan : aplikasi
# cair : cair
# superrrr : superrrr
# juni : juni
# junu : junu
# ditanggal : tanggal
# juli : juli
# pinpon : pinpon
# ulas : ulas
# jelly : jelly
# cleansernya : cleansernya
# mempan : mempan
# bersihin : bersihin
# pembersih : bersih
# preloved : preloved
# alhamdulillah : alhamdulillah
# hasil : hasil
# limited : limited
# burning : burning
# sensation : sensation
# rutin : rutin
# kayaknya : kayak
# wajahku : wajah
# hentikan : henti
# pekat : pekat
# kulitku : kulit
# sulit : sulit
# meresap : resap
# biru : biru
# memerah : merah
# digulung : gulung
# wrap : wrap
# diaplikasikan : aplikasi
# basically : basically
# staynya : staynya
# rentang : rentang
# pekan : pekan
# fragrance : fragrance
# kuat : kuat
# tingling : tingling
# sabaaarrrrr : sabaaarrrrr
# lecet : lecet
# leleeet : leleeet
# knowledge : knowledge
# laman : laman
# reaksi : reaksi
# cairan : cair
# nunjukin : nunjukin
# menghilangkan : hilang
# dagu : dagu
# pelipis : pelipis
# dahi : dahi
# purging : purging
# penuh : penuh
# kardus : kardus
# smells : smells
# rat : rat
# piss : piss
# sg : sg
# why : why
# smell : smell
# weird : weird
# discontinue : discontinue
# them : them
# after : after
# couple : couple
# times : times
# cuz : cuz
# cant : cant
# stand : stand
# membersihkan : bersih
# very : very
# light : light
# non : non
# termakan : makan
# iklan : iklan
# influencer : influencer
# will : will
# be : be
# last : last
# pengemasannya : emas
# dicek : cek
# nutupnya : nutupnya
# honest : honest
# easy : easy
# carry : carry
# everywhere : everywhere
# touch : touch
# whenever : whenever
# we : we
# want : want
# pokoknya : pokok
# praktis : praktis
# tapiiii : tapiiii
# minthinc : minthinc
# development : development
# hantu : hantu
# baca : baca
# skintone : skintone
# neutral : neutral
# oil : oil
# control : control
# saking : saking
# okenya : oke
# nge : nge
# applynya : applynya
# ide : ide
# improve : improve
# love : love
# bucin : bucin
# perbaikan : baik
# rembes : rembes
# flash : flash
# sale : sale
# tipu : tipu
# ditiitpkan : ditiitpkan
# pemilik : milik
# shg : shg
# ditujuan : tuju
# dipesan : pes
# didalam : dalam
# ngefek : ngefek
# kualitas : kualitas
# clickbait : clickbait
# terbatas : batas
# kemarinnya : kemarin
# mahal : mahal
# iming : iming
# dikit : dikit
# lembabnya : lembabnya
# not : not
# hypeee : hypeee
# dicobain : dicobain
# diraut : raut
# menyebalkan : sebal
# somethic : somethic
# worst : worst
# ongkirnya : ongkirnya
# sicepat : sicepat
# wadahnya : wadah
# ditolerir : tolerir
# qc : qc
# update : update
# membiasakan : biasa
# concentrate : concentrate
# gel : gel
# membekas : bekas
# esok : esok
# mendukung : dukung
# fitur : fitur
# plus : plus
# tumpahan : tumpah
# lulus : lulus
# knapa : knapa
# higienis : higienis
# ngambilnya : ngambilnya
# transparan : transparan
# promosinya : promosi
# disemprotkan : semprot
# bercak : bercak
# menggumpal : gumpal
# petunjuk : tunjuk
# overall : overall
# paketan : paket
# bolong : bolong
# dibolongin : dibolongin
# buble : buble
# dikemasan : kemas
# ulasan : ulas
# lem : lem
# luntur : luntur
# ac : ac
# keringetan : keringetan
# ketiga : tiga
# nyiplak : nyiplak
# ngantuk : ngantuk
# ganjel : ganjel
# tergantung : gantung
# tipe : tipe
# hmm : hmm
# dtgnya : dtgnya
# tok : tok
# revieuw : revieuw
# setengahnya : tengah
# tebal : tebal
# berhenti : henti
# resurrect : resurrect
# terlampir : lampir
# monmaap : monmaap
# didalem : dalem
# jmbut : jmbut
# metalik : metalik
# unpleasant : unpleasant
# ig : ig
# before : before
# sending : sending
# paginya : pagi
# slow : slow
# pembayaran : bayar
# terkonfirmasi : konfirmasi
# harap : harap
# ditutup : tutup
# nutup : nutup
# beleber : beber
# gadungan : gadungan
# samasekali : samasekali
# ampuh : ampuh
# paparan : papar
# menit : menit
# ciwi : ciwi
# unyu : unyu
# mobil : mobil
# driver : driver
# pejuang : juang
# mengemudi : kemudi
# reapply : reapply
# sunburned : sunburned
# bebas : bebas
# alkohol : alkohol
# encapsulated : encapsulated
# uv : uv
# filter : filter
# hybrid : hybrid
# iklannya : iklan
# dipersulit : sulit
# tombol : tombol
# mbaknya : mbak
# gerangan : gerangan
# kesel : kesel
# melebihi : lebih
# kuas : kuas
# masker : masker
# negeri : negeri
# lokal : lokal
# november : november
# kerjanya : kerja
# dideskripsikan : deskripsi
# kolom : kolom
# jangka : jangka
# pikirkan : pikir
# jeruk : jeruk
# apek : apek
# flek : flek
# noda : noda
# tumoah : tumoah
# nyerap : nyerap
# bungkusnya : bungkus
# oackingnya : oackingnya
# diupgrade : diupgrade
# min : min
# terulang : ulang
# brownya : brownya
# tulisannya : tulis
# brow : brow
# bubblewarp : bubblewarp
# jne : jne
# hate : hate
# bad : bad
# cushion : cushion
# daerah : daerah
# hidung : hidung
# longgar : longgar
# keluarga : keluarga
# bantuin : bantuin
# belikan : belikan
# duluan : duluan
# memiliki : milik
# ditegur : tegur
# batal : batal
# tinggal : tinggal
# good : good
# luck : luck
# keduanys : keduanys
# musim : musim
# hujan : hujan
# dilapisi : lapis
# plastic : plastic
# label : label
# dibaca : baca
# makan : makan
# stay : stay
# transferproof : transferproof
# claim : claim
# butiran : butir
# lipstiknya : lipstik
# {'pengiriman': 'kirim', 'lambat': 'lambat', 'sungguh': 'sungguh', 'mengecewakan': 'kecewa', 'pakai': 'pakai', 'jasa': 'jasa', 'merugikan': 'rugi', 'konsumen': 'konsumen', 'kecewa': 'kecewa', 'banget': 'banget', 'pelayanannya': 'layan', 'membantu': 'bantu', 'kayak': 'kayak', 'chat': 'chat', 'robot': 'robot', 'salah': 'salah', 'kirim': 'kirim', 'glow': 'glow', 'maker': 'maker', 'pesanan': 'pesan', 'diterima': 'terima', 'amsih': 'amsih', 'ajukan': 'aju', 'komplain': 'komplain', 'terima': 'terima', 'selesai': 'selesai', 'muncul': 'muncul', 'jerawat': 'jerawat', 'pas': 'pas', 'kalo': 'kalo', 'beli': 'beli', 'nya': 'nya', 'ya': 'ya', 'sih': 'sih', 'somethinc': 'somethinc', 'masalahkan': 'masalah', 'masalahkah': 'masalah', 'packing': 'packing', 'karyawan': 'karyawan', 'jam': 'jam', 'pagi': 'pagi', 'loh': 'loh', 'jarak': 'jarak', 'kecamatan': 'camat', 'tolong': 'tolong', 'diperbaiki': 'baik', 'management': 'management', 'kalinya': 'kali', 'kasih': 'kasih', 'bintang': 'bintang', 'pelayanan': 'layan', 'nih': 'nih', 'pembelian': 'beli', 'sangatttttttttt': 'sangatttttttttt', 'respon': 'respon', 'penjual': 'jual', 'lelet': 'lelet', 'pikir': 'pikir', 'cepat': 'cepat', 'ditambah': 'tambah', 'barang': 'barang', 'free': 'free', 'ongkir': 'ongkir', 'pelit': 'pelit', 'kikir': 'kikir', 'care': 'care', 'customer': 'customer', 'laku': 'laku', 'gratis': 'gratis', 'kalah': 'kalah', 'brand': 'brand', 'mengasih': 'asih', 'terbaik': 'baik', 'note': 'note', 'bye': 'bye', 'produk': 'produk', 'mukaku': 'muka', 'beruntusan': 'beruntus', 'parah': 'parah', 'kulitnya': 'kulit', 'disentuh': 'sentuh', 'sakit': 'sakit', 'konsultasi': 'konsultasi', 'wa': 'wa', 'please': 'please', 'muka': 'muka', 'orang': 'orang', 'jual': 'jual', 'doang': 'doang', 'no': 'no', 'review': 'review', 'found': 'found', 'irritated': 'irritated', 'my': 'my', 'eyelids': 'eyelids', 'takes': 'takes', 'while': 'while', 'absorb': 'absorb', 'kemasan': 'kemas', 'botol': 'botol', 'pecah': 'pecah', 'isi': 'isi', 'serum': 'serum', 'tumpah': 'tumpah', 'rapi': 'rapi', 'pastikan': 'pasti', 'mengirim': 'kirim', 'periksa': 'periksa', 'menambah': 'tambah', 'baunya': 'bau', 'menyengat': 'sengat', 'suka': 'suka', 'admin': 'admin', 'pesan': 'pesan', 'mata': 'mata', 'matanya': 'mata', 'invoice': 'invoice', 'percaya': 'percaya', 'notifnya': 'notifnya', 'sekelas': 'kelas', 'prima': 'prima', 'stok': 'stok', 'habis': 'habis', 'tanggung': 'tanggung', 'wanti': 'wanti', 'sopan': 'sopan', 'cek': 'cek', 'dikemas': 'kemas', 'aman': 'aman', 'bikin': 'bikin', 'botolnya': 'botol', 'so': 'so', 'disappointed': 'disappointed', 'paraaaaah': 'paraaaaah', 'produknya': 'produk', 'bocor': 'bocor', 'next': 'next', 'time': 'time', 'packaging': 'packaging', 'rusak': 'rusak', 'dikasih': 'kasih', 'cocok': 'cocok', 'kali': 'kali', 'malam': 'malam', 'wajah': 'wajah', 'menyerap': 'serap', 'kulit': 'kulit', 'lengket': 'lengket', 'pakeny': 'pakeny', 'hancur': 'hancur', 'edit': 'edit', 'coba': 'coba', 'holy': 'holy', 'grail': 'grail', 'bau': 'bau', 'asam': 'asam', 'bruntusan': 'bruntusan', 'seblmnya': 'seblmnya', 'halus': 'halus', 'sulwha': 'sulwha', 'mencoba': 'coba', 'via': 'via', 'service': 'service', 'toped': 'toped', 'muterrr': 'muterrr', 'lelah': 'lelah', 'sorry': 'sorry', 'berniat': 'niat', 'ganti': 'ganti', 'rugi': 'rugi', 'feedback': 'feedback', 'jujur': 'jujur', 'repurchase': 'repurchase', 'holygrail': 'holygrail', 'salmon': 'salmon', 'dna': 'dna', 'krim': 'krim', 'sos': 'sos', 'bakuchiol': 'bakuchiol', 'tau': 'tau', 'trigger': 'trigger', 'anggep': 'anggep', 'buang': 'buang', 'sial': 'sial', 'deh': 'deh', 'first': 'first', 'moga': 'moga', 'bundling': 'bundling', 'warnanya': 'warna', 'beda': 'beda', 'kuning': 'kuning', 'gratisan': 'gratis', 'mini': 'mini', 'dikirimkan': 'kirim', 'eyeshadow': 'eyeshadow', 'bagus': 'bagus', 'sayangnya': 'sayang', 'shade': 'shade', 'official': 'official', 'store': 'store', 'pipetnya': 'pipet', 'gabisanyedot': 'gabisanyedot', 'beling': 'beling', 'pecahin': 'pecahin', 'isinya': 'isi', 'lumayan': 'lumaya ...
# ------------------------
# Pandas Apply: 100%|██████████| 356/356 [00:00<00:00, 50821.01it/s]
# 0      [kirim, lambat, sungguh, kecewa, pakai, jasa, ...
# 1      [kecewa, banget, layan, bantu, kayak, chat, ro...
# 2                            [salah, kirim, glow, maker]
# 3      [pesan, terima, amsih, aju, komplain, terima, ...
# 4                          [muncul, jerawat, pas, pakai]
#                              ...
# 352                           [jujur, asih, efek, serum]
# 353                        [order, keduanys, kirim, nya]
# 354    [packaging, aman, musim, hujan, lapis, plastic...
# 355                           [tokopedia, kirim, lambat]
# 356    [tahan, pakai, makan, langsung, hilang, stay, ...
# Name: review_tokens_stemmed, Length: 356, dtype: object
#                                               Review  \
# 0  pengiriman yg sangat lambat sungguh mengecewak...
# 1  kecewa bgt pelayanannya krg bisa membantu udah...
# 2                    salah kirim harusnya glow maker
# 3  pesanan belum diterima dan amsih ajukan kompla...
# 4  malah muncul jerawat pas pake ini sekali sebel...
#
#                                          Review_norm  \
# 0  pengiriman yang sangat lambat sungguh mengecew...
# 1  kecewa banget pelayanannya kurang bisa membant...
# 2                    salah kirim harusnya glow maker
# 3  pesanan belum diterima dan amsih ajukan kompla...
# 4  malah muncul jerawat pas pakai ini sekali sebe...
#
#                                        review_tokens  \
# 0  [pengiriman, yang, sangat, lambat, sungguh, me...
# 1  [kecewa, banget, pelayanannya, kurang, bisa, m...
# 2              [salah, kirim, harusnya, glow, maker]
# 3  [pesanan, belum, diterima, dan, amsih, ajukan,...
# 4  [malah, muncul, jerawat, pas, pakai, ini, seka...
#
#                                     review_tokens_SR  \
# 0  [pengiriman, lambat, sungguh, mengecewakan, pa...
# 1  [kecewa, banget, pelayanannya, membantu, kayak...
# 2                        [salah, kirim, glow, maker]
# 3  [pesanan, diterima, amsih, ajukan, komplain, t...
# 4                      [muncul, jerawat, pas, pakai]
#
#                                review_tokens_stemmed
# 0  [kirim, lambat, sungguh, kecewa, pakai, jasa, ...
# 1  [kecewa, banget, layan, bantu, kayak, chat, ro...
# 2                        [salah, kirim, glow, maker]
# 3  [pesan, terima, amsih, aju, komplain, terima, ...
# 4                      [muncul, jerawat, pas, pakai]

# %%
# import hasil preprocessing menjadi csv
df.to_csv("lemma_somethinc.csv")
