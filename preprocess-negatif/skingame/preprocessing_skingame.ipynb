# %%
# Load data ke dalam data frame 
import pandas as pd

# Spesifikasi encoding diperlukan karena data tidak menggunakan UTF-8
df = pd.read_csv('scraping_skingame-neg.csv', encoding='latin-1')

df.head()
# Out:
#                                               Review  \
# 0  barang sampai di saya, plastik seal nya udh ru...
# 1  Bau nya ko beda ya, bikin mual, aneh aja ngga ...
# 2                                    No review found
# 3                                    No review found
# 4                                 Tutup botol mampet
#
#                             Product     Rating Username  \
# 0  Skin Game Daily Kind Moisturizer  bintang 1    e***a
# 1  Skin Game Daily Kind Facial Wash  bintang 1    shopi
# 2    Skin Game Theory of Everything  bintang 1  Rachmat
# 3            Skin Game Acne Warrior  bintang 1    K***n
# 4            Skin Game Acne Warrior  bintang 1    b***u
#
#                       Date
# 0  Lebih dari 1 tahun lalu
# 1  Lebih dari 1 tahun lalu
# 2             8 bulan lalu
# 3               2024-01-27
# 4  Lebih dari 1 tahun lalu

# %%
# Drop kolom yang tidak terpakai
df = df.drop(df.iloc[:,1:], axis=1)

# Cek data teratas
df.head()
# Out:
#                                               Review
# 0  barang sampai di saya, plastik seal nya udh ru...
# 1  Bau nya ko beda ya, bikin mual, aneh aja ngga ...
# 2                                    No review found
# 3                                    No review found
# 4                                 Tutup botol mampet

# %% [markdown]
# PREPROCESSING

# %%
# PROSES CASE FOLDING (menjadikan semua huruf di kolom Review menjadi huruf kecil)
df['Review'] = df['Review'].str.lower()

print('Case Folding Result: \n')
df.head()
# Out:
# Case Folding Result:
#                                               Review
# 0  barang sampai di saya, plastik seal nya udh ru...
# 1  bau nya ko beda ya, bikin mual, aneh aja ngga ...
# 2                                    no review found
# 3                                    no review found
# 4                                 tutup botol mampet

# %%
# import hasil case folding menjadi csv
df.to_csv("casefolding_skingame.csv")

# %%
# CLEANING
import re # regex library

def remove_tweet_special(text):
    # remove tab, new line, and back slice
    text = text.replace('\\t'," ").replace('\\n', " ").replace('\\u', " ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

df['Review'] = df['Review'].apply(remove_tweet_special)

# remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Review'] = df['Review'].apply(remove_number)

# remove punctuation and replace with space
def remove_punctuation(text):
    return re.sub(r'[.,]', ' ', text)

df['Review'] = df['Review'].apply(remove_punctuation)

# remove punctuation
def remove_symbol(text):
    # Menghapus simbol-simbol tidak standar dan menggantinya dengan spasi
    cleaned_text = re.sub(r'[^\w\s]', ' ', text)
    
    # Menghapus multiple whitespace
    cleaned_text = re.sub('\s+', ' ', cleaned_text).strip()
    
    return cleaned_text

df['Review'] = df['Review'].apply(remove_symbol)

# Menentukan ambang batas panjang string acak
threshold_length = 20

# Fungsi untuk menghapus string acak berdasarkan panjangnya
def hapus_string_acak_dengan_panjang(text):
    # Memeriksa panjang string dan menghapus jika melebihi ambang batas
    return ' '.join(word for word in text.split() if len(word) <= threshold_length)

# Menggunakan fungsi untuk menghapus string acak pada kolom 'Text'
df['Review'] = df['Review'].apply(hapus_string_acak_dengan_panjang)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Review'] = df['Review'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['Review'] = df['Review'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Review'] = df['Review'].apply(remove_single_char)

def remove_laughter(text):
    laughter_patterns = r'\b((ha)+h*|(he)+h*|(hi)+h*|(wk)+w*k*|(eh)+e*|(ah)+a*|(ih)+i*|(kw)+k*w*|(hem)+m*)\b'
    return re.sub(laughter_patterns, '', text, flags=re.IGNORECASE)

df['Review'] = df['Review'].apply(remove_laughter)

print('Cleaning Result : \n') 
print(df.head())
# Out:
# Cleaning Result :
#
#                                               Review
# 0  barang sampai di saya plastik seal nya udh rus...
# 1  bau nya ko beda ya bikin mual aneh aja ngga ky...
# 2                                    no review found
# 3                                    no review found
# 4                                 tutup botol mampet

# %%
# import hasil cleaning menjadi csv
df.to_csv("cleaning_skingame.csv")

# %%
# REMOVE DUPLICATE
df = df.drop_duplicates()
df = df.reset_index(drop=True)
# Menghapus baris yang kosong
df = df.dropna(subset=['Review'])
# Menghapus baris yang hanya berisi spasi atau whitespace
df = df[df['Review'].str.strip() != '']
df.head()
# Out:
#                                               Review
# 0  barang sampai di saya plastik seal nya udh rus...
# 1  bau nya ko beda ya bikin mual aneh aja ngga ky...
# 2                                    no review found
# 3                                 tutup botol mampet
# 4                                         pump macet

# %%
# import hasil remove duplicate menjadi csv
df.to_csv("removedup_skingame.csv")

# %%
# NORMALIZATION
import pandas as pd
import re

slang_dictionary = pd.read_csv('../colloquial-indonesian-lexicon2.csv')
slang_dict = pd.Series(slang_dictionary['formal'].values,index=slang_dictionary['slang']).to_dict()

slang_dictionary.head()
# Out:
#      slang    formal  In-dictionary  \
# 0     woww       wow            1.0
# 1    aminn      amin            1.0
# 2      met   selamat            1.0
# 3   netaas   menetas            1.0
# 4  keberpa  keberapa            0.0
#
#                                              context  category1 category2  \
# 0                                                wow   elongasi         0
# 1  Selamat ulang tahun kakak tulus semoga panjang...   elongasi         0
# 2  Met hari netaas kak!? Wish you all the best @t...  abreviasi         0
# 3  Met hari netaas kak!? Wish you all the best @t...   afiksasi  elongasi
# 4                           Birthday yg keberpa kak?  abreviasi         0
#
#   category3
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# Normalisasi kata menggunakan kamus colloquial-indonesian-lexicon2.csv
def Slangwords(text, slang_dict):
    for word in text.split():
        if word in slang_dict.keys():
            # menambahkan \b untuk menandakan batas kata di sekitar kata slang
            text = re.sub(r'\b{}\b'.format(re.escape(word)), slang_dict[word], text)
    
    text = re.sub('@[\w]+', '', text)
    return text

df['Review_norm'] = df['Review'].apply(lambda x: Slangwords(x, slang_dict))
print(df.head())
# Out:
#                                               Review  \
# 0  barang sampai di saya plastik seal nya udh rus...
# 1  bau nya ko beda ya bikin mual aneh aja ngga ky...
# 2                                    no review found
# 3                                 tutup botol mampet
# 4                                         pump macet
#
#                                          Review_norm
# 0  barang sampai di saya plastik seal nya sudah r...
# 1  bau nya kok beda ya bikin mual aneh saja engga...
# 2                                    no review found
# 3                                 tutup botol mampet
# 4                                         pump macet

# %%
# import hasil replace slang words menjadi csv
df.to_csv("normalization_skingame.csv")

# %%
# PROSES TOKENIZING (word_tokenize() untuk memecah string kedalam tokens)

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Tokenizing
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['review_tokens'] = df['Review_norm'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df.head())
# Out:
# Tokenizing Result :
#
#                                               Review  \
# 0  barang sampai di saya plastik seal nya udh rus...
# 1  bau nya ko beda ya bikin mual aneh aja ngga ky...
# 2                                    no review found
# 3                                 tutup botol mampet
# 4                                         pump macet
#
#                                          Review_norm  \
# 0  barang sampai di saya plastik seal nya sudah r...
# 1  bau nya kok beda ya bikin mual aneh saja engga...
# 2                                    no review found
# 3                                 tutup botol mampet
# 4                                         pump macet
#
#                                        review_tokens
# 0  [barang, sampai, di, saya, plastik, seal, nya,...
# 1  [bau, nya, kok, beda, ya, bikin, mual, aneh, s...
# 2                                [no, review, found]
# 3                             [tutup, botol, mampet]
# 4                                      [pump, macet]

# %%
# import hasil tokenizing menjadi csv
df.to_csv("tokenizing_skingame.csv")

# %%
# PROSES FILTERING (Stopword Removal)
from nltk.corpus import stopwords

# get stopword indonesia from NLTK stopword
list_stopwords = stopwords.words('indonesian')

# convert list to dictionary
list_stopwords = set(list_stopwords)

# remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['review_tokens_SR'] = df['review_tokens'].apply(stopwords_removal) 

print(df.head())
# Out:
#                                               Review  \
# 0  barang sampai di saya plastik seal nya udh rus...
# 1  bau nya ko beda ya bikin mual aneh aja ngga ky...
# 2                                    no review found
# 3                                 tutup botol mampet
# 4                                         pump macet
#
#                                          Review_norm  \
# 0  barang sampai di saya plastik seal nya sudah r...
# 1  bau nya kok beda ya bikin mual aneh saja engga...
# 2                                    no review found
# 3                                 tutup botol mampet
# 4                                         pump macet
#
#                                        review_tokens  \
# 0  [barang, sampai, di, saya, plastik, seal, nya,...
# 1  [bau, nya, kok, beda, ya, bikin, mual, aneh, s...
# 2                                [no, review, found]
# 3                             [tutup, botol, mampet]
# 4                                      [pump, macet]
#
#                                     review_tokens_SR
# 0  [barang, plastik, seal, nya, rusak, dikasih, s...
# 1  [bau, nya, beda, ya, bikin, mual, aneh, kayak,...
# 2                                [no, review, found]
# 3                             [tutup, botol, mampet]
# 4                                      [pump, macet]

# %%
# import hasil stopword removal menjadi csv
df.to_csv("stopword_skingame.csv")

# %%
# PROSES LEMMATIZATION 
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['review_tokens_SR']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['review_tokens_stemmed'] = df['review_tokens_SR'].swifter.apply(get_stemmed_term)
print(df['review_tokens_stemmed'])
print(df.head())
# Out:
# 1452
# ------------------------
# barang : barang
# plastik : plastik
# seal : seal
# nya : nya
# rusak : rusak
# dikasih : kasih
# tape : tape
# bening : bening
# biar : biar
# tutup : tutup
# kebuka : buka
# maaf : maaf
# ya : ya
# beli : beli
# loh : loh
# bayar : bayar
# lo : lo
# gratisan : gratis
# tolong : tolong
# diperhatikan : perhati
# quality : quality
# control : control
# bau : bau
# beda : beda
# bikin : bikin
# mual : mual
# aneh : aneh
# kayak : kayak
# repurchase : repurchase
# fash : fash
# wash : wash
# skingame : skingame
# kaget : kaget
# banget : banget
# sih : sih
# sumpah : sumpah
# no : no
# review : review
# found : found
# botol : botol
# mampet : mampet
# pump : pump
# macet : macet
# breakout : breakout
# pakai : pakai
# selangnya : selang
# sependek : pendek
# hilang : hilang
# kebawah : bawah
# wtf : wtf
# annoying : annoying
# pakenya : pakenya
# coba : coba
# cari : cari
# tube : tube
# ajalah : aja
# kalo : kalo
# packaging : packaging
# bermasalah : masalah
# mulu : mulu
# sayang : sayang
# formulanya : formula
# sebagus : bagus
# packagingnya : packagingnya
# big : big
# deh : deh
# parah : parah
# seller : seller
# pengiriman : kirim
# kurir : kurir
# kirimnya : kirim
# plus : plus
# dibuka : buka
# paketnya : paket
# professional : professional
# niat : niat
# jualan : jual
# official : official
# store : store
# hargai : harga
# customer : customer
# membungkus : bungkus
# paket : paket
# suka : suka
# pengeriman : rim
# cepat : cepat
# cuman : cuman
# sorry : sorry
# kykny : kykny
# cocok : cocok
# langsung : langsung
# jerawatan : jerawat
# warnanya : warna
# kuning : kuning
# kiri : kiri
# pemakaian : pakai
# kanan : kanan
# geprek : geprek
# bubble : bubble
# wrap : wrap
# hancur : hancur
# bibir : bibir
# kering : kering
# mending : mending
# vaselin : vaselin
# singkat : singkat
# ergonomis : ergonomis
# fungsional : fungsional
# sulit : sulit
# dibersihin : dibersihin
# packing : packing
# mengecewakan : kecewa
# kardus : kardus
# apapun : apa
# dibiarkan : biar
# terbuka : buka
# membukanya : buka
# mudah : mudah
# selapis : selap
# berbelanja : belanja
# toko : toko
# rembes : rembes
# cairan : cair
# berkurang : kurang
# ml : ml
# diperkuat : kuat
# sealernya : sealernya
# dichat : dichat
# pesanan : pesan
# konfirmasi : konfirmasi
# chat : chat
# diantar : antar
# diluar : luar
# estimasi : estimasi
# next : next
# day : day
# butuh : butuh
# pas : pas
# jerawat : jerawat
# mendem : mendem
# benjolan : benjol
# gosong : gosong
# nimbulin : nimbulin
# ditempat : tempat
# dikulit : kulit
# mulus : mulus
# sebel : sebel
# bagus : bagus
# pelayanan : layan
# sellernya : sellernya
# komplain : komplain
# senin : senin
# rabu : rabu
# pick : pick
# up : up
# ambil : ambil
# lupa : lupa
# kasihin : kasihin
# jawabannya : jawab
# berteletele : berteletele
# oksidasi : oksidasi
# packingnya : packingnya
# aman : aman
# benda : benda
# cair : cair
# produknya : produk
# tumpah : tumpah
# kemasan : kemas
# essence : essence
# transparant : transparant
# tau : tau
# tumpahnya : tumpah
# ok : ok
# rapi : rapi
# but : but
# fungsionalitas : fungsionalitas
# pore : pore
# armour : armour
# habis : habis
# dibilas : bilas
# putih : putih
# mencoba : coba
# sodara : sodara
# menghilangkan : hilang
# komedo : komedo
# acne : acne
# warrior : warrior
# ngefek : ngefek
# wajahku : wajah
# kempes : kempes
# mateng : mateng
# even : even
# ngaruh : ngaruh
# produk : produk
# susah : susah
# diblend : diblend
# peeling : peeling
# nyerep : nyerep
# sesuai : sesuai
# deskripsi : deskripsi
# isi : isi
# whitecast : whitecast
# muka : muka
# belang : belang
# abu : abu
# dempul : dempul
# dipakai : pakai
# dosis : dosis
# anjuran : anjur
# sunscreen : sunscreen
# sendok : sendok
# teh : teh
# lengket : lengket
# kerasa : rasa
# tertarik : tarik
# kesat : kesat
# gatal : gatal
# kena : kena
# keringat : keringat
# luntur : luntur
# kacau : kacau
# whitecastnya : whitecastnya
# patchy : patchy
# dimana : mana
# isinya : isi
# pink : pink
# hero : hero
# kaya : kaya
# harga : harga
# normal : normal
# penyok : penyok
# diratainnya : diratainnya
# kulit : kulit
# warna : warna
# besokannya : besok
# muncul : muncul
# berantakan : beranta
# kombinasi : kombinasi
# berjerawat : jerawat
# seminggu : minggu
# nge : nge
# trigger : trigger
# miring : miring
# kontak : kontak
# lumayan : lumayan
# dikit : dikit
# bruntusan : bruntusan
# service : service
# admin : admin
# full : full
# kosong : kosong
# ujung : ujung
# merosot : merosot
# product : product
# terima : terima
# kasih : kasih
# kali : kali
# jujur : jujur
# dibkosongin : dibkosongin
# diiisi : diiisi
# sik : sik
# gede : gede
# reaksi : reaksi
# bagusnya : bagus
# oles : oles
# efek : efek
# okay : okay
# efeknya : efek
# membetikan : beti
# berbeda : beda
# individu : individu
# rekomendasi : rekomendasi
# teman : teman
# kayaknya : kayak
# perubahan : ubah
# pasa : pasa
# malam : malam
# sembuh : sembuh
# serum : serum
# nyatu : nyatu
# buka : buka
# serumnya : serum
# manual : manual
# khawatir : khawatir
# bersih : bersih
# ngambil : ngambil
# nyendok : nyendok
# belerang : belerang
# signifikan : signifikan
# tekstur : tekstur
# keras : keras
# menggumpal : gumpal
# diterima : terima
# keaadan : keaadan
# bocor : bocor
# bekas : bekas
# lubang : lubang
# paku : paku
# lem : lem
# belanja : belanja
# kecewa : kecewa
# malas : malas
# complain : complain
# entar : entar
# prosesnya : proses
# teksturnya : tekstur
# kental : kental
# probably : probably
# semprotnya : semprot
# ngawur : ngawur
# arahnya : arah
# kesel : kesel
# pumpnya : pumpnya
# super : super
# ringan : ringan
# mahal : mahal
# memperparah : parah
# kemasannya : kemas
# ekspektasi : ekspektasi
# semoga : moga
# kedepannya : depan
# kardusnya : kardus
# dilapisin : dilapisin
# halo : halo
# kalimya : kalimya
# skin : skin
# game : game
# salah : salah
# woshlist : woshlist
# ku : ku
# nabung : nabung
# nyisihin : nyisihin
# uang : uang
# checkout : checkout
# pengirimannya : kirim
# tima : tima
# tanggal : tanggal
# jakarta : jakarta
# jogja : jogja
# cek : cek
# makassar : makassar
# stabilitas : stabilitas
# obat : obat
# sediaan : sedia
# gapapa : gapapa
# mengasih : asih
# berharap : harap
# dicover : dicover
# diseal : diseal
# just : just
# little : little
# input : input
# tumpahan : tumpah
# untung : untung
# pelan : pelan
# bukanya : buka
# buru : buru
# dikulitku : kulit
# dibilang : bilang
# dinanti : nanti
# perekat : rekat
# untungnya : untung
# jatuh : jatuh
# membasmi : basmi
# stamping : stamping
# black : black
# mask : mask
# ex : ex
# sisa : sisa
# clay : clay
# area : area
# suliiit : suliiit
# dibasuh : basuh
# berpengalaman : alam
# innisfree : innisfree
# masker : masker
# sari : sari
# ayu : ayu
# ketimbang : ketimbang
# mohon : mohon
# ditingkatkan : tingkat
# formulasinya : formulasi
# tujuannya : tuju
# kurangi : kurang
# minyak : minyak
# wajah : wajah
# basically : basically
# zero : zero
# result : result
# hasil : hasil
# rubah : rubah
# ratingnya : ratingnya
# juni : juni
# dikemas : kemas
# kirim : kirim
# start : start
# minggu : minggu
# rutin : rutin
# jam : jam
# senang : senang
# skincare : skincare
# cocokan : cocok
# tipe : tipe
# sensitif : sensitif
# mengatasi : atas
# warriornya : warriornya
# tengahnya : tengah
# ksg : ksg
# dkit : dkit
# tgal : tgal
# sgitu : sgitu
# masukkana : masukkana
# kekny : kekny
# better : better
# ditutupi : tutup
# something : something
# bbuknya : bbuknya
# armor : armor
# diproduksi : produksi
# pergerakan : gera
# bismillah : bismillah
# totol : totol
# dahi : dahi
# kalem : kalem
# kemerahan : merah
# pasta : pasta
# padat : padat
# enak : enak
# dibaur : baur
# ditotol : totol
# pisan : pis
# botolnya : botol
# semprotannya : semprot
# doang : doang
# tinggal : tinggal
# toner : toner
# so : so
# sad : sad
# because : because
# this : this
# didn : didn
# works : works
# on : on
# my : my
# prone : prone
# moist : moist
# proses : proses
# efektif : efektif
# huhu : huhu
# barangnya : barang
# sampainya : sampai
# diproses : proses
# dikirim : kirim
# pelekat : pelekat
# bunda : bunda
# harganya : harga
# segini : gin
# mah : mah
# overprice : overprice
# dicek : cek
# tingkatkan : tingkat
# tone : tone
# upnya : upnya
# langsat : langsat
# air : air
# keringet : keringet
# lsng : lsng
# cemong : cemong
# meresap : resap
# keringetan : keringetan
# gampang : gampang
# sengaja : sengaja
# gosend : gosend
# disuruh : suruh
# reorder : reorder
# alasan : alas
# kompensasi : kompensasi
# taunya : tau
# dijanjikan : janji
# baunya : bau
# apek : apek
# besi : besi
# tempatnya : tempat
# sabun : sabun
# nyaman : nyaman
# pakainya : pakai
# order : order
# penuh : penuh
# drama : drama
# bentuk : bentuk
# jelek : jelek
# muncrat : muncrat
# bedak : bedak
# brantakan : brantakan
# brall : brall
# serbuk : serbuk
# bedaknya : bedak
# perbaiki : baik
# maskernya : masker
# katane : katane
# nyonyahe : nyonyahe
# rekommended : rekommended
# pokoke : pokoke
# fast : fast
# respon : respon
# lanjutkan : lanjut
# min : min
# merk : merk
# pup : pup
# kak : kak
# meresapnya : resap
# greasy : greasy
# daan : daan
# jerawatku : jerawat
# memudar : pudar
# bestie : bestie
# tapiii : tapiii
# menurutku : turut
# perhatikan : perhati
# pemilihan : pilih
# loncat : loncat
# terbuang : buang
# leher : leher
# terjun : terjun
# bebas : bebas
# sedih : sedih
# hiks : hiks
# konsiderasi : konsiderasi
# improve : improve
# bintang : bintang
# gelap : gelap
# desainnya : desain
# lucu : lucu
# hasilnya : hasil
# matte : matte
# ukurannya : ukur
# compact : compact
# berkilau : kilau
# mantap : mantap
# pertimbangan : timbang
# redesign : redesign
# struggle : struggle
# mengeluarkan : keluar
# sprayed : sprayed
# kemana : mana
# trial : trial
# lambat : lambat
# kinerjanya : kerja
# bersihkan : sih
# diwajahku : wajah
# tutupnya : tutup
# rapat : rapat
# dioren : oren
# yauda : yauda
# essense : essense
# semangat : semangat
# pejuang : juang
# bekasnyaaa : bekasnyaaa
# overall : overall
# instan : instan
# rajin : rajin
# free : free
# kuas : kuas
# spatula : spatula
# ramah : ramah
# orisinal : orisinal
# disalotip : disalotip
# takut : takut
# higyenis : higyenis
# kulitku : kulit
# cantik : cantik
# transparan : transparan
# lihat : lihat
# nih : nih
# penutupnya : tutup
# penutup : tutup
# degdegan : degdegan
# tonernya : tonernya
# dipasang : pasang
# ribet : ribet
# ngempesin : ngempesin
# akuuuu : akuuuu
# huhuhu : huhuhu
# markicob : markicob
# mudahan : mudah
# reviewnya : reviewnya
# over : over
# all : all
# mencet : mencet
# dipencet : pencet
# dianternya : anter
# ekspedinya : ekspedinya
# tujuan : tuju
# selamat : selamat
# blend : blend
# gue : gue
# blenong : blenong
# orang : orang
# jamuran : jamur
# amin : amin
# kadang : kadang
# buluk : buluk
# mereda : reda
# gaes : gaes
# merubah : rubah
# moisturizer : moisturizer
# digunain : digunain
# memakai : pakai
# berat : berat
# keisi : isi
# segar : segar
# hmm : hmm
# lembab : lembab
# daily : daily
# light : light
# saran : saran
# seeing : seeing
# tidur : tidur
# ty : ty
# rehehe : rehehe
# prosesnyaaa : prosesnyaaa
# jasa : jasa
# ekspedisinya : ekspedisi
# ekspedisi : ekspedisi
# anter : anter
# jne : jne
# juta : juta
# nelfon : nelfon
# gasampe : gasampe
# bantu : bantu
# cap : cap
# lepas : lepas
# dagu : dagu
# tiada : tiada
# sukanya : suka
# walopun : walopun
# bahannya : bahan
# jenis : jenis
# lembut : lembut
# optimis : optimis
# lemaknya : lemak
# semalam : malam
# redainnya : redainnya
# dikombinasi : kombinasi
# dll : dll
# and : and
# error : error
# diperbaiki : baik
# menselotip : menselotip
# aslinya : asli
# alhamdulillah : alhamdulillah
# boxnya : boxnya
# ampuh : ampuh
# redain : redain
# jerawatnya : jerawat
# pengemasan : emas
# love : love
# mempan : mempan
# ngolesin : ngolesin
# foundation : foundation
# wangi : wangi
# original : original
# wariornya : wariornya
# armornya : armornya
# juara : juara
# pori : pori
# poriku : pori
# segede : gede
# mulut : mulut
# gunung : gunung
# api : api
# thankyouu : thankyouu
# khasiatnya : khasiat
# kudu : kudu
# sabar : sabar
# elegan : elegan
# dipakainya : pakai
# berminyak : minyak
# dipakein : dipakein
# melembabkan : melembabkan
# shiny : shiny
# lipstick : lipstick
# mengganggu : ganggu
# standar : standar
# box : box
# tulis : tulis
# notes : notes
# anyway : anyway
# skincarenya : skincarenya
# not : not
# sure : sure
# what : what
# difference : difference
# does : does
# give : give
# facial : facial
# like : like
# the : the
# old : old
# tahan : tahan
# new : new
# one : one
# mean : mean
# aluminium : aluminium
# case : case
# was : was
# kind : kind
# of : of
# your : your
# brand : brand
# signature : signature
# maybe : maybe
# you : you
# should : should
# keep : keep
# smell : smell
# very : very
# weird : weird
# opinion : opinion
# texture : texture
# menyerap : serap
# sebulan : bulan
# if : if
# cuz : cuz
# face : face
# is : is
# really : really
# hopefully : hopefully
# sudsh : sudsh
# at : at
# least : least
# could : could
# some : some
# hear : hear
# bakuchiol : bakuchiol
# work : work
# lil : lil
# bit : bit
# slower : slower
# buln : buln
# kemarin : kemarin
# oh : oh
# for : for
# me : me
# bathroom : bathroom
# cleaner : cleaner
# sort : sort
# that : that
# personal : personal
# other : other
# doesn : doesn
# have : have
# any : any
# odor : odor
# quite : quite
# suprised : suprised
# when : when
# use : use
# pengobatan : obat
# selesai : selesai
# kotaknya : kotak
# mungil : mungil
# oke : oke
# gentle : gentle
# tacky : tacky
# nyerap : nyerap
# halus : halus
# hydrated : hydrated
# generous : generous
# wise : wise
# after : after
# feelnya : feelnya
# bottle : bottle
# keren : keren
# punyaku : punya
# eror : eror
# terpaksa : paksa
# pleasant : pleasant
# bauk : bauk
# performanya : performa
# boros : boros
# busanya : busa
# apply : apply
# cerah : cerah
# simpel : simpel
# negatif : negatif
# personally : personally
# efisien : efisien
# sayangnya : sayang
# interest : interest
# isinyanbanyak : isinyanbanyak
# murahh : murahh
# amann : amann
# thank : thank
# youu : youu
# dioles : oles
# pendem : pendem
# sakit : sakit
# mingguan : minggu
# pemakainan : pemakainan
# skip : skip
# diriku : diri
# menyimpulkan : simpul
# mukaku : muka
# combination : combination
# oily : oily
# bo : bo
# batu : batu
# mengering : ering
# tumbuh : tumbuh
# saviour : saviour
# perawatan : awat
# sensisitf : sensisitf
# combat : combat
# kotak : kotak
# spot : spot
# guard : guard
# teo : teo
# hempas : hempas
# noda : noda
# sentosa : sentosa
# kasij : kasij
# pelayanannya : layan
# dmrnya : dmrnya
# claimnya : claimnya
# aromanya : aroma
# sedap : sedap
# aroma : aroma
# bahan : bahan
# kimia : kimia
# makan : makan
# serasi : serasi
# kemerahannya : merah
# pudar : pudar
# sulfurnya : sulfur
# kecium : cium
# menempel : tempel
# bed : bed
# sheet : sheet
# tersegel : segel
# kecewanya : kecewa
# pipi : pipi
# merona : rona
# fighter : fighter
# far : far
# reda : reda
# sisanya : sisa
# harian : hari
# daya : daya
# simpannya : simpan
# terhitung : hitung
# sebentar : sebentar
# ngobatin : ngobatin
# jarang : jarang
# diaplikasiin : diaplikasiin
# bsknya : bsknya
# sukses : sukses
# selau : selau
# worth : worth
# ribu : ribu
# banyakan : banyak
# udara : udara
# gedenya : gede
# gram : gram
# first : first
# buy : buy
# melembapkan : lembap
# gelnya : gel
# mayang : mayang
# menyebalkan : sebal
# dipengirimannya : kirim
# cuci : cuci
# puas : puas
# sreg : sreg
# itupun : itu
# kegedean : gede
# kaca : kaca
# dimasukkan : masuk
# basah : basah
# menghidrasi : hidrasi
# tebal : tebal
# teng : teng
# moistnya : moistnya
# pembelian : beli
# sg : sg
# barunya : baru
# alumunium : alumunium
# white : white
# cast : cast
# zinc : zinc
# oxidenya : oxidenya
# cyst : cyst
# besok : besok
# paginya : pagi
# sesui : sesui
# perkiraan : kira
# bis : bis
# bilang : bilang
# rada : rada
# panas : panas
# kebakar : bakar
# chek : chek
# ingredientnya : ingredientnya
# menyimpang : simpang
# carbomer : carbomer
# list : list
# kadar : kadar
# nampol : nampol
# say : say
# matanya : mata
# gara : gara
# diskon : diskon
# bubuk : bubuk
# residunya : residu
# good : good
# note : note
# bangun : bangun
# bantal : bantal
# terlay : terlay
# makeup : makeup
# untukku : untuk
# wrapnya : wrapnya
# dibungkus : bungkus
# cocokkemasannya : cocokkemasannya
# kukit : kit
# dilanjut : lanjut
# cleanser : cleanser
# lux : lux
# pigmented : pigmented
# insight : insight
# luxury : luxury
# thanks : thanks
# langganan : langgan
# kualitas : kualitas
# ditungkatkan : ditungkatkan
# bundle : bundle
# dicoba : coba
# terimanya : terima
# rekomen : rekomen
# brentusan : brentusan
# viral : viral
# kebalik : balik
# keluarkan : keluar
# an : an
# manfaat : manfaat
# berfungsi : fungsi
# washnya : washnya
# safely : safely
# arrived : arrived
# adminnya : adminnya
# responsif : responsif
# membantu : bantu
# ngelupas : ngelupas
# dalemnya : dalem
# ganggu : ganggu
# cream : cream
# dilepas : lepas
# sempurna : sempurna
# alhasil : alhasil
# plastiknya : plastik
# experince : experince
# usingnya : usingnya
# segi : segi
# dus : dus
# satuan : satu
# masuk : masuk
# kondisinya : kondisi
# kondisi : kondisi
# sensitive : sensitive
# huaa : huaa
# milia : milia
# btw : btw
# hydrathing : hydrathing
# kuraaang : kuraaang
# model : model
# ditmbh : ditmbh
# tmbhan : tmbhan
# dalamnya : dalam
# loose : loose
# powder : powder
# seret : seret
# nyimpennya : nyimpennya
# favorite : favorite
# kiraiin : kiraiin
# pe : pe
# unik : unik
# tangan : tangan
# diwajah : wajah
# kualitasnya : kualitas
# restock : restock
# time : time
# formula : formula
# alkohol : alkohol
# kandungan : kandung
# nyelekit : nyelekit
# warp : warp
# sampi : sampi
# dimasuki : masuk
# mardus : mardus
# beresiko : resiko
# atasnya : atas
# longgar : longgar
# click : click
# cakep : cakep
# gel : gel
# licin : licin
# dingiiiin : dingiiiin
# calming : calming
# lembabnya : lembabnya
# keringku : kering
# luber : luber
# kebagian : bagi
# menunggu : tunggu
# toe : toe
# mata : mata
# ukuran : ukur
# nice : nice
# sunscreennya : sunscreennya
# waterproof : waterproof
# wudhu : wudhu
# meninggalkan : tinggal
# which : which
# keset : keset
# bland : bland
# seringan : sering
# cloud : cloud
# ane : ane
# rekom : rekom
# claim : claim
# lemgket : lemgket
# baurkan : baur
# grenjel : grenjel
# nakar : nakar
# konsisten : konsisten
# volume : volume
# jari : jari
# blendnya : blendnya
# once : once
# set : set
# glow : glow
# effectnya : effectnya
# minusnya : minus
# bingung : bingung
# selipin : selipin
# keambil : ambil
# awet : awet
# dikirimnya : kirim
# mendarat : darat
# pelembab : pelembab
# kesayangan : sayang
# sampaiiii : sampaiiii
# memuaskan : muas
# hhehehehr : hhehehehr
# ketiga : tiga
# pertamakali : pertamakali
# mengecil : kecil
# januari : januari
# feb : feb
# pertengahan : tengah
# pack : pack
# pelelehan : leleh
# kokoh : kokoh
# testimoni : testimoni
# diaku : dia
# porenya : porenya
# best : best
# purchase : purchase
# during : during
# quarantine : quarantine
# rumah : rumah
# besoknya : besok
# ban : ban
# bandel : bandel
# motornya : motor
# parkir : parkir
# sembarangan : sembarang
# siang : siang
# sesusai : sesusai
# khasiat : khasiat
# manjur : manjur
# merah : merah
# malamnya : malam
# pagi : pagi
# pokoknya : pokok
# mengobati : obat
# stocknya : stocknya
# ngebersihin : ngebersihin
# berhasil : hasil
# menyelamatkan : selamat
# bermunculan : muncul
# maju : maju
# mundur : mundur
# lets : lets
# hope : hope
# flash : flash
# sale : sale
# habisnya : habis
# menyangka : sangka
# seefektif : efektif
# ngecilin : ngecilin
# blackheads : blackheads
# whiteheads : whiteheads
# hidung : hidung
# panik : panik
# kulitnya : kulit
# apa-apa : apa
# yaudah : yaudah
# finally : finally
# bolak : bolak
# promo : promo
# gercep : gercep
# pesan : pesan
# kakakk : kakakk
# anehnya : aneh
# bentonite : bentonite
# airnya : air
# keringnya : kering
# bijinya : biji
# jaman : jaman
# mereknya : merek
# latul : latul
# sesenang : senang
# ditunggu : tunggu
# huahhh : huahhh
# ramahh : ramahh
# trimkasii : trimkasii
# manding : manding
# whitehead : whitehead
# takjub : takjub
# hati : hati
# serbuknya : serbuk
# pre : pre
# lmayan : lmayan
# treatment : treatment
# repot : repot
# nyampurin : nyampurin
# konsistensi : konsistensi
# semenjak : semenjak
# campur : campur
# top : top
# beruntusan : beruntus
# gone : gone
# kempessss : kempessss
# bekasnya : bekas
# kentara : kentara
# weekend : weekend
# mandi : mandi
# sorenya : sore
# biarkan : biar
# wait : wait
# numbuh : numbuh
# fix : fix
# nyetok : nyetok
# blackheadnya : blackheadnya
# dipegang : pegang
# hidungnya : hidung
# bayi : bayi
# amazing : amazing
# bersihin : bersihin
# membandel : bandel
# terjangkau : jangkau
# cucmey : cucmey
# hempaskan : hempas
# berkat : berkat
# yeyyyy : yeyyyy
# warior : warior
# gratis : gratis
# yuhuuuu : yuhuuuu
# check : check
# out : out
# secepet : secepet
# blackhead : blackhead
# repeat : repeat
# shock : shock
# komedonya : komedonya
# mencuat : cuat
# bersiihin : bersiihin
# cepaaatt : cepaaatt
# minim : minim
# sampah : sampah
# favorit : favorit
# membesar : besar
# bengkak : bengkak
# luvvvvv : luvvvvv
# youuu : youuu
# sehari : hari
# excited : excited
# pengin : pengin
# sebagiannya : bagi
# its : its
# terbang : terbang
# dipinggiran : pinggir
# sekundernya : sekunder
# yay : yay
# belinya : beli
# kemasnya : kemas
# recommended : recommended
# lusanya : lusa
# kurirnya : kurir
# nyasar : nyasar
# cepeeet : cepeeet
# second : second
# buying : buying
# obsessed : obsessed
# cute : cute
# started : started
# using : using
# dew : dew
# right : right
# today : today
# absolutely : absolutely
# think : think
# going : going
# tint : tint
# lips : lips
# natural : natural
# pinkish : pinkish
# color : color
# actually : actually
# visible : visible
# put : put
# there : there
# faint : faint
# taste : taste
# chemical : chemical
# apparent : apparent
# don : don
# mind : mind
# ve : ve
# never : never
# used : used
# lip : lip
# oil : oil
# before : before
# expected : expected
# feel : feel
# heavy : heavy
# well : well
# moisturizing : moisturizing
# hm : hm
# barunyaa : barunyaa
# versi : versi
# kluarin : kluarin
# kontrol : kontrol
# glowing : glowing
# superr : superr
# andalan : andal
# lancaarr : lancaarr
# jualannyaa : jualannyaa
# diambil : ambil
# segel : segel
# came : came
# faster : faster
# hydrating : hydrating
# gaperlu : gaperlu
# deal : deal
# terbungkus : bungkus
# mantafff : mantafff
# traveling : traveling
# cepatt : cepatt
# moga : moga
# setahun : tahun
# cinta : cinta
# nicee : nicee
# kandungannya : kandung
# taruh : taruh
# harapan : harap
# maksimal : maksimal
# maakasiih : maakasiih
# keduaku : dua
# heboh : heboh
# sepele : sepele
# diimbangi : imbang
# pemakaiannya : pakai
# abadi : abadi
# kelompok : kelompok
# pertemananku : teman
# maksimalnya : maksimal
# bentuknya : bentuk
# berasa : asa
# holy : holy
# grail : grail
# kesekian : sekian
# thankyou : thankyou
# mingem : mingem
# request : request
# ihiiww : ihiiww
# aw : aw
# ude : ude
# mendingan : mending
# paraaahhh : paraaahhh
# dokter : dokter
# sip : sip
# packagenya : packagenya
# trying : trying
# pertolongan : tolong
# repuschase : repuschase
# ilangin : ilangin
# pih : pih
# pie : pie
# bundlenya : bundlenya
# murce : murce
# busa : busa
# nyengat : nyengat
# pikir : pikir
# unyil : unyil
# secuil : cuil
# swatch : swatch
# pls : pls
# syukur : syukur
# ngecewain : ngecewain
# nyerahin : nyerahin
# cerahan : cerah
# im : im
# will : will
# based : based
# ingredients : ingredients
# fyi : fyi
# totolnya : totol
# job : job
# matengnya : matengnya
# kerusakan : rusa
# bange : bange
# sampeeeeeee : sampeeeeeee
# repurchased : repurchased
# berkali : kali
# skinker : skinker
# bingitz : bingitz
# jeriwitt : jeriwitt
# kempiiiss : kempiiiss
# fotonya : foto
# packingannya : packingannya
# dilapis : lap
# respons : respons
# course : course
# much : much
# sceptical : sceptical
# murah : murah
# blackheadsnya : blackheadsnya
# beberaoa : beberaoa
# kudos : dos
# fine : fine
# lines : les
# ikutan : ikut
# wlpun : wlpun
# stok : stok
# nakal : nakal
# kempesin : kempesin
# benaran : benar
# ngeringin : ngeringin
# simple : simple
# engganya : engganya
# pergi : pergi
# istri : istri
# mengirim : kirim
# hubungi : hubung
# penerima : terima
# itemnya : item
# residu : residu
# cabut : cabut
# penggunaan : guna
# worthed : worthed
# dikid : dikid
# kepakenya : kepakenya
# kaleng : kaleng
# puluhan : puluh
# jumat : jumat
# lho : lho
# makasiiih : makasiiih
# paham : paham
# bekerjaa : bekerjaa
# seeeeeegitu : seeeeeegitu
# dihempaskan : hempas
# war : war
# pelipis : pelipis
# hinggap : hinggap
# tadaaaa : tadaaaa
# memudarkan : pudar
# mi : mi
# laf : laf
# yuk : yuk
# tabungan : tabung
# skincaree : skincaree
# kuharap : harap
# membungkam : bungkam
# jahanam : jahanam
# tetangga : tetangga
# termantul : termantul
# pemrosesan : pemrosesan
# mampus : mampus
# lengkap : lengkap
# luarnya : luar
# eco : eco
# friendly : friendly
# sangatttt : sangatttt
# deliv : deliv
# uuu : uuu
# kelas : kelas
# stock : stock
# ready : ready
# kupake : kupake
# putty : putty
# senggaknya : senggak
# samping : samping
# kuedit : edit
# rejeki : rejeki
# hormon : hormon
# buanyakkk : buanyakkk
# matang : matang
# mengeringkan : ering
# meredakan : reda
# peradangan : adang
# kedepan : depan
# ngatasin : ngatasin
# perih : perih
# pantesan : pantesan
# viraaal : viraaal
# blgnya : blgnya
# terbaik : baik
# rednees : rednees
# spots : spots
# ngurang : ngurang
# combo : combo
# terkeran : keran
# pengirimanya : pengirimanya
# bguss : bguss
# pengemasannya : emas
# mantul : mantul
# daebak : daebak
# klaim : klaim
# prosedur : prosedur
# taking : taking
# care : care
# sample : sample
# cekat : cekat
# cekit : cekit
# sehat : sehat
# aplikator : aplikator
# elegant : elegant
# khas : khas
# pengaplikasiannya : aplikasi
# membutuhkan : butuh
# pengulangan : ulang
# bibitnya : bibit
# aplikasikan : aplikasi
# diulang : ulang
# tokopedia : tokopedia
# nyembuhin : nyembuhin
# type : type
# affordable : affordable
# supple : supple
# kenyal : kenyal
# {'barang': 'barang', 'plastik': 'plastik', 'seal': 'seal', 'nya': 'nya', 'rusak': 'rusak', 'dikasih': 'kasih', 'tape': 'tape', 'bening': 'bening', 'biar': 'biar', 'tutup': 'tutup', 'kebuka': 'buka', 'maaf': 'maaf', 'ya': 'ya', 'beli': 'beli', 'loh': 'loh', 'bayar': 'bayar', 'lo': 'lo', 'gratisan': 'gratis', 'tolong': 'tolong', 'diperhatikan': 'perhati', 'quality': 'quality', 'control': 'control', 'bau': 'bau', 'beda': 'beda', 'bikin': 'bikin', 'mual': 'mual', 'aneh': 'aneh', 'kayak': 'kayak', 'repurchase': 'repurchase', 'fash': 'fash', 'wash': 'wash', 'skingame': 'skingame', 'kaget': 'kaget', 'banget': 'banget', 'sih': 'sih', 'sumpah': 'sumpah', 'no': 'no', 'review': 'review', 'found': 'found', 'botol': 'botol', 'mampet': 'mampet', 'pump': 'pump', 'macet': 'macet', 'breakout': 'breakout', 'pakai': 'pakai', 'selangnya': 'selang', 'sependek': 'pendek', 'hilang': 'hilang', 'kebawah': 'bawah', 'wtf': 'wtf', 'annoying': 'annoying', 'pakenya': 'pakenya', 'coba': 'coba', 'cari': 'cari', 'tube': 'tube', 'ajalah': 'aja', 'kalo': 'kalo', 'packaging': 'packaging', 'bermasalah': 'masalah', 'mulu': 'mulu', 'sayang': 'sayang', 'formulanya': 'formula', 'sebagus': 'bagus', 'packagingnya': 'packagingnya', 'big': 'big', 'deh': 'deh', 'parah': 'parah', 'seller': 'seller', 'pengiriman': 'kirim', 'kurir': 'kurir', 'kirimnya': 'kirim', 'plus': 'plus', 'dibuka': 'buka', 'paketnya': 'paket', 'professional': 'professional', 'niat': 'niat', 'jualan': 'jual', 'official': 'official', 'store': 'store', 'hargai': 'harga', 'customer': 'customer', 'membungkus': 'bungkus', 'paket': 'paket', 'suka': 'suka', 'pengeriman': 'rim', 'cepat': 'cepat', 'cuman': 'cuman', 'sorry': 'sorry', 'kykny': 'kykny', 'cocok': 'cocok', 'langsung': 'langsung', 'jerawatan': 'jerawat', 'warnanya': 'warna', 'kuning': 'kuning', 'kiri': 'kiri', 'pemakaian': 'pakai', 'kanan': 'kanan', 'geprek': 'geprek', 'bubble': 'bubble', 'wrap': 'wrap', 'hancur': 'hancur', 'bibir': 'bibir', 'kering': 'kering', 'mending': 'mending', 'vaselin': 'vaselin', 'singkat': 'singkat', 'ergonomis': 'ergonomis', 'fungsional': 'fungsional', 'sulit': 'sulit', 'dibersihin': 'dibersihin', 'packing': 'packing', 'mengecewakan': 'kecewa', 'kardus': 'kardus', 'apapun': 'apa', 'dibiarkan': 'biar', 'terbuka': 'buka', 'membukanya': 'buka', 'mudah': 'mudah', 'selapis': 'selap', 'berbelanja': 'belanja', 'toko': 'toko', 'rembes': 'rembes', 'cairan': 'cair', 'berkurang': 'kurang', 'ml': 'ml', 'diperkuat': 'kuat', 'sealernya': 'sealernya', 'dichat': 'dichat', 'pesanan': 'pesan', 'konfirmasi': 'konfirmasi', 'chat': 'chat', 'diantar': 'antar', 'diluar': 'luar', 'estimasi': 'estimasi', 'next': 'next', 'day': 'day', 'butuh': 'butuh', 'pas': 'pas', 'jerawat': 'jerawat', 'mendem': 'mendem', 'benjolan': 'benjol', 'gosong': 'gosong', 'nimbulin': 'nimbulin', 'ditempat': 'tempat', 'dikulit': 'kulit', 'mulus': 'mulus', 'sebel': 'sebel', 'bagus': 'bagus', 'pelayanan': 'layan', 'sellernya': 'sellernya', 'komplain': 'komplain', 'senin': 'senin', 'rabu': 'rabu', 'pick': 'pick', 'up': 'up', 'ambil': 'ambil', 'lupa': 'lupa', 'kasihin': 'kasihin', 'jawabannya': 'jawab', 'berteletele': 'berteletele', 'oksidasi': 'oksidasi', 'packingnya': 'packingnya', 'aman': 'aman', 'benda': 'benda', 'cair': 'cair', 'produknya': 'produk', 'tumpah': 'tumpah', 'kemasan': 'kemas', 'essence': 'essence', 'transparant': 'transparant', 'tau': 'tau', 'tumpahnya': 'tumpah', 'ok': 'ok', 'rapi': 'rapi', 'but': 'but', 'fungsionalitas': 'fungsionalitas', 'pore': 'pore', 'armour': 'armour', 'habis': 'habis', 'dibilas': 'bilas', 'putih': 'putih', 'mencoba': 'coba', 'sodara': 'sodara', 'menghilangkan': 'hilang', 'komedo': 'komedo', 'acne': 'acne', 'warrior': 'warrior', 'ngefek': 'ngefek', 'wajahku': 'wajah', 'kempes': 'kempes', 'mateng': 'mateng', 'even': 'even', 'ngaruh': 'ngaruh', 'produk': 'produk', 'susah': 'susah', 'diblend': 'diblend', 'peeling': 'peeling', 'nyerep': 'nyerep', 'sesuai': 'sesuai', 'deskripsi': 'deskripsi', 'isi': 'isi', 'whitecast': 'whitecast', 'muka': 'm ...
# ------------------------
# Pandas Apply: 100%|██████████| 450/450 [00:00<00:00, 50031.46it/s]
# 0      [barang, plastik, seal, nya, rusak, kasih, sea...
# 1      [bau, nya, beda, ya, bikin, mual, aneh, kayak,...
# 2                                    [no, review, found]
# 3                                 [tutup, botol, mampet]
# 4                                          [pump, macet]
#                              ...
# 446                 [bagus, ngebersihin, ngecilin, pori]
# 447                          [cocok, nyembuhin, jerawat]
# 448    [cocok, kulit, kombinasi, cepat, resap, kemas,...
# 449    [skin, type, time, coba, toner, affordable, bi...
# 450    [cocok, kulit, kombinasi, bikin, kulit, kenyal...
# Name: review_tokens_stemmed, Length: 450, dtype: object
#                                               Review  \
# 0  barang sampai di saya plastik seal nya udh rus...
# 1  bau nya ko beda ya bikin mual aneh aja ngga ky...
# 2                                    no review found
# 3                                 tutup botol mampet
# 4                                         pump macet
#
#                                          Review_norm  \
# 0  barang sampai di saya plastik seal nya sudah r...
# 1  bau nya kok beda ya bikin mual aneh saja engga...
# 2                                    no review found
# 3                                 tutup botol mampet
# 4                                         pump macet
#
#                                        review_tokens  \
# 0  [barang, sampai, di, saya, plastik, seal, nya,...
# 1  [bau, nya, kok, beda, ya, bikin, mual, aneh, s...
# 2                                [no, review, found]
# 3                             [tutup, botol, mampet]
# 4                                      [pump, macet]
#
#                                     review_tokens_SR  \
# 0  [barang, plastik, seal, nya, rusak, dikasih, s...
# 1  [bau, nya, beda, ya, bikin, mual, aneh, kayak,...
# 2                                [no, review, found]
# 3                             [tutup, botol, mampet]
# 4                                      [pump, macet]
#
#                                review_tokens_stemmed
# 0  [barang, plastik, seal, nya, rusak, kasih, sea...
# 1  [bau, nya, beda, ya, bikin, mual, aneh, kayak,...
# 2                                [no, review, found]
# 3                             [tutup, botol, mampet]
# 4                                      [pump, macet]

# %%
# import hasil preprocessing menjadi csv
df.to_csv("lemma_skingame.csv")
