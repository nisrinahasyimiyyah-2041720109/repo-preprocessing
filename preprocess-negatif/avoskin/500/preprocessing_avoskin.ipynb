# %%
# Load data ke dalam data frame 
import pandas as pd

# Spesifikasi encoding diperlukan karena data tidak menggunakan UTF-8
df = pd.read_csv('scraping_avoskin-neg 500.csv', encoding='latin-1')

df.head()
# Out:
#                                               Review  \
# 0  Kecewa banget. Saya pesan yang free pouch tapi...
# 1  Kali ini pengemasan tidak safe,, sepertinya tu...
# 2  paket datangnya barang sudah pecah dan sy retu...
# 3              ga ada sabun nya, ga sesuai deskripsi
# 4                                  ga sesuai harapan
#
#                                              Product     Rating   Username  \
# 0  Perfect Light Skin Protection (BLPXAVOSKIN MTS...  bintang 1      A***a
# 1                Avoskin Hydrating Treatment Essence  bintang 1     Joshua
# 2                Avoskin Hydrating Treatment Essence  bintang 1  Fransisca
# 3  Avoskin Perfect Hydrating Treatment Essence 100ml  bintang 1      A***y
# 4                  Avoskin Miraculous Retinol Series  bintang 1      D***a
#
#                       Date
# 0  Lebih dari 1 tahun lalu
# 1  Lebih dari 1 tahun lalu
# 2  Lebih dari 1 tahun lalu
# 3  Lebih dari 1 tahun lalu
# 4  Lebih dari 1 tahun lalu

# %%
# Drop kolom yang tidak terpakai
df = df.drop(df.iloc[:,1:], axis=1)

# Cek data teratas
df.head()
# Out:
#                                               Review
# 0  Kecewa banget. Saya pesan yang free pouch tapi...
# 1  Kali ini pengemasan tidak safe,, sepertinya tu...
# 2  paket datangnya barang sudah pecah dan sy retu...
# 3              ga ada sabun nya, ga sesuai deskripsi
# 4                                  ga sesuai harapan

# %% [markdown]
# PREPROCESSING

# %%
# PROSES CASE FOLDING (menjadikan semua huruf di kolom Review menjadi huruf kecil)
df['Review'] = df['Review'].str.lower()

print('Case Folding Result: \n')
df.head()
# Out:
# Case Folding Result:
#                                               Review
# 0  kecewa banget. saya pesan yang free pouch tapi...
# 1  kali ini pengemasan tidak safe,, sepertinya tu...
# 2  paket datangnya barang sudah pecah dan sy retu...
# 3              ga ada sabun nya, ga sesuai deskripsi
# 4                                  ga sesuai harapan

# %%
# import hasil case folding menjadi csv
df.to_csv("casefolding_avoskin.csv")

# %%
# CLEANING
import re # regex library

def remove_tweet_special(text):
    # remove tab, new line, and back slice
    text = text.replace('\\t'," ").replace('\\n', " ").replace('\\u', " ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

df['Review'] = df['Review'].apply(remove_tweet_special)

# remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Review'] = df['Review'].apply(remove_number)

# remove punctuation and replace with space
def remove_punctuation(text):
    return re.sub(r'[.,]', ' ', text)

df['Review'] = df['Review'].apply(remove_punctuation)

# remove punctuation
def remove_symbol(text):
    # Menghapus simbol-simbol tidak standar dan menggantinya dengan spasi
    cleaned_text = re.sub(r'[^\w\s]', ' ', text)
    
    # Menghapus multiple whitespace
    cleaned_text = re.sub('\s+', ' ', cleaned_text).strip()
    
    return cleaned_text

df['Review'] = df['Review'].apply(remove_symbol)

# Menentukan ambang batas panjang string acak
threshold_length = 20

# Fungsi untuk menghapus string acak berdasarkan panjangnya
def hapus_string_acak_dengan_panjang(text):
    # Memeriksa panjang string dan menghapus jika melebihi ambang batas
    return ' '.join(word for word in text.split() if len(word) <= threshold_length)

# Menggunakan fungsi untuk menghapus string acak pada kolom 'Text'
df['Review'] = df['Review'].apply(hapus_string_acak_dengan_panjang)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Review'] = df['Review'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['Review'] = df['Review'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Review'] = df['Review'].apply(remove_single_char)

def remove_laughter(text):
    laughter_patterns = r'\b((ha)+h*|(he)+h*|(hi)+h*|(wk)+w*k*|(eh)+e*|(ah)+a*|(ih)+i*|(kw)+k*w*|(hem)+m*)\b'
    return re.sub(laughter_patterns, '', text, flags=re.IGNORECASE)

df['Review'] = df['Review'].apply(remove_laughter)

print('Cleaning Result : \n') 
print(df.head())
# Out:
# Cleaning Result :
#
#                                               Review
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan sy retu...
# 3               ga ada sabun nya ga sesuai deskripsi
# 4                                  ga sesuai harapan

# %%
# import hasil cleaning menjadi csv
df.to_csv("cleaning_avoskin.csv")

# %%
# REMOVE DUPLICATE
df = df.drop_duplicates()
df = df.reset_index(drop=True)
# Menghapus baris yang kosong
df = df.dropna(subset=['Review'])
# Menghapus baris yang hanya berisi spasi atau whitespace
df = df[df['Review'].str.strip() != '']
df.head()
# Out:
#                                               Review
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan sy retu...
# 3               ga ada sabun nya ga sesuai deskripsi
# 4                                  ga sesuai harapan

# %%
# import hasil remove duplicate menjadi csv
df.to_csv("removedup_avoskin.csv")

# %%
# NORMALIZATION
import pandas as pd
import re

slang_dictionary = pd.read_csv('../../colloquial-indonesian-lexicon2.csv')
slang_dict = pd.Series(slang_dictionary['formal'].values,index=slang_dictionary['slang']).to_dict()

slang_dictionary.head()
# Out:
#      slang    formal  In-dictionary  \
# 0     woww       wow            1.0
# 1    aminn      amin            1.0
# 2      met   selamat            1.0
# 3   netaas   menetas            1.0
# 4  keberpa  keberapa            0.0
#
#                                              context  category1 category2  \
# 0                                                wow   elongasi         0
# 1  Selamat ulang tahun kakak tulus semoga panjang...   elongasi         0
# 2  Met hari netaas kak!? Wish you all the best @t...  abreviasi         0
# 3  Met hari netaas kak!? Wish you all the best @t...   afiksasi  elongasi
# 4                           Birthday yg keberpa kak?  abreviasi         0
#
#   category3
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# Normalisasi kata menggunakan kamus colloquial-indonesian-lexicon2.csv
def Slangwords(text, slang_dict):
    for word in text.split():
        if word in slang_dict.keys():
            # menambahkan \b untuk menandakan batas kata di sekitar kata slang
            text = re.sub(r'\b{}\b'.format(re.escape(word)), slang_dict[word], text)
    
    text = re.sub('@[\w]+', '', text)
    return text

df['Review_norm'] = df['Review'].apply(lambda x: Slangwords(x, slang_dict))
print(df.head())
# Out:
#                                               Review  \
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan sy retu...
# 3               ga ada sabun nya ga sesuai deskripsi
# 4                                  ga sesuai harapan
#
#                                          Review_norm
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan saya re...
# 3       enggak ada sabun nya enggak sesuai deskripsi
# 4                              enggak sesuai harapan

# %%
# import hasil replace slang words menjadi csv
df.to_csv("normalization_avoskin.csv")

# %%
# PROSES TOKENIZING (word_tokenize() untuk memecah string kedalam tokens)

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Tokenizing
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['review_tokens'] = df['Review_norm'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df.head())
# Out:
# Tokenizing Result :
#
#                                               Review  \
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan sy retu...
# 3               ga ada sabun nya ga sesuai deskripsi
# 4                                  ga sesuai harapan
#
#                                          Review_norm  \
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan saya re...
# 3       enggak ada sabun nya enggak sesuai deskripsi
# 4                              enggak sesuai harapan
#
#                                        review_tokens
# 0  [kecewa, banget, saya, pesan, yang, free, pouc...
# 1  [kali, ini, pengemasan, tidak, safe, sepertiny...
# 2  [paket, datangnya, barang, sudah, pecah, dan, ...
# 3  [enggak, ada, sabun, nya, enggak, sesuai, desk...
# 4                          [enggak, sesuai, harapan]

# %%
# import hasil tokenizing menjadi csv
df.to_csv("tokenizing_avoskin.csv")

# %%
# PROSES FILTERING (Stopword Removal)
from nltk.corpus import stopwords

# get stopword indonesia from NLTK stopword
list_stopwords = stopwords.words('indonesian')

# convert list to dictionary
list_stopwords = set(list_stopwords)

# remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['review_tokens_SR'] = df['review_tokens'].apply(stopwords_removal) 

print(df.head())
# Out:
#                                               Review  \
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan sy retu...
# 3               ga ada sabun nya ga sesuai deskripsi
# 4                                  ga sesuai harapan
#
#                                          Review_norm  \
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan saya re...
# 3       enggak ada sabun nya enggak sesuai deskripsi
# 4                              enggak sesuai harapan
#
#                                        review_tokens  \
# 0  [kecewa, banget, saya, pesan, yang, free, pouc...
# 1  [kali, ini, pengemasan, tidak, safe, sepertiny...
# 2  [paket, datangnya, barang, sudah, pecah, dan, ...
# 3  [enggak, ada, sabun, nya, enggak, sesuai, desk...
# 4                          [enggak, sesuai, harapan]
#
#                                     review_tokens_SR
# 0  [kecewa, banget, pesan, free, pouch, dikirimny...
# 1  [kali, pengemasan, safe, tutup, botol, kencang...
# 2  [paket, datangnya, barang, pecah, return, sell...
# 3                    [sabun, nya, sesuai, deskripsi]
# 4                                  [sesuai, harapan]

# %%
# import hasil stopword removal menjadi csv
df.to_csv("stopword_avoskin.csv")

# %%
# PROSES LEMMATIZATION 
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['review_tokens_SR']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['review_tokens_stemmed'] = df['review_tokens_SR'].swifter.apply(get_stemmed_term)
print(df['review_tokens_stemmed'])
print(df.head())
# Out:
# 1616
# ------------------------
# kecewa : kecewa
# banget : banget
# pesan : pesan
# free : free
# pouch : pouch
# dikirimnya : kirim
# cotton : cotton
# pad : pad
# kaget : kaget
# pas : pas
# unboxing : unboxing
# untung : untung
# videokan : video
# kabarin : kabarin
# customer : customer
# servicenya : servicenya
# disuruh : suruh
# isi : isi
# googleform : googleform
# dikirimkan : kirim
# ulang : ulang
# pouchnya : pouchnya
# kabar : kabar
# dikabari : kabar
# stock : stock
# habis : habis
# sabar : sabar
# mengikuti : ikut
# prosedur : prosedur
# service : service
# berpikiran : pikir
# positif : positif
# ya : ya
# kali : kali
# pengemasan : emas
# safe : safe
# tutup : tutup
# botol : botol
# kencang : kencang
# toner : toner
# merembes : rembes
# dus : dus
# basah : basah
# video : video
# produk : produk
# packaging : packaging
# bagus : bagus
# avoskin : avoskin
# hujan : hujan
# dibuka : buka
# kosong : kosong
# semoga : moga
# tanggapan : tanggap
# paket : paket
# datangnya : datang
# barang : barang
# pecah : pecah
# return : return
# seller : seller
# ikuti : ikut
# komplain : komplain
# proses : proses
# seakan : akan
# pesanan : pesan
# selesai : selesai
# terima : terima
# uangnya : uang
# dilepas : lepas
# trauma : trauma
# beli : beli
# kesini : kesini
# chat : chat
# nanyain : nanyain
# diterima : terima
# formalitas : formalitas
# belanja : belanja
# uang : uang
# cuman : cuman
# responsnya : respons
# mengecewakan : kecewa
# mohon : mohon
# improvement : improvement
# thanks : thanks
# sabun : sabun
# nya : nya
# sesuai : sesuai
# deskripsi : deskripsi
# harapan : harap
# nyesal : nyesal
# dah : dah
# infokan : info
# acc : acc
# bekas : bekas
# jerawat : jerawat
# muncul : muncul
# jerawatan : jerawat
# bruntusan : bruntusan
# sayang : sayang
# maaf : maaf
# hasil : hasil
# pemakaian : pakai
# apply : apply
# whitecas : whitecas
# isinya : isi
# angin : angin
# doang : doang
# pencet : pencet
# khusus : khusus
# ss : ss
# susah : susah
# heran : heran
# versi : versi
# besarnya : besar
# cancel : cancel
# salah : salah
# balasin : balasin
# message : message
# inbox : inbox
# dicancel : dicancel
# bilang : bilang
# admin : admin
# suruh : suruh
# menunggu : tunggu
# batal : batal
# otomatis : otomatis
# taunya : tau
# tinggal : tinggal
# jam : jam
# diproses : proses
# konfirmasi : konfirmasi
# hasilnya : hasil
# dikirim : kirim
# habisin : habisin
# professional : professional
# official : official
# store : store
# ribet : ribet
# kayak : kayak
# poor : poor
# retinol : retinol
# sheet : sheet
# mask : mask
# berkisar : kisar
# ribu : ribu
# sekelas : kelas
# hits : hits
# kasih : kasih
# mystery : mystery
# box : box
# pembeli : beli
# sheetmask : sheetmask
# sebelah : belah
# tokopedia : tokopedia
# please : please
# saring : saring
# kalo : kalo
# mengajak : ajak
# brand : brand
# bikin : bikin
# niat : niat
# pokoknya : pokok
# kecewaaaaa : kecewaaaaa
# pengiriman : kirim
# wajah : wajah
# breakout : breakout
# tau : tau
# mengerti : erti
# muka : muka
# lamgsung : lamgsung
# pakai : pakai
# sekalinya : sekali
# online : online
# sampainya : sampai
# teman : teman
# reviewnya : reviewnya
# diperbaiki : baik
# sistemnya : sistem
# tim : tim
# avo : avo
# kirim : kirim
# harga : harga
# musim : musim
# pandemi : pandemi
# malas : malas
# ongkir : ongkir
# tanggung : tanggung
# pastinya : pasti
# memutuskan : putus
# serum : serum
# pikir : pikir
# normal : normal
# kesalahan : salah
# penjual : jual
# selisih : selisih
# bayar : bayar
# voucher : voucher
# pembelian : beli
# senilai : nila
# dapatkan : dapat
# kekurangan : kurang
# ampun : ampun
# sih : sih
# logika : logika
# diperbolehkan : boleh
# trf : trf
# rekening : rekening
# tokok : tokok
# amanah : amanah
# pembohong : bohong
# ucapan : ucap
# jualan : jual
# laku : laku
# toko : toko
# rusak : rusak
# tanggubg : tanggubg
# dipersulit : sulit
# lihat : lihat
# deh : deh
# mengkristal : kristal
# tisp : tisp
# dalamnya : dalam
# berdebu : debu
# manfaatnya : manfaat
# suncreen : suncreen
# spf : spf
# qcnya : qcnya
# menerima : terima
# berkurang : kurang
# prtama : prtama
# cocok : cocok
# kulitku : kulit
# sedih : sedih
# mata : mata
# bengkak : bengkak
# alergi : alergi
# bahan : bahan
# pcs : pcs
# essence : essence
# ekspedisi : ekspedisi
# dusnya : dus
# rembes : rembes
# air : air
# tonerku : tonerku
# tiris : tiris
# jdinya : jdinya
# kutolak : tolak
# paketnya : paket
# ujungnya : ujung
# duit : duit
# dibalikin : dibalikin
# huft : huft
# dikirimin : dikirimin
# tonernya : tonernya
# aman : aman
# kubalikin : kubalikin
# bocor : bocor
# terbayang : bayang
# sunscreen : sunscreen
# ml : ml
# dipencet : pencet
# mending : mending
# ganti : ganti
# sku : sku
# percaya : percaya
# buka : buka
# divideo : video
# atasnya : atas
# sobek : sobek
# essencenya : essencenya
# kering : kering
# lesson : lesson
# learned : learned
# jaman : jaman
# terpercaya : percaya
# menampak : tampak
# minggu : minggu
# segel : segel
# plastik : plastik
# krtas : krtas
# robek : robek
# rapat : rapat
# kemasan : kemas
# kosongnya : kosong
# no : no
# review : review
# found : found
# bonus : bonus
# timbul : timbul
# gatal : gatal
# iritasi : iritasi
# coba : coba
# berhenti : henti
# aduh : aduh
# senang : senang
# pc : pc
# yoongi : yoongi
# barangnya : barang
# memakai : pakai
# sunscreennya : sunscreennya
# promonya : promonya
# duanya : dua
# checkout : checkout
# guasha : guasha
# guashanya : guashanya
# duluan : duluan
# gue : gue
# suka : suka
# butuh : butuh
# travelling : travelling
# sla : sla
# eta : eta
# estimasi : estimasi
# keterangan : terang
# baca : baca
# diskripsi : skripsi
# copi : cop
# memilih : pilih
# kurir : kurir
# lhaa : lhaa
# parah : parah
# mengajukan : aju
# ditanggepin : ditanggepin
# templated : templated
# tanggal : tanggal
# hilang : hilang
# anteraja : anteraja
# beserta : serta
# skin : skin
# care : care
# tapitidak : tapitidak
# complaint : complaint
# ujung : ujung
# ditindak : tindak
# lanjuti : lanjut
# ordernya : order
# buru : buru
# cekout : cekout
# biar : biar
# asli : asli
# ngalamin : ngalamin
# berlebih : lebih
# bungkus : bungkus
# kardus : kardus
# bubble : bubble
# wrap : wrap
# dilempar : lempar
# menerus : terus
# mengulang : ulang
# informasi : informasi
# dijadwalkan : jadwal
# dipick : dipick
# up : up
# whatsappan : whatsappan
# apartemen : apartemen
# seharian : hari
# pick : pick
# upnya : upnya
# besoknya : besok
# kota : kota
# ditelpon : telpon
# anter : anter
# asap : asap
# bad : bad
# experience : experience
# sungguh : sungguh
# serumnya : serum
# kertas : kertas
# boxnya : boxnya
# lepek : lepek
# berurai : urai
# chatbox : chatbox
# email : email
# respon : respon
# wa : wa
# dk : dk
# sminggu : sminggu
# kelar : kelar
# ngurusinnya : ngurusinnya
# muter : muter
# ngmgnya : ngmgnya
# pelayanan : layan
# ajuin : ajuin
# ngebayangin : ngebayangin
# mesti : mesti
# seminggu : minggu
# bintang : bintang
# setau : tau
# basic : basic
# sakit : sakit
# set : set
# night : night
# cream : cream
# day : day
# dibeli : beli
# hai : hai
# kak : kak
# hydrating : hydrating
# treatmen : treatmen
# tumpah : tumpah
# agustus : agustus
# pengembalian : kembali
# dana : dana
# penukaran : tukar
# produknya : produk
# dikeluarin : dikeluarin
# gimanapun : gimanapun
# tutupnya : tutup
# manual : manual
# belingnya : beling
# instagram : instagram
# wajar : wajar
# meng : meng
# kristal : kristal
# repurchase : repurchase
# retur : retur
# repot : repot
# gosend : gosend
# kayanya : kaya
# bye : bye
# allah : allah
# biji : biji
# dikardusnya : kardus
# ketulis : ketul
# kardusnya : kardus
# freenya : freenya
# bilangnya : bilang
# orang : orang
# sebelumnyaaa : sebelumnyaaa
# pengin : pengin
# teliti : teliti
# cek : cek
# kerapatan : rapat
# dikasih : kasih
# hancur : hancur
# refund : refund
# ditolak : tolak
# dikonfirmasi : konfirmasi
# toped : toped
# mulu : mulu
# detik : detik
# produksi : produksi
# mengalami : alami
# dissapointing : dissapointing
# rugi : rugi
# dapetnya : dapetnya
# hati : hati
# break : break
# out : out
# kirimkan : kirim
# terlambat : lambat
# molor : molor
# maximum : maximum
# dijanjikan : janji
# akibatnya : akibat
# terbawa : bawa
# anak : anak
# ukuran : ukur
# membatalkan : batal
# status : status
# mengubungi : ubung
# merchant : merchant
# via : via
# chats : chats
# ok : ok
# dipaksan : dipaksan
# expired : expired
# date : date
# kemasa : masa
# layak : layak
# segitu : segitu
# jelek : jelek
# oknum : oknum
# ngambil : ngambil
# samping : samping
# tolong : tolong
# next : next
# packing : packing
# tertipu : tipu
# gratis : gratis
# hadiah : hadiah
# sarung : sarung
# gambar : gambar
# dapetnyabulan : dapetnyabulan
# masker : masker
# my : my
# lalai : lalai
# team : team
# kerja : kerja
# fokus : fokus
# dirugikan : rugi
# so : so
# sorry : sorry
# benaran : benar
# be : be
# more : more
# careful : careful
# sesibuk : sibuk
# apapun : apa
# sempetin : sempetin
# cepat : cepat
# diantar : antar
# kejadian : jadi
# kekeliruan : keliru
# dianggap : anggap
# sah : sah
# ditoleransi : toleransi
# lansia : lansia
# membelikan : beli
# tua : tua
# langsung : langsung
# ajukan : aju
# pembatalan : batal
# masukan : masuk
# kupon : kupon
# dibalas : balas
# makan : makan
# tuh : tuh
# ikhlas : ikhlas
# slow : slow
# recommend : recommend
# mahal : mahal
# huhu : huhu
# sebulan : bulan
# diiklankan : iklan
# special : special
# edition : edition
# refining : refining
# kekirim : kirim
# memuaskan : muas
# berat : berat
# gram : gram
# mini : mini
# mah : mah
# hadiahnya : hadiah
# dibilanh : dibilanh
# over : over
# load : load
# mengecewakam : mengecewakam
# jawabannya : jawab
# diulang : ulang
# ekspektasi : ekspektasi
# ku : ku
# ketinggian : tinggi
# ruas : ruas
# jari : jari
# indak : indak
# ditekan : tekan
# serius : serius
# segini : gin
# dll : dll
# penuh : penuh
# packagingnya : packagingnya
# tebal : tebal
# diatas : atas
# rekomen : rekomen
# jarang : jarang
# lebar : lebar
# semengecewakan : kecewa
# rela : rela
# malam : malam
# gift : gift
# harganya : harga
# sistem : sistem
# shop : shop
# buruk : buruk
# detil : detil
# tertulis : tulis
# deskripsinya : deskripsi
# foto : foto
# menampilkan : tampil
# system : system
# transparan : transparan
# membingungkan : bingung
# terbuka : buka
# giftnya : giftnya
# adminny : adminny
# dicek : cek
# dicantumkan : cantum
# gadapet : gadapet
# dikasihnya : kasih
# kesannya : kesan
# murahan : murah
# berguna : guna
# ketiga : tiga
# ditanggapi : tanggap
# labelnya : label
# ketidakbenaran : ketidakbenaran
# sepele : sepele
# keempat : empat
# update : update
# cuci : cuci
# tangan : tangan
# lelet : lelet
# giliran : gilir
# gerak : gerak
# boro : boro
# dibales : dibales
# pelayanannya : layan
# order : order
# jujur : jujur
# adminnya : adminnya
# brgnya : brgnya
# gmbr : gmbr
# balikin : balikin
# lebihnya : lebih
# lucu : lucu
# menyusahkan : susah
# diam : diam
# diteror : teror
# curi : curi
# nih : nih
# karyawannya : karyawannya
# kompeten : kompeten
# tunggu : tunggu
# oct : oct
# kuyup : kuyup
# dikit : dikit
# menyesal : sesal
# hubungi : hubung
# avoskinnya : avoskinnya
# unboxingnya : unboxingnya
# tumpeh : tumpeh
# mengaco : aco
# disuru : disuru
# coy : coy
# literally : literally
# dipaksa : paksa
# nominalnya : nominal
# mengirim : kirim
# bermasalah : masalah
# kualitas : kualitas
# purchase : purchase
# pelit : pelit
# dirubah : rubah
# alasan : alas
# paham : paham
# tokped : tokped
# fokusnya : fokus
# kepuasam : kepuasam
# pelanggan : langgan
# mempertahankan : tahan
# image : image
# bara : bara
# selamat : selamat
# mengomong : omong
# sop : sop
# transaksi : transaksi
# kemana : mana
# loh : loh
# ygdikirim : ygdikirim
# original : original
# aroma : aroma
# telur : telur
# busuk : busuk
# pengguna : guna
# ysb : ysb
# aa : aa
# familiar : familiar
# baunya : bau
# kimia : kimia
# menyengat : sengat
# complain : complain
# terpakai : pakai
# ampul : ampul
# syok : syok
# berharap : harap
# penipuan : tipu
# marketink : marketink
# ribut : ribut
# berkepanjangan : panjang
# untunk : untunk
# membantu : bantu
# sa : sa
# atasi : atas
# solusi : solusi
# tentukan : tentu
# tolonk : tolonk
# catatan : catat
# pentink : pentink
# kena : kena
# dampak : dampak
# jempol : jempol
# menyelesaikan : selesai
# akhirx : akhirx
# berkat : berkat
# bintank : bintank
# belajar : ajar
# menjd : menjd
# bae : bae
# tekstur : tekstur
# warnanya : warna
# berbed : berbed
# belinya : beli
# kekuningan : kuning
# kental : kental
# putih : putih
# encer : encer
# konsisten : konsisten
# ragu : ragu
# makenya : makenya
# rp : rp
# sale : sale
# kemarin : kemarin
# exp : exp
# januari : januari
# protes : protes
# mengirimkan : kirim
# bukti : bukti
# pengecekan : kece
# memakan : makan
# diproduksi : produksi
# november : november
# membeli : beli
# berpindah : pindah
# merk : merk
# lepas : lepas
# terang : terang
# kapok : kapok
# beralih : alih
# mengutamakan : utama
# dijual : jual
# cari : cari
# pilih : pilih
# mukanya : muka
# kuning : kuning
# bertahun : tahun
# pengecekkan : ecek
# botolnya : botol
# bersisa : sisa
# penutupnya : tutup
# pengecekkannya : ecek
# kesekian : sekian
# kalinya : kali
# kayaknya : kayak
# endapan : endap
# bawahnya : bawah
# bentuk : bentuk
# kotak : kotak
# blepotan : blepot
# tube : tube
# seal : seal
# keruh : keruh
# gelembungnya : gelembung
# aneh : aneh
# gapapakah : gapapakah
# sumpah : sumpah
# creamnya : creamnya
# memasuki : pasuk
# kulkas : kulkas
# dipakai : pakai
# officialnya : officialnya
# hmm : hmm
# kerak : kerak
# putihnya : putih
# kulit : kulit
# unproffesional : unproffesional
# with : with
# handling : handling
# wallet : wallet
# fotonya : foto
# missleading : missleading
# miraculois : miraculois
# refinning : refinning
# kualitasnya : kualitas
# peeling : peeling
# harganyamemang : harganyamemang
# diskon : diskon
# ikutan : ikut
# didiskon : diskon
# daoet : daoet
# form : form
# berulang : ulang
# konsumen : konsumen
# maklum : maklum
# praktis : praktis
# bolak : bolak
# penanganannya : tangan
# lho : lho
# oke : oke
# semalam : malam
# perih : perih
# plus : plus
# merah : merah
# paginya : pagi
# tetes : tetes
# perihh : perihh
# panas : panas
# dalih : dalih
# pemaksaan : paksa
# literatur : literatur
# rentan : rentan
# rusaknya : rusak
# pakainya : pakai
# habisnya : habis
# hak : hak
# disertai : serta
# menolak : tolak
# menggantikan : ganti
# terbaru : baru
# cso : cso
# mepet : mepet
# ketawa : ketawa
# marah : marah
# kagak : kagak
# sangka : sangka
# lagak : lagak
# komitmen : komitmen
# melindungi : lindung
# menjaga : jaga
# terkecoh : kecoh
# screenshoot : screenshoot
# edikit : edikit
# jual : jual
# diskonan : diskon
# diawal : awal
# menutupi : tutup
# sekian : sekian
# fair : fair
# adil : adil
# pantang : pantang
# menipu : tipu
# kontak : kontak
# berkali : kali
# digubris : gubris
# btw : btw
# keluhan : keluh
# berhubungan : hubung
# kosmetik : kosmetik
# situ : situ
# menginformasikan : informasi
# kenyataannya : nyata
# expirednya : expirednya
# sisa : sisa
# valid : valid
# screenshot : screenshot
# kalimat : kalimat
# penolakan : tolak
# ditambah : tambah
# kedaluwarsa : kedaluwarsa
# berkompeten : kompeten
# pembaca : baca
# ulasan : ulas
# tertawa : tertawa
# diajukan : aju
# hahahahaa : hahahahaa
# palsu : palsu
# bohong : bohong
# patut : patut
# dikenai : kena
# sanksi : sanksi
# kesal : kesal
# jengkel : jengkel
# berdalih : dalih
# komedi : komedi
# titik : titik
# profesional : profesional
# berjualan : jual
# kemerahan : merah
# gatel : gatel
# tonnernya : tonnernya
# pesanannya : pesan
# qc : qc
# digambarnya : gambar
# limited : limited
# ditulis : tulis
# gambarnya : gambar
# diganti : ganti
# mengeluhkan : keluh
# memperbaiki : baik
# umur : umur
# simpan : simpan
# nov : nov
# purchased : purchased
# the : the
# first : first
# of : of
# campaign : campaign
# mirror : mirror
# but : but
# package : package
# didn : didn
# include : include
# as : as
# said : said
# their : their
# product : product
# also : also
# looks : looks
# cheap : cheap
# doesn : doesn
# know : know
# well : well
# totally : totally
# bintik : bintik
# kea : kea
# diperhatikan : perhati
# mumpung : mumpung
# puasa : puasa
# termakan : makan
# iklan : iklan
# youtube : youtube
# rekomendasi : rekomendasi
# very : very
# not : not
# recomended : recomended
# kusam : kusam
# terik : terik
# mngkn : mngkn
# komedo : komedo
# mencari : cari
# pembenaran : benar
# contohnya : contoh
# wajib : wajib
# dideskripsi : deskripsi
# penjelasannya : jelas
# didunia : dunia
# ngamburin : ngamburin
# akhirat : akhirat
# menjual : jual
# lengkap : lengkap
# alhamdulillah : alhamdulillah
# islam : islam
# diajarkan : ajar
# penjelasan : jelas
# gumpalan : gumpal
# didalamnya : dalam
# responnya : responnya
# dijualnya : jual
# cacat : cacat
# officalnya : officalnya
# penerima : terima
# videoin : videoin
# divine : divine
# ampoule : ampoule
# bingung : bingung
# dicheck : dicheck
# stok : stok
# komplin : komplin
# disediakan : sedia
# deal : deal
# kekurangannya : kurang
# dibatalkan : batal
# komplainnya : komplain
# dipickup : dipickup
# repacking : repacking
# pickup : pickup
# resi : resi
# dichat : dichat
# berbeda : beda
# slowrespon : slowrespon
# juni : juni
# langganan : langgan
# kepakai : pakai
# perhatian : perhati
# dipenuhi : penuh
# nyelotipnya : nyelotipnya
# lengket : lengket
# coklat : coklat
# nyebelinnya : nyebelinnya
# diselotip : diselotip
# menempel : tempel
# ngerusak : ngerusak
# estetika : estetika
# plis : plis
# selotipnya : selotipnya
# packingnya : packingnya
# super : super
# mulus : mulus
# skincarenya : skincarenya
# kadaluarsanya : kadaluarsanya
# singkat : singkat
# insyaallah : insyaallah
# damage : damage
# reject : reject
# dipasarkan : pasar
# membayar : bayar
# seharga : harga
# kedepannya : depan
# takut : takut
# pao : pao
# etalase : etalase
# jualin : jualin
# murah : murah
# saran : saran
# gapapa : gapapa
# brandnya : brandnya
# skincare : skincare
# mengorbankan : korban
# kepercayaan : percaya
# menghabiskan : habis
# efektif : efektif
# diskusi : diskusi
# penulisan : tulis
# alat : alat
# klaim : klaim
# pemberitahuan : pemberitahuan
# sertakan : serta
# himbauan : himbauan
# terjual : jual
# batch : batch
# panass : panass
# apa-apa : apa
# nyelekit : nyelekit
# sensitif : sensitif
# menyebabkan : sebab
# kemerahaan : kemerahaan
# daerah : daerah
# dagu : dagu
# kedepan : depan
# pilihan : pilih
# sangaaaaaaaaaat : sangaaaaaaaaaat
# makasar : makasar
# gampang : gampang
# penyok : penyok
# inti : inti
# sebentar : sebentar
# disaat : saat
# berlomba : lomba
# lomba : lomba
# mempercepat : cepat
# san : san
# berlarut : larut
# larut : larut
# cih : cih
# selesaikan : selesai
# mendekati : dekat
# batas : batas
# maret : maret
# september : september
# kadaluwarsa : kadaluwarsa
# jarak : jarak
# medan : medan
# jogja : jogja
# februari : februari
# sociolla : sociolla
# website : website
# bercak : bercak
# warna : warna
# full : full
# orange : orange
# diretur : retur
# yasudahlah : yasudahlah
# menyerap : serap
# keringnya : kering
# lapisan : lapis
# mati : mati
# gosok : gosok
# mengelupas : kelupas
# sicepat : sicepat
# pengajuan : aju
# akibat : akibat
# kondisi : kondisi
# sealed : sealed
# lilit : lilit
# pengamannya : kam
# taruh : taruh
# permintaan : minta
# tolak : tolak
# asuransi : asuransi
# abisin : abisin
# musti : musti
# bis : bis
# kebuka : buka
# disalahin : disalahin
# perfect : perfect
# combo : combo
# miraculous : miraculous
# dark : dark
# spot : spot
# selisihnya : selisih
# shipping : shipping
# label : label
# blur : blur
# sayangnya : sayang
# syarat : syarat
# tingkatkan : tingkat
# database : database
# mengecek : ecek
# after : after
# sales : sales
# dihapus : hapus
# histori : histori
# data : data
# pergantian : ganti
# dikabarin : dikabarin
# clearance : clearance
# kaca : kaca
# dimana : mana
# buang : buang
# facial : facial
# wash : wash
# opsi : opsi
# dijemput : jemput
# stand : stand
# by : by
# dirumah : rumah
# sumbangin : sumbangin
# pegawai : pegawai
# muat : muat
# penanganan : tangan
# butub : butub
# responsif : responsif
# cenderung : cenderung
# pasif : pasif
# lemot : lot
# hadapi : hadap
# mencoba : coba
# kendalanya : kendala
# pengalaman : alam
# time : time
# reseller : reseller
# lebib : lebib
# ramah : ramah
# gede : gede
# kepalanya : kepala
# beda : beda
# reselleler : reselleler
# solutif : solutif
# adik : adik
# berminyak : minyak
# promo : promo
# kadaluarsa : kadaluarsa
# orderan : order
# tukar : tukar
# zonk : zonk
# tuker : tuker
# lactic : lactic
# acid : acid
# jeroan : jeroan
# tamia : tamia
# sialan : sial
# blunder : blunder
# angkat : angkat
# kecewakan : kecewa
# diwaktu : waktu
# lambat : lambat
# menyebalkan : sebal
# setahun : tahun
# didnt : didnt
# receive : receive
# they : they
# switched : switched
# ampoulenya : ampoulenya
# alamat : alamat
# mengambil : ambil
# rumah : rumah
# dikenal : kenal
# bau : bau
# karma : karma
# sampah : sampah
# tracking : tracking
# detail : detail
# kotaknya : kotak
# muntahan : muntah
# menjatuhkan : jatuh
# zong : zong
# tulisan : tulis
# oplos : oplos
# kocak : kocak
# dj : dj
# sialnya : sial
# rugikan : rugi
# keterlambatan : lambat
# berbelanjanya : belanja
# dibawa : bawa
# terbang : terbang
# menyenangkan : senang
# penipu : tipu
# tll : tll
# berdiriin : berdiriin
# like : like
# wtf : wtf
# woiii : woiii
# kelas : kelas
# pabrikan : pabrikan
# produksinya : produksi
# tertera : tera
# sabunnya : sabun
# defect : defect
# alias : alias
# blogger : blogger
# dalemnya : dalem
# jamuran : jamur
# gagal : gagal
# brngnya : brngnya
# posisi : posisi
# follow : follow
# balesannya : balesannya
# dcek : dcek
# kbr : kbr
# april : april
# antrinya : antri
# izin : izin
# kepastian : pasti
# dibilang : bilang
# berkala : kala
# kenyataan : nyata
# iseng : iseng
# belu : belu
# favorit : favorit
# engah : engah
# seukuran : ukur
# leher : leher
# diluar : luar
# ekspetasi : ekspetasi
# pengirimannya : kirim
# direview : direview
# cair : cair
# butek : butek
# bening : bening
# niacinamide : niacinamide
# salicylic : salicylic
# ditunggu : tunggu
# menangis : menang
# klam : klam
# persutujuan : persutujuan
# sengaja : sengaja
# memaksa : paksa
# total : total
# barunya : baru
# size : size
# kaya : kaya
# reccomend : reccomend
# keracun : racun
# series : series
# kombucha : kombucha
# niacimide : niacimide
# pertanggungjwban : pertanggungjwban
# solusinya : solusi
# ditukar : tukar
# waktuku : waktu
# terbuang : buang
# rada : rada
# yaudahlah : yaudahlah
# sebotol : botol
# exsaited : exsaited
# setetes : tetes
# dblg : dblg
# sngat : sngat
# tulisannya : tulis
# secuil : cuil
# wadahnya : wadah
# dipesan : pes
# diubah : ubah
# men : men
# sensor : sensor
# nama : nama
# okeh : okeh
# tasnya : tas
# balasan : balas
# cabang : cabang
# sticker : sticker
# popsocket : popsocket
# jualannya : jual
# kadarluarsa : kadarluarsa
# debunya : debu
# poll : poll
# ngabisin : ngabisin
# somethinc : somethinc
# duh : duh
# kritikan : kritik
# mengasih : asih
# dibawah : bawah
# perbaiki : baik
# kepencet : pencet
# sellernya : sellernya
# your : your
# tipis : tipis
# pipet : pipet
# pumpnya : pumpnya
# berfungsi : fungsi
# tersedot : sedot
# dicoba : coba
# pump : pump
# effortless : effortless
# replace : replace
# dioper : oper
# whatsapp : whatsapp
# lakukan : laku
# followup : followup
# mengoper : oper
# usaha : usaha
# sejelas : jelas
# pipetnya : pipet
# jelasin : jelasin
# diputer : puter
# puter : puter
# beratnya : berat
# sdm : sdm
# sukses : sukses
# tulisnya : tulis
# kamis : kamis
# senin : senin
# pesannya : pesan
# drama : drama
# acne : acne
# ridho : ridho
# jaga : jaga
# pekerjaan : kerja
# becus : becus
# war : war
# flashsale : flashsale
# kiriman : kirim
# komplit : komplit
# datengnya : datengnya
# solution : solution
# upload : upload
# benerin : benerin
# lihatnya : lihat
# silakan : sila
# nilai : nilai
# seriously : seriously
# merekam : rekam
# membuka : buka
# tuhan : tuhan
# maha : maha
# kebenaran : benar
# okelah : oke
# harap : harap
# mempromosikan : promosi
# lingkungan : lingkung
# dikirimi : kirim
# never : never
# received : received
# products : products
# for : for
# month : month
# waiting : waiting
# and : and
# now : now
# waste : waste
# separah : parah
# trik : trik
# sapa : sapa
# rib : rib
# sedap : sedap
# direfund : direfund
# item : item
# mengemas : emas
# laris : laris
# mensejahterakan : sejahtera
# semangat : semangat
# konsentrasi : konsentrasi
# logistiknya : logistik
# evaluasi : evaluasi
# bermitra : mitra
# mempengaruhi : pengaruh
# kepuasan : puas
# ecommerce : ecommerce
# bebas : bebas
# selambat : lambat
# sori : sori
# ditangani : tangan
# ngurangin : ngurangin
# kempes : kempes
# ngefek : ngefek
# haid : haid
# dijejerkan : jejer
# bedanya : beda
# auto : auto
# close : close
# disayangkan : sayang
# eww : eww
# tonner : tonner
# gara : gara
# gapaham : gapaham
# dapatnya : dapat
# pulang : pulang
# jatohnya : jatohnya
# luarnya : luar
# utuh : utuh
# tersegel : segel
# cairan : cair
# menulis : tulis
# setelahnya : telah
# terlanjur : lanjur
# dikomplain : komplain
# penjualnya : jual
# lo : lo
# halu : halu
# sebaigai : sebaigai
# pelanggal : pelanggal
# hafusnya : hafusnya
# gel : gel
# diresi : resi
# divideoin : divideoin
# eeeehh : eeeehh
# kotor : kotor
# lecet : lecet
# obat : obat
# totol : totol
# jerawatnya : jerawat
# padat : padat
# oktober : oktober
# sebelumya : sebelumya
# kau : kau
# datenya : datenya
# dipakein : dipakein
# bublewrap : bublewrap
# cap : cap
# bangun : bangun
# tidur : tidur
# too : too
# impressed : impressed
# affordable : affordable
# average : average
# quality : quality
# expnya : expnya
# minimal : minimal
# tlsnnya : tlsnnya
# cash : cash
# back : back
# ditutup : tutup
# enak : enak
# malamny : malamny
# keras : keras
# est : est
# ditampilkan : tampil
# alasanya : alasanya
# overload : overload
# ontime : ontime
# penilaian : nilai
# hc : hc
# recommended : recommended
# requestnya : requestnya
# action : action
# eye : eye
# intensive : intensive
# nourishing : nourishing
# terpisah : pisah
# keluarkan : keluar
# niacin : niacin
# misleading : misleading
# menyesatkan : sesat
# cantik : cantik
# individual : individual
# jualnya : jual
# sok : sok
# tulis : tulis
# glow : glow
# pasang : pasang
# kopong : kopong
# worth : worth
# batu : batu
# bekasnya : bekas
# kukira : kira
# efek : efek
# trnyt : trnyt
# preloved : preloved
# menguning : kuning
# overall : overall
# respect : respect
# tas : tas
# buyers : buyers
# are : are
# expect : expect
# something : something
# wrong : wrong
# disalahkan : salah
# olah : olah
# buyer : buyer
# part : part
# ratusan : ratus
# tambahan : tambah
# info : info
# tight : tight
# solasinya : solasinya
# logikanya : logika
# setight : setight
# tipe : tipe
# langsungjerawat : langsungjerawat
# pket : pket
# terlama : lama
# nyangkut : nyangkut
# pipi : pipi
# jidat : jidat
# longgar : longgar
# terlepas : lepas
# pegangan : pegang
# tumbuh : tumbuh
# piye : piye
# ppkm : ppkm
# huv : huv
# spatula : spatula
# hmmmm : hmmmm
# menyesak : sesak
# cekot : cekot
# ysk : ysk
# phte : phte
# dsb : dsb
# juli : juli
# prone : prone
# launch : launch
# kandungan : kandung
# actives : actives
# permasalahan : masalah
# bumil : bumil
# busui : busui
# membela : bela
# sehari : hari
# ditempat : tempat
# menyembuhkan : sembuh
# berjerawat : jerawat
# berani : berani
# bareface : bareface
# amburadul : amburadul
# kulitnya : kulit
# monggo : monggo
# badak : badak
# dirasa : rasa
# pertimbangin : pertimbangin
# dipakainya : pakai
# memakainya : maka
# positifnya : positif
# mubazir : mubazir
# dm : dm
# hmmmmmm : hmmmmmm
# terimabarang : terimabarang
# ambrulradul : ambrulradul
# pinggirnya : pinggir
# sedihnya : sedih
# ditanggal : tanggal
# release : release
# ehhhh : ehhhh
# miris : miris
# ntaran : ntaran
# flash : flash
# puluh : puluh
# paonya : paonya
# ih : ih
# tujuan : tuju
# dihari : hari
# jerawaten : jerawaten
# mengandung : kandung
# friendly : friendly
# mukaku : muka
# duper : duper
# jnt : jnt
# haduhhh : haduhhh
# sabtu : sabtu
# nyampr : nyampr
# garansi : garansi
# durasi : durasi
# tampilan : tampil
# belikan : belikan
# transparasi : transparasi
# pengaturan : atur
# php : php
# pribadi : pribadi
# terkesan : kes
# sedikkit : sedikkit
# whitecast : whitecast
# nyata : nyata
# tepung : tepung
# hidrasi : hidrasi
# ngeblend : ngeblend
# takaran : takar
# cemong : cemong
# wudhu : wudhu
# bersihin : bersihin
# cleansing : cleansing
# oil : oil
# kombinasi : kombinasi
# dry : dry
# age : age
# keatas : atas
# tempatnya : tempat
# kegedean : gede
# menyangka : sangka
# kebanyakan : banyak
# menambah : tambah
# batalin : batalin
# pemesanan : mesan
# intinya : inti
# akh : akh
# reschedule : reschedule
# kirimnya : kirim
# sananya : sana
# wallahualam : wallahualam
# untungnya : untung
# didalam : dalam
# rapi : rapi
# perhatikan : perhati
# pengemasannya : emas
# lapisi : lapis
# productnya : productnya
# difoto : foto
# nyatu : nyatu
# ditarik : tarik
# ambil : ambil
# packaginya : packaginya
# kedpnnya : kedpnnya
# dikirain : dikirain
# kejual : jual
# hrgnya : hrgnya
# dibandingin : dibandingin
# jakarta : jakarta
# masak : masak
# huhuu : huhuu
# orisinal : orisinal
# halo : halo
# perasaan : asa
# takutnya : takut
# teroksidasi : oksidasi
# kejar : kejar
# doh : doh
# at : at
# all : all
# build : build
# tolerance : tolerance
# ed : ed
# ngepas : ngepas
# setaun : taun
# diskonnya : diskon
# bebasss : bebasss
# bunn : bunn
# {'kecewa': 'kecewa', 'banget': 'banget', 'pesan': 'pesan', 'free': 'free', 'pouch': 'pouch', 'dikirimnya': 'kirim', 'cotton': 'cotton', 'pad': 'pad', 'kaget': 'kaget', 'pas': 'pas', 'unboxing': 'unboxing', 'untung': 'untung', 'videokan': 'video', 'kabarin': 'kabarin', 'customer': 'customer', 'servicenya': 'servicenya', 'disuruh': 'suruh', 'isi': 'isi', 'googleform': 'googleform', 'dikirimkan': 'kirim', 'ulang': 'ulang', 'pouchnya': 'pouchnya', 'kabar': 'kabar', 'dikabari': 'kabar', 'stock': 'stock', 'habis': 'habis', 'sabar': 'sabar', 'mengikuti': 'ikut', 'prosedur': 'prosedur', 'service': 'service', 'berpikiran': 'pikir', 'positif': 'positif', 'ya': 'ya', 'kali': 'kali', 'pengemasan': 'emas', 'safe': 'safe', 'tutup': 'tutup', 'botol': 'botol', 'kencang': 'kencang', 'toner': 'toner', 'merembes': 'rembes', 'dus': 'dus', 'basah': 'basah', 'video': 'video', 'produk': 'produk', 'packaging': 'packaging', 'bagus': 'bagus', 'avoskin': 'avoskin', 'hujan': 'hujan', 'dibuka': 'buka', 'kosong': 'kosong', 'semoga': 'moga', 'tanggapan': 'tanggap', 'paket': 'paket', 'datangnya': 'datang', 'barang': 'barang', 'pecah': 'pecah', 'return': 'return', 'seller': 'seller', 'ikuti': 'ikut', 'komplain': 'komplain', 'proses': 'proses', 'seakan': 'akan', 'pesanan': 'pesan', 'selesai': 'selesai', 'terima': 'terima', 'uangnya': 'uang', 'dilepas': 'lepas', 'trauma': 'trauma', 'beli': 'beli', 'kesini': 'kesini', 'chat': 'chat', 'nanyain': 'nanyain', 'diterima': 'terima', 'formalitas': 'formalitas', 'belanja': 'belanja', 'uang': 'uang', 'cuman': 'cuman', 'responsnya': 'respons', 'mengecewakan': 'kecewa', 'mohon': 'mohon', 'improvement': 'improvement', 'thanks': 'thanks', 'sabun': 'sabun', 'nya': 'nya', 'sesuai': 'sesuai', 'deskripsi': 'deskripsi', 'harapan': 'harap', 'nyesal': 'nyesal', 'dah': 'dah', 'infokan': 'info', 'acc': 'acc', 'bekas': 'bekas', 'jerawat': 'jerawat', 'muncul': 'muncul', 'jerawatan': 'jerawat', 'bruntusan': 'bruntusan', 'sayang': 'sayang', 'maaf': 'maaf', 'hasil': 'hasil', 'pemakaian': 'pakai', 'apply': 'apply', 'whitecas': 'whitecas', 'isinya': 'isi', 'angin': 'angin', 'doang': 'doang', 'pencet': 'pencet', 'khusus': 'khusus', 'ss': 'ss', 'susah': 'susah', 'heran': 'heran', 'versi': 'versi', 'besarnya': 'besar', 'cancel': 'cancel', 'salah': 'salah', 'balasin': 'balasin', 'message': 'message', 'inbox': 'inbox', 'dicancel': 'dicancel', 'bilang': 'bilang', 'admin': 'admin', 'suruh': 'suruh', 'menunggu': 'tunggu', 'batal': 'batal', 'otomatis': 'otomatis', 'taunya': 'tau', 'tinggal': 'tinggal', 'jam': 'jam', 'diproses': 'proses', 'konfirmasi': 'konfirmasi', 'hasilnya': 'hasil', 'dikirim': 'kirim', 'habisin': 'habisin', 'professional': 'professional', 'official': 'official', 'store': 'store', 'ribet': 'ribet', 'kayak': 'kayak', 'poor': 'poor', 'retinol': 'retinol', 'sheet': 'sheet', 'mask': 'mask', 'berkisar': 'kisar', 'ribu': 'ribu', 'sekelas': 'kelas', 'hits': 'hits', 'kasih': 'kasih', 'mystery': 'mystery', 'box': 'box', 'pembeli': 'beli', 'sheetmask': 'sheetmask', 'sebelah': 'belah', 'tokopedia': 'tokopedia', 'please': 'please', 'saring': 'saring', 'kalo': 'kalo', 'mengajak': 'ajak', 'brand': 'brand', 'bikin': 'bikin', 'niat': 'niat', 'pokoknya': 'pokok', 'kecewaaaaa': 'kecewaaaaa', 'pengiriman': 'kirim', 'wajah': 'wajah', 'breakout': 'breakout', 'tau': 'tau', 'mengerti': 'erti', 'muka': 'muka', 'lamgsung': 'lamgsung', 'pakai': 'pakai', 'sekalinya': 'sekali', 'online': 'online', 'sampainya': 'sampai', 'teman': 'teman', 'reviewnya': 'reviewnya', 'diperbaiki': 'baik', 'sistemnya': 'sistem', 'tim': 'tim', 'avo': 'avo', 'kirim': 'kirim', 'harga': 'harga', 'musim': 'musim', 'pandemi': 'pandemi', 'malas': 'malas', 'ongkir': 'ongkir', 'tanggung': 'tanggung', 'pastinya': 'pasti', 'memutuskan': 'putus', 'serum': 'serum', 'pikir': 'pikir', 'normal': 'normal', 'kesalahan': 'salah', 'penjual': 'jual', 'selisih': 'selisih', 'bayar': 'bayar', 'voucher': 'voucher', 'pembelian': 'beli', 'senilai': 'nila', 'dapatkan': 'dapat', 'kekurangan': 'kurang', 'ampu ...
# ------------------------
# Pandas Apply: 100%|██████████| 383/383 [00:00<00:00, 95415.68it/s]
# 0      [kecewa, banget, pesan, free, pouch, kirim, co...
# 1      [kali, emas, safe, tutup, botol, kencang, tone...
# 2      [paket, datang, barang, pecah, return, seller,...
# 3                        [sabun, nya, sesuai, deskripsi]
# 4                                        [sesuai, harap]
#                              ...
# 379    [bara, selamat, customer, service, avoskin, to...
# 380                       [barang, bagus, sayang, layan]
# 381    [halo, kak, warna, produk, kuning, bening, kay...
# 382    [harga, kejar, diskon, doh, not, cheap, at, al...
# 383                    [ukur, produk, mahal, harga, gin]
# Name: review_tokens_stemmed, Length: 383, dtype: object
#                                               Review  \
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan sy retu...
# 3               ga ada sabun nya ga sesuai deskripsi
# 4                                  ga sesuai harapan
#
#                                          Review_norm  \
# 0  kecewa banget saya pesan yang free pouch tapi ...
# 1  kali ini pengemasan tidak safe sepertinya tutu...
# 2  paket datangnya barang sudah pecah dan saya re...
# 3       enggak ada sabun nya enggak sesuai deskripsi
# 4                              enggak sesuai harapan
#
#                                        review_tokens  \
# 0  [kecewa, banget, saya, pesan, yang, free, pouc...
# 1  [kali, ini, pengemasan, tidak, safe, sepertiny...
# 2  [paket, datangnya, barang, sudah, pecah, dan, ...
# 3  [enggak, ada, sabun, nya, enggak, sesuai, desk...
# 4                          [enggak, sesuai, harapan]
#
#                                     review_tokens_SR  \
# 0  [kecewa, banget, pesan, free, pouch, dikirimny...
# 1  [kali, pengemasan, safe, tutup, botol, kencang...
# 2  [paket, datangnya, barang, pecah, return, sell...
# 3                    [sabun, nya, sesuai, deskripsi]
# 4                                  [sesuai, harapan]
#
#                                review_tokens_stemmed
# 0  [kecewa, banget, pesan, free, pouch, kirim, co...
# 1  [kali, emas, safe, tutup, botol, kencang, tone...
# 2  [paket, datang, barang, pecah, return, seller,...
# 3                    [sabun, nya, sesuai, deskripsi]
# 4                                    [sesuai, harap]

# %%
# import hasil preprocessing menjadi csv
df.to_csv("lemma_avoskin 500.csv")
