# %%
# Load data ke dalam data frame 
import pandas as pd

# Spesifikasi encoding diperlukan karena data tidak menggunakan UTF-8
df = pd.read_csv('scraping_azarine-neg.csv', encoding='latin-1')

df.head()
# Out:
#                                               Review  \
# 0  Pengiriman sangat lama, 3hari setelah order ba...
# 1                                 Salah kirim barang
# 2  Paket Acne nya tidak lengkap Facial foamnya ti...
# 3  Packing tidak baik. Packing luar rusak & sdh t...
# 4  barang tak pernah sampai kaga amanh lama bange...
#
#                               Product     Rating   Username  \
# 0                       C-White Serum  bintang 1  Nocturnal
# 1           C White Night Moisturizer  bintang 1      N***i
# 2  Paket Intense Acne & repair Series  bintang 1    Faridah
# 3                       C-White Serum  bintang 1      Yanti
# 4      AZARINE EASY WHITE PAKET HEMAT  bintang 1      S***a
#
#                       Date
# 0  Lebih dari 1 tahun lalu
# 1  Lebih dari 1 tahun lalu
# 2  Lebih dari 1 tahun lalu
# 3  Lebih dari 1 tahun lalu
# 4  Lebih dari 1 tahun lalu

# %%
# Drop kolom yang tidak terpakai
df = df.drop(df.iloc[:,1:], axis=1)

# Cek data teratas
df.head()
# Out:
#                                               Review
# 0  Pengiriman sangat lama, 3hari setelah order ba...
# 1                                 Salah kirim barang
# 2  Paket Acne nya tidak lengkap Facial foamnya ti...
# 3  Packing tidak baik. Packing luar rusak & sdh t...
# 4  barang tak pernah sampai kaga amanh lama bange...

# %% [markdown]
# PREPROCESSING

# %%
# PROSES CASE FOLDING (menjadikan semua huruf di kolom Review menjadi huruf kecil)
df['Review'] = df['Review'].str.lower()

print('Case Folding Result: \n')
df.head()
# Out:
# Case Folding Result:
#                                               Review
# 0  pengiriman sangat lama, 3hari setelah order ba...
# 1                                 salah kirim barang
# 2  paket acne nya tidak lengkap facial foamnya ti...
# 3  packing tidak baik. packing luar rusak & sdh t...
# 4  barang tak pernah sampai kaga amanh lama bange...

# %%
# import hasil case folding menjadi csv
df.to_csv("casefolding_azarine.csv")

# %%
# CLEANING
import re # regex library

def remove_tweet_special(text):
    # remove tab, new line, and back slice
    text = text.replace('\\t'," ").replace('\\n', " ").replace('\\u', " ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")

df['Review'] = df['Review'].apply(remove_tweet_special)

# remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

df['Review'] = df['Review'].apply(remove_number)

# remove punctuation and replace with space
def remove_punctuation(text):
    return re.sub(r'[.,]', ' ', text)

df['Review'] = df['Review'].apply(remove_punctuation)

# remove punctuation
def remove_symbol(text):
    # Menghapus simbol-simbol tidak standar dan menggantinya dengan spasi
    cleaned_text = re.sub(r'[^\w\s]', ' ', text)
    
    # Menghapus multiple whitespace
    cleaned_text = re.sub('\s+', ' ', cleaned_text).strip()
    
    return cleaned_text

df['Review'] = df['Review'].apply(remove_symbol)

# Menentukan ambang batas panjang string acak
threshold_length = 20

# Fungsi untuk menghapus string acak berdasarkan panjangnya
def hapus_string_acak_dengan_panjang(text):
    # Memeriksa panjang string dan menghapus jika melebihi ambang batas
    return ' '.join(word for word in text.split() if len(word) <= threshold_length)

# Menggunakan fungsi untuk menghapus string acak pada kolom 'Text'
df['Review'] = df['Review'].apply(hapus_string_acak_dengan_panjang)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

df['Review'] = df['Review'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

df['Review'] = df['Review'].apply(remove_whitespace_multiple)

# remove single char
def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

df['Review'] = df['Review'].apply(remove_single_char)

def remove_laughter(text):
    laughter_patterns = r'\b((ha)+h*|(he)+h*|(hi)+h*|(wk)+w*k*|(eh)+e*|(ah)+a*|(ih)+i*|(kw)+k*w*|(hem)+m*)\b'
    return re.sub(laughter_patterns, '', text, flags=re.IGNORECASE)

df['Review'] = df['Review'].apply(remove_laughter)

print('Cleaning Result : \n') 
print(df.head())
# Out:
# Cleaning Result :
#
#                                               Review
# 0  pengiriman sangat lama hari setelah order baru...
# 1                                 salah kirim barang
# 2  paket acne nya tidak lengkap facial foamnya ti...
# 3  packing tidak baik packing luar rusak sdh terb...
# 4  barang tak pernah sampai kaga amanh lama bange...

# %%
# import hasil cleaning menjadi csv
df.to_csv("cleaning_azarine.csv")

# %%
# REMOVE DUPLICATE
df = df.drop_duplicates()
df = df.reset_index(drop=True)
# Menghapus baris yang kosong
df = df.dropna(subset=['Review'])
# Menghapus baris yang hanya berisi spasi atau whitespace
df = df[df['Review'].str.strip() != '']
df.head()
# Out:
#                                               Review
# 0  pengiriman sangat lama hari setelah order baru...
# 1                                 salah kirim barang
# 2  paket acne nya tidak lengkap facial foamnya ti...
# 3  packing tidak baik packing luar rusak sdh terb...
# 4  barang tak pernah sampai kaga amanh lama bange...

# %%
# import hasil remove duplicate menjadi csv
df.to_csv("removedup_azarine.csv")

# %%
# NORMALIZATION
import pandas as pd
import re

slang_dictionary = pd.read_csv('../colloquial-indonesian-lexicon2.csv')
slang_dict = pd.Series(slang_dictionary['formal'].values,index=slang_dictionary['slang']).to_dict()

slang_dictionary.head()
# Out:
#      slang    formal  In-dictionary  \
# 0     woww       wow            1.0
# 1    aminn      amin            1.0
# 2      met   selamat            1.0
# 3   netaas   menetas            1.0
# 4  keberpa  keberapa            0.0
#
#                                              context  category1 category2  \
# 0                                                wow   elongasi         0
# 1  Selamat ulang tahun kakak tulus semoga panjang...   elongasi         0
# 2  Met hari netaas kak!? Wish you all the best @t...  abreviasi         0
# 3  Met hari netaas kak!? Wish you all the best @t...   afiksasi  elongasi
# 4                           Birthday yg keberpa kak?  abreviasi         0
#
#   category3
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
# Normalisasi kata menggunakan kamus colloquial-indonesian-lexicon2.csv
def Slangwords(text, slang_dict):
    for word in text.split():
        if word in slang_dict.keys():
            # menambahkan \b untuk menandakan batas kata di sekitar kata slang
            text = re.sub(r'\b{}\b'.format(re.escape(word)), slang_dict[word], text)
    
    text = re.sub('@[\w]+', '', text)
    return text

df['Review_norm'] = df['Review'].apply(lambda x: Slangwords(x, slang_dict))
print(df.head())
# Out:
#                                               Review  \
# 0  pengiriman sangat lama hari setelah order baru...
# 1                                 salah kirim barang
# 2  paket acne nya tidak lengkap facial foamnya ti...
# 3  packing tidak baik packing luar rusak sdh terb...
# 4  barang tak pernah sampai kaga amanh lama bange...
#
#                                          Review_norm
# 0  pengiriman sangat lama hari setelah order baru...
# 1                                 salah kirim barang
# 2  paket acne nya tidak lengkap facial foamnya ti...
# 3  packing tidak baik packing luar rusak sudah te...
# 4  barang tak pernah sampai kagak amanh lama bang...

# %%
# import hasil replace slang words menjadi csv
df.to_csv("normalization_azarine.csv")

# %%
# PROSES TOKENIZING (word_tokenize() untuk memecah string kedalam tokens)

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# Tokenizing
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df['review_tokens'] = df['Review_norm'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(df.head())
# Out:
# Tokenizing Result :
#
#                                               Review  \
# 0  pengiriman sangat lama hari setelah order baru...
# 1                                 salah kirim barang
# 2  paket acne nya tidak lengkap facial foamnya ti...
# 3  packing tidak baik packing luar rusak sdh terb...
# 4  barang tak pernah sampai kaga amanh lama bange...
#
#                                          Review_norm  \
# 0  pengiriman sangat lama hari setelah order baru...
# 1                                 salah kirim barang
# 2  paket acne nya tidak lengkap facial foamnya ti...
# 3  packing tidak baik packing luar rusak sudah te...
# 4  barang tak pernah sampai kagak amanh lama bang...
#
#                                        review_tokens
# 0  [pengiriman, sangat, lama, hari, setelah, orde...
# 1                             [salah, kirim, barang]
# 2  [paket, acne, nya, tidak, lengkap, facial, foa...
# 3  [packing, tidak, baik, packing, luar, rusak, s...
# 4  [barang, tak, pernah, sampai, kagak, amanh, la...

# %%
# import hasil tokenizing menjadi csv
df.to_csv("tokenizing_azarine.csv")

# %%
# PROSES FILTERING (Stopword Removal)
from nltk.corpus import stopwords

# get stopword indonesia from NLTK stopword
list_stopwords = stopwords.words('indonesian')

# convert list to dictionary
list_stopwords = set(list_stopwords)

# remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

df['review_tokens_SR'] = df['review_tokens'].apply(stopwords_removal) 

print(df.head())
# Out:
#                                               Review  \
# 0  pengiriman sangat lama hari setelah order baru...
# 1                                 salah kirim barang
# 2  paket acne nya tidak lengkap facial foamnya ti...
# 3  packing tidak baik packing luar rusak sdh terb...
# 4  barang tak pernah sampai kaga amanh lama bange...
#
#                                          Review_norm  \
# 0  pengiriman sangat lama hari setelah order baru...
# 1                                 salah kirim barang
# 2  paket acne nya tidak lengkap facial foamnya ti...
# 3  packing tidak baik packing luar rusak sudah te...
# 4  barang tak pernah sampai kagak amanh lama bang...
#
#                                        review_tokens  \
# 0  [pengiriman, sangat, lama, hari, setelah, orde...
# 1                             [salah, kirim, barang]
# 2  [paket, acne, nya, tidak, lengkap, facial, foa...
# 3  [packing, tidak, baik, packing, luar, rusak, s...
# 4  [barang, tak, pernah, sampai, kagak, amanh, la...
#
#                                     review_tokens_SR
# 0          [pengiriman, order, dikirim, barang, nya]
# 1                             [salah, kirim, barang]
# 2       [paket, acne, nya, lengkap, facial, foamnya]
# 3  [packing, packing, rusak, terbuka, terima, dit...
# 4               [barang, kagak, amanh, banget, bakl]

# %%
# import hasil stopword removal menjadi csv
df.to_csv("stopword_azarine.csv")

# %%
# PROSES LEMMATIZATION 
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['review_tokens_SR']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['review_tokens_stemmed'] = df['review_tokens_SR'].swifter.apply(get_stemmed_term)
print(df['review_tokens_stemmed'])
print(df.head())
# Out:
# 1265
# ------------------------
# pengiriman : kirim
# order : order
# dikirim : kirim
# barang : barang
# nya : nya
# salah : salah
# kirim : kirim
# paket : paket
# acne : acne
# lengkap : lengkap
# facial : facial
# foamnya : foamnya
# packing : packing
# rusak : rusak
# terbuka : buka
# terima : terima
# diterima : terima
# orang : orang
# rumah : rumah
# serum : serum
# penyok : penyok
# jual : jual
# kagak : kagak
# amanh : amanh
# banget : banget
# bakl : bakl
# belanja : belanja
# tanggal : tanggal
# transaksi : transaksi
# syarat : syarat
# member : member
# platinum : platinum
# gagal : gagal
# gara : gara
# semoga : moga
# kecewa : kecewa
# buang : buang
# tong : tong
# sampah : sampah
# product : product
# pelindungnya : lindung
# menandakan : tanda
# segel : segel
# plastik : plastik
# maaf : maaf
# kasih : kasih
# bintang : bintang
# diperhatikan : perhati
# ya : ya
# perihal : perihal
# kemasan : kemas
# dikonfirmasi : konfirmasi
# pesan : pesan
# mei : mei
# konfirmasi : konfirmasi
# produk : produk
# sesuai : sesuai
# urutan : urut
# orderan : order
# pengajuan : aju
# pick : pick
# up : up
# juni : juni
# jam : jam
# batal : batal
# otomatis : otomatis
# berhasil : hasil
# dijemput : jemput
# estimasi : estimasi
# mohon : mohon
# toko : toko
# cepat : cepat
# proses : proses
# meningkatkan : tingkat
# kualitas : kualitas
# pelayanan : layan
# sih : sih
# oke : oke
# cuman : cuman
# customer : customer
# service : service
# pengepakan : epak
# kecuali : kecuali
# azarine : azarine
# doang : doang
# admin : admin
# balesnya : balesnya
# menambah : tambah
# karyawan : karyawan
# print : print
# tulisan : tulis
# body : body
# rendah : rendah
# diperbaiki : baik
# murahan : murah
# sabar : sabar
# mbak : mbak
# mas : mas
# bu : bu
# any : any
# gender : gender
# pronouns : pronouns
# ditunjang : tunjang
# pengirimannya : kirim
# sehari : hari
# penuh : penuh
# diproses : proses
# sampainya : sampai
# seminggu : minggu
# pas : pas
# sun : sun
# shield : shield
# paketnya : paket
# barangnya : barang
# kosong : kosong
# langsung : langsung
# tuh : tuh
# pesenannya : sen
# ribet : ribet
# komplain : komplain
# tokopedia : tokopedia
# pengembalian : kembali
# dananya : dana
# bundle : bundle
# parah : parah
# pelayanannya : layan
# respon : respon
# adminnya : adminnya
# kardus : kardus
# lakban : lakban
# batalkan : batal
# udamah : udamah
# ujung : ujung
# produknya : produk
# cacat : cacat
# lobangnya : lobangnya
# darimana : darimana
# coba : coba
# mencoba : coba
# tusuk : tusuk
# jarum : jarum
# tebal : tebal
# nembus : nembus
# kepencet : pencet
# bocor : bocor
# sebel : sebel
# kebuang : buang
# sia : sia
# yaudah : yaudah
# deh : deh
# digunting : gunting
# telanjur : telanjur
# belakangnya : belakang
# tekstur : tekstur
# habis : habis
# dipakai : pakai
# ngelembabin : ngelembabin
# bikin : bikin
# keset : keset
# murah : murah
# expired : expired
# jul : jul
# minggu : minggu
# update : update
# delivery : delivery
# ok : ok
# pengemasan : emas
# bgtttttttttt : bgtttttttttt
# pesanan : pesan
# chat : chat
# direspon : direspon
# jml : jml
# item : item
# pearl : pearl
# horizon : horizon
# goats : goats
# milk : milk
# duanya : dua
# kali : kali
# perbaiki : baik
# min : min
# teliti : teliti
# kalo : kalo
# kayak : kayak
# ngerugiin : ngerugiin
# pembeli : beli
# thanks : thanks
# beli : beli
# kerdus : kerdus
# kebuka : buka
# robek : robek
# selernya : selernya
# mengirimkan : kirim
# asli : asli
# melebihi : lebih
# dirumah : rumah
# penjual : jual
# tanggepin : tanggepin
# rapi : rapi
# tau : tau
# isinya : isi
# segini : gin
# buka : buka
# full : full
# the : the
# memakai : pakai
# my : my
# on : on
# point : point
# dichat : dichat
# berrrrkali : berrrrkali
# tolong : tolong
# kapoooooook : kapoooooook
# menyesaaaaaal : menyesaaaaaal
# mengecewakan : kecewa
# prosesnya : proses
# kota : kota
# kurir : kurir
# cek : cek
# resi : resi
# ekpedisi : ekpedisi
# memproses : proses
# ditempat : tempat
# menjual : jual
# berguna : guna
# ganti : ganti
# memesan : mes
# tmpat : tmpat
# ngefek : ngefek
# pakai : pakai
# air : air
# putih : putih
# saran : saran
# kedepan : depan
# dikasih : kasih
# bubble : bubble
# sekelas : kelas
# official : official
# store : store
# loh : loh
# suka : suka
# empati : empati
# ditatar : tatar
# ulang : ulang
# attitudenya : attitudenya
# rekomended : rekomended
# brand : brand
# repurchase : repurchase
# dipacking : dipacking
# buble : buble
# asalan : asal
# daun : daun
# servicenya : servicenya
# white : white
# sadar : sadar
# des : des
# tg : tg
# ditagih : tagih
# dikomplain : komplain
# sellernya : sellernya
# dihubungi : hubung
# recommended : recommended
# rachel : rachel
# goddard : goddard
# penyak : nyak
# scrub : scrub
# tersegel : segel
# lightening : lightening
# sreg : sreg
# pakeknya : pakeknya
# dikirimnya : kirim
# seller : seller
# dibatalkan : batal
# tokped : tokped
# huaaa : huaaa
# foam : foam
# berantakan : beranta
# wrap : wrap
# setidak : tidak
# tutup : tutup
# wash : wash
# diisolasi : isolasi
# tumbuh : tumbuh
# jerawat : jerawat
# muka : muka
# gue : gue
# beruntusan : beruntus
# tersedia : sedia
# disuruh : suruh
# menunggu : tunggu
# dibatalin : dibatalin
# sunscreen : sunscreen
# mist : mist
# gel : gel
# ajuin : ajuin
# complain : complain
# riwayat : riwayat
# hilang : hilang
# kemana : mana
# kabupaten : kabupaten
# lambat : lambat
# answer : answer
# slow : slow
# lihat : lihat
# malas : malas
# jelek : jelek
# menjelekkan : jelek
# nih : nih
# sosmed : sosmed
# review : review
# jujur : jujur
# bantuan : bantu
# toped : toped
# lapak : lapak
# seadanya : ada
# video : video
# terbilang : bilang
# an : an
# penutup : tutup
# plastiknya : plastik
# dus : dus
# botol : botol
# terbuat : buat
# puas : puas
# gambar : gambar
# buluk : buluk
# jlk : jlk
# limited : limited
# editionnya : editionnya
# hanha : hanha
# cream : cream
# siang : siang
# siangnya : siang
# cocok : cocok
# gatal : gatal
# ku : ku
# perih : perih
# sayang : sayang
# tersisa : sisa
# creamnya : creamnya
# ekspektasi : ekspektasi
# kulit : kulit
# diaku : dia
# utuh : utuh
# blackhead : blackhead
# remover : remover
# mask : mask
# tinggal : tinggal
# kertas : kertas
# dikit : dikit
# ngaretnya : ngaretnya
# sore : sore
# pecah : pecah
# sayangnya : sayang
# upload : upload
# unboxingnya : unboxingnya
# kaya : kaya
# dpkai : dpkai
# kamis : kamis
# pagi : pagi
# status : status
# jumat : jumat
# memutuskan : putus
# mengajukan : aju
# ajukan : aju
# dibantu : bantu
# pembatalan : batal
# ajuan : aju
# menerima : terima
# sabtu : sabtu
# tolak : tolak
# pencet : pencet
# accept : accept
# berulang : ulang
# ditolak : tolak
# berdalih : dalih
# rincian : rincian
# bilang : bilang
# ucapan : ucap
# menolak : tolak
# sufah : sufah
# alasan : alas
# history : history
# rinciannya : rinciannya
# verifikasi : verifikasi
# pembayaran : bayar
# kalimat : kalimat
# ditahan : tahan
# emosi : emosi
# joasa : joasa
# spf : spf
# vit : vit
# terpisah : pisah
# pembelian : beli
# balikin : balikin
# rugi : rugi
# biaya : biaya
# kirimnya : kirim
# terlama : lama
# pemakai : pakai
# suncreen : suncreen
# hyrosoothe : hyrosoothe
# dikulit : kulit
# panas : panas
# semprotannya : semprot
# isi : isi
# essence : essence
# komplainnya : komplain
# dicabut : cabut
# cabut : cabut
# percaya : percaya
# buruk : buruk
# sistem : sistem
# permintaan : minta
# benahi : benah
# sgera : sgera
# bintangnya : bintang
# hair : hair
# lotion : lotion
# sda : sda
# surabaya : surabaya
# bilangnya : bilang
# mesen : mesen
# desember : desember
# kemarin : kemarin
# dimohon : mohon
# kendala : kendala
# nigh : nigh
# deuh : deuh
# no : no
# found : found
# lengketin : lengketin
# tangan : tangan
# sedih : sedih
# uang : uang
# dibalikin : dibalikin
# usaha : usaha
# uangnya : uang
# muncul : muncul
# harga : harga
# ribu : ribu
# ml : ml
# nomor : nomor
# aman : aman
# gedek : gedek
# ekspedisinya : ekspedisi
# main : main
# lempar : lempar
# masuk : masuk
# pagar : pagar
# manggil : manggil
# nelpon : nelpon
# kemasannya : kemas
# fragile : fragile
# complaint : complaint
# ditanggapi : tanggap
# ekpedisinya : ekpedisinya
# diregur : diregur
# plus : plus
# dibalut : balut
# biar : biar
# dalamnya : dalam
# rentan : rentan
# lemot : lot
# datangnya : datang
# malam : malam
# meradang : radang
# diki : dik
# dih : dih
# pesannya : pesan
# night : night
# butuh : butuh
# dtng : dtng
# takut : takut
# aneh : aneh
# dipencet : pencet
# day : day
# mah : mah
# diteken : teken
# komplen : komplen
# jawabannya : jawab
# memuaskan : muas
# lupa : lupa
# unboxing : unboxing
# inbox : inbox
# laris : laris
# mentang : mentang
# bubblewrap : bubblewrap
# kalah : kalah
# amatiran : amatir
# polosan : polos
# sticker : sticker
# apapun : apa
# wajib : wajib
# tanggung : tanggung
# penjualnya : jual
# so : so
# far : far
# dibeli : beli
# lelet : lelet
# niat : niat
# purna : purna
# jualnya : jual
# mengaco : aco
# berbenah : benah
# rame : rame
# diikuti : ikut
# offstorenya : offstorenya
# shame : shame
# you : you
# langganan : langgan
# lubangnya : lubang
# pao : pao
# exp : exp
# date : date
# cashback : cashback
# input : input
# promo : promo
# tokonya : toko
# bagus : bagus
# mending : mending
# cari : cari
# distributor : distributor
# setah : setah
# hitam : hitam
# beda : beda
# sebelom : bom
# sehitam : hitam
# ikutan : ikut
# flash : flash
# sale : sale
# bohongin : bohongin
# konsumen : konsumen
# opsi : opsi
# dana : dana
# ready : ready
# dikirimkan : kirim
# pilih : pilih
# berebutan : rebut
# indonesia : indonesia
# keesokan : esok
# harinya : hari
# diselesaikan : selesai
# perak : perak
# mengasih : asih
# apricot : apricot
# palsu : palsu
# dipacknya : dipacknya
# ngasal : ngasal
# wrapnya : wrapnya
# super : super
# packagingnya : packagingnya
# dalemnya : dalem
# bolong : bolong
# sengaja : sengaja
# dibolongin : dibolongin
# azarin : azarin
# ss : ss
# kesegel : segel
# divideoin : divideoin
# series : series
# didalam : dalam
# beres : beres
# bruntusan : bruntusan
# geleuh : geleuh
# kerasa : rasa
# kotor : kotor
# ewh : ewh
# toner : toner
# soft : soft
# light : light
# sensitif : sensitif
# kering : kering
# area : area
# tubuh : tubuh
# gelap : gelap
# serumnya : serum
# aloe : aloe
# vera : vera
# ubah : ubah
# keterangan : terang
# libur : libur
# diprosesny : diprosesny
# kapok : kapok
# bingung : bingung
# ratingnya : ratingnya
# lgsng : lgsng
# dibalas : balas
# checkout : checkout
# ekspedisi : ekspedisi
# berhari : hari
# brightening : brightening
# hadiah : hadiah
# november : november
# wa : wa
# balas : balas
# dm : dm
# baca : baca
# wajah : wajah
# sunscreenya : sunscreenya
# termalas : malas
# profesional : profesional
# niacinamide : niacinamide
# barengan : bareng
# retinolnya : retinolnya
# gatot : gatot
# klaim : klaim
# fine : fine
# but : but
# actually : actually
# owe : owe
# me : me
# smt : smt
# entar : entar
# disono : sono
# kutagih : tagih
# next : next
# time : time
# packaging : packaging
# warnanya : warna
# meminimalisir : meminimalisir
# kesalahan : salah
# fatal : fatal
# hadoo : hadoo
# yodah : yodah
# segitu : segitu
# bye : bye
# love : love
# much : much
# guys : guys
# hati : hati
# huhh : huhh
# berat : berat
# ruang : ruang
# twin : twin
# pack : pack
# harusanya : harusanya
# setelahnya : telah
# berhati : hati
# memperhatikan : perhati
# kesel : kesel
# bungkusnya : bungkus
# alhasil : alhasil
# kehilangan : hilang
# kepercayaan : percaya
# fotonya : foto
# dilampirkan : lampir
# gangguan : ganggu
# serah : serah
# data : data
# gudang : gudang
# harian : hari
# berminyak : minyak
# merah : merah
# berbuih : buih
# perubahan : ubah
# lapisan : lapis
# bibir : bibir
# menebal : tebal
# bagusnya : bagus
# kaget : kaget
# paketan : paket
# dibubble : dibubble
# dibaca : baca
# diduga : duga
# keteken : teken
# ngirimnya : ngirimnya
# cleanser : cleanser
# tumpah : tumpah
# basah : basah
# pekiannya : kian
# box : box
# menyesal : sesal
# officially : officially
# jualan : jual
# kotak : kotak
# suhu : suhu
# tertera : tera
# terlanjur : lanjur
# klik : klik
# selesai : selesai
# memasuki : pasuk
# dusnya : dus
# brgnya : brgnya
# komen : komen
# luama : luama
# mepet : mepet
# batas : batas
# berubah : ubah
# ditambah : tambah
# total : total
# minim : minim
# tanggapan : tanggap
# disetujui : tuju
# berharap : harap
# sisi : sisi
# improvement : improvement
# kedepannya : depan
# orisinal : orisinal
# check : check
# out : out
# senin : senin
# durasi : durasi
# kasihan : kasihan
# dikiriim : dikiriim
# lumayan : lumayan
# kacau : kacau
# diaplikasikan : aplikasi
# sompel : sompel
# kena : kena
# paham : paham
# kutek : kutek
# peel : peel
# off : off
# lepasnya : lepas
# segampang : gampang
# sok : sok
# menjadikan : jadi
# lee : lee
# ho : ho
# ambasador : ambasador
# becus : becus
# mengiriman : kirim
# tergolong : golong
# fotocopyan : fotocopyan
# kinerja : kerja
# layak : layak
# era : era
# online : online
# perusahaannya : usaha
# maju : maju
# kritik : kritik
# membangun : bangun
# lokal : lokal
# bogor : bogor
# info : info
# buru : buru
# diambil : ambil
# pemayaran : payar
# cod : cod
# dkirim : dkirim
# kembalikan : kembali
# bayar : bayar
# stok : stok
# suruh : suruh
# list : list
# gamungkin : gamungkin
# nilep : nilep
# diitung : diitung
# bundling : bundling
# dikembalikan : kembali
# jarang : jarang
# kualitasnya : kualitas
# dicoba : coba
# dipesan : pes
# merespon : merespon
# pusat : pusat
# resolusi : resolusi
# baramg : baramg
# stlah : stlah
# pulanh : pulanh
# crk : crk
# sdngkan : sdngkan
# pemesanan : mesan
# tanggep : tanggep
# didiemin : didiemin
# untung : untung
# duit : duit
# os : os
# pengalaman : alam
# enek : enek
# ordernya : order
# dicek : cek
# diorder : order
# kunjung : kunjung
# teramat : amat
# membeli : beli
# azarinenya : azarinenya
# botolnya : botol
# packagingya : packagingya
# dibawah : bawah
# dagu : dagu
# viral : viral
# spkk : spkk
# kecewaaaa : kecewaaaa
# shopping : shopping
# resmi : resmi
# tipu : tipu
# free : free
# giftnya : giftnya
# penipuan : tipu
# ikhlas : ikhlas
# gift : gift
# dasar : dasar
# penipu : tipu
# spray : spray
# responsif : responsif
# diaccept : diaccept
# notes : notes
# stand : stand
# by : by
# hubungin : hubungin
# via : via
# dibales : dibales
# claim : claim
# susah : susah
# aplikasi : aplikasi
# sebelah : belah
# perpanjang : panjang
# garansi : garansi
# dibuka : buka
# walopun : walopun
# janji : janji
# stock : stock
# mengharap : harap
# berkali : kali
# custumer : custumer
# nyampek : nyampek
# menyambung : sambung
# kalinya : kali
# dibawa : bawa
# reseller : reseller
# jakarta : jakarta
# pertimbangkan : timbang
# kondisi : kondisi
# prpduk : prpduk
# direspond : direspond
# ikhlasin : ikhlasin
# berkah : berkah
# nomer : nomer
# kah : kah
# secarik : carik
# refund : refund
# vouchsr : vouchsr
# pengaturan : atur
# mata : mata
# praktek : praktek
# semprotan : semprot
# hadehh : hadehh
# okee : okee
# hydrasooth : hydrasooth
# hydramax : hydramax
# duh : duh
# luamaaa : luamaaa
# bukanny : bukanny
# lngsng : lngsng
# drefund : drefund
# dksh : dksh
# tulisanny : tulisanny
# sdngkn : sdngkn
# diluar : luar
# dtulis : dtulis
# blgny : blgny
# kekurangannya : kurang
# djawab : djawab
# brgny : brgny
# manual : manual
# ngevideoin : ngevideoin
# segelnya : segel
# kayanya : kaya
# sisa : sisa
# azzarinenya : azzarinenya
# kapokk : kapokk
# payah : payah
# items : items
# eye : eye
# terkirim : kirim
# alumunium : alumunium
# foil : foil
# baunya : bau
# pcs : pcs
# skincare : skincare
# komplainan : komplain
# solusi : solusi
# coustemer : coustemer
# ragu : ragu
# keaslian : asli
# produkx : produkx
# hologramx : hologramx
# wanginya : wangi
# alamat : alamat
# namn : namn
# menyetujui : tuju
# jne : jne
# bantu : bantu
# antarkan : antar
# retinol : retinol
# eyeshadow : eyeshadow
# brownzer : brownzer
# apps : apps
# hiks : hiks
# packingnya : packingnya
# pelit : pelit
# kotaknya : kotak
# lem : lem
# sampingnya : samping
# worst : worst
# ever : ever
# respond : respond
# recommend : recommend
# sorry : sorry
# kirm : kirm
# hand : hand
# sanitizer : sanitizer
# bahan : bahan
# pngiriman : pngiriman
# kecewaa : kecewaa
# servis : servis
# mubazir : mubazir
# padhaay : padhaay
# pastikan : pasti
# memvideo : video
# bertanggung : tanggung
# this : this
# is : is
# gon : gon
# na : na
# be : be
# last : last
# okay : okay
# better : better
# move : move
# others : others
# kusam : kusam
# dikeroyok : keroyok
# telat : telat
# stocknya : stocknya
# kejelasan : jelas
# eh : eh
# suratnya : surat
# direfund : direfund
# februari : februari
# dicancel : dicancel
# diselidiki : selidik
# pegawainya : pegawai
# vitamin : vitamin
# twinpack : twinpack
# penanganan : tangan
# kurangnya : kurang
# serasa : serasa
# robot : robot
# ditunggu : tunggu
# pindah : pindah
# wkkw : wkkw
# tenggat : tenggat
# dibeginikan : begini
# user : user
# ribetin : ribetin
# twins : twins
# nyata : nyata
# amanah : amanah
# ekspidisi : ekspidisi
# melembabkan : melembabkan
# sblumnya : sblumnya
# segininya : gin
# liptint : liptint
# perihsorry : perihsorry
# ciki : cik
# puki : puki
# kurirnya : kurir
# peak : peak
# wow : wow
# sehelai : hela
# bubblewarp : bubblewarp
# kodam : kodam
# ngelindungin : ngelindungin
# keren : keren
# terbaik : baik
# bonusnya : bonus
# persediaannya : sedia
# seandainya : anda
# berkenan : kenan
# gratisan : gratis
# deskripsi : deskripsi
# dituliskan : tulis
# persediaan : sedia
# anti : anti
# aging : aging
# perusahaan : usaha
# kehabisan : habis
# control : control
# produksi : produksi
# bekas : bekas
# sedikitttt : sedikitttt
# pemakaian : pakai
# cairan : cair
# pipet : pipet
# gila : gila
# zonk : zonk
# rekomen : rekomen
# mengepack : mengepack
# mengirim : kirim
# jasa : jasa
# keterlambatan : lambat
# pengirim : kirim
# memasukkan : masuk
# terlambat : lambat
# setengahnya : tengah
# ngehabisin : ngehabisin
# dsb : dsb
# hydrashoote : hydrashoote
# huft : huft
# hydrama : hydrama
# hydrosoothe : hydrosoothe
# return : return
# resend : resend
# diresend : diresend
# sicepat : sicepat
# berasa : asa
# second : second
# set : set
# feedback : feedback
# herawatan : herawatan
# tube : tube
# ditutup : tutup
# ala : ala
# kadarnya : kadar
# sesalkan : sesal
# posisi : posisi
# sehat : sehat
# hasilnya : hasil
# kepes : pes
# mati : mati
# numpuk : numpuk
# chatnya : chatnya
# buangetttt : buangetttt
# stor : stor
# jail : jail
# warna : warna
# ofc : ofc
# ngeri : ngeri
# dibungkus : bungkus
# samasekali : samasekali
# pengimanan : iman
# sidoarjo : sidoarjo
# halaman : halaman
# beroperasi : operasi
# operasionalnya : operasional
# membutuhkan : butuh
# kerja : kerja
# informasi : informasi
# minimal : minimal
# disemprotkan : semprot
# merata : rata
# cancel : cancel
# laporin : laporin
# bla : bla
# garcep : garcep
# sop : sop
# mesan : mesan
# ditingkatkan : tingkat
# segi : segi
# re : re
# eorder : eorder
# tipe : tipe
# prone : prone
# sharing : sharing
# tertarik : tarik
# kurangi : kurang
# arah : arah
# stop : stop
# membaik : baik
# csnya : csnya
# telopon : telopon
# abisin : abisin
# pulsa : pulsa
# ampir : ampir
# rbu : rbu
# saolnya : saolnya
# baranf : baranf
# lipcream : lipcream
# tone : tone
# kardusnya : kardus
# kesalahannya : salah
# mudah : mudah
# acakan : acak
# bersihkan : sih
# dihubunginya : hubung
# mesennya : mesennya
# whitening : whitening
# ampun : ampun
# payaahhh : payaahhh
# samapi : samapi
# menampak : tampak
# selesaikan : selesai
# bilangx : bilangx
# debuan : debu
# paraaaah : paraaaah
# dalem : dalem
# ceritanya : cerita
# kesan : kesan
# berkinyak : berkinyak
# gossy : gossy
# nemu : nemu
# menghilangkan : hilang
# flex : flex
# tim : tim
# maksimal : maksimal
# kedatangan : datang
# agustus : agustus
# dibuatkan : buat
# laporan : lapor
# belah : belah
# bad : bad
# maksa : maksa
# tulis : tulis
# penerima : terima
# resepsionis : resepsionis
# gedung : gedung
# tujuan : tuju
# alias : alias
# anggep : anggep
# datengnya : datengnya
# overall : overall
# gaes : gaes
# numplek : numplek
# benaran : benar
# lecek : lecek
# biyuuh : biyuuh
# tutupnya : tutup
# miring : miring
# menara : menara
# italy : italy
# kayaknya : kayak
# mesin : mesin
# pabriknya : pabrik
# hai : hai
# dibarengin : dibarengin
# gentle : gentle
# washnya : washnya
# salahnya : salah
# foto : foto
# bongkar : bongkar
# dirugikan : rugi
# ramah : ramah
# sgala : sgala
# lamban : lamban
# reorder : reorder
# oren : oren
# alternatif : alternatif
# konsisten : konsisten
# diinfo : info
# terkendala : kendala
# hold : hold
# makan : makan
# komunikasi : komunikasi
# message : message
# diskon : diskon
# rupiah : rupiah
# menganggap : anggap
# pembelinya : bel
# alangkah : alangkah
# baiknya : baik
# dijual : jual
# hasil : hasil
# lengket : lengket
# not : not
# seukuran : ukur
# dupee : dupee
# eatimasi : eatimasi
# warp : warp
# mention : mention
# twitter : twitter
# nggaada : nggaada
# perbaikan : baik
# ditengah : tengah
# jalan : jalan
# selamat : selamat
# tukar : tukar
# duper : duper
# perkiraan : kira
# layanannya : layan
# lho : lho
# masak : masak
# lokasi : lokasi
# galengkap : galengkap
# videoin : videoin
# mikir : mikir
# yaudahlah : yaudahlah
# batu : batu
# notabene : notabene
# skin : skin
# care : care
# jerat : jerat
# keci : keci
# kedokter : dokter
# teman : teman
# diterusin : diterusin
# alami : alami
# capek : capek
# pokoknya : pokok
# serahkan : serah
# memberika : memberika
# penjelasan : jelas
# sungguh : sungguh
# pitching : pitching
# quality : quality
# berbeda : beda
# iyalah : iya
# gampang : gampang
# setujui : tuju
# indomaret : indomaret
# ditentukan : tentu
# dibayar : bayar
# lakukan : laku
# secepatnya : cepat
# membatalkan : batal
# ketawa : ketawa
# sekalinya : sekali
# alesan : alesan
# blabla : blabla
# ditoko : toko
# terang : terang
# urus : urus
# sulit : sulit
# hairspa : hairspa
# invoicenya : invoicenya
# pemrosesan : pemrosesan
# negeri : negeri
# tapinya : tapi
# wkwkkwkwkwk : wkwkkwkwkwk
# kocak : kocak
# tracking : tracking
# repeat : repeat
# unboaxing : unboaxing
# cctv : cctv
# korban : korban
# sumpah : sumpah
# late : late
# pusing : pusing
# mengurus : urus
# retur : retur
# dll : dll
# mempekerjakan : kerja
# picek : picek
# matanya : mata
# pengerjaannya : kerja
# twinoack : twinoack
# solusinya : solusi
# nungguny : nungguny
# notif : notif
# tny : tny
# sejuta : juta
# umat : umat
# pengemasannya : emas
# dibenahi : benah
# masalh : masalh
# produkny : produkny
# bertele : tele
# tele : tele
# pelindung : lindung
# lpg : lpg
# nunggunya : nunggunya
# ganiat : ganiat
# olshop : olshop
# lamaaaaaaaaaaaaa : lamaaaaaaaaaaaaa
# banggeetttttttttttt : banggeetttttttttttt
# tertulis : tulis
# direspons : respons
# taunya : tau
# pickup : pickup
# dipickup : dipickup
# september : september
# statusnya : status
# saller : saller
# {'pengiriman': 'kirim', 'order': 'order', 'dikirim': 'kirim', 'barang': 'barang', 'nya': 'nya', 'salah': 'salah', 'kirim': 'kirim', 'paket': 'paket', 'acne': 'acne', 'lengkap': 'lengkap', 'facial': 'facial', 'foamnya': 'foamnya', 'packing': 'packing', 'rusak': 'rusak', 'terbuka': 'buka', 'terima': 'terima', 'diterima': 'terima', 'orang': 'orang', 'rumah': 'rumah', 'serum': 'serum', 'penyok': 'penyok', 'jual': 'jual', 'kagak': 'kagak', 'amanh': 'amanh', 'banget': 'banget', 'bakl': 'bakl', 'belanja': 'belanja', 'tanggal': 'tanggal', 'transaksi': 'transaksi', 'syarat': 'syarat', 'member': 'member', 'platinum': 'platinum', 'gagal': 'gagal', 'gara': 'gara', 'semoga': 'moga', 'kecewa': 'kecewa', 'buang': 'buang', 'tong': 'tong', 'sampah': 'sampah', 'product': 'product', 'pelindungnya': 'lindung', 'menandakan': 'tanda', 'segel': 'segel', 'plastik': 'plastik', 'maaf': 'maaf', 'kasih': 'kasih', 'bintang': 'bintang', 'diperhatikan': 'perhati', 'ya': 'ya', 'perihal': 'perihal', 'kemasan': 'kemas', 'dikonfirmasi': 'konfirmasi', 'pesan': 'pesan', 'mei': 'mei', 'konfirmasi': 'konfirmasi', 'produk': 'produk', 'sesuai': 'sesuai', 'urutan': 'urut', 'orderan': 'order', 'pengajuan': 'aju', 'pick': 'pick', 'up': 'up', 'juni': 'juni', 'jam': 'jam', 'batal': 'batal', 'otomatis': 'otomatis', 'berhasil': 'hasil', 'dijemput': 'jemput', 'estimasi': 'estimasi', 'mohon': 'mohon', 'toko': 'toko', 'cepat': 'cepat', 'proses': 'proses', 'meningkatkan': 'tingkat', 'kualitas': 'kualitas', 'pelayanan': 'layan', 'sih': 'sih', 'oke': 'oke', 'cuman': 'cuman', 'customer': 'customer', 'service': 'service', 'pengepakan': 'epak', 'kecuali': 'kecuali', 'azarine': 'azarine', 'doang': 'doang', 'admin': 'admin', 'balesnya': 'balesnya', 'menambah': 'tambah', 'karyawan': 'karyawan', 'print': 'print', 'tulisan': 'tulis', 'body': 'body', 'rendah': 'rendah', 'diperbaiki': 'baik', 'murahan': 'murah', 'sabar': 'sabar', 'mbak': 'mbak', 'mas': 'mas', 'bu': 'bu', 'any': 'any', 'gender': 'gender', 'pronouns': 'pronouns', 'ditunjang': 'tunjang', 'pengirimannya': 'kirim', 'sehari': 'hari', 'penuh': 'penuh', 'diproses': 'proses', 'sampainya': 'sampai', 'seminggu': 'minggu', 'pas': 'pas', 'sun': 'sun', 'shield': 'shield', 'paketnya': 'paket', 'barangnya': 'barang', 'kosong': 'kosong', 'langsung': 'langsung', 'tuh': 'tuh', 'pesenannya': 'sen', 'ribet': 'ribet', 'komplain': 'komplain', 'tokopedia': 'tokopedia', 'pengembalian': 'kembali', 'dananya': 'dana', 'bundle': 'bundle', 'parah': 'parah', 'pelayanannya': 'layan', 'respon': 'respon', 'adminnya': 'adminnya', 'kardus': 'kardus', 'lakban': 'lakban', 'batalkan': 'batal', 'udamah': 'udamah', 'ujung': 'ujung', 'produknya': 'produk', 'cacat': 'cacat', 'lobangnya': 'lobangnya', 'darimana': 'darimana', 'coba': 'coba', 'mencoba': 'coba', 'tusuk': 'tusuk', 'jarum': 'jarum', 'tebal': 'tebal', 'nembus': 'nembus', 'kepencet': 'pencet', 'bocor': 'bocor', 'sebel': 'sebel', 'kebuang': 'buang', 'sia': 'sia', 'yaudah': 'yaudah', 'deh': 'deh', 'digunting': 'gunting', 'telanjur': 'telanjur', 'belakangnya': 'belakang', 'tekstur': 'tekstur', 'habis': 'habis', 'dipakai': 'pakai', 'ngelembabin': 'ngelembabin', 'bikin': 'bikin', 'keset': 'keset', 'murah': 'murah', 'expired': 'expired', 'jul': 'jul', 'minggu': 'minggu', 'update': 'update', 'delivery': 'delivery', 'ok': 'ok', 'pengemasan': 'emas', 'bgtttttttttt': 'bgtttttttttt', 'pesanan': 'pesan', 'chat': 'chat', 'direspon': 'direspon', 'jml': 'jml', 'item': 'item', 'pearl': 'pearl', 'horizon': 'horizon', 'goats': 'goats', 'milk': 'milk', 'duanya': 'dua', 'kali': 'kali', 'perbaiki': 'baik', 'min': 'min', 'teliti': 'teliti', 'kalo': 'kalo', 'kayak': 'kayak', 'ngerugiin': 'ngerugiin', 'pembeli': 'beli', 'thanks': 'thanks', 'beli': 'beli', 'kerdus': 'kerdus', 'kebuka': 'buka', 'robek': 'robek', 'selernya': 'selernya', 'mengirimkan': 'kirim', 'asli': 'asli', 'melebihi': 'lebih', 'dirumah': 'rumah', 'penjual': 'jual', 'tanggepin': 'tanggepin', 'rapi': 'rapi', 'tau': 'tau', 'isinya': 'isi', 'segini': 'gin', 'buka': ' ...
# ------------------------
# Pandas Apply: 100%|██████████| 347/347 [00:00<00:00, 115675.05it/s]
# 0                     [kirim, order, kirim, barang, nya]
# 1                                 [salah, kirim, barang]
# 2           [paket, acne, nya, lengkap, facial, foamnya]
# 3      [packing, packing, rusak, buka, terima, terima...
# 4                   [barang, kagak, amanh, banget, bakl]
#                              ...
# 343    [barang, terima, order, produk, item, kirim, s...
# 344    [order, tanggal, mei, pas, libur, kirim, tau, ...
# 345    [segel, barang, pas, buka, kayak, habis, pakai...
# 346                            [order, dipickup, barang]
# 347    [barang, terima, tanggal, september, status, t...
# Name: review_tokens_stemmed, Length: 347, dtype: object
#                                               Review  \
# 0  pengiriman sangat lama hari setelah order baru...
# 1                                 salah kirim barang
# 2  paket acne nya tidak lengkap facial foamnya ti...
# 3  packing tidak baik packing luar rusak sdh terb...
# 4  barang tak pernah sampai kaga amanh lama bange...
#
#                                          Review_norm  \
# 0  pengiriman sangat lama hari setelah order baru...
# 1                                 salah kirim barang
# 2  paket acne nya tidak lengkap facial foamnya ti...
# 3  packing tidak baik packing luar rusak sudah te...
# 4  barang tak pernah sampai kagak amanh lama bang...
#
#                                        review_tokens  \
# 0  [pengiriman, sangat, lama, hari, setelah, orde...
# 1                             [salah, kirim, barang]
# 2  [paket, acne, nya, tidak, lengkap, facial, foa...
# 3  [packing, tidak, baik, packing, luar, rusak, s...
# 4  [barang, tak, pernah, sampai, kagak, amanh, la...
#
#                                     review_tokens_SR  \
# 0          [pengiriman, order, dikirim, barang, nya]
# 1                             [salah, kirim, barang]
# 2       [paket, acne, nya, lengkap, facial, foamnya]
# 3  [packing, packing, rusak, terbuka, terima, dit...
# 4               [barang, kagak, amanh, banget, bakl]
#
#                                review_tokens_stemmed
# 0                 [kirim, order, kirim, barang, nya]
# 1                             [salah, kirim, barang]
# 2       [paket, acne, nya, lengkap, facial, foamnya]
# 3  [packing, packing, rusak, buka, terima, terima...
# 4               [barang, kagak, amanh, banget, bakl]

# %%
# import hasil preprocessing menjadi csv
df.to_csv("lemma_azarine.csv")
